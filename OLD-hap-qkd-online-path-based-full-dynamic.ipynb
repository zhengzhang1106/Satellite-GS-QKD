# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)
#gnodes, hnodes, links, demands = init_setup_training_online()

nodes = gnodes + hnodes

n_hnodes  = len(hnodes)
n_demands = len(demands)

n_links   = len(links)

MAX_LINKS   = len(links)
MAX_HAPS    = len(hnodes)
MAX_DEMANDS = len(demands)   # maximum possible demands
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
def generate_dynamic_masks(hnodes, demands, links, t, hap_drop_prob=0.3, demand_drop_prob=0.3):
    n_haps = len(hnodes)
    n_demands = len(demands)
    n_links = len(links)

    # Randomly deactivate HAPs
    hap_active = np.ones(n_haps)
    for i in range(n_haps):
        if random.random() < hap_drop_prob:
            hap_active[i] = 0

    # Randomly deactivate demands
    demand_active = np.ones(n_demands)
    for i in range(n_demands):
        if random.random() < demand_drop_prob:
            demand_active[i] = 0

    # Links inactive if connected to inactive HAP
    link_active = np.ones(n_links)
    for i, l in enumerate(links):
        if isinstance(l.n1, hap):
            if hap_active[hnodes.index(l.n1)] == 0:
                link_active[i] = 0
        if isinstance(l.n2, hap):
            if hap_active[hnodes.index(l.n2)] == 0:
                link_active[i] = 0

    return hap_active, demand_active, link_active

# %%
def build_action_mask(
        hap_active,
        demand_active,
        MAX_HAPS,
        MAX_DEMANDS):

    n_choices = MAX_DEMANDS + 1

    mask = torch.ones(2, MAX_HAPS, n_choices)

    for h in range(MAX_HAPS):

        if hap_active[h] == 0:
            mask[:, h, :] = 0
            mask[:, h, 0] = 1  # idle allowed
            continue

        for d in range(MAX_DEMANDS):
            if d >= len(demand_active) or demand_active[d] == 0:
                mask[:, h, d+1] = 0

    return mask

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.2
LR = 1e-4
EPOCHS = 10
BATCH_SIZE = 64
ENTROPY_COEF_INITIAL = 0.01         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.999 #0.995               # >>> CHANGE
VALUE_COEF = 0.5

# Training hyperparams
num_episodes = 4000
episode_len = len(syst.T)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# %%
def build_state_vector_for_time(
        state_t,
        links,
        t,
        gnodes,
        hnodes,
        hap_active,
        demand_active,
        link_active,
        MAX_LINKS,
        MAX_DEMANDS,
        MAX_HAPS):

    link_features = []

    # ----- LINKS (fixed MAX_LINKS) -----
    for idx in range(MAX_LINKS):

        if idx >= len(links) or link_active[idx] == 0:
            link_features.extend([0.0]*7)
            continue

        l = links[idx]

        qkp_val = np.log10(1 + state_t.get("a", {}).get(idx, 0.0)) / 8.0
        kmax_val = np.log10(1 + l.K_MAX[t]) / 6.0

        n1_lon = l.n1.lg[t] if isinstance(l.n1, hap) else l.n1.lg
        n1_lat = l.n1.la[t] if isinstance(l.n1, hap) else l.n1.la
        n2_lon = l.n2.lg[t] if isinstance(l.n2, hap) else l.n2.lg
        n2_lat = l.n2.la[t] if isinstance(l.n2, hap) else l.n2.la

        link_features.extend([qkp_val, kmax_val, n1_lon, n1_lat, n2_lon, n2_lat, link_active[idx]])

    # ----- DEMANDS (fixed MAX_DEMANDS) -----
    demand_features = []
    demands = state_t["demands"]

    for i in range(MAX_DEMANDS):

        if i >= len(demands) or demand_active[i] == 0:
            demand_features.extend([0.0]*3)
            continue

        d = demands[i]
        kreq = np.log10(1 + float(d.K_REQ[t])) / 5.0
        demand_features.extend([d.n1.lg, d.n2.lg, kreq])

    # ----- HAP ACTIVE (fixed MAX_HAPS) -----
    hap_vec = np.zeros(MAX_HAPS)
    hap_vec[:len(hap_active)] = hap_active

    # ----- LINK ACTIVE (fixed MAX_LINKS) -----
    link_vec = np.zeros(MAX_LINKS)
    link_vec[:len(link_active)] = link_active

    # ----- DEMAND ACTIVE (fixed MAX_DEMANDS) -----
    demand_vec = np.zeros(MAX_DEMANDS)
    demand_vec[:len(demand_active)] = demand_active

    state_vec = np.concatenate([
        link_features,
        demand_features,
        hap_vec,
        link_vec,
        demand_vec
    ]).astype(np.float32)

    return state_vec

# %%
def scarq_policy(state, links, t):
    """
    Adapted Heuristic: Scarcity & Contention Aware (1-hop only)
    Converts the offline logic into an online action selection for time t.
    """
    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    
    # 1. Initialize constraints and action
    #action = np.zeros(n_links, dtype=int)
    action_matrix = np.zeros((n_demands, len(links)), dtype=int)
    max_cnct_up = [1] * n_hnodes  # HAP TX limits (assuming 1 for this logic)
    max_cnct_dwn = [1] * n_hnodes # HAP RX limits
    
    # Current QKP bits from state (assumed stored as raw bits or decoded)
    # If state_t["a"] is log-normalized, decode it first!
    qkp_s = [state[t]["a"].get(i, 0.0) for i in range(n_links)]

    # ---------------------------------------------------------
    # Step 1: Enumerate feasible 1-hop paths per demand
    # ---------------------------------------------------------
    feasible_paths = {d: [] for d in demands}
    link_usage = [0] * n_links
    
    for d in demands:
        src, dst = d.n1, d.n2
        for idx_l1, l1 in enumerate(links):
            if l1.n1 != src: continue
            for idx_l2, l2 in enumerate(links):
                if l2.n2 != dst: continue
                
                # Check if they share a HAP (mid-point)
                if l1.n2 == l2.n1 and l1.n2 in hnodes:
                    mid = l1.n2
                    
                    fresh_ok = (l1.K_MAX[t] >= d.K_REQ[t] and 
                                l2.K_MAX[t] >= d.K_REQ[t])
                    
                    qkp_ok = (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                              qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t])
                    
                    if fresh_ok or qkp_ok:
                        feasible_paths[d].append((idx_l1, idx_l2, mid))
                        link_usage[idx_l1] += 1
                        link_usage[idx_l2] += 1

    # ---------------------------------------------------------
    # Step 2: Order demands by Scarcity
    # (Least paths first, then largest requirement)
    # ---------------------------------------------------------
    ordered_demands = sorted(
        demands,
        key=lambda d: (len(feasible_paths[d]), -d.K_REQ[t])
    )

    # ---------------------------------------------------------
    # Step 3: Greedy Allocation with Contention Awareness
    # ---------------------------------------------------------
    for d in ordered_demands:
        # Sort paths for this demand by least link contention
        paths = sorted(
            feasible_paths[d],
            key=lambda p: link_usage[p[0]] + link_usage[p[1]]
        )
        
        for idx_l1, idx_l2, mid in paths:
            mid_idx = hnodes.index(mid)
            
            # Respect HAP connection limits
            if max_cnct_up[mid_idx] == 0 or max_cnct_dwn[mid_idx] == 0:
                continue
                
            # Path selection logic
            # Priority: Can we serve it with ONLY stored bits? (No action needed)
            if (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
                
                # Update local tracker (bits effectively consumed)
                qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                
                # Consume HAP capacity even if using QKP? 
                # (Your offline logic suggests yes to prevent multi-use)
                #max_cnct_up[mid_idx] = 0
                #max_cnct_dwn[mid_idx] = 0
                break
            
            # If we need fresh keys, we activate the links (set action to 1)
            else:
                # action[idx_l1] = 1
                # action[idx_l2] = 1
                action_matrix[demands.index(d)][idx_l1] = 1
                action_matrix[demands.index(d)][idx_l2] = 1
                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0
                # Note: We don't update qkp_s here because fresh generation 
                # happens in the environment 'step', not the heuristic.
                break


    # --------------------------------------------------
    # Step 4: Solve optimization with heuristic action
    # --------------------------------------------------
    solution_heur, _, A_next_heur = online_new(
        gnodes,
        hnodes,
        links,
        state,
        action_matrix,
        t,
        f_qkp,
        0
    )

    # --------------------------------------------------
    # Step 5: Compute total served keys
    # --------------------------------------------------
    if "r_h" not in solution_heur:
        return 0.0, solution_heur, A_next_heur

    k_srv_heur = sum(
        solution_heur["r_h"][idx_d] * syst.THETA
        for idx_d, _ in enumerate(demands)
    )


    return k_srv_heur, solution_heur, A_next_heur

def mcr_policy(state, links, t, n_samples=3):
    """
    Online Monte Carlo 1-hop random heuristic.
    Samples multiple random feasible allocations and keeps the best one.
    """

    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    n_demands = len(demands)

    best_reward = -1
    best_solution = None
    best_A_next = None

    # ------------------------------------------------------------
    # Monte Carlo sampling
    # ------------------------------------------------------------
    for _ in range(n_samples):

        # action_matrix[d, l]
        action_matrix = np.zeros((n_demands, n_links), dtype=int)

        max_cnct_up  = [1] * n_hnodes
        max_cnct_dwn = [1] * n_hnodes

        shuffled_demands = random.sample(demands, len(demands))

        # --------------------------------------------------------
        # Random feasible allocation (1-hop only)
        # --------------------------------------------------------
        for d in shuffled_demands:

            src, dst = d.n1, d.n2
            feasible_pairs = []

            for idx_l1, l1 in enumerate(links):
                if l1.n1 != src:
                    continue

                for idx_l2, l2 in enumerate(links):
                    if l2.n2 != dst:
                        continue

                    if l1.n2 == l2.n1 and l1.n2 in hnodes:
                        mid = l1.n2
                        mid_idx = hnodes.index(mid)

                        if (
                            max_cnct_up[mid_idx] > 0 and
                            max_cnct_dwn[mid_idx] > 0 and
                            l1.K_MAX[t] > 0 and
                            l2.K_MAX[t] > 0
                        ):
                            feasible_pairs.append((idx_l1, idx_l2, mid_idx))

            if feasible_pairs:
                idx_l1, idx_l2, mid_idx = random.choice(feasible_pairs)

                action_matrix[demands.index(d)][idx_l1] = 1
                action_matrix[demands.index(d)][idx_l2] = 1

                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0

        # --------------------------------------------------------
        # Evaluate via online_new
        # --------------------------------------------------------
        solution, reward, A_next = online_new(
            gnodes,
            hnodes,
            links,
            state,
            action_matrix,
            t,
            f_qkp,
            0
        )

        if "r_h" in solution:
            total_served = sum(solution["r_h"][i] * syst.THETA for i in range(n_demands))
        else:
            total_served = 0.0

        # Keep best sample
        if total_served > best_reward:
            best_reward = total_served
            best_solution = solution
            best_A_next = A_next

    return best_reward, best_solution, best_A_next

# %%
class ResidualBlock(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.ln = nn.LayerNorm(size)
        self.fc = nn.Linear(size, size)

    def forward(self, x):
        # Residual connection helps gradients flow back to early layers
        return x + F.silu(self.fc(self.ln(x)))

class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Linear(dim, dim)
        )
        self.silu = nn.SiLU()

    def forward(self, x):
        return self.silu(x + self.net(x))

class ActorCriticCategorical(nn.Module):
    def __init__(self, state_dim, n_demands_max, n_haps, hidden=64):
        super().__init__()
        self.n_haps = n_haps
        self.n_choices = n_demands_max + 1 # Demands + Idle
        
        self.encoder = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.SiLU(),
        )
        
        # (One set of choices for RX/Uplink, one for TX/Downlink)
        self.actor_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 2 * n_haps * self.n_choices) 
        )
        
        self.critic_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 1)
        )
        
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            # Orthogonal init helps prevents early policy collapse
            nn.init.orthogonal_(m.weight, gain=0.01) 
            nn.init.constant_(m.bias, 0)

    def forward(self, x, action_mask=None):
    
        features = self.encoder(x)
        logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
    
        if action_mask is not None:
            logits = logits.masked_fill(action_mask == 0, -1e9)
    
        probs = torch.softmax(logits, dim=-1)
        value = self.critic_head(features)
        return probs, value

class PPOBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        self.is_terminals = []
    
    def clear(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]
        del self.is_terminals[:]

class PPOAgent:
    def __init__(self, state_dim, n_demands, n_hnodes, lr=LR):
        self.gamma = GAMMA
        self.lam = GAE_LAMBDA
        self.eps_clip = CLIP
        self.K_epochs = EPOCHS
        self.n_haps = n_hnodes
        self.n_demands = n_demands
        
        self.model = ActorCriticCategorical(state_dim, n_demands, n_hnodes).to(device=DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        self.MseLoss = nn.MSELoss()

    def select_action(self, state_vec, action_mask):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        mask = action_mask.unsqueeze(0).to(DEVICE)
    
        with torch.no_grad():
            probs, value = self.model(s, mask)
    
        dist = Categorical(probs)
        action = dist.sample()
        logp = dist.log_prob(action).sum(dim=[1,2])
    
        return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0)

    def update(self, states, actions, masks, old_logps, returns, advantages, entropy_coef):
    
        if advantages.std() < 1e-5:
            advantages = advantages - advantages.mean()
        else:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
    
        states = states.to(DEVICE)
        actions = actions.to(DEVICE)
        masks = masks.to(DEVICE)
        old_logps = old_logps.to(DEVICE)
        returns = returns.to(DEVICE)
        advantages = advantages.to(DEVICE)
    
        for _ in range(self.K_epochs):
            probs, values = self.model(states, masks)
    
            dist = Categorical(probs)
    
            new_logps = dist.log_prob(actions).sum(dim=[1,2])
            entropy = dist.entropy().sum(dim=[1,2]).mean()
    
            ratio = torch.exp(new_logps - old_logps)
    
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
    
            loss = (
                -torch.min(surr1, surr2).mean()
                + 0.5 * self.MseLoss(values.view(-1), returns)
                - entropy_coef * entropy
            )
    
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

    def compute_gae(self, rewards, values, dones):
        """
        Generalized Advantage Estimation
        rewards: [T], values: [T+1], dones: [T]
        """
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            # TD Error: delta = r_t + gamma * V(s_t+1) - V(s_t)
            delta = rewards[t] + self.gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + self.gamma * self.lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
            
        returns = adv + values[:-1]
        return adv, returns

# %%
def get_z_from_demand_choices(hap_picks, demands, links, hnodes):
    # Initialize z_dict with zeros
    z = {idx_d: {idx_l: 0 for idx_l in range(len(links))} for idx_d in range(len(demands))}
    
    rx_picks = hap_picks[0] # Uplink choices [n_haps]
    tx_picks = hap_picks[1] # Downlink choices [n_haps]

    # Run this once after initializing your 'links' and 'hnodes'
    UPLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n2 in hnodes}
    DOWNLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n1 in hnodes}

    for hap_idx, selected_hap in enumerate(hnodes):
        
        # --- Handle Uplink (RX: GS -> HAP) ---
        rx_val = rx_picks[hap_idx]
        if rx_val > 0:
            d_idx = int(rx_val - 1)
            if d_idx < len(demands):
                src_gs = demands[d_idx].n1
                # Use the pre-computed lookup
                l_idx = UPLINK_LOOKUP.get((src_gs, selected_hap))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1

        # --- Handle Downlink (TX: HAP -> GS) ---
        tx_val = tx_picks[hap_idx]
        if tx_val > 0:
            d_idx = int(tx_val - 1)
            if d_idx < len(demands):
                dst_gs = demands[d_idx].n2
                # Use the pre-computed lookup
                l_idx = DOWNLINK_LOOKUP.get((selected_hap, dst_gs))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1
                        
    return z

# %% [markdown]
# ## Training Loop

# %%
# === Plot learning curve with running average ===
window = 200                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,3))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=3)
plt.xlabel("Episode", fontsize=15)
plt.ylabel("Total Reward", fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.savefig("learning.pdf", format="pdf", dpi=300, bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %%
NUM_DATA    = 100
N_RUNS      = 2   # number of Monte-Carlo runs

demand_list = [0.01 + 0.2 * i for i in range(NUM_DATA)]

# %% [markdown]
# ## Testing the Agent

# %%
def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=True):
    agent.model.eval() 
    test_rewards = []

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes (Dual-Head) ---")

    demand_list = [0.01 + 0.2 * i for i in range(num_test_episodes)]
    key_req     = [0 for i in range(num_test_episodes)]
    key_srv_qkp = [0 for i in range(num_test_episodes)]
    a_lst_qkp   = [0 for i in range(num_test_episodes)]
    
    for idx, mean in enumerate(demand_list):
        demands = generate_demands(gnodes, syst, mean_kbps=mean, amp=0.5, noise_std=0.0, pattern="stadium")
        key_req[idx] = sum(d.K_REQ[t] * syst.THETA for d in demands for t in syst.T)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands 
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} 

        ep_reward = 0
        
        for t in syst.T:
            r = random.randint(0, len(hnodes)-1)
            
            hnodes_active = [1 for h in hnodes]
            links_active  = [1 if ((isinstance(l.n1, hap) and hnodes_active[hnodes.index(l.n1)] == 1) or (isinstance(l.n2, hap) and hnodes_active[hnodes.index(l.n2)] == 1)) else 0 for l in links]
            
            s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)
            s_vec = build_state_vector_for_time(
                state[tt-1],
                links,
                t,
                gnodes,
                hnodes,
                dummy_hap,
                dummy_dem,
                dummy_link,
                MAX_LINKS,
                MAX_DEMANDS,
                MAX_HAPS
            )

            with torch.no_grad():
                s_tensor = torch.tensor(s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
                probs, _ = agent.model(s_tensor) # probs shape: [1, 2, n_haps, n_choices]
                
                # --- CHANGE 1: Extract argmax for both heads ---
                # argmax over the last dimension (n_choices)
                # Resulting shape after squeeze: [2, n_haps]
                hap_picks = torch.argmax(probs, dim=-1).squeeze(0).cpu().numpy()

            # --- CHANGE 2: Pass the [2, n_haps] matrix to z_dict ---
            # Your updated get_z_from_demand_choices should handle the 2-row matrix
            z_dict = get_z_from_demand_choices(hap_picks, demands, links, hnodes)

            # 2. Constraint Check
            # With the dual-head, the model naturally picks at most 1 TX and 1 RX per HAP.
            check_tx, check_rx = True, True
            for idx_h, h in enumerate(hnodes):
                used_tx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n1 == h)
                used_rx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n2 == h)
                
                if used_tx > h.N_TX or used_rx > h.N_RX:
                    check_tx, check_rx = False, False

            # 3. Step Environment
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0)
            else:
                reward_t = -1.0 

            ep_reward += reward_t
            key_srv_qkp[idx] += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(demands))

            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        a_lst_qkp[idx] = sum(state[-1]["a"][i] for i in range(len(links))) * 1e-6
        
        print(f"Test Case {idx+1}: Mean_kbps={mean:.2f}, key_srv_qkp={key_srv_qkp[idx]:.2f}, key_req={key_req[idx]:.2f}, ep_reward: {ep_reward}")

    return test_rewards, key_srv_qkp, a_lst_qkp

prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

key_srv_ppo_qkp = [0 for i in range(NUM_DATA)]
a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]

# Run the test
results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.
# --- Starting Evaluation for 100 Episodes (Dual-Head) ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 96
#      93 a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]
#      95 # Run the test
# ---> 96 results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
#
# Cell In[14], line 29, in test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes, f_qkp)
#      26 hnodes_active = [1 for h in hnodes]
#      27 links_active  = [1 if ((isinstance(l.n1, hap) and hnodes_active[hnodes.index(l.n1)] == 1) or (isinstance(l.n2, hap) and hnodes_active[hnodes.index(l.n2)] == 1)) else 0 for l in links]
# ---> 29 s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)
#      30 s_vec = build_state_vector_for_time(
#      31     state[t],
#      32     links,
#    (...)
#      41     MAX_HAPS
#      42 )
#      44 with torch.no_grad():
#
# TypeError: build_state_vector_for_time() missing 6 required positional arguments: 'hap_active', 'demand_active', 'link_active', 'MAX_LINKS', 'MAX_DEMANDS', and 'MAX_HAPS'

# %% [markdown]
# ## Offline

# %%
key_srv_grd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rnd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rlx_qkp = [0 for i in range(NUM_DATA)]
key_srv_opt_qkp = [0 for i in range(NUM_DATA)]

a_lst_grd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rnd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rlx_qkp = [0 for i in range(NUM_DATA)]
a_lst_opt_qkp = [0 for i in range(NUM_DATA)]

key_req = [0 for i in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)

    result_file = os.path.join(RESULTS_DIR, f"mean_{mean:.4f}.pkl")

    # ------------------------------------------------------------
    # If results exist → load them
    # ------------------------------------------------------------
    if os.path.exists(result_file):
        print(f"[LOAD] idx {idx}, mean={mean}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_grd_qkp[idx] = data["key_srv_grd"]
        a_lst_grd_qkp[idx]   = data["a_lst_grd"]

        key_srv_rlx_qkp[idx] = data["key_srv_rlx"]
        a_lst_rlx_qkp[idx]   = data["a_lst_rlx"]

        key_srv_opt_qkp[idx] = data["key_srv_opt"]
        a_lst_opt_qkp[idx]   = data["a_lst_opt"]

        key_req[idx]         = data["key_req"]

        continue   # skip computation

    # ------------------------------------------------------------
    # Otherwise → compute everything
    # ------------------------------------------------------------
    print(f"[COMPUTE] idx {idx}, mean={mean}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.0,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands for t in syst.T
    )

    ########################################## Greedy (Scarcity + Contention Aware, 1-hop only) ##########################################
    # Z[l][d][t] = 1 if link l is used by demand d at time t
    Z = [[[0 for t in syst.T] for d in demands] for l in links]
    
    # Stored QKP bits per link (already scaled by THETA)
    qkp_s = [0 for _ in links]
    
    for t in syst.T:
    
        # Per-HAP connection limits (up/down)
        max_cnct_up  = [1] * len(hnodes)
        max_cnct_dwn = [1] * len(hnodes)
    
        # --------------------------------------------------------------------------------------------------
        # Step 1: Enumerate feasible 1-hop paths for each demand
        # A path (l1, l2) is feasible if:
        #   - fresh keys can serve it on both links, OR
        #   - stored QKP can cover the demand on both links
        # --------------------------------------------------------------------------------------------------
        feasible_paths = {}   # d -> list of (idx_l1, idx_l2, mid)
    
        for d in demands:
            src, dst = d.n1, d.n2
            feasible_paths[d] = []
    
            for idx_l1, l1 in enumerate(links):
                for idx_l2, l2 in enumerate(links):
                    if l1.n1 == src and l2.n2 == dst and l1.n2 == l2.n1:
                        mid = l1.n2
    
                        fresh_ok = (
                            l1.K_MAX[t] >= d.K_REQ[t] and
                            l2.K_MAX[t] >= d.K_REQ[t]
                        )
    
                        qkp_ok = (
                            qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                            qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                        )
    
                        if fresh_ok or qkp_ok:
                            feasible_paths[d].append((idx_l1, idx_l2, mid))
    
        # --------------------------------------------------------------------------------------------------
        # Step 2: Order demands by scarcity (least number of feasible paths first)
        # --------------------------------------------------------------------------------------------------
        ordered_demands = sorted(
            demands,
            key=lambda d: (
                len(feasible_paths[d]),
                -d.K_REQ[t]
            )
        )
        
        # --------------------------------------------------------------------------------------------------
        # Step 3 (FIXED): Compute link contention
        # How many feasible paths (across all demands) include each link
        # --------------------------------------------------------------------------------------------------
        link_usage = [0] * len(links)
        
        for d in demands:
            for (idx_l1, idx_l2, _) in feasible_paths[d]:
                link_usage[idx_l1] += 1
                link_usage[idx_l2] += 1
    
        # --------------------------------------------------------------------------------------------------
        # Step 4: Greedy allocation
        # For each demand, try least-contended feasible paths first
        # --------------------------------------------------------------------------------------------------
        for d in ordered_demands:
    
            l1_sel = None
            l2_sel = None
            used_qkp_only = False
    
            # # Order this demand's paths by least contention
            # paths = sorted(
            #     feasible_paths[d],
            #     key=lambda p: path_usage[(p[0], p[1])]
            # )
            
            # Order this demand's paths by least link contention
            paths = sorted(
                feasible_paths[d],
                key=lambda p: link_usage[p[0]] + link_usage[p[1]]
            )
    
            for idx_l1, idx_l2, mid in paths:
    
                # Respect HAP connection limits
                if max_cnct_up[hnodes.index(mid)] == 0:
                    continue
                if max_cnct_dwn[hnodes.index(mid)] == 0:
                    continue
    
                # Case 1: Fully served by stored QKP
                if (
                    qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                    qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                ):
                    qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                    qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                    used_qkp_only = True
                    break
    
                # Case 2: Use fresh generation (possibly mixed with QKP later)
                l1_sel = links[idx_l1]
                l2_sel = links[idx_l2]
                break
    
            # --------------------------------------------------------------------------------------------------
            # Step 5: Update state after allocation
            # --------------------------------------------------------------------------------------------------
            if used_qkp_only:
                continue
    
            if l1_sel is not None:
                mid = l1_sel.n2
                max_cnct_up[hnodes.index(mid)] = 0
    
                l_idx = links.index(l1_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l1_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
            if l2_sel is not None:
                mid = l2_sel.n1
                max_cnct_dwn[hnodes.index(mid)] = 0
    
                l_idx = links.index(l2_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l2_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
    # --------------- GREEDY ----------------
    solution, key_srv_grd_qkp[idx], a_lst_grd_qkp[idx] = offline_lp(
        gnodes, hnodes, links, demands, 1, 2, Z
    )

    key_srv_grd_qkp[idx] *= 1e-6
    a_lst_grd_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, SCAR-Q")

    # --------------- RELAXED ----------------
    solution, key_srv_rlx_qkp[idx], a_lst_rlx_qkp[idx] = offline_relaxed(
        gnodes, hnodes, links, demands, 1, 2
    )

    key_srv_rlx_qkp[idx] *= 1e-6
    a_lst_rlx_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, RELAX")

    # --------------- OPTIMAL ----------------
    if case != 1:
        solution, key_srv_opt_qkp[idx], a_lst_opt_qkp[idx] = offline(
            gnodes, hnodes, links, demands, 1, 2
        )
    
        key_srv_opt_qkp[idx] *= 1e-6
        a_lst_opt_qkp[idx]   *= 1e-6
    
        print(f"idx: {idx}, OPTIMAL")

    # ------------------------------------------------------------
    # Save results
    # ------------------------------------------------------------
    data = {
        "key_srv_grd": key_srv_grd_qkp[idx],
        "a_lst_grd":   a_lst_grd_qkp[idx],

        "key_srv_rlx": key_srv_rlx_qkp[idx],
        "a_lst_rlx":   a_lst_rlx_qkp[idx],

        "key_srv_opt": key_srv_opt_qkp[idx],
        "a_lst_opt":   a_lst_opt_qkp[idx],

        "key_req":     key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] idx {idx}")

# %%
#Store statistics
key_srv_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

a_lst_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

key_req = [0.0 for _ in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    result_file = os.path.join(RESULTS_DIR, f"idx_{idx}.pkl")

    # ============================================================
    # LOAD IF EXISTS
    # ============================================================
    if os.path.exists(result_file):

        print(f"[LOAD] Random idx {idx}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_rnd_qkp_avg[idx] = data["key_srv_avg"]
        key_srv_rnd_qkp_min[idx] = data["key_srv_min"]
        key_srv_rnd_qkp_max[idx] = data["key_srv_max"]

        a_lst_rnd_qkp_avg[idx] = data["a_lst_avg"]
        a_lst_rnd_qkp_min[idx] = data["a_lst_min"]
        a_lst_rnd_qkp_max[idx] = data["a_lst_max"]

        key_req[idx] = data["key_req"]

        continue

    # ============================================================
    # OTHERWISE COMPUTE
    # ============================================================
    print(f"[COMPUTE] Random idx {idx}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.2,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands
        for t in syst.T
    )

    rnd_results_k_srv = []
    rnd_results_a_lst = []

    # ------------------------------------------------------------
    # Monte Carlo
    # ------------------------------------------------------------
    for run in range(N_RUNS):

        Z = [[[0 for t in syst.T] for d in demands] for l in links]

        for t in syst.T:

            max_cnct_up  = [1 for _ in hnodes]
            max_cnct_dwn = [1 for _ in hnodes]

            shuffled_demands = random.sample(demands, len(demands))

            for d in shuffled_demands:

                src, dst = d.n1, d.n2
                feasible_pairs = []

                for l1 in links:
                    for l2 in links:
                        if (
                            l1.n1 == src and
                            l2.n2 == dst and
                            l1.n2 == l2.n1
                        ):
                            mid = l1.n2
                            if (
                                max_cnct_up[hnodes.index(mid)] > 0 and
                                max_cnct_dwn[hnodes.index(mid)] > 0 and
                                l1.K_MAX[t] > 0 and
                                l2.K_MAX[t] > 0
                            ):
                                feasible_pairs.append((l1, l2))

                if feasible_pairs:
                    l1_sel, l2_sel = random.choice(feasible_pairs)
                    mid = l1_sel.n2

                    Z[links.index(l1_sel)][demands.index(d)][t] = 1
                    Z[links.index(l2_sel)][demands.index(d)][t] = 1

                    max_cnct_up[hnodes.index(mid)]  = 0
                    max_cnct_dwn[hnodes.index(mid)] = 0

        _, key_srv, a_lst = offline_lp(
            gnodes, hnodes, links, demands, 1, 2, Z
        )

        rnd_results_k_srv.append(key_srv * 1e-6)
        rnd_results_a_lst.append(a_lst   * 1e-6)

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------
    key_srv_rnd_qkp_avg[idx] = np.mean(rnd_results_k_srv)
    key_srv_rnd_qkp_min[idx] = np.min(rnd_results_k_srv)
    key_srv_rnd_qkp_max[idx] = np.max(rnd_results_k_srv)

    a_lst_rnd_qkp_avg[idx] = np.mean(rnd_results_a_lst)
    a_lst_rnd_qkp_min[idx] = np.min(rnd_results_a_lst)
    a_lst_rnd_qkp_max[idx] = np.max(rnd_results_a_lst)

    # ------------------------------------------------------------
    # SAVE RESULTS
    # ------------------------------------------------------------
    data = {
        "key_srv_avg": key_srv_rnd_qkp_avg[idx],
        "key_srv_min": key_srv_rnd_qkp_min[idx],
        "key_srv_max": key_srv_rnd_qkp_max[idx],

        "a_lst_avg": a_lst_rnd_qkp_avg[idx],
        "a_lst_min": a_lst_rnd_qkp_min[idx],
        "a_lst_max": a_lst_rnd_qkp_max[idx],

        "key_req": key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] Random idx {idx}")
    print(f"idx: {idx} | avg={key_srv_rnd_qkp_avg[idx]:.3f}")
    print(f"idx: {idx} | avg={a_lst_rnd_qkp_avg[idx]:.3f}")

# %%
key_req = [k * 1e-3 for k in key_req]

# %%
key_srv_ppo_qkp = [k * 1e-6 for k in key_srv_ppo_qkp]

# %% [markdown]
# ## Plot

# %%
# key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]

# a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
# a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]

# %%
#key_srv_ppo_qkp_old = [k for k in key_srv_ppo_qkp]
# key_srv_ppo_qkp = [k + 0.1*(key_srv_rlx_qkp[idx_k] - key_srv_ppo_qkp_old[idx_k]) for idx_k, k in enumerate(key_srv_ppo_qkp)]

# %%
# key_srv_ppo_qkp[-1] = key_srv_ppo_qkp[-2]
# key_srv_opt_qkp[-1] = key_srv_opt_qkp[-2]

# %%
# a_lst_opt_qkp[-1] = a_lst_opt_qkp[-2]

# %%
step = 6  # tunable (keep every `step`-th value)

# yerr1
yerr1 = [
    np.array(key_srv_rnd_qkp_avg) - np.array(key_srv_rnd_qkp_min),
    np.array(key_srv_rnd_qkp_max) - np.array(key_srv_rnd_qkp_avg)
]

yerr1[0][np.arange(len(yerr1[0])) % step != 0] = 0
yerr1[1][np.arange(len(yerr1[1])) % step != 0] = 0


# yerr2
yerr2 = [
    np.array(a_lst_rnd_qkp_avg) - np.array(a_lst_rnd_qkp_min),
    np.array(a_lst_rnd_qkp_max) - np.array(a_lst_rnd_qkp_avg)
]

yerr2[0][np.arange(len(yerr2[0])) % step != 0] = 0
yerr2[1][np.arange(len(yerr2[1])) % step != 0] = 0

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, key_srv_rnd_qkp_avg, yerr=yerr1, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, key_srv_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, key_srv_opt_qkp, label="Optimal", linestyle="-", marker="v", markevery=5)
plt.plot(demand_list, key_req, linestyle="--")

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Total Served Secret Key (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_k_srv.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

############################

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, a_lst_rnd_qkp_avg, yerr=yerr2, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, a_lst_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, a_lst_opt_qkp, label="Optimal-QKP", linestyle="-", marker="v", markevery=5)

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Final QKP Stored Keys (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_a_lst.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %% [markdown]
# #####

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T

hap_active    = np.ones(n_hnodes)
demand_active = np.ones(n_demands)
link_active   = np.ones(n_links)

# choose state_dim produced by build_state_vector_for_time
dummy_hap = np.ones(MAX_HAPS)
dummy_dem = np.ones(MAX_DEMANDS)
dummy_link = np.ones(MAX_LINKS)

state_vector_example = build_state_vector_for_time(
    state[0],
    links,
    0,
    gnodes,
    hnodes,
    dummy_hap,
    dummy_dem,
    dummy_link,
    MAX_LINKS,
    MAX_DEMANDS,
    MAX_HAPS
)

state_dim = len(state_vector_example)

agent = PPOAgent(state_dim, n_demands, n_hnodes, lr=LR)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

#WARM_EPISODES  = 500
DECAY_EPISODES = 300
k = 1

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf  = []
    actions_buf = []
    logps_buf   = []
    rewards_buf = []
    dones_buf   = []
    values_buf  = []
    masks_buf   = []

    total_reward = 0.0

    # Calculate a 'progress' factor from 0.0 to 1.0
    progress = ep / num_episodes
    
    # Start with a max of 50 kbps, end with 1000 kbps
    max_now = 10 + (990 * progress) 
    
    # Still use randomness, but within an ever-expanding "boundary"
    mean_kbps_rand = random.uniform(1, max_now)

    #mean_kbps_rand = random.randint(1, 1 + int(10 * ep/num_episodes))
    #mean_kbps_rand = random.randint(1, 1000)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.01*mean_kbps_rand, amp=0.5, noise_std=0.0, pattern="stadium")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    # Before the for t in syst.T: loop
    if ep < num_episodes / 10:
        k = 1  # Only 1 demand: let the agent learn basic RX/TX pairing first
    elif ep < 2 * num_episodes / 10:
        k = random.randint(1, 2) # Slightly more complex
    else:
        k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity

    demands = random.sample(demands_space, k)
    random.shuffle(demands)

    state[0]["demands"] = demands.copy()

    k_srv = 0
    k_req = 0

    k_heur_sum = 0

    for t in syst.T:
        hap_active, demand_active, link_active = generate_dynamic_masks(
            hnodes, demands, links, t
        )
        
        s_vec = build_state_vector_for_time(
            state[t],
            links,
            t,
            gnodes,
            hnodes,
            dummy_hap,
            dummy_dem,
            dummy_link,
            MAX_LINKS,
            MAX_DEMANDS,
            MAX_HAPS
        )
        
        action_mask = build_action_mask(
            hap_active,
            demand_active,
            MAX_HAPS,
            MAX_DEMANDS
            )
        
        hap_choices, logp, value = agent.select_action(s_vec, action_mask)
        
        # 2. Convert to the dictionary format for Gurobi
        z_dict = get_z_from_demand_choices(hap_choices, demands, links, hnodes)

        #print(z_dict)

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes

        k_srv_heur1, k_srv_heur2 = -math.inf, -math.inf
        k_srv_heur1, _, _ = scarq_policy(state, links, t)
        k_srv_heur2, _, _ = mcr_policy(state, links, t)
        
        k_srv_heur = max(k_srv_heur1, k_srv_heur2)

        k_heur_sum += k_srv_heur

        solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, k_srv_heur)

        reward[t] = reward_t
        total_reward += reward_t

        k_srv += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))
        k_req += sum(d.K_REQ[t] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))

        # store rollout data
        states_buf.append(torch.tensor(s_vec))
        actions_buf.append(torch.tensor(hap_choices))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))
        masks_buf.append(action_mask)

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(
        state[-1],
        links,
        t,
        gnodes,
        hnodes,
        dummy_hap,
        dummy_dem,
        dummy_link,
        MAX_LINKS,
        MAX_DEMANDS,
        MAX_HAPS
    )
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor.view(-1), final_value.view(-1)])  # Now shape is [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    masks_b = torch.stack(masks_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, masks_b, old_logps_b, returns_b, adv_b, entropy_coef)

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}, mean_kbps_rand: {mean_kbps_rand}, ratio_heur={k_heur_sum/k_req*1e2} ratio={int(k_srv/k_req*1e2)}, k_srv_heur={int(k_heur_sum)}, k_srv={int(k_srv)}, k_req={int(k_req)}")

# === Plot learning curve ===
plt.figure(figsize=(6,3))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/4000, total reward: 46.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 3.5692647696259283, ratio_heur=100.0000832315701 ratio=98, k_srv_heur=792372, k_srv=778471, k_req=792371
# Episode 2/4000, total reward: 42.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 1.4443500762815344, ratio_heur=100.00048139961115 ratio=94, k_srv_heur=867328, k_srv=821676, k_req=867324
# Episode 3/4000, total reward: 48.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 5.315875036353568, ratio_heur=100.0004387024075 ratio=100, k_srv_heur=1388955, k_srv=1388955, k_req=1388949
# Episode 4/4000, total reward: 42.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 10.247767254319948, ratio_heur=100.00011257310408 ratio=94, k_srv_heur=2274993, k_srv=2155249, k_req=2274990
# Episode 5/4000, total reward: 44.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 7.09457522038218, ratio_heur=100.00057153281894 ratio=96, k_srv_heur=1853704, k_srv=1788663, k_req=1853694
# Episode 6/4000, total reward: 48.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 8.105879750799915, ratio_heur=100.00004645199884 ratio=100, k_srv_heur=2117932, k_srv=2117932, k_req=2117931
# Episode 7/4000, total reward: 48.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 6.311905908538428, ratio_heur=99.9998554040338 ratio=99, k_srv_heur=3790258, k_srv=3790258, k_req=3790263
# Episode 8/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 9.214868084235402, ratio_heur=100.00022372065072 ratio=96, k_srv_heur=2045692, k_srv=1973914, k_req=2045688
# Episode 9/4000, total reward: 38.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 4.679134147070293, ratio_heur=100.00015297925493 ratio=91, k_srv_heur=1222581, k_srv=1115269, k_req=1222579
# Episode 10/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 3.485332599441697, ratio_heur=100.00003387283165 ratio=96, k_srv_heur=910659, k_srv=878705, k_req=910659
# Episode 11/4000, total reward: 38.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 2.808884180053788, ratio_heur=99.99967311070105 ratio=91, k_srv_heur=733912, k_srv=669495, k_req=733914
# Episode 12/4000, total reward: 38.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 11.89042508517457, ratio_heur=100.00003935078003 ratio=91, k_srv_heur=7140135, k_srv=6513417, k_req=7140132
# Episode 13/4000, total reward: 48.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 6.140820489154314, ratio_heur=100.0001009109327 ratio=100, k_srv_heur=1363255, k_srv=1363255, k_req=1363253
# Episode 14/4000, total reward: 22.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 1.1881051172368693, ratio_heur=99.99991858080905 ratio=76, k_srv_heur=713449, k_srv=545657, k_req=713450
# Episode 15/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 10.936941924992638, ratio_heur=100.00008582710502 ratio=96, k_srv_heur=6567577, k_srv=6337135, k_req=6567571
# Episode 16/4000, total reward: 46.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 6.8507743269088355, ratio_heur=99.99963701764139 ratio=98, k_srv_heur=1789986, k_srv=1758583, k_req=1789993
# Episode 17/4000, total reward: 32.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 9.835812588659472, ratio_heur=99.99992812416238 ratio=85, k_srv_heur=5906345, k_srv=5073415, k_req=5906349
# Episode 18/4000, total reward: 46.665, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 11.97903386253107, ratio_heur=99.99994914344697 ratio=99, k_srv_heur=7193338, k_srv=7146379, k_req=7193341
# Episode 19/4000, total reward: 40.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 2.1712999031868887, ratio_heur=100.00023636607528 ratio=92, k_srv_heur=567325, k_srv=527506, k_req=567324
# Episode 20/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 5.5825075036951, ratio_heur=100.00070447881401 ratio=94, k_srv_heur=1458626, k_srv=1381850, k_req=1458616
# Episode 21/4000, total reward: 40.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 3.227334047223411, ratio_heur=99.99990846414907 ratio=92, k_srv_heur=843247, k_srv=784058, k_req=843248
# Episode 22/4000, total reward: 44.474, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 10.011531609004146, ratio_heur=100.00004125471527 ratio=96, k_srv_heur=6011870, k_srv=5823397, k_req=6011867
# Episode 23/4000, total reward: 46.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 10.512617772121176, ratio_heur=100.00017731227987 ratio=98, k_srv_heur=2746776, k_srv=2698586, k_req=2746771
# Episode 24/4000, total reward: 48.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 8.072223110169944, ratio_heur=99.99978191965776 ratio=99, k_srv_heur=4847313, k_srv=4846212, k_req=4847324
# Episode 25/4000, total reward: 48.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 12.606370175870707, ratio_heur=99.9998609902134 ratio=99, k_srv_heur=2798593, k_srv=2798593, k_req=2798597
# Episode 26/4000, total reward: 34.806, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 15.810008175685054, ratio_heur=99.99997056919754 ratio=88, k_srv_heur=9493817, k_srv=8415412, k_req=9493820
# Episode 27/4000, total reward: 46.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 15.980282240225902, ratio_heur=100.00007906574385 ratio=98, k_srv_heur=3547603, k_srv=3485365, k_req=3547600
# Episode 28/4000, total reward: 24.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 7.890673802585119, ratio_heur=99.99990203088703 ratio=78, k_srv_heur=4738300, k_srv=3717453, k_req=4738304
# Episode 29/4000, total reward: 38.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 10.338260701876143, ratio_heur=99.99976665787162 ratio=91, k_srv_heur=6208052, k_srv=5663147, k_req=6208066
# Episode 30/4000, total reward: 40.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 1.9631397289162205, ratio_heur=100.0006050627849 ratio=92, k_srv_heur=1178861, k_srv=1096117, k_req=1178854
# Episode 31/4000, total reward: 42.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 1.062037193345825, ratio_heur=100.00054755647028 ratio=94, k_srv_heur=637750, k_srv=604182, k_req=637747
# Episode 32/4000, total reward: 44.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 4.518461041875096, ratio_heur=100.00009707571205 ratio=96, k_srv_heur=1003093, k_srv=967895, k_req=1003092
# Episode 33/4000, total reward: 38.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 11.948314027726628, ratio_heur=99.99998649877882 ratio=91, k_srv_heur=3121894, k_srv=2847873, k_req=3121895
# Episode 34/4000, total reward: 42.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 6.539779523307935, ratio_heur=99.99964061680521 ratio=94, k_srv_heur=1708729, k_srv=1618792, k_req=1708735
# Episode 35/4000, total reward: 46.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 4.283064813243208, ratio_heur=99.99996439694704 ratio=98, k_srv_heur=2571955, k_srv=2526832, k_req=2571956
# Episode 36/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 2.2249785826316932, ratio_heur=99.99978945845315 ratio=99, k_srv_heur=1336084, k_srv=1336084, k_req=1336087
# Episode 37/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 13.851108274203366, ratio_heur=100.00015391630936 ratio=100, k_srv_heur=3619069, k_srv=3619069, k_req=3619063
# Episode 38/4000, total reward: 38.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 13.635251075205868, ratio_heur=99.99978013715904 ratio=91, k_srv_heur=3027000, k_srv=2761309, k_req=3027007
# Episode 39/4000, total reward: 44.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 18.973792875424337, ratio_heur=100.00005452308518 ratio=96, k_srv_heur=4957538, k_srv=4783588, k_req=4957535
# Episode 40/4000, total reward: 46.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 13.90612645854551, ratio_heur=99.99979841618328 ratio=98, k_srv_heur=3087135, k_srv=3032974, k_req=3087141
# Episode 41/4000, total reward: 44.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 18.48798662706758, ratio_heur=100.0002151497333 ratio=96, k_srv_heur=4104316, k_srv=3960306, k_req=4104307
# Episode 42/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 10.489022827496486, ratio_heur=100.00028991528833 ratio=100, k_srv_heur=2328555, k_srv=2328555, k_req=2328548
# Episode 43/4000, total reward: 40.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 9.2753694213965, ratio_heur=99.99999814024434 ratio=92, k_srv_heur=5569806, k_srv=5178857, k_req=5569806
# Episode 44/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 1.487931684741475, ratio_heur=100.00083567632284 ratio=100, k_srv_heur=893502, k_srv=893502, k_req=893494
# Episode 45/4000, total reward: 44.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 19.389109773748906, ratio_heur=100.00001035988629 ratio=96, k_srv_heur=11643051, k_srv=11234521, k_req=11643050
# Episode 46/4000, total reward: 46.380, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 20.963380037381818, ratio_heur=100.00003690893683 ratio=98, k_srv_heur=12588395, k_srv=12451483, k_req=12588390
# Episode 47/4000, total reward: 46.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 4.568499276333825, ratio_heur=99.99992604497643 ratio=98, k_srv_heur=1193671, k_srv=1172730, k_req=1193672
# Episode 48/4000, total reward: 38.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 12.256952907122873, ratio_heur=100.00028921732572 ratio=91, k_srv_heur=2721034, k_srv=2482198, k_req=2721026
# Episode 49/4000, total reward: 44.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 6.8515905716056205, ratio_heur=100.00003747262289 ratio=96, k_srv_heur=4114342, k_srv=3969979, k_req=4114341
# Episode 50/4000, total reward: 46.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 1.6050961263324246, ratio_heur=100.00068357074134 ratio=98, k_srv_heur=356331, k_srv=350080, k_req=356329
# Episode 51/4000, total reward: 34.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 8.324401932223232, ratio_heur=100.00000299194988 ratio=87, k_srv_heur=1848005, k_srv=1620435, k_req=1848005
# Episode 52/4000, total reward: 44.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 1.2270389845438183, ratio_heur=100.00011658712292 ratio=96, k_srv_heur=320605, k_srv=309355, k_req=320604
# Episode 53/4000, total reward: 40.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 18.820897428860285, ratio_heur=100.00008812677592 ratio=92, k_srv_heur=4917590, k_srv=4572421, k_req=4917586
# Episode 54/4000, total reward: 42.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 3.0986454543161113, ratio_heur=99.99963391790159 ratio=94, k_srv_heur=1860712, k_srv=1762774, k_req=1860719
# Episode 55/4000, total reward: 40.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 6.052176927542124, ratio_heur=100.00045596173292 ratio=92, k_srv_heur=1343581, k_srv=1249275, k_req=1343575
# Episode 56/4000, total reward: 44.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 2.876391158749, ratio_heur=100.00035421932287 ratio=96, k_srv_heur=638557, k_srv=616150, k_req=638554
# Episode 57/4000, total reward: 44.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 14.436309322890205, ratio_heur=99.99984873488161 ratio=96, k_srv_heur=3771961, k_srv=3639610, k_req=3771966
# Episode 58/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 5.198323015950965, ratio_heur=100.00084375519562 ratio=98, k_srv_heur=1154030, k_srv=1133783, k_req=1154020
# Episode 59/4000, total reward: 26.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 12.18983401866155, ratio_heur=100.00022068205674 ratio=80, k_srv_heur=2706132, k_srv=2175071, k_req=2706126
# Episode 60/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 19.32511799372104, ratio_heur=100.00001402734769 ratio=98, k_srv_heur=4290150, k_srv=4214885, k_req=4290149
# Episode 61/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 22.07824892254804, ratio_heur=99.99999251107175 ratio=99, k_srv_heur=13257862, k_srv=13257862, k_req=13257863
# Episode 62/4000, total reward: 45.567, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 24.888047177100947, ratio_heur=100.0000167260888 ratio=99, k_srv_heur=14945133, k_srv=14831623, k_req=14945131
# Episode 63/4000, total reward: 44.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 21.289943252460585, ratio_heur=100.00005200213644 ratio=96, k_srv_heur=4726341, k_srv=4560503, k_req=4726338
# Episode 64/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 11.786902045971233, ratio_heur=99.99999473492726 ratio=99, k_srv_heur=3079720, k_srv=3079720, k_req=3079720
# Episode 65/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 12.32588824216645, ratio_heur=99.99994129670007 ratio=98, k_srv_heur=7401621, k_srv=7271767, k_req=7401625
# Episode 66/4000, total reward: 44.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 24.737244544810114, ratio_heur=100.00013437647259 ratio=96, k_srv_heur=6463438, k_srv=6236650, k_req=6463429
# Episode 67/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 18.50800742515593, ratio_heur=99.99998913005072 ratio=99, k_srv_heur=4835833, k_srv=4834933, k_req=4835833
# Episode 68/4000, total reward: 42.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 15.547372080718285, ratio_heur=99.9999795478671 ratio=94, k_srv_heur=9336106, k_srv=8844708, k_req=9336108
# Episode 69/4000, total reward: 40.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 1.1516928323510818, ratio_heur=100.00075335480378 ratio=92, k_srv_heur=300920, k_srv=279799, k_req=300918
# Episode 70/4000, total reward: 46.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 20.673356400496218, ratio_heur=99.99977587259278 ratio=98, k_srv_heur=5401591, k_srv=5306826, k_req=5401603
# Episode 71/4000, total reward: 46.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 19.41433698229365, ratio_heur=99.99998856770429 ratio=98, k_srv_heur=4309956, k_srv=4234343, k_req=4309956
# Episode 72/4000, total reward: 30.504, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 26.54523349730847, ratio_heur=99.99998694069326 ratio=85, k_srv_heur=15940260, k_srv=13678243, k_req=15940262
# Episode 73/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 10.613678915453194, ratio_heur=100.00006053598065 ratio=100, k_srv_heur=2773179, k_srv=2773179, k_req=2773177
# Episode 74/4000, total reward: 26.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 6.218632131369107, ratio_heur=100.00052201415612 ratio=80, k_srv_heur=3734272, k_srv=3001444, k_req=3734253
# Episode 75/4000, total reward: 40.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 14.153416137312846, ratio_heur=99.99994501364998 ratio=92, k_srv_heur=3698049, k_srv=3438480, k_req=3698051
# Episode 76/4000, total reward: 40.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 17.747707294628817, ratio_heur=99.99992991601997 ratio=92, k_srv_heur=3939964, k_srv=3663413, k_req=3939966
# Episode 77/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 25.245842506285847, ratio_heur=99.9999390836214 ratio=99, k_srv_heur=5604539, k_srv=5604539, k_req=5604542
# Episode 78/4000, total reward: 26.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 16.533578104953403, ratio_heur=100.00010551876922 ratio=80, k_srv_heur=3670435, k_srv=2950138, k_req=3670431
# Episode 79/4000, total reward: 44.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 2.2738049190540486, ratio_heur=99.99981317143515 ratio=96, k_srv_heur=1365404, k_srv=1317495, k_req=1365406
# Episode 80/4000, total reward: 46.847, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 27.235505677441143, ratio_heur=99.99998404842775 ratio=99, k_srv_heur=16354763, k_srv=16310836, k_req=16354766
# Episode 81/4000, total reward: 42.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 20.58278455028067, ratio_heur=100.00008195954821 ratio=94, k_srv_heur=5377942, k_srv=5094878, k_req=5377938
# Episode 82/4000, total reward: 48.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 1.8604263599811612, ratio_heur=99.99938574056038 ratio=99, k_srv_heur=486095, k_srv=486095, k_req=486098
# Episode 83/4000, total reward: 46.873, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 24.677967835289166, ratio_heur=99.99998527121762 ratio=99, k_srv_heur=5478474, k_srv=5466299, k_req=5478475
# Episode 84/4000, total reward: 40.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 14.948224557814507, ratio_heur=100.00026552515537 ratio=92, k_srv_heur=3318494, k_srv=3085567, k_req=3318485
# Episode 85/4000, total reward: 44.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 5.884288186344226, ratio_heur=99.99988392282988 ratio=96, k_srv_heur=1537464, k_srv=1483518, k_req=1537466
# Episode 86/4000, total reward: 46.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 25.829326518685363, ratio_heur=99.99994777775159 ratio=98, k_srv_heur=6748768, k_srv=6630368, k_req=6748772
# Episode 87/4000, total reward: 38.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 29.918385109434418, ratio_heur=100.00006416803527 ratio=91, k_srv_heur=6641845, k_srv=6058863, k_req=6641840
# Episode 88/4000, total reward: 48.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 20.3987567269843, ratio_heur=99.99998804004646 ratio=99, k_srv_heur=4528495, k_srv=4528495, k_req=4528496
# Episode 89/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 17.5203689371784, ratio_heur=100.00004252704413 ratio=100, k_srv_heur=10520886, k_srv=10520886, k_req=10520882
# Episode 90/4000, total reward: 44.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 7.356943011879707, ratio_heur=100.00011785394958 ratio=96, k_srv_heur=1922248, k_srv=1854801, k_req=1922246
# Episode 91/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 13.067702031410702, ratio_heur=99.99991092203163 ratio=99, k_srv_heur=3414369, k_srv=3414369, k_req=3414372
# Episode 92/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 15.434680965052797, ratio_heur=99.99999849492855 ratio=99, k_srv_heur=3426478, k_srv=3426478, k_req=3426478
# Episode 93/4000, total reward: 40.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 3.333068531540965, ratio_heur=99.99884833772907 ratio=92, k_srv_heur=870865, k_srv=809738, k_req=870875
# Episode 94/4000, total reward: 46.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 32.84224627116866, ratio_heur=99.99995127523727 ratio=98, k_srv_heur=7290930, k_srv=7163018, k_req=7290934
# Episode 95/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 11.613521095272326, ratio_heur=100.00045224435085 ratio=100, k_srv_heur=2578197, k_srv=2578197, k_req=2578185
# Episode 96/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 27.716790588569673, ratio_heur=99.9999327357857 ratio=99, k_srv_heur=6153085, k_srv=6153085, k_req=6153089
# Episode 97/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 8.87572228943154, ratio_heur=100.00002453007721 ratio=100, k_srv_heur=1970398, k_srv=1970398, k_req=1970398
# Episode 98/4000, total reward: 46.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 22.095011405556942, ratio_heur=100.00000854483729 ratio=98, k_srv_heur=4905063, k_srv=4819008, k_req=4905062
# Episode 99/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 14.663574252236835, ratio_heur=99.99993625883764 ratio=99, k_srv_heur=3831344, k_srv=3831344, k_req=3831347
# Episode 100/4000, total reward: 44.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 13.735401487708524, ratio_heur=99.99985205891099 ratio=96, k_srv_heur=3049235, k_srv=2942243, k_req=3049240
# Episode 101/4000, total reward: 48.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 30.738144426148033, ratio_heur=100.0001143766377 ratio=100, k_srv_heur=6823834, k_srv=6823834, k_req=6823826
# Episode 102/4000, total reward: 42.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 25.77337365104631, ratio_heur=100.00000040033201 ratio=94, k_srv_heur=6734152, k_srv=6379703, k_req=6734152
# Episode 103/4000, total reward: 48.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 1.6630015796147326, ratio_heur=99.99958970662897 ratio=99, k_srv_heur=434512, k_srv=434512, k_req=434514
# Episode 104/4000, total reward: 38.245, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 29.549999556451777, ratio_heur=100.00004029746499 ratio=93, k_srv_heur=17744614, k_srv=16574205, k_req=17744607
# Episode 105/4000, total reward: 48.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 1.8709256114345063, ratio_heur=100.00169749303993 ratio=100, k_srv_heur=415349, k_srv=415349, k_req=415342
# Episode 106/4000, total reward: 46.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 19.32322740060441, ratio_heur=99.99997927383292 ratio=98, k_srv_heur=4289729, k_srv=4214471, k_req=4289730
# Episode 107/4000, total reward: 48.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 15.64396474937389, ratio_heur=99.99981663965045 ratio=99, k_srv_heur=3472932, k_srv=3472932, k_req=3472938
# Episode 108/4000, total reward: 38.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 9.386179326423484, ratio_heur=100.00004294713311 ratio=91, k_srv_heur=2452453, k_srv=2237191, k_req=2452452
# Episode 109/4000, total reward: 48.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 31.996428544414286, ratio_heur=100.00002303608058 ratio=100, k_srv_heur=7103165, k_srv=7103165, k_req=7103163
# Episode 110/4000, total reward: 39.937, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 30.95264328125927, ratio_heur=99.99998898855287 ratio=94, k_srv_heur=18586884, k_srv=17586604, k_req=18586886
# Episode 111/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 19.67296894993446, ratio_heur=99.9998754639872 ratio=99, k_srv_heur=4367367, k_srv=4367367, k_req=4367372
# Episode 112/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 12.619028341626892, ratio_heur=99.9996578161564 ratio=99, k_srv_heur=2801397, k_srv=2801397, k_req=2801407
# Episode 113/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 13.484630379757672, ratio_heur=99.99992433613951 ratio=96, k_srv_heur=2993567, k_srv=2888530, k_req=2993569
# Episode 114/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 1.5031406671322058, ratio_heur=100.00258004838915 ratio=100, k_srv_heur=333703, k_srv=333703, k_req=333695
# Episode 115/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 14.11741024614978, ratio_heur=99.99997032924945 ratio=96, k_srv_heur=3688642, k_srv=3559215, k_req=3688643
# Episode 116/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 13.792078816519599, ratio_heur=100.00008278646675 ratio=100, k_srv_heur=3603643, k_srv=3603643, k_req=3603640
# Episode 117/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 9.65809998137548, ratio_heur=100.00030298658965 ratio=100, k_srv_heur=2144091, k_srv=2144091, k_req=2144085
# Episode 118/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 37.21168983953147, ratio_heur=99.99996245448564 ratio=96, k_srv_heur=8260941, k_srv=7971082, k_req=8260944
# Episode 119/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 38.02576333686993, ratio_heur=99.99994652127914 ratio=99, k_srv_heur=8441663, k_srv=8441663, k_req=8441667
# Episode 120/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 1.4183852517852955, ratio_heur=99.9994562298925 ratio=99, k_srv_heur=370598, k_srv=370598, k_req=370600
# Episode 121/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 36.636539093443, ratio_heur=100.00005888043137 ratio=100, k_srv_heur=9572522, k_srv=9572522, k_req=9572516
# Episode 122/4000, total reward: 46.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 31.977289165460952, ratio_heur=99.99997308433367 ratio=98, k_srv_heur=8355130, k_srv=8208549, k_req=8355132
# Episode 123/4000, total reward: 44.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 3.626722674248093, ratio_heur=100.00006749131367 ratio=96, k_srv_heur=947602, k_srv=914353, k_req=947602
# Episode 124/4000, total reward: 38.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 39.001408789164316, ratio_heur=100.00003158085397 ratio=91, k_srv_heur=10190421, k_srv=9295965, k_req=10190417
# Episode 125/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 5.952837049942115, ratio_heur=100.00010998150961 ratio=100, k_srv_heur=3574648, k_srv=3574648, k_req=3574644
# Episode 126/4000, total reward: 46.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 22.963618351409544, ratio_heur=99.99999391782198 ratio=98, k_srv_heur=6000010, k_srv=5894746, k_req=6000010
# Episode 127/4000, total reward: 44.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 26.461968834001336, ratio_heur=100.00015643313299 ratio=96, k_srv_heur=5874530, k_srv=5668405, k_req=5874521
# Episode 128/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 22.217775910075307, ratio_heur=99.99997981662338 ratio=99, k_srv_heur=5805133, k_srv=5805133, k_req=5805134
# Episode 129/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 14.313127049252287, ratio_heur=99.99977961885666 ratio=99, k_srv_heur=3177487, k_srv=3177487, k_req=3177494
# Episode 130/4000, total reward: 46.248, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 32.154641117027815, ratio_heur=99.9999889883022 ratio=98, k_srv_heur=19308677, k_srv=19053865, k_req=19308679
# Episode 131/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 42.01009331239941, ratio_heur=99.99997675301778 ratio=99, k_srv_heur=9326181, k_srv=9326181, k_req=9326183
# Episode 132/4000, total reward: 42.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 15.310140946030462, ratio_heur=99.99994155514403 ratio=94, k_srv_heur=4000282, k_srv=3789730, k_req=4000284
# Episode 133/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 15.632890255480236, ratio_heur=100.00011971366098 ratio=100, k_srv_heur=3470484, k_srv=3470484, k_req=3470480
# Episode 134/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 6.741859840265492, ratio_heur=99.9997631077179 ratio=99, k_srv_heur=1496680, k_srv=1496680, k_req=1496683
# Episode 135/4000, total reward: 42.940, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 28.189189416759167, ratio_heur=100.00010929885595 ratio=96, k_srv_heur=7365373, k_srv=7099221, k_req=7365365
# Episode 136/4000, total reward: 46.864, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 21.19611665803685, ratio_heur=99.9999594646647 ratio=99, k_srv_heur=5538189, k_srv=5524966, k_req=5538191
# Episode 137/4000, total reward: 35.708, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 42.99344023139342, ratio_heur=99.9999979355656 ratio=90, k_srv_heur=11233468, k_srv=10183595, k_req=11233469
# Episode 138/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 3.0113968766863257, ratio_heur=99.99963733820893 ratio=99, k_srv_heur=668523, k_srv=668523, k_req=668526
# Episode 139/4000, total reward: 46.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 9.122936133874259, ratio_heur=100.0004744774992 ratio=98, k_srv_heur=2383682, k_srv=2341863, k_req=2383671
# Episode 140/4000, total reward: 44.486, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 23.73509447947561, ratio_heur=99.99996949453617 ratio=97, k_srv_heur=14252785, k_srv=13874171, k_req=14252789
# Episode 141/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 39.02915916402974, ratio_heur=100.00002276020675 ratio=100, k_srv_heur=8664422, k_srv=8664422, k_req=8664420
# Episode 142/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 34.88719689017136, ratio_heur=99.99996252936373 ratio=99, k_srv_heur=9115439, k_srv=9115439, k_req=9115442
# Episode 143/4000, total reward: 46.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 40.61842072239337, ratio_heur=100.00000430191179 ratio=98, k_srv_heur=24391132, k_srv=23963218, k_req=24391131
# Episode 144/4000, total reward: 43.259, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 42.04090257015585, ratio_heur=99.99998800455761 ratio=96, k_srv_heur=25245320, k_srv=24474083, k_req=25245323
# Episode 145/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 18.06709569392942, ratio_heur=99.99985929143627 ratio=99, k_srv_heur=4720624, k_srv=4720624, k_req=4720630
# Episode 146/4000, total reward: 42.961, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 29.568723086384736, ratio_heur=99.99990558441688 ratio=96, k_srv_heur=7725807, k_srv=7448715, k_req=7725814
# Episode 147/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 4.7275376553696375, ratio_heur=99.99992478710271 ratio=99, k_srv_heur=2838857, k_srv=2838857, k_req=2838859
# Episode 148/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 23.19239089426158, ratio_heur=99.99984578964657 ratio=99, k_srv_heur=5148671, k_srv=5148671, k_req=5148679
# Episode 149/4000, total reward: 44.849, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 36.75215900805406, ratio_heur=99.99992057844287 ratio=97, k_srv_heur=8158923, k_srv=7994143, k_req=8158929
# Episode 150/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 14.782670716372813, ratio_heur=100.00000811640145 ratio=100, k_srv_heur=8876910, k_srv=8876910, k_req=8876909
# Episode 151/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 21.864474383980543, ratio_heur=99.99985012851167 ratio=98, k_srv_heur=4853876, k_srv=4768720, k_req=4853883
# Episode 152/4000, total reward: 46.441, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 41.49017221190922, ratio_heur=100.00007227506617 ratio=99, k_srv_heur=10840698, k_srv=10734447, k_req=10840690
# Episode 153/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 30.78777856972767, ratio_heur=99.99996916200323 ratio=98, k_srv_heur=6834842, k_srv=6714934, k_req=6834845
# Episode 154/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 11.529204220910367, ratio_heur=99.99975352343273 ratio=98, k_srv_heur=2559461, k_srv=2514558, k_req=2559467
# Episode 155/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 2.1909029274993603, ratio_heur=100.00010691293362 ratio=100, k_srv_heur=486378, k_srv=486378, k_req=486377
# Episode 156/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 27.26184923803749, ratio_heur=99.99999379205275 ratio=99, k_srv_heur=6052093, k_srv=6052093, k_req=6052093
# Episode 157/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 38.60384078385623, ratio_heur=100.00001488789889 ratio=100, k_srv_heur=8570001, k_srv=8570001, k_req=8570000
# Episode 158/4000, total reward: 46.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 23.890863759971918, ratio_heur=99.99997041406552 ratio=98, k_srv_heur=5303737, k_srv=5210690, k_req=5303739
# Episode 159/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 5.486761065861581, ratio_heur=100.00053208046897 ratio=100, k_srv_heur=1218059, k_srv=1218059, k_req=1218053
# Episode 160/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 43.887412542757474, ratio_heur=99.99999245416728 ratio=99, k_srv_heur=26354140, k_srv=26354140, k_req=26354142
# Episode 161/4000, total reward: 46.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 19.48622301259035, ratio_heur=99.99986837451209 ratio=98, k_srv_heur=4325909, k_srv=4250016, k_req=4325915
# Episode 162/4000, total reward: 42.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 5.212709825951715, ratio_heur=99.99994438956932 ratio=94, k_srv_heur=1361993, k_srv=1290304, k_req=1361994
# Episode 163/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 16.869264603077994, ratio_heur=100.00009638438834 ratio=100, k_srv_heur=4407661, k_srv=4407661, k_req=4407657
# Episode 164/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 6.933320198092201, ratio_heur=100.000123811683 ratio=100, k_srv_heur=1811563, k_srv=1811563, k_req=1811560
# Episode 165/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 29.780314098763295, ratio_heur=99.99991891238128 ratio=99, k_srv_heur=6611184, k_srv=6611184, k_req=6611189
# Episode 166/4000, total reward: 43.011, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 29.388781126452493, ratio_heur=99.99999718373962 ratio=96, k_srv_heur=17647795, k_srv=17031787, k_req=17647796
# Episode 167/4000, total reward: 44.563, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 20.47964615656601, ratio_heur=99.99994223960037 ratio=97, k_srv_heur=12297904, k_srv=11987886, k_req=12297911
# Episode 168/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 16.034211600805396, ratio_heur=100.00002085158411 ratio=100, k_srv_heur=4189473, k_srv=4189473, k_req=4189472
# Episode 169/4000, total reward: 44.691, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 43.238130396059745, ratio_heur=100.00003179771709 ratio=97, k_srv_heur=25964260, k_srv=25356175, k_req=25964251
# Episode 170/4000, total reward: 46.746, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 21.370833513056027, ratio_heur=99.99998399627921 ratio=99, k_srv_heur=12833062, k_srv=12775798, k_req=12833064
# Episode 171/4000, total reward: 44.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 27.392755070777604, ratio_heur=100.00002080822713 ratio=96, k_srv_heur=16449197, k_srv=15872029, k_req=16449193
# Episode 172/4000, total reward: 42.552, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 27.051015488594707, ratio_heur=100.0000215627729 ratio=95, k_srv_heur=16243984, k_srv=15546234, k_req=16243981
# Episode 173/4000, total reward: 46.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 26.365976103105286, ratio_heur=99.99997199653585 ratio=98, k_srv_heur=15832614, k_srv=15554849, k_req=15832619
# Episode 174/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 28.145734558530314, ratio_heur=99.99995688655262 ratio=99, k_srv_heur=16901346, k_srv=16901346, k_req=16901353
# Episode 175/4000, total reward: 46.711, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 22.41615380341841, ratio_heur=100.00008947211762 ratio=99, k_srv_heur=13460785, k_srv=13392509, k_req=13460773
# Episode 176/4000, total reward: 46.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 12.685515338689743, ratio_heur=99.99992060750654 ratio=98, k_srv_heur=3314511, k_srv=3256362, k_req=3314513
# Episode 177/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 15.173924624047903, ratio_heur=99.99993180117391 ratio=99, k_srv_heur=3368588, k_srv=3368588, k_req=3368590
# Episode 178/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 8.213058375365396, ratio_heur=100.00006507132385 ratio=100, k_srv_heur=2145936, k_srv=2145936, k_req=2145935
# Episode 179/4000, total reward: 44.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 25.254867319146307, ratio_heur=100.00006581046425 ratio=96, k_srv_heur=5606550, k_srv=5409828, k_req=5606546
# Episode 180/4000, total reward: 46.878, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 49.07016431469666, ratio_heur=99.99998384175008 ratio=99, k_srv_heur=10893508, k_srv=10870272, k_req=10893509
# Episode 181/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 32.7347538245419, ratio_heur=99.99991893180386 ratio=99, k_srv_heur=8553038, k_srv=8553038, k_req=8553045
# Episode 182/4000, total reward: 46.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 42.26350486245096, ratio_heur=99.99995961975485 ratio=98, k_srv_heur=9382437, k_srv=9217832, k_req=9382440
# Episode 183/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 43.977888086759464, ratio_heur=100.00002928910021 ratio=100, k_srv_heur=9763034, k_srv=9763034, k_req=9763031
# Episode 184/4000, total reward: 41.340, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 49.409510505885365, ratio_heur=99.99999433831628 ratio=96, k_srv_heur=29670129, k_srv=28769943, k_req=29670130
# Episode 185/4000, total reward: 46.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 6.554811703597487, ratio_heur=100.00012113151695 ratio=98, k_srv_heur=3936132, k_srv=3867076, k_req=3936127
# Episode 186/4000, total reward: 46.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 41.08333236863896, ratio_heur=99.99993574157861 ratio=98, k_srv_heur=10734382, k_srv=10546059, k_req=10734389
# Episode 187/4000, total reward: 44.904, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 12.755636932566704, ratio_heur=100.00004706544023 ratio=98, k_srv_heur=7659691, k_srv=7512429, k_req=7659687
# Episode 188/4000, total reward: 46.758, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 28.440891477498415, ratio_heur=99.99998488073737 ratio=99, k_srv_heur=6313838, k_srv=6287007, k_req=6313839
# Episode 189/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 31.462600906396553, ratio_heur=99.99999943483536 ratio=99, k_srv_heur=18893113, k_srv=18893113, k_req=18893113
# Episode 190/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 8.03012703231283, ratio_heur=100.00017300739455 ratio=100, k_srv_heur=1782680, k_srv=1782680, k_req=1782677
# Episode 191/4000, total reward: 46.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 8.247923543697272, ratio_heur=100.00032060899635 ratio=98, k_srv_heur=2155051, k_srv=2117244, k_req=2155044
# Episode 192/4000, total reward: 44.326, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 35.37899619330852, ratio_heur=99.99998563131318 ratio=96, k_srv_heur=21244883, k_srv=20602330, k_req=21244886
# Episode 193/4000, total reward: 46.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 18.226967092650256, ratio_heur=100.00021894373268 ratio=98, k_srv_heur=4762412, k_srv=4678862, k_req=4762402
# Episode 194/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 25.334463798530106, ratio_heur=100.00010956693184 ratio=100, k_srv_heur=6619480, k_srv=6619480, k_req=6619472
# Episode 195/4000, total reward: 41.585, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 39.23726262268544, ratio_heur=100.00002992411774 ratio=95, k_srv_heur=23561760, k_srv=22561036, k_req=23561753
# Episode 196/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 7.345112421471527, ratio_heur=99.99959519260683 ratio=99, k_srv_heur=1630598, k_srv=1630598, k_req=1630605
# Episode 197/4000, total reward: 46.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 49.23079611922325, ratio_heur=99.9999368766577 ratio=98, k_srv_heur=12863178, k_srv=12637508, k_req=12863186
# Episode 198/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 52.616124742618894, ratio_heur=100.00001280360055 ratio=100, k_srv_heur=13747717, k_srv=13747717, k_req=13747716
# Episode 199/4000, total reward: 46.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 9.822521959304565, ratio_heur=99.99980514595813 ratio=98, k_srv_heur=2566456, k_srv=2521431, k_req=2566461
# Episode 200/4000, total reward: 42.484, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 57.92561899435904, ratio_heur=99.99999740774017 ratio=97, k_srv_heur=34784004, k_srv=33841634, k_req=34784005
# Episode 201/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 9.451854003727851, ratio_heur=100.00003925793868 ratio=100, k_srv_heur=2098299, k_srv=2098299, k_req=2098298
# Episode 202/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 34.82068995046464, ratio_heur=99.99989434364431 ratio=99, k_srv_heur=7730137, k_srv=7730137, k_req=7730145
# Episode 203/4000, total reward: 43.529, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 41.566897843602476, ratio_heur=99.99995721360543 ratio=97, k_srv_heur=24960675, k_srv=24312103, k_req=24960686
# Episode 204/4000, total reward: 46.822, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 28.07569032423544, ratio_heur=100.00004554440822 ratio=99, k_srv_heur=16859300, k_srv=16806520, k_req=16859292
# Episode 205/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 16.719580934324036, ratio_heur=100.00012578588604 ratio=100, k_srv_heur=4368553, k_srv=4368553, k_req=4368547
# Episode 206/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 45.32800628267974, ratio_heur=100.00000049866098 ratio=100, k_srv_heur=10062755, k_srv=10062755, k_req=10062755
# Episode 207/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 17.24601631281949, ratio_heur=100.000042359082 ratio=100, k_srv_heur=4506098, k_srv=4506098, k_req=4506096
# Episode 208/4000, total reward: 46.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 28.407792434991894, ratio_heur=100.00006368117951 ratio=98, k_srv_heur=7422487, k_srv=7292267, k_req=7422482
# Episode 209/4000, total reward: 46.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 11.906359358716076, ratio_heur=99.99993046962837 ratio=98, k_srv_heur=2643193, k_srv=2596822, k_req=2643195
# Episode 210/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 16.24076480262397, ratio_heur=100.00002854543584 ratio=100, k_srv_heur=3605428, k_srv=3605428, k_req=3605427
# Episode 211/4000, total reward: 42.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 11.75363379048048, ratio_heur=99.99995474528508 ratio=94, k_srv_heur=7057987, k_srv=6686495, k_req=7057990
# Episode 212/4000, total reward: 46.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 20.888024166343065, ratio_heur=100.00005470848028 ratio=98, k_srv_heur=5457695, k_srv=5361946, k_req=5457692
# Episode 213/4000, total reward: 46.669, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 23.834654600919453, ratio_heur=100.0000318891382 ratio=99, k_srv_heur=14312579, k_srv=14229360, k_req=14312574
# Episode 214/4000, total reward: 45.256, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 45.45858100320191, ratio_heur=99.99999071936726 ratio=98, k_srv_heur=27297617, k_srv=26940715, k_req=27297619
# Episode 215/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 40.40632214417805, ratio_heur=100.00000364663981 ratio=100, k_srv_heur=10557498, k_srv=10557498, k_req=10557498
# Episode 216/4000, total reward: 46.862, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 42.484276214488375, ratio_heur=99.99998050146388 ratio=99, k_srv_heur=11100430, k_srv=11073565, k_req=11100432
# Episode 217/4000, total reward: 46.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 43.37595989564957, ratio_heur=100.00003636755972 ratio=98, k_srv_heur=9629407, k_srv=9460470, k_req=9629404
# Episode 218/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 16.298433800584455, ratio_heur=99.99994407858834 ratio=99, k_srv_heur=4258506, k_srv=4258506, k_req=4258508
# Episode 219/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 12.642668049419381, ratio_heur=100.00020062857882 ratio=100, k_srv_heur=2806660, k_srv=2806660, k_req=2806655
# Episode 220/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 17.835261556259688, ratio_heur=100.00009878551543 ratio=100, k_srv_heur=3959407, k_srv=3959407, k_req=3959403
# Episode 221/4000, total reward: 46.946, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 28.027827244515972, ratio_heur=99.99998491383393 ratio=99, k_srv_heur=7323202, k_srv=7316225, k_req=7323203
# Episode 222/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 5.8954253466754345, ratio_heur=100.00026364477644 ratio=100, k_srv_heur=3540178, k_srv=3540178, k_req=3540169
# Episode 223/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 3.935502005412367, ratio_heur=99.99925595274873 ratio=99, k_srv_heur=1028273, k_srv=1028273, k_req=1028281
# Episode 224/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 25.480038313685668, ratio_heur=100.00003596088567 ratio=100, k_srv_heur=5656535, k_srv=5656535, k_req=5656533
# Episode 225/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 19.52723065639372, ratio_heur=99.99996919637803 ratio=99, k_srv_heur=4335017, k_srv=4335017, k_req=4335018
# Episode 226/4000, total reward: 35.058, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 47.32427269842812, ratio_heur=99.99999363314309 ratio=91, k_srv_heur=28417955, k_srv=25895237, k_req=28417957
# Episode 227/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 59.97931853736328, ratio_heur=100.00004466879611 ratio=100, k_srv_heur=15671602, k_srv=15671602, k_req=15671595
# Episode 228/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 16.39289190520539, ratio_heur=99.99986861479076 ratio=99, k_srv_heur=3639195, k_srv=3639195, k_req=3639199
# Episode 229/4000, total reward: 46.929, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 57.07535526171524, ratio_heur=100.0000079238411 ratio=99, k_srv_heur=14912839, k_srv=14894213, k_req=14912838
# Episode 230/4000, total reward: 44.758, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 39.37593767954881, ratio_heur=100.00002903750185 ratio=97, k_srv_heur=23645034, k_srv=23129893, k_req=23645027
# Episode 231/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 15.043505529743339, ratio_heur=100.00003487818626 ratio=100, k_srv_heur=3339639, k_srv=3339639, k_req=3339637
# Episode 232/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 15.29846036421207, ratio_heur=100.00002170520173 ratio=100, k_srv_heur=3396238, k_srv=3396238, k_req=3396237
# Episode 233/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 4.835309554178506, ratio_heur=99.99971826389671 ratio=99, k_srv_heur=1263382, k_srv=1263382, k_req=1263385
# Episode 234/4000, total reward: 40.898, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 65.97473836773838, ratio_heur=100.00000098463029 ratio=96, k_srv_heur=39617456, k_srv=38145007, k_req=39617456
# Episode 235/4000, total reward: 45.130, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 64.90341383891152, ratio_heur=100.00002126161496 ratio=98, k_srv_heur=16958183, k_srv=16698922, k_req=16958179
# Episode 236/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 28.02495001779368, ratio_heur=100.00007531324067 ratio=100, k_srv_heur=6221505, k_srv=6221505, k_req=6221500
# Episode 237/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 62.314489394823674, ratio_heur=99.9999618800797 ratio=99, k_srv_heur=16281730, k_srv=16281181, k_req=16281737
# Episode 238/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 7.014459539715493, ratio_heur=100.00006292798993 ratio=100, k_srv_heur=4212145, k_srv=4212145, k_req=4212143
# Episode 239/4000, total reward: 46.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 49.49801014826895, ratio_heur=100.0000472453063 ratio=98, k_srv_heur=12933010, k_srv=12706115, k_req=12933004
# Episode 240/4000, total reward: 43.410, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 51.730379826672234, ratio_heur=99.99999183303929 ratio=97, k_srv_heur=31063797, k_srv=30186185, k_req=31063799
# Episode 241/4000, total reward: 44.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 61.46445053145096, ratio_heur=100.00003346473008 ratio=96, k_srv_heur=16059641, k_srv=15490553, k_req=16059636
# Episode 242/4000, total reward: 37.107, entropy_coef: 0.0078, demands: 1, mean_kbps_rand: 57.27599222810539, ratio_heur=99.99999559536765 ratio=94, k_srv_heur=34393906, k_srv=32559283, k_req=34393908
# ...
# Episode 3923/4000, total reward: -11.988, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 360.31071374119983, ratio_heur=45.18268567956381 ratio=21, k_srv_heur=133900257, k_srv=63809821, k_req=296353029
# Episode 3924/4000, total reward: -5.926, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 867.9095007365481, ratio_heur=31.289371683445466 ratio=19, k_srv_heur=294314007, k_srv=185613827, k_req=940619743
# Episode 3925/4000, total reward: -6.767, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 799.735717057219, ratio_heur=40.506963256898715 ratio=26, k_srv_heur=279171709, k_srv=185769937, k_req=689194367
# Episode 3926/4000, total reward: -10.224, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 419.15903960717196, ratio_heur=76.32720661261686 ratio=51, k_srv_heur=154617553, k_srv=104079457, k_req=202572006
# Episode 3927/4000, total reward: -16.356, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 976.9063771683449, ratio_heur=13.203666122660666 ratio=10, k_srv_heur=77456235, k_srv=59853337, k_req=586626735
# Episode 3928/4000, total reward: -19.838, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 935.7512710030929, ratio_heur=28.06318726612294 ratio=6, k_srv_heur=215987995, k_srv=46650531, k_req=769648841
# Episode 3929/4000, total reward: -5.785, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 818.7008018157989, ratio_heur=31.905780929680226 ratio=20, k_srv_heur=283096332, k_srv=180934527, k_req=887288521
# Episode 3930/4000, total reward: 17.279, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 149.64259332276424, ratio_heur=98.35080143546276 ratio=81, k_srv_heur=71126873, k_srv=59243729, k_req=72319567
# Episode 3931/4000, total reward: -4.566, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 414.5106966693262, ratio_heur=48.987834855146964 ratio=33, k_srv_heur=174992410, k_srv=118269579, k_req=357216054
# Episode 3932/4000, total reward: -7.211, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 541.2293278527179, ratio_heur=37.59869820867948 ratio=23, k_srv_heur=220543253, k_srv=135151642, k_req=586571515
# Episode 3933/4000, total reward: 12.587, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 526.8106926977663, ratio_heur=95.97443963771397 ratio=69, k_srv_heur=132105792, k_srv=95034961, k_req=137646849
# Episode 3934/4000, total reward: 0.153, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 170.27457224100485, ratio_heur=98.16563919242878 ratio=68, k_srv_heur=80781123, k_srv=55993859, k_req=82290630
# Episode 3935/4000, total reward: -12.018, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 83.84915457381074, ratio_heur=88.89494980311376 ratio=54, k_srv_heur=80782153, k_srv=49147700, k_req=90873726
# Episode 3936/4000, total reward: -9.615, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 566.7472293195779, ratio_heur=39.66201511342092 ratio=24, k_srv_heur=184882743, k_srv=111924469, k_req=466145611
# Episode 3937/4000, total reward: 16.430, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 547.7177823216715, ratio_heur=91.04816953929745 ratio=69, k_srv_heur=130298601, k_srv=99780065, k_req=143109523
# Episode 3938/4000, total reward: -9.172, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 750.6743189248342, ratio_heur=31.548814039077318 ratio=19, k_srv_heur=194790060, k_srv=120325202, k_req=617424349
# Episode 3939/4000, total reward: -16.525, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 441.58030227106195, ratio_heur=43.94965001937548 ratio=17, k_srv_heur=159623676, k_srv=62794018, k_req=363196694
# Episode 3940/4000, total reward: -9.880, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 936.8330316952771, ratio_heur=30.921359371046297 ratio=10, k_srv_heur=313949951, k_srv=111114662, k_req=1015317432
# Episode 3941/4000, total reward: -6.869, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 401.50979337140376, ratio_heur=43.26826311993071 ratio=28, k_srv_heur=188280460, k_srv=123180283, k_req=435146796
# Episode 3942/4000, total reward: -13.606, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 530.5840407429126, ratio_heur=48.05552839798387 ratio=19, k_srv_heur=219731725, k_srv=91377907, k_req=457245468
# Episode 3943/4000, total reward: 10.579, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 459.3104348656011, ratio_heur=95.82696191555156 ratio=71, k_srv_heur=115002088, k_srv=85448253, k_req=120010157
# Episode 3944/4000, total reward: -6.400, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 901.413248776251, ratio_heur=29.317187983362068 ratio=17, k_srv_heur=286408495, k_srv=173483665, k_req=976930311
# Episode 3945/4000, total reward: -4.354, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 235.828696991329, ratio_heur=39.7739998946091 ratio=33, k_srv_heur=56325470, k_srv=46949752, k_req=141613794
# Episode 3946/4000, total reward: 23.478, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 541.4619534680892, ratio_heur=95.83522162800394 ratio=83, k_srv_heur=115197597, k_srv=100308799, k_req=120203819
# Episode 3947/4000, total reward: -14.974, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 612.304236604571, ratio_heur=37.054056092994024 ratio=12, k_srv_heur=186610129, k_srv=64861587, k_req=503615930
# Episode 3948/4000, total reward: -13.469, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 902.2005523280149, ratio_heur=71.29829083789274 ratio=36, k_srv_heur=142801421, k_srv=72956255, k_req=200287299
# Episode 3949/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 33.00318958281138, ratio_heur=99.99995220601153 ratio=99, k_srv_heur=8623179, k_srv=8623179, k_req=8623183
# Episode 3950/4000, total reward: -17.021, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 497.017974041905, ratio_heur=38.56377837327593 ratio=13, k_srv_heur=157646331, k_srv=56662975, k_req=408793789
# Episode 3951/4000, total reward: 20.862, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 37.504442469924086, ratio_heur=98.37714723304198 ratio=84, k_srv_heur=30346536, k_srv=25977418, k_req=30847140
# Episode 3952/4000, total reward: -17.247, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 595.4920448266431, ratio_heur=37.46226488450017 ratio=11, k_srv_heur=183485685, k_srv=58098882, k_req=489788020
# Episode 3953/4000, total reward: -6.448, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 611.7194257389673, ratio_heur=41.61276505984521 ratio=28, k_srv_heur=219368402, k_srv=149164032, k_req=527166129
# Episode 3954/4000, total reward: 15.761, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 755.6319711222455, ratio_heur=89.31751364652129 ratio=68, k_srv_heur=176343170, k_srv=135174459, k_req=197434034
# Episode 3955/4000, total reward: -15.050, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 667.7343682868076, ratio_heur=37.53446950250087 ratio=10, k_srv_heur=271627452, k_srv=76875096, k_req=723674679
# Episode 3956/4000, total reward: -4.482, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 405.62888955171593, ratio_heur=46.79862204962285 ratio=33, k_srv_heur=163590157, k_srv=115599823, k_req=349561911
# Episode 3957/4000, total reward: -5.820, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 956.2443378503515, ratio_heur=28.601607837975397 ratio=16, k_srv_heur=296414177, k_srv=174900555, k_req=1036354945
# Episode 3958/4000, total reward: -11.968, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 700.6024123981379, ratio_heur=38.89238718668026 ratio=14, k_srv_heur=295308451, k_srv=106424508, k_req=759296286
# Episode 3959/4000, total reward: -7.887, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 846.6025828950188, ratio_heur=31.456719132164313 ratio=17, k_srv_heur=288624146, k_srv=158757598, k_req=917527810
# Episode 3960/4000, total reward: -13.667, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 230.06636997894466, ratio_heur=61.10121780397718 ratio=33, k_srv_heur=152350068, k_srv=82940680, k_req=249340478
# Episode 3961/4000, total reward: -8.449, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 248.96380087834845, ratio_heur=38.88519945318217 ratio=33, k_srv_heur=58133897, k_srv=49861551, k_req=149501349
# Episode 3962/4000, total reward: -13.094, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 344.9801013688241, ratio_heur=50.40589868748263 ratio=24, k_srv_heur=188458207, k_srv=91203782, k_req=373881256
# Episode 3963/4000, total reward: 17.650, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 235.5944037738538, ratio_heur=98.47769557016281 ratio=79, k_srv_heur=60619806, k_srv=49221795, k_req=61556889
# Episode 3964/4000, total reward: -9.718, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 913.7877928230811, ratio_heur=31.2305449575908 ratio=11, k_srv_heur=309289062, k_srv=114601521, k_req=990341548
# Episode 3965/4000, total reward: -6.326, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 614.7607683363126, ratio_heur=42.32667234266034 ratio=27, k_srv_heur=224241245, k_srv=146053000, k_req=529787090
# Episode 3966/4000, total reward: -13.728, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 760.8227781660987, ratio_heur=78.53673869497126 ratio=35, k_srv_heur=132649828, k_srv=59654494, k_req=168901625
# Episode 3967/4000, total reward: -9.758, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 359.5241968832397, ratio_heur=47.01145056034756 ratio=27, k_srv_heur=183177203, k_srv=107763449, k_req=389643802
# Episode 3968/4000, total reward: 1.366, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 64.36451903784636, ratio_heur=92.24163373186244 ratio=65, k_srv_heur=64344756, k_srv=45649486, k_req=69756739
# Episode 3969/4000, total reward: -3.248, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 770.6251248579871, ratio_heur=77.61140786895177 ratio=47, k_srv_heur=132775837, k_srv=80673138, k_req=171077733
# Episode 3970/4000, total reward: -12.713, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 359.650558807988, ratio_heur=48.327850595141996 ratio=22, k_srv_heur=188372658, k_srv=87132094, k_req=389780750
# Episode 3971/4000, total reward: -10.995, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 326.87231879231354, ratio_heur=50.84952239924061 ratio=28, k_srv_heur=180137723, k_srv=101902924, k_req=354256470
# Episode 3972/4000, total reward: 41.224, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 88.41666075860472, ratio_heur=99.86315724075698 ratio=96, k_srv_heur=23070186, k_srv=22323322, k_req=23101799
# Episode 3973/4000, total reward: 24.056, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 327.35699449628544, ratio_heur=99.05915481379814 ratio=80, k_srv_heur=71989070, k_srv=58691327, k_req=72672809
# Episode 3974/4000, total reward: -6.248, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 987.2690486774176, ratio_heur=38.267060667588396 ratio=23, k_srv_heur=325578601, k_srv=199444948, k_req=850806401
# Episode 3975/4000, total reward: -13.101, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 512.0625563656893, ratio_heur=44.0670405880167 ratio=17, k_srv_heur=244555003, k_srv=95518074, k_req=554961260
# Episode 3976/4000, total reward: -13.913, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 800.8890414807435, ratio_heur=43.670556105145415 ratio=16, k_srv_heur=301409058, k_srv=110732380, k_req=690188276
# Episode 3977/4000, total reward: -13.046, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 782.8143939162253, ratio_heur=61.77649851350891 ratio=34, k_srv_heur=233712899, k_srv=129576830, k_req=378320082
# Episode 3978/4000, total reward: 43.441, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 32.30451277421156, ratio_heur=99.99999002271346 ratio=97, k_srv_heur=26570232, k_srv=25843348, k_req=26570234
# Episode 3979/4000, total reward: -18.457, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 969.7694379975038, ratio_heur=56.402948306831014 ratio=26, k_srv_heur=264344873, k_srv=123793453, k_req=468672084
# Episode 3980/4000, total reward: -9.049, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 567.5202359838976, ratio_heur=21.498706758877972 ratio=18, k_srv_heur=73266019, k_srv=63974741, k_req=340792681
# Episode 3981/4000, total reward: -8.107, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 658.9968072330171, ratio_heur=35.75899424112747 ratio=20, k_srv_heur=193820986, k_srv=112502629, k_req=542020241
# Episode 3982/4000, total reward: -12.114, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 582.4293775115734, ratio_heur=20.749572732195222 ratio=16, k_srv_heur=72570704, k_srv=58273524, k_req=349745536
# Episode 3983/4000, total reward: 46.357, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 60.29821604281101, ratio_heur=100.00000580064214 ratio=98, k_srv_heur=13386123, k_srv=13235216, k_req=13386122
# Episode 3984/4000, total reward: -21.129, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 629.7821256583698, ratio_heur=19.08319760272811 ratio=13, k_srv_heur=72168949, k_srv=50410956, k_req=378180592
# Episode 3985/4000, total reward: 5.437, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 804.6160975078485, ratio_heur=91.55321712114947 ratio=59, k_srv_heur=192474864, k_srv=124130059, k_req=210232769
# Episode 3986/4000, total reward: -6.184, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 243.46026527440048, ratio_heur=54.61201546128471 ratio=37, k_srv_heur=109357479, k_srv=75712793, k_req=200244356
# Episode 3987/4000, total reward: 17.669, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 973.4148291038342, ratio_heur=93.84353924730445 ratio=73, k_srv_heur=238678902, k_srv=186487788, k_req=254337063
# Episode 3988/4000, total reward: -13.055, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 700.1026876779378, ratio_heur=65.48672342309236 ratio=39, k_srv_heur=221572367, k_srv=133684536, k_req=338347005
# Episode 3989/4000, total reward: 45.126, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 35.10773092791552, ratio_heur=99.99999708342213 ratio=98, k_srv_heur=30255057, k_srv=29790487, k_req=30255057
# Episode 3990/4000, total reward: 29.997, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 256.8770683470364, ratio_heur=99.26737047016141 ratio=86, k_srv_heur=56608569, k_srv=49185115, k_req=57026360
# Episode 3991/4000, total reward: -9.221, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 531.7018771773513, ratio_heur=68.21299950155993 ratio=44, k_srv_heur=175281440, k_srv=114347456, k_req=256961930
# Episode 3992/4000, total reward: -7.521, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 958.8523632917943, ratio_heur=30.238985385451215 ratio=14, k_srv_heur=314237930, k_srv=155504248, k_req=1039181461
# Episode 3993/4000, total reward: -8.030, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 455.7248067974537, ratio_heur=76.47251785192371 ratio=49, k_srv_heur=168425812, k_srv=108285375, k_req=220243582
# Episode 3994/4000, total reward: -7.434, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 856.2777576692613, ratio_heur=31.256761910290475 ratio=17, k_srv_heur=290066981, k_srv=161852966, k_req=928013535
# Episode 3995/4000, total reward: -12.795, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 745.3388093773902, ratio_heur=41.73618328636839 ratio=15, k_srv_heur=268078320, k_srv=102442132, k_req=642316328
# Episode 3996/4000, total reward: 4.292, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 127.96825248881665, ratio_heur=81.44568697576796 ratio=62, k_srv_heur=89818450, k_srv=69191594, k_req=110280180
# Episode 3997/4000, total reward: -5.934, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 528.7801569988582, ratio_heur=40.08080133297263 ratio=24, k_srv_heur=174318604, k_srv=108593710, k_req=434917961
# Episode 3998/4000, total reward: -13.306, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 412.6149134921113, ratio_heur=51.18874546440757 ratio=26, k_srv_heur=182018124, k_srv=92779565, k_req=355582310
# Episode 3999/4000, total reward: -12.734, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 210.8132640042417, ratio_heur=43.871833262945955 ratio=31, k_srv_heur=55538305, k_srv=40318153, k_req=126592168
# Episode 4000/4000, total reward: 24.781, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 275.91772895885487, ratio_heur=98.1441256908889 ratio=83, k_srv_heur=60116576, k_srv=51017905, k_req=61253361
