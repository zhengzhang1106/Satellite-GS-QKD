# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)
#gnodes, hnodes, links, demands = init_setup_training_online()

nodes = gnodes + hnodes

n_hnodes  = len(hnodes)
n_demands = len(demands)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.2
LR = 1e-4 #3e-4
EPOCHS = 10
BATCH_SIZE = 128
ENTROPY_COEF_INITIAL = 0.01         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.999 #0.995               # >>> CHANGE
VALUE_COEF = 0.5

# Training hyperparams
num_episodes = 4000
episode_len = len(syst.T)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# %%
def build_state_vector_for_time(state_t, links, t, gnodes, hnodes, max_links=20, normalize=True):
    link_features = []
    total_nodes = len(gnodes) + len(hnodes)
    
    # Pre-calculate coordinate bounds for normalization (Example ranges)
    # Better yet, use the service area limits (e.g., 270-285 lon, 40-55 lat)
    LON_MIN, LON_MAX = 276.0, 285.0
    LAT_MIN, LAT_MAX = 46.0, 50.0
    ALT_MAX = 25.0

    def norm_lon(l): return (l - LON_MIN) / (LON_MAX - LON_MIN)
    def norm_lat(l): return (l - LAT_MIN) / (LAT_MAX - LAT_MIN)
    def norm_alt(a): return a / ALT_MAX

    # 1. Process Links with Geometric Context
    for idx_l in range(max_links):
        if idx_l < len(links):
            l = links[idx_l]
            
            # Key Buffer (QKP) - Log Scaled
            qkp_val = np.log10(1 + state_t.get("a", {}).get(idx_l, 0.0)) / 8.0
            
            # Current Capacity (K_MAX) - Normalized by a realistic max (e.g., 100Mbps)
            kmax_val = np.log10(1 + l.K_MAX[t]) / 6.0 
            
            # GEOMETRIC ENCODING: Position of Node 1 and Node 2
            # This is much more powerful than normalized IDs
            n1_coords = [norm_lon(l.n1.lg[t] if isinstance(l.n1, hap) else l.n1.lg),
                         norm_lat(l.n1.la[t] if isinstance(l.n1, hap) else l.n1.la)]
            
            n2_coords = [norm_lon(l.n2.lg[t] if isinstance(l.n2, hap) else l.n2.lg),
                         norm_lat(l.n2.la[t] if isinstance(l.n2, hap) else l.n2.la)]
            
            # Add features: [QKP, Capacity, Src_Lon, Src_Lat, Dst_Lon, Dst_Lat, Active]
            link_features.extend([qkp_val, kmax_val] + n1_coords + n2_coords + [1.0])
        else:
            # Padding (7 features per link now)
            link_features.extend([0.0] * 7)

    # 2. Process Demands with Geometric Pairs
    d_vec = []
    demands_list = state_t.get("demands", [])
    
    # Instead of iterating all pairs (which is O(N^2)), 
    # you might want to only encode the 'Active' demands to save space, 
    # but for a fixed-size MLP input, the GS-to-GS grid is fine.
    for src in gnodes:
        for dst in gnodes:
            if src == dst: continue
            
            matched = next((d for d in demands_list if d.n1 == src and d.n2 == dst), None)
            
            # Geometric info for the demand pair
            src_pos = [norm_lon(src.lg), norm_lat(src.la)]
            dst_pos = [norm_lon(dst.lg), norm_lat(dst.la)]
            
            if matched:
                kreq = np.log10(1 + float(matched.K_REQ[t])) / 5.0
                d_vec.extend(src_pos + dst_pos + [kreq, 1.0])
            else:
                d_vec.extend(src_pos + dst_pos + [0.0, 0.0])

    return np.concatenate([link_features, d_vec]).astype(np.float32)

def scarq_policy(state, links, t):
    """
    Adapted Heuristic: Scarcity & Contention Aware (1-hop only)
    Converts the offline logic into an online action selection for time t.
    """
    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    
    # 1. Initialize constraints and action
    #action = np.zeros(n_links, dtype=int)
    action_matrix = np.zeros((n_demands, len(links)), dtype=int)
    max_cnct_up = [1] * n_hnodes  # HAP TX limits (assuming 1 for this logic)
    max_cnct_dwn = [1] * n_hnodes # HAP RX limits
    
    # Current QKP bits from state (assumed stored as raw bits or decoded)
    # If state_t["a"] is log-normalized, decode it first!
    qkp_s = [state[t]["a"].get(i, 0.0) for i in range(n_links)]

    # ---------------------------------------------------------
    # Step 1: Enumerate feasible 1-hop paths per demand
    # ---------------------------------------------------------
    feasible_paths = {d: [] for d in demands}
    link_usage = [0] * n_links
    
    for d in demands:
        src, dst = d.n1, d.n2
        for idx_l1, l1 in enumerate(links):
            if l1.n1 != src: continue
            for idx_l2, l2 in enumerate(links):
                if l2.n2 != dst: continue
                
                # Check if they share a HAP (mid-point)
                if l1.n2 == l2.n1 and l1.n2 in hnodes:
                    mid = l1.n2
                    
                    fresh_ok = (l1.K_MAX[t] >= d.K_REQ[t] and 
                                l2.K_MAX[t] >= d.K_REQ[t])
                    
                    qkp_ok = (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                              qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t])
                    
                    if fresh_ok or qkp_ok:
                        feasible_paths[d].append((idx_l1, idx_l2, mid))
                        link_usage[idx_l1] += 1
                        link_usage[idx_l2] += 1

    # ---------------------------------------------------------
    # Step 2: Order demands by Scarcity
    # (Least paths first, then largest requirement)
    # ---------------------------------------------------------
    ordered_demands = sorted(
        demands,
        key=lambda d: (len(feasible_paths[d]), -d.K_REQ[t])
    )

    # ---------------------------------------------------------
    # Step 3: Greedy Allocation with Contention Awareness
    # ---------------------------------------------------------
    for d in ordered_demands:
        # Sort paths for this demand by least link contention
        paths = sorted(
            feasible_paths[d],
            key=lambda p: link_usage[p[0]] + link_usage[p[1]]
        )
        
        for idx_l1, idx_l2, mid in paths:
            mid_idx = hnodes.index(mid)
            
            # Respect HAP connection limits
            if max_cnct_up[mid_idx] == 0 or max_cnct_dwn[mid_idx] == 0:
                continue
                
            # Path selection logic
            # Priority: Can we serve it with ONLY stored bits? (No action needed)
            if (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
                
                # Update local tracker (bits effectively consumed)
                qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                
                # Consume HAP capacity even if using QKP? 
                # (Your offline logic suggests yes to prevent multi-use)
                #max_cnct_up[mid_idx] = 0
                #max_cnct_dwn[mid_idx] = 0
                break
            
            # If we need fresh keys, we activate the links (set action to 1)
            else:
                # action[idx_l1] = 1
                # action[idx_l2] = 1
                action[demands.index(d)][idx_l1] = 1
                action[demands.index(d)][idx_l2] = 1
                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0
                # Note: We don't update qkp_s here because fresh generation 
                # happens in the environment 'step', not the heuristic.
                break


    # --------------------------------------------------
    # Step 4: Solve optimization with heuristic action
    # --------------------------------------------------
    solution_heur, _, A_next_heur = online_new(
        gnodes,
        hnodes,
        links,
        state,
        action_matrix,
        t,
        f_qkp,
        0
    )

    # --------------------------------------------------
    # Step 5: Compute total served keys
    # --------------------------------------------------
    if "r_h" not in solution_heur:
        return 0.0, solution_heur, A_next_heur

    k_srv_heur = sum(
        solution_heur["r_h"][idx_d]
        for idx_d, _ in enumerate(demands)
    )

    return k_srv_heur, solution_heur, A_next_heur

def mcr_policy(state, links, t, n_samples=3):
    """
    Online Monte Carlo 1-hop random heuristic.
    Samples multiple random feasible allocations and keeps the best one.
    """

    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    n_demands = len(demands)

    best_reward = -1
    best_solution = None
    best_A_next = None

    # ------------------------------------------------------------
    # Monte Carlo sampling
    # ------------------------------------------------------------
    for _ in range(n_samples):

        # action_matrix[d, l]
        action_matrix = np.zeros((n_demands, n_links), dtype=int)

        max_cnct_up  = [1] * n_hnodes
        max_cnct_dwn = [1] * n_hnodes

        shuffled_demands = random.sample(demands, len(demands))

        # --------------------------------------------------------
        # Random feasible allocation (1-hop only)
        # --------------------------------------------------------
        for d in shuffled_demands:

            src, dst = d.n1, d.n2
            feasible_pairs = []

            for idx_l1, l1 in enumerate(links):
                if l1.n1 != src:
                    continue

                for idx_l2, l2 in enumerate(links):
                    if l2.n2 != dst:
                        continue

                    if l1.n2 == l2.n1 and l1.n2 in hnodes:
                        mid = l1.n2
                        mid_idx = hnodes.index(mid)

                        if (
                            max_cnct_up[mid_idx] > 0 and
                            max_cnct_dwn[mid_idx] > 0 and
                            l1.K_MAX[t] > 0 and
                            l2.K_MAX[t] > 0
                        ):
                            feasible_pairs.append((idx_l1, idx_l2, mid_idx))

            if feasible_pairs:
                idx_l1, idx_l2, mid_idx = random.choice(feasible_pairs)

                action_matrix[demands.index(d)][idx_l1] = 1
                action_matrix[demands.index(d)][idx_l2] = 1

                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0

        # --------------------------------------------------------
        # Evaluate via online_new
        # --------------------------------------------------------
        solution, reward, A_next = online_new(
            gnodes,
            hnodes,
            links,
            state,
            action_matrix,
            t,
            f_qkp,
            0
        )

        if "r_h" in solution:
            total_served = sum(solution["r_h"][i] for i in range(n_demands))
        else:
            total_served = 0.0

        # Keep best sample
        if total_served > best_reward:
            best_reward = total_served
            best_solution = solution
            best_A_next = A_next

    return best_reward, best_solution, best_A_next

class ResidualBlock(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.ln = nn.LayerNorm(size)
        self.fc = nn.Linear(size, size)

    def forward(self, x):
        # Residual connection helps gradients flow back to early layers
        return x + F.silu(self.fc(self.ln(x)))

class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Linear(dim, dim)
        )
        self.silu = nn.SiLU()

    def forward(self, x):
        return self.silu(x + self.net(x))

class ActorCriticCategorical(nn.Module):
    def __init__(self, state_dim, n_demands_max, n_haps, hidden=64):
        super().__init__()
        self.n_haps = n_haps
        self.n_choices = n_demands_max + 1 # Demands + Idle
        
        self.encoder = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.SiLU(),
        )
        
        # (One set of choices for RX/Uplink, one for TX/Downlink)
        self.actor_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 2 * n_haps * self.n_choices) 
        )
        
        self.critic_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 1)
        )
        
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            # Orthogonal init helps prevents early policy collapse
            nn.init.orthogonal_(m.weight, gain=0.01) 
            nn.init.constant_(m.bias, 0)

    def forward(self, x):
        features = self.encoder(x)
        
        # index 0: RX (Uplink), index 1: TX (Downlink)
        logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        probs = torch.softmax(logits, dim=-1) 
        
        value = self.critic_head(features)
        return probs, value

class PPOBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        self.is_terminals = []
    
    def clear(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]
        del self.is_terminals[:]

class PPOAgent:
    def __init__(self, state_dim, n_demands, n_hnodes, lr=1e-4):
        self.gamma = 0.99
        self.lam = 0.95
        self.eps_clip = 0.2
        self.K_epochs = 10
        self.n_haps = n_hnodes
        self.n_demands = n_demands
        
        self.model = ActorCriticCategorical(state_dim, n_demands, n_hnodes).to(device=DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        self.MseLoss = nn.MSELoss()

    def select_action(self, state_vec):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        with torch.no_grad():
            probs, value = self.model(s) # [1, 2, n_haps, n_choices]
        
        dist = Categorical(probs)
        action = dist.sample() # [1, 2, n_haps]
        
        # Sum log_prob across BOTH heads and ALL HAPs
        logp = dist.log_prob(action).sum(dim=[1, 2])
        
        return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0)

    # ... compute_gae remains exactly the same as your previous code ...

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef):
        #advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        if advantages.std() < 1e-5:
            advantages = advantages - advantages.mean()
        else:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        for _ in range(self.K_epochs):
            probs, values = self.model(states.to(DEVICE))
            dist = Categorical(probs)
            
            # logp is summed across the choices of all HAPs
            #new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=-1)
            new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
            entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
            ratio = torch.exp(new_logps - old_logps)
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
            loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

    def compute_gae(self, rewards, values, dones):
        """
        Generalized Advantage Estimation
        rewards: [T], values: [T+1], dones: [T]
        """
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            # TD Error: delta = r_t + gamma * V(s_t+1) - V(s_t)
            delta = rewards[t] + self.gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + self.gamma * self.lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
            
        returns = adv + values[:-1]
        return adv, returns

# %%
def get_z_from_demand_choices(hap_picks, demands, links, hnodes):
    # Initialize z_dict with zeros
    z = {idx_d: {idx_l: 0 for idx_l in range(len(links))} for idx_d in range(len(demands))}
    
    rx_picks = hap_picks[0] # Uplink choices [n_haps]
    tx_picks = hap_picks[1] # Downlink choices [n_haps]

    # Run this once after initializing your 'links' and 'hnodes'
    UPLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n2 in hnodes}
    DOWNLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n1 in hnodes}

    for hap_idx, selected_hap in enumerate(hnodes):
        
        # --- Handle Uplink (RX: GS -> HAP) ---
        rx_val = rx_picks[hap_idx]
        if rx_val > 0:
            d_idx = int(rx_val - 1)
            if d_idx < len(demands):
                src_gs = demands[d_idx].n1
                # Use the pre-computed lookup
                l_idx = UPLINK_LOOKUP.get((src_gs, selected_hap))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1

        # --- Handle Downlink (TX: HAP -> GS) ---
        tx_val = tx_picks[hap_idx]
        if tx_val > 0:
            d_idx = int(tx_val - 1)
            if d_idx < len(demands):
                dst_gs = demands[d_idx].n2
                # Use the pre-computed lookup
                l_idx = DOWNLINK_LOOKUP.get((selected_hap, dst_gs))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1
                        
    return z

# %% [markdown]
# ## Training Loop

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(state[0], links, 0, gnodes, hnodes)
state_dim = len(state_vector_example)

agent = PPOAgent(state_dim, n_demands, n_hnodes, lr=LR)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

#WARM_EPISODES  = 500
DECAY_EPISODES = 300
k = 1

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf = []
    actions_buf = []
    logps_buf = []
    rewards_buf = []
    dones_buf = []
    values_buf = []

    total_reward = 0.0

    # Calculate a 'progress' factor from 0.0 to 1.0
    progress = ep / num_episodes
    
    # Start with a max of 50 kbps, end with 1000 kbps
    max_now = 10 + (990 * progress) 
    
    # Still use randomness, but within an ever-expanding "boundary"
    mean_kbps_rand = random.uniform(1, max_now)

    #mean_kbps_rand = random.randint(1, 1 + int(10 * ep/num_episodes))
    #mean_kbps_rand = random.randint(1, 1000)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.01*mean_kbps_rand, amp=0.5, noise_std=0.0, pattern="stadium")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    # Before the for t in syst.T: loop
    if ep < num_episodes / 10:
        k = 1  # Only 1 demand: let the agent learn basic RX/TX pairing first
    elif ep < 2 * num_episodes / 10:
        k = random.randint(1, 2) # Slightly more complex
    else:
        k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity

    ################
    k=3
    ################
    demands = random.sample(demands_space, k)
    random.shuffle(demands)

    state[0]["demands"] = demands.copy()

    k_srv = 0
    k_req = 0

    for t in syst.T:
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)
        
        # Inside the for t in syst.T: loop
        hap_choices, logp, value = agent.select_action(s_vec) 
        
        # 2. Convert to the dictionary format for Gurobi
        z_dict = get_z_from_demand_choices(hap_choices, demands, links, hnodes)

        #print(z_dict)

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes

        k_srv_heur1, k_srv_heur2 = -math.inf, -math.inf
        k_srv_heur1, _, _ = scarq_policy(state, links, t)
        k_srv_heur2, _, _ = mcr_policy(state, links, t)
        
        k_srv_heur = max(k_srv_heur1, k_srv_heur2)

        solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, k_srv_heur)

        reward[t] = reward_t
        total_reward += reward_t

        k_srv += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))
        k_req += sum(d.K_REQ[t] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        # Ensure hap_choices is converted to a tensor for the buffer
        # Shape: [2, n_haps]
        actions_buf.append(torch.tensor(hap_choices, dtype=torch.long, device=DEVICE))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(state[-1], links, t, gnodes, hnodes)
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor.view(-1), final_value.view(-1)])  # Now shape is [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}, mean_kbps_rand: {mean_kbps_rand}, ratio_heur={k_srv_heur/k_req*1e2} ratio={int(k_srv/k_req*1e2)}, k_srv={int(k_srv)}, k_req={int(k_req)}")

# === Plot learning curve ===
plt.figure(figsize=(6,3))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/4000, total reward: -8.416, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 6.69369307227237, ratio_heur=0.0009746667217220673 ratio=38, k_srv=3261751, k_req=8568159
# Episode 2/4000, total reward: 2.845, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 6.668711952957031, ratio_heur=0.0009746670726755624 ratio=63, k_srv=3817364, k_req=6012104
# Episode 3/4000, total reward: 35.768, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 7.588710308848894, ratio_heur=0.0009746641893319122 ratio=92, k_srv=4978830, k_req=5387701
# Episode 4/4000, total reward: 46.000, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 4.637729196067175, ratio_heur=0.0009746983458400539 ratio=98, k_srv=4168420, k_req=4242851
# Episode 5/4000, total reward: -4.830, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 7.438123631875703, ratio_heur=0.0009746613816479451 ratio=66, k_srv=5606864, k_req=8487152
# Episode 6/4000, total reward: -2.568, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 8.945046707994166, ratio_heur=0.0009746631182458968 ratio=63, k_srv=6292366, k_req=9855200
# Episode 7/4000, total reward: -12.078, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 9.743030996322762, ratio_heur=0.0009746691516187573 ratio=29, k_srv=3798720, k_req=12808551
# Episode 8/4000, total reward: -1.620, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 2.1537354217006905, ratio_heur=0.0009746481251653424 ratio=60, k_srv=1702648, k_req=2831380
# Episode 9/4000, total reward: 35.029, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 10.70820627301592, ratio_heur=0.000974675486039431 ratio=92, k_srv=7067087, k_req=7602427
# Episode 10/4000, total reward: -1.070, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 5.342773182777835, ratio_heur=0.0009746603331053255 ratio=64, k_srv=4450422, k_req=6885065
# Episode 11/4000, total reward: 9.632, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 4.713525378054856, ratio_heur=0.0009746772451702914 ratio=72, k_srv=3919710, k_req=5378293
# Episode 12/4000, total reward: -11.309, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 11.629607124599438, ratio_heur=0.0009746729782234155 ratio=45, k_srv=5880198, k_req=12812912
# Episode 13/4000, total reward: -2.962, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 11.088296519049814, ratio_heur=0.000974661706455128 ratio=61, k_srv=6371121, k_req=10432132
# Episode 14/4000, total reward: 29.870, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 11.171283591930683, ratio_heur=0.0009746667997069554 ratio=90, k_srv=9242242, k_req=10220108
# Episode 15/4000, total reward: 42.286, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 3.218250942511799, ratio_heur=0.0009746508106769679 ratio=95, k_srv=2804003, k_req=2944233
# Episode 16/4000, total reward: 32.664, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 2.2929235677559654, ratio_heur=0.0009746383256018621 ratio=90, k_srv=1818480, k_req=2007616
# Episode 17/4000, total reward: -8.655, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 7.358924375054651, ratio_heur=0.0009746632112733945 ratio=40, k_srv=3919323, k_req=9674316
# Episode 18/4000, total reward: 16.212, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 2.6748460752551635, ratio_heur=0.0009746488428220355 ratio=81, k_srv=2399693, k_req=2947010
# Episode 19/4000, total reward: -9.763, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 7.510864173621595, ratio_heur=0.0009746671449257819 ratio=55, k_srv=3730913, k_req=6771337
# Episode 20/4000, total reward: -3.975, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 3.349446069550827, ratio_heur=0.0009746593240300868 ratio=55, k_srv=1952855, k_req=3514150
# Episode 21/4000, total reward: -6.409, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 4.93556186847741, ratio_heur=0.000974672145515227 ratio=49, k_srv=3594240, k_req=7305841
# Episode 22/4000, total reward: 21.537, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 2.480555298915203, ratio_heur=0.0009746562191922301 ratio=84, k_srv=2699298, k_req=3196614
# Episode 23/4000, total reward: 0.883, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 4.705171471096226, ratio_heur=0.0009746664229071227 ratio=66, k_srv=4040379, k_req=6063407
# Episode 24/4000, total reward: 0.408, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 7.365094317581343, ratio_heur=0.000974664598396798 ratio=61, k_srv=4235760, k_req=6929255
# Episode 25/4000, total reward: -3.210, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 15.004776544132728, ratio_heur=0.0009746694340180286 ratio=47, k_srv=7778145, k_req=16261821
# Episode 26/4000, total reward: 37.719, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 8.546452881118174, ratio_heur=0.0009746679256539529 ratio=95, k_srv=7435483, k_req=7778751
# Episode 27/4000, total reward: -8.539, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 12.956648769051943, ratio_heur=0.0009746676638562488 ratio=28, k_srv=4785939, k_req=17033293
# Episode 28/4000, total reward: 39.754, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 6.894423841892052, ratio_heur=0.0009746701298978165 ratio=95, k_srv=4695265, k_req=4894784
# Episode 29/4000, total reward: -9.230, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 12.453907358600418, ratio_heur=0.0009746736140915453 ratio=50, k_srv=8054182, k_req=16048962
# Episode 30/4000, total reward: 2.316, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 6.877971101978709, ratio_heur=0.0009746814991105023 ratio=70, k_srv=5550415, k_req=7847999
# Episode 31/4000, total reward: 42.713, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.0357812850775905, ratio_heur=0.0009747116863140114 ratio=95, k_srv=904910, k_req=942740
# Episode 32/4000, total reward: 38.833, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.228787744626553, ratio_heur=0.0009747070029052379 ratio=94, k_srv=1480014, k_req=1567137
# Episode 33/4000, total reward: -3.298, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 10.466477732146945, ratio_heur=0.0009746616996958882 ratio=50, k_srv=5760365, k_req=11343320
# Episode 34/4000, total reward: -2.309, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 2.998821135193653, ratio_heur=0.000974671074131369 ratio=66, k_srv=1873533, k_req=2821362
# Episode 35/4000, total reward: 41.414, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 11.952125616352465, ratio_heur=0.000974670411529409 ratio=95, k_srv=10405522, k_req=10934465
# Episode 36/4000, total reward: -3.586, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 13.238933136132452, ratio_heur=0.000974669581469449 ratio=51, k_srv=7345515, k_req=14348041
# Episode 37/4000, total reward: -8.426, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 15.093501400390846, ratio_heur=0.000974670057994114 ratio=49, k_srv=9426707, k_req=18928251
# Episode 38/4000, total reward: -10.883, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 17.57681935612979, ratio_heur=0.0009746681776014809 ratio=22, k_srv=5075807, k_req=22498939
# Episode 39/4000, total reward: -9.191, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 15.675319885885903, ratio_heur=0.0009746632745846295 ratio=59, k_srv=10659153, k_req=17886074
# Episode 40/4000, total reward: -5.901, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 12.253743232662199, ratio_heur=0.0009746698483691611 ratio=57, k_srv=6301322, k_req=11047227
# Episode 41/4000, total reward: -2.696, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 11.575184119012226, ratio_heur=0.0009746667826264278 ratio=60, k_srv=6551573, k_req=10836011
# Episode 42/4000, total reward: -1.140, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 11.616268102304257, ratio_heur=0.0009746760284965852 ratio=65, k_srv=8659733, k_req=13254558
# Episode 43/4000, total reward: 30.968, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 14.357333854874778, ratio_heur=0.0009746733725718118 ratio=92, k_srv=12032978, k_req=13067659
# Episode 44/4000, total reward: 34.857, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 14.966049110788743, ratio_heur=0.000974669019113813 ratio=91, k_srv=12033050, k_req=13103832
# Episode 45/4000, total reward: 26.145, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 10.53875156957037, ratio_heur=0.0009746601711344622 ratio=90, k_srv=8306719, k_req=9227421
# Episode 46/4000, total reward: -7.773, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 20.94912924925098, ratio_heur=0.0009746723777787654 ratio=48, k_srv=12726685, k_req=26271597
# Episode 47/4000, total reward: -8.588, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 11.278410550211232, ratio_heur=0.0009746692726603852 ratio=52, k_srv=7364899, k_req=14143874
# Episode 48/4000, total reward: 35.789, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 18.88445376460092, ratio_heur=0.0009746669954371267 ratio=91, k_srv=15167577, k_req=16534672
# Episode 49/4000, total reward: -6.548, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 15.765255849969174, ratio_heur=0.0009746693241987486 ratio=26, k_srv=5363938, k_req=20180074
# Episode 50/4000, total reward: -4.212, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 11.494989571842789, ratio_heur=0.0009746680523260912 ratio=61, k_srv=6615136, k_req=10814758
# Episode 51/4000, total reward: -0.093, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 22.043626228560893, ratio_heur=0.0009746651127236019 ratio=44, k_srv=10628460, k_req=23890359
# Episode 52/4000, total reward: -7.832, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 20.742246752956646, ratio_heur=0.0009746713497411826 ratio=50, k_srv=13261519, k_req=26012152
# Episode 53/4000, total reward: -4.840, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 17.279111389612584, ratio_heur=0.0009746706519952932 ratio=43, k_srv=7868979, k_req=18128790
# Episode 54/4000, total reward: -4.239, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 17.023170625233654, ratio_heur=0.0009746692491650585 ratio=26, k_srv=5859433, k_req=21710544
# Episode 55/4000, total reward: -8.489, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 3.1735492252247672, ratio_heur=0.0009746729736676923 ratio=50, k_srv=2115971, k_req=4172066
# Episode 56/4000, total reward: 8.242, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 4.728485644943329, ratio_heur=0.0009746730055918411 ratio=70, k_srv=3156087, k_req=4448671
# Episode 57/4000, total reward: -6.057, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 21.111954777049743, ratio_heur=0.0009746679370126233 ratio=46, k_srv=8775286, k_req=19033251
# Episode 58/4000, total reward: -11.724, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 6.274808632328978, ratio_heur=0.0009746613016086198 ratio=51, k_srv=4059421, k_req=7839646
# Episode 59/4000, total reward: -6.614, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 22.633030561852102, ratio_heur=0.0009746649406947015 ratio=25, k_srv=7687809, k_req=29754225
# Episode 60/4000, total reward: -7.258, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 24.573220682397604, ratio_heur=0.0009746672750987446 ratio=48, k_srv=11297235, k_req=23119069
# Episode 61/4000, total reward: -2.427, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 9.867744459115317, ratio_heur=0.0009746602684559142 ratio=61, k_srv=7643316, k_req=12328603
# Episode 62/4000, total reward: -13.589, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 10.451623400697459, ratio_heur=0.0009746780924381792 ratio=43, k_srv=4780708, k_req=10965569
# Episode 63/4000, total reward: 3.620, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 6.524247207697128, ratio_heur=0.0009746721502868014 ratio=67, k_srv=4115932, k_req=6138166
# Episode 64/4000, total reward: 28.081, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 19.47674043738076, ratio_heur=0.0009746698454323169 ratio=88, k_srv=15053947, k_req=17053261
# Episode 65/4000, total reward: -2.252, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 12.640678315962408, ratio_heur=0.0009746666042890848 ratio=34, k_srv=5558135, k_req=16180507
# Episode 66/4000, total reward: -5.164, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 13.987683532989651, ratio_heur=0.0009746645498885294 ratio=46, k_srv=6856306, k_req=14675510
# Episode 67/4000, total reward: -5.871, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 18.808915360136638, ratio_heur=0.000974669742488892 ratio=58, k_srv=12099412, k_req=20722711
# Episode 68/4000, total reward: -1.827, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 14.616332882837753, ratio_heur=0.0009746670991948896 ratio=57, k_srv=10494010, k_req=18261414
# Episode 69/4000, total reward: -8.697, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 23.556362413357263, ratio_heur=0.0009746683773188924 ratio=23, k_srv=7231847, k_req=30968071
# Episode 70/4000, total reward: -5.880, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 21.810330742321906, ratio_heur=0.0009746668992802485 ratio=48, k_srv=13290157, k_req=27351600
# Episode 71/4000, total reward: -5.423, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 19.58111259512573, ratio_heur=0.0009746712546094055 ratio=52, k_srv=9538219, k_req=18330693
# Episode 72/4000, total reward: -7.894, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 23.936843913870916, ratio_heur=0.000974667074686328 ratio=35, k_srv=8880039, k_req=25113908
# Episode 73/4000, total reward: -1.862, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 12.596987351728865, ratio_heur=0.0009746697721110234 ratio=51, k_srv=7040669, k_req=13652316
# Episode 74/4000, total reward: 29.964, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 25.433499123234974, ratio_heur=0.0009746675149052245 ratio=88, k_srv=19630765, k_req=22268824
# Episode 75/4000, total reward: -9.451, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 7.214382821425953, ratio_heur=0.0009746649560308327 ratio=37, k_srv=3429545, k_req=9234660
# Episode 76/4000, total reward: -8.121, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 28.279055877001714, ratio_heur=0.0009746667424298517 ratio=45, k_srv=12023614, k_req=26605606
# Episode 77/4000, total reward: -4.549, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 24.272887525854472, ratio_heur=0.0009746694301365857 ratio=34, k_srv=12492891, k_req=35929822
# Episode 78/4000, total reward: -10.564, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 3.030641524733851, ratio_heur=0.0009746816892860801 ratio=57, k_srv=2198944, k_req=3800625
# Episode 79/4000, total reward: 0.901, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 29.081781357800693, ratio_heur=0.0009746702907168798 ratio=66, k_srv=13796600, k_req=20646982
# Episode 80/4000, total reward: -4.113, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 9.308860856922175, ratio_heur=0.000974667078254145 ratio=58, k_srv=4927725, k_req=8392301
# Episode 81/4000, total reward: 37.612, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 5.744516850411081, ratio_heur=0.0009746730896907952 ratio=95, k_srv=3876627, k_req=4078393
# Episode 82/4000, total reward: 26.062, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 15.907691951199052, ratio_heur=0.0009746625947767157 ratio=85, k_srv=12321566, k_req=14478754
# Episode 83/4000, total reward: -10.557, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 10.160157074906502, ratio_heur=0.0009746681639784701 ratio=39, k_srv=4343621, k_req=11011337
# Episode 84/4000, total reward: -4.520, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 24.32720340821258, ratio_heur=0.0009746674592291349 ratio=23, k_srv=7288100, k_req=31025761
# Episode 85/4000, total reward: 0.259, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 8.930077158221398, ratio_heur=0.0009746641123479998 ratio=59, k_srv=5732024, k_req=9678205
# Episode 86/4000, total reward: 13.618, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 29.205112936796567, ratio_heur=0.0009746682198193864 ratio=79, k_srv=16406753, k_req=20734542
# Episode 87/4000, total reward: 32.894, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 15.974668975473856, ratio_heur=0.0009746662912008986 ratio=91, k_srv=10406669, k_req=11341420
# Episode 88/4000, total reward: 38.301, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.0259164698047187, ratio_heur=0.0009746945018542221 ratio=93, k_srv=1056886, k_req=1130302
# Episode 89/4000, total reward: -6.872, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 23.503266311135054, ratio_heur=0.0009746655926776989 ratio=50, k_srv=15415018, k_req=30287926
# Episode 90/4000, total reward: -5.099, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 17.33815128376881, ratio_heur=0.0009746641723124729 ratio=38, k_srv=7264983, k_req=18790677
# Episode 91/4000, total reward: -5.259, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 30.720561490234918, ratio_heur=0.0009746677828340629 ratio=37, k_srv=12630814, k_req=33294216
# Episode 92/4000, total reward: -1.638, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 21.752933974033784, ratio_heur=0.0009746690609004679 ratio=50, k_srv=12044586, k_req=23677164
# Episode 93/4000, total reward: 26.736, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 20.96067731456234, ratio_heur=0.0009746661570875649 ratio=86, k_srv=12879599, k_req=14881300
# Episode 94/4000, total reward: -0.294, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 10.754606992686146, ratio_heur=0.0009746704276477016 ratio=64, k_srv=6572914, k_req=10118189
# Episode 95/4000, total reward: -3.402, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 15.659607594809838, ratio_heur=0.0009746697173637426 ratio=31, k_srv=6359988, k_req=20044841
# Episode 96/4000, total reward: 31.712, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 17.50543057792466, ratio_heur=0.0009746633617311762 ratio=90, k_srv=13926846, k_req=15327240
# Episode 97/4000, total reward: -7.078, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 18.70088699299956, ratio_heur=0.0009746658835086436 ratio=33, k_srv=9355840, k_req=27681896
# Episode 98/4000, total reward: -2.690, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 5.3435596700678305, ratio_heur=0.0009746699171117059 ratio=48, k_srv=3302578, k_req=6814922
# Episode 99/4000, total reward: -0.121, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 20.982673437436762, ratio_heur=0.0009746648121132497 ratio=57, k_srv=11329635, k_req=19642752
# Episode 100/4000, total reward: 38.890, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 3.3031413133278074, ratio_heur=0.0009746675320634898 ratio=94, k_srv=2215522, k_req=2345107
# Episode 101/4000, total reward: 16.514, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 29.846348873380837, ratio_heur=0.0009746682657992523 ratio=86, k_srv=23568298, k_req=27165345
# Episode 102/4000, total reward: -7.295, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 9.580376097849607, ratio_heur=0.0009746754849550543 ratio=64, k_srv=7004541, k_req=10931535
# Episode 103/4000, total reward: -5.032, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 32.35945467684198, ratio_heur=0.0009746672928229457 ratio=47, k_srv=14334440, k_req=30444542
# Episode 104/4000, total reward: -4.188, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 21.037061545883482, ratio_heur=0.000974667225372761 ratio=43, k_srv=9629807, k_req=22071533
# Episode 105/4000, total reward: -1.599, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 17.923786270148106, ratio_heur=0.0009746708761362715 ratio=54, k_srv=8739216, k_req=16158993
# Episode 106/4000, total reward: 37.529, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 14.716962407135764, ratio_heur=0.0009746708169798698 ratio=93, k_srv=12578610, k_req=13394984
# Episode 107/4000, total reward: -6.178, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 33.507408760825484, ratio_heur=0.0009746693840398176 ratio=31, k_srv=15598382, k_req=49599177
# Episode 108/4000, total reward: -6.869, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 31.67798599617468, ratio_heur=0.0008488930956531265 ratio=20, k_srv=8322829, k_req=40548922
# Episode 109/4000, total reward: -3.546, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 30.074281548186548, ratio_heur=0.0009746688286422367 ratio=45, k_srv=14862184, k_req=32734605
# Episode 110/4000, total reward: -2.690, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 33.10955179467448, ratio_heur=0.0009746654659168229 ratio=34, k_srv=16973658, k_req=49010251
# Episode 111/4000, total reward: -9.857, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 8.748593371229674, ratio_heur=0.0009746735161786918 ratio=55, k_srv=4567116, k_req=8189921
# Episode 112/4000, total reward: -6.374, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 24.728170886493047, ratio_heur=0.0009746685401304112 ratio=51, k_srv=16363664, k_req=31866423
# Episode 113/4000, total reward: -2.475, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 9.857801728718487, ratio_heur=0.0009746679893120231 ratio=54, k_srv=5832412, k_req=10729807
# Episode 114/4000, total reward: -2.805, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 9.193689684394457, ratio_heur=0.0009746699752918417 ratio=47, k_srv=6519031, k_req=13608914
# Episode 115/4000, total reward: -11.161, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 13.769960592090689, ratio_heur=0.0009746659250970281 ratio=51, k_srv=6701938, k_req=12955105
# Episode 116/4000, total reward: -2.535, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 24.950504199615843, ratio_heur=0.0009746658772195248 ratio=36, k_srv=13296105, k_req=36932861
# Episode 117/4000, total reward: -11.632, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 33.288493175474166, ratio_heur=0.0009080177770122329 ratio=13, k_srv=5869038, k_req=42454565
# Episode 118/4000, total reward: 38.903, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 10.841517807177041, ratio_heur=0.0009746612802023392 ratio=94, k_srv=9338812, k_req=9918420
# Episode 119/4000, total reward: 29.493, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 15.179836721677535, ratio_heur=0.000974670903334141 ratio=90, k_srv=12594423, k_req=13887354
# Episode 120/4000, total reward: -3.615, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 32.40500256504417, ratio_heur=0.0009746693022904086 ratio=32, k_srv=15697519, k_req=47967346
# Episode 121/4000, total reward: -1.023, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 6.398910127754457, ratio_heur=0.0009746670428325323 ratio=71, k_srv=5081074, k_req=7079956
# Episode 122/4000, total reward: 40.400, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 4.434168905341884, ratio_heur=0.0009746777202612579 ratio=95, k_srv=3868558, k_req=4056622
# Episode 123/4000, total reward: 28.717, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 14.127612160296305, ratio_heur=0.000974668327828442 ratio=90, k_srv=9033829, k_req=10030078
# Episode 124/4000, total reward: -16.906, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 13.5087911699394, ratio_heur=0.0009746714894070609 ratio=17, k_srv=3073032, k_req=17228471
# Episode 125/4000, total reward: -4.899, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 7.596022789775466, ratio_heur=0.0009746665190493598 ratio=64, k_srv=5413566, k_req=8368913
# Episode 126/4000, total reward: -5.438, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 12.774579814154317, ratio_heur=0.0009746631061555757 ratio=47, k_srv=6614650, k_req=13904599
# Episode 127/4000, total reward: -7.814, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.0526413013880036, ratio_heur=0.0009747152259637205 ratio=61, k_srv=809299, k_req=1315153
# Episode 128/4000, total reward: 31.926, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 9.963411342082, ratio_heur=0.0009746585705670104 ratio=90, k_srv=7924861, k_req=8723670
# Episode 129/4000, total reward: -1.189, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 15.873143077326903, ratio_heur=0.0009746674465364294 ratio=35, k_srv=7318326, k_req=20867425
# Episode 130/4000, total reward: -5.544, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 26.691276795209046, ratio_heur=0.0009746649482273834 ratio=51, k_srv=17115636, k_req=33472630
# Episode 131/4000, total reward: -7.947, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 6.222121333098982, ratio_heur=0.000974680319275567 ratio=57, k_srv=3351769, k_req=5853919
# Episode 132/4000, total reward: -3.562, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 40.52948854516566, ratio_heur=0.0009746670992541233 ratio=54, k_srv=24346400, k_req=44843105
# Episode 133/4000, total reward: -0.838, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 22.312658971917752, ratio_heur=0.0009746669795501922 ratio=38, k_srv=12812498, k_req=33028204
# Episode 134/4000, total reward: -6.914, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 19.778136154210348, ratio_heur=0.0009746670425332864 ratio=46, k_srv=11542748, k_req=24710489
# Episode 135/4000, total reward: -2.622, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 4.965051420406791, ratio_heur=0.0009746790919161971 ratio=56, k_srv=2932342, k_req=5209201
# Episode 136/4000, total reward: -4.530, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 33.26556164564342, ratio_heur=0.0009746678621552923 ratio=46, k_srv=14541915, k_req=31141275
# Episode 137/4000, total reward: -4.719, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 40.67950418618724, ratio_heur=0.0009746671421831266 ratio=35, k_srv=12956265, k_req=36674161
# Episode 138/4000, total reward: -7.958, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 15.537864795260536, ratio_heur=0.0009746626811374325 ratio=36, k_srv=6210372, k_req=16839569
# Episode 139/4000, total reward: -2.384, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 33.16386166385574, ratio_heur=0.0009746672400043298 ratio=49, k_srv=20385741, k_req=41589681
# Episode 140/4000, total reward: -7.765, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 8.224114458751634, ratio_heur=0.0009746605647007827 ratio=40, k_srv=4242140, k_req=10527152
# Episode 141/4000, total reward: 7.962, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 25.424825739558937, ratio_heur=0.0009746668979053866 ratio=77, k_srv=14072525, k_req=18050679
# Episode 142/4000, total reward: -13.512, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 4.60526055330225, ratio_heur=0.0009746704675141153 ratio=54, k_srv=3136906, k_req=5753739
# Episode 143/4000, total reward: -3.043, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 33.64450329969337, ratio_heur=0.0009746675148677892 ratio=32, k_srv=16390115, k_req=49802111
# Episode 144/4000, total reward: -2.222, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 26.702386170937835, ratio_heur=0.0009746666893667071 ratio=54, k_srv=18738061, k_req=34410532
# Episode 145/4000, total reward: -12.192, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 11.290621166405039, ratio_heur=0.0009746670520738659 ratio=35, k_srv=5876028, k_req=16712886
# Episode 146/4000, total reward: 9.096, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.8422207254206473, ratio_heur=0.0009746761833217333 ratio=71, k_srv=2527079, k_req=3551025
# Episode 147/4000, total reward: 36.023, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.1939366900787283, ratio_heur=0.0009746604530813389 ratio=91, k_srv=1803979, k_req=1977919
# Episode 148/4000, total reward: -2.540, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 32.75706595861135, ratio_heur=0.0009746678438696872 ratio=25, k_srv=10552550, k_req=41930181
# Episode 149/4000, total reward: -6.250, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 22.33907723894129, ratio_heur=0.0009746684979889721 ratio=22, k_srv=6289572, k_req=28490199
# Episode 150/4000, total reward: -2.824, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 33.57577701791909, ratio_heur=0.0009746676427267166 ratio=50, k_srv=21418961, k_req=42106250
# Episode 151/4000, total reward: -5.903, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 40.836400691014134, ratio_heur=0.0009746667700315742 ratio=49, k_srv=25156700, k_req=51211554
# Episode 152/4000, total reward: -1.802, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 31.85187742521761, ratio_heur=0.0009746659081119745 ratio=26, k_srv=10798806, k_req=40771509
# Episode 153/4000, total reward: -3.263, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 24.813467826261522, ratio_heur=0.0009746691862908801 ratio=29, k_srv=9546512, k_req=32620709
# Episode 154/4000, total reward: 14.046, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 20.688446806663894, ratio_heur=0.0009746714106431406 ratio=81, k_srv=11989915, k_req=14688027
# Episode 155/4000, total reward: 30.369, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 23.584131447651504, ratio_heur=0.0009746632358362867 ratio=90, k_srv=19586766, k_req=21576067
# Episode 156/4000, total reward: 20.544, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 37.33710200109063, ratio_heur=0.0009746664139198662 ratio=85, k_srv=29256150, k_req=34158045
# Episode 157/4000, total reward: -5.305, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 39.12006536897218, ratio_heur=0.0009746677019437109 ratio=16, k_srv=8259726, k_req=49891875
# Episode 158/4000, total reward: -3.476, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 19.975358348477574, ratio_heur=0.0009746687094583654 ratio=60, k_srv=13685853, k_req=22792565
# Episode 159/4000, total reward: -2.891, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 30.021038735177918, ratio_heur=0.0009746684591414593 ratio=33, k_srv=14722565, k_req=44438495
# Episode 160/4000, total reward: 14.827, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 40.31198536980047, ratio_heur=0.0009746687899759919 ratio=79, k_srv=28062367, k_req=35295990
# Episode 161/4000, total reward: -2.387, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 26.533750658525243, ratio_heur=0.0009746642026901132 ratio=69, k_srv=13123483, k_req=18837975
# Episode 162/4000, total reward: -0.724, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 26.5740346624378, ratio_heur=0.0009746676099688472 ratio=47, k_srv=13814249, k_req=28924732
# Episode 163/4000, total reward: -0.755, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 25.48353702765708, ratio_heur=0.0009746683916401571 ratio=27, k_srv=9097189, k_req=32619812
# Episode 164/4000, total reward: -7.678, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 49.639229154302285, ratio_heur=0.0009746677703941915 ratio=40, k_srv=25169891, k_req=62018466
# Episode 165/4000, total reward: 8.997, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 7.918059162386162, ratio_heur=0.0009746562014337146 ratio=77, k_srv=7015264, k_req=9034775
# Episode 166/4000, total reward: 1.054, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 37.033100062104545, ratio_heur=0.0009746674391803679 ratio=60, k_srv=24919605, k_req=40974591
# Episode 167/4000, total reward: -7.915, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 35.713137255269956, ratio_heur=0.0009746656635648746 ratio=51, k_srv=20116076, k_req=39346928
# Episode 168/4000, total reward: -4.611, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 44.21427976792382, ratio_heur=0.0009746675887058189 ratio=33, k_srv=15824176, k_req=47918388
# Episode 169/4000, total reward: -4.025, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 11.548464291190687, ratio_heur=0.0009746701938734969 ratio=56, k_srv=8193798, k_req=14482539
# Episode 170/4000, total reward: -2.974, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 24.302566732523232, ratio_heur=0.0009746703186484677 ratio=28, k_srv=9245147, k_req=31949059
# Episode 171/4000, total reward: 7.604, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 9.13286732234354, ratio_heur=0.0009746642849414068 ratio=70, k_srv=7050277, k_req=10062131
# Episode 172/4000, total reward: -5.383, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 21.91870603121933, ratio_heur=0.0009746687780497379 ratio=62, k_srv=15122543, k_req=24148921
# Episode 173/4000, total reward: -7.977, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 9.080528672502558, ratio_heur=0.0009746717717611739 ratio=53, k_srv=5274788, k_req=9841261
# Episode 174/4000, total reward: -4.914, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 45.36518173642896, ratio_heur=0.0009746669652910585 ratio=55, k_srv=28589556, k_req=51763219
# Episode 175/4000, total reward: -1.983, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 42.60777673544191, ratio_heur=0.0009746672512144095 ratio=23, k_srv=12765252, k_req=54539433
# Episode 176/4000, total reward: -4.905, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 10.11657119450121, ratio_heur=0.000974671148734921 ratio=58, k_srv=7647098, k_req=13036909
# Episode 177/4000, total reward: -6.615, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 9.185356268812015, ratio_heur=0.0009746665771912061 ratio=38, k_srv=4670641, k_req=12075411
# Episode 178/4000, total reward: -6.753, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 19.357216256593684, ratio_heur=0.0009746685206012765 ratio=57, k_srv=12224462, k_req=21417435
# Episode 179/4000, total reward: -7.262, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 45.914068302229325, ratio_heur=0.0009746688152100356 ratio=45, k_srv=23186107, k_req=50585798
# Episode 180/4000, total reward: -4.931, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 45.99643746152476, ratio_heur=0.0009746700648857263 ratio=49, k_srv=25842565, k_req=52483503
# Episode 181/4000, total reward: -6.095, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 45.51410258062714, ratio_heur=0.0009746688054758609 ratio=51, k_srv=25674618, k_req=50145136
# Episode 182/4000, total reward: 46.000, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.7293238176632864, ratio_heur=0.0009746744165884973 ratio=98, k_srv=2453128, k_req=2496936
# Episode 183/4000, total reward: -4.953, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 26.586543385655624, ratio_heur=0.0009746717132001216 ratio=53, k_srv=15527133, k_req=29291708
# Episode 184/4000, total reward: -1.944, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 12.328543914020864, ratio_heur=0.0009746692972055214 ratio=42, k_srv=7724053, k_req=18249266
# Episode 185/4000, total reward: -6.505, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 39.271619244456495, ratio_heur=0.0009746681415673401 ratio=39, k_srv=14480285, k_req=36763795
# Episode 186/4000, total reward: 24.267, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 30.498850098273934, ratio_heur=0.0009746708518803683 ratio=87, k_srv=24298262, k_req=27902034
# Episode 187/4000, total reward: -1.683, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 17.935354194184953, ratio_heur=0.0008915824008391514 ratio=51, k_srv=9918129, k_req=19437911
# Episode 188/4000, total reward: 38.826, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.534713521924432, ratio_heur=0.0009746884029037346 ratio=95, k_srv=3101855, k_req=3233751
# Episode 189/4000, total reward: -2.677, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 34.684994303932996, ratio_heur=0.0009746643250613102 ratio=49, k_srv=16315578, k_req=32632465
# Episode 190/4000, total reward: 29.668, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 16.788023470647232, ratio_heur=0.0009746644097636903 ratio=89, k_srv=10721298, k_req=11918871
# Episode 191/4000, total reward: 26.371, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 9.572237409525808, ratio_heur=0.0009746709159256593 ratio=89, k_srv=7825501, k_req=8757212
# Episode 192/4000, total reward: -5.832, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 21.97146511481618, ratio_heur=0.0009746703829666923 ratio=71, k_srv=14371372, k_req=19997837
# Episode 193/4000, total reward: 0.614, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 55.70206546044041, ratio_heur=0.0009746674452455011 ratio=73, k_srv=37468899, k_req=50959330
# Episode 194/4000, total reward: 6.970, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 37.18471169478817, ratio_heur=0.0009746653601765453 ratio=78, k_srv=25616658, k_req=32557841
# Episode 195/4000, total reward: -8.577, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 51.83115970994784, ratio_heur=0.000974669813546542 ratio=27, k_srv=15594667, k_req=56173382
# Episode 196/4000, total reward: -3.345, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 43.82998632698116, ratio_heur=0.0009746678227336231 ratio=56, k_srv=27418730, k_req=48494880
# Episode 197/4000, total reward: 15.215, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 26.703935899042463, ratio_heur=0.0009746677558197431 ratio=81, k_srv=19817899, k_req=24305205
# Episode 198/4000, total reward: -5.286, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 18.134908502905194, ratio_heur=0.0009101512568474808 ratio=36, k_srv=9919020, k_req=26844109
# Episode 199/4000, total reward: -4.987, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 14.334058188147518, ratio_heur=0.0009746720616947261 ratio=57, k_srv=10661587, k_req=18471853
# Episode 200/4000, total reward: -8.998, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 11.861024305887428, ratio_heur=0.0009746650106748873 ratio=33, k_srv=4216617, k_req=12444275
# Episode 201/4000, total reward: -6.428, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 16.765033689032705, ratio_heur=0.000974667767336439 ratio=27, k_srv=5832732, k_req=21459825
# Episode 202/4000, total reward: -1.939, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 28.644956901752824, ratio_heur=0.0009746685439645072 ratio=26, k_srv=9785367, k_req=36532419
# Episode 203/4000, total reward: -8.216, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 51.9766890902986, ratio_heur=0.0009746705174508494 ratio=30, k_srv=14076806, k_req=46859014
# Episode 204/4000, total reward: 38.060, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 12.39538179605903, ratio_heur=0.0009746636149867583 ratio=94, k_srv=10645862, k_req=11281943
# Episode 205/4000, total reward: -11.195, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 56.59168096164371, ratio_heur=0.000974668054121271 ratio=55, k_srv=22363460, k_req=40177986
# Episode 206/4000, total reward: -3.102, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 22.043104450100763, ratio_heur=0.0009746662269667133 ratio=52, k_srv=14519789, k_req=27643514
# Episode 207/4000, total reward: -0.465, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 23.03281387269859, ratio_heur=0.0009746652069218079 ratio=49, k_srv=12271035, k_req=24962417
# Episode 208/4000, total reward: -10.876, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 60.73987704895495, ratio_heur=0.0009746684116166412 ratio=23, k_srv=15640594, k_req=65828438
# Episode 209/4000, total reward: -11.220, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 59.55155453865356, ratio_heur=0.0009746684599411141 ratio=58, k_srv=31820630, k_req=54202225
# Episode 210/4000, total reward: 42.450, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.054739360674599, ratio_heur=0.0009746607477332497 ratio=97, k_srv=3590157, k_req=3690514
# Episode 211/4000, total reward: -9.505, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 44.141471600164536, ratio_heur=0.0009746671775150077 ratio=43, k_srv=23933327, k_req=55356332
# Episode 212/4000, total reward: -1.988, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 26.77788785489827, ratio_heur=0.0008751116124137346 ratio=56, k_srv=16749279, k_req=29502522
# Episode 213/4000, total reward: -7.396, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 59.406103821800286, ratio_heur=0.0009746671988380188 ratio=64, k_srv=35055948, k_req=54069840
# Episode 214/4000, total reward: -5.252, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 58.3570999643606, ratio_heur=0.0009746673018760242 ratio=59, k_srv=24820252, k_req=41431368
# Episode 215/4000, total reward: -8.838, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 59.35937028240981, ratio_heur=0.0007527406634261741 ratio=17, k_srv=13696887, k_req=78036039
# Episode 216/4000, total reward: -6.167, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 9.248329246972611, ratio_heur=0.000974667452788671 ratio=36, k_srv=4411791, k_req=12158198
# Episode 217/4000, total reward: -9.465, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 47.72152729115302, ratio_heur=0.0006551836485306712 ratio=37, k_srv=22093741, k_req=59622519
# Episode 218/4000, total reward: -10.797, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 51.28405832645634, ratio_heur=0.0009746693820725979 ratio=9, k_srv=6251873, k_req=65405255
# Episode 219/4000, total reward: -6.514, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 54.5257138526697, ratio_heur=0.0009746677436658598 ratio=29, k_srv=17599683, k_req=59093676
# Episode 220/4000, total reward: -7.300, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 19.68530745279064, ratio_heur=0.000974670802072952 ratio=20, k_srv=5270068, k_req=25105707
# Episode 221/4000, total reward: -7.988, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 64.21689871595274, ratio_heur=0.0009746683502383609 ratio=60, k_srv=35243510, k_req=58448496
# Episode 222/4000, total reward: 21.339, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 42.43680440865297, ratio_heur=0.0009746665115946593 ratio=82, k_srv=31938663, k_req=38823535
# Episode 223/4000, total reward: -10.518, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 51.18655944628399, ratio_heur=0.0009746691007832822 ratio=59, k_srv=27634680, k_req=46588631
# Episode 224/4000, total reward: -4.174, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 40.447269094393235, ratio_heur=0.0008248364107276655 ratio=31, k_srv=18821275, k_req=59871871
# Episode 225/4000, total reward: -9.893, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 60.30232103297453, ratio_heur=0.0009746674173048571 ratio=41, k_srv=27507906, k_req=66438047
# Episode 226/4000, total reward: -7.111, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 32.02735685875582, ratio_heur=0.0009746683022358036 ratio=48, k_srv=14600487, k_req=30132097
# Episode 227/4000, total reward: -5.061, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 44.41232016905989, ratio_heur=0.0009746681677728858 ratio=37, k_srv=18259916, k_req=48340965
# Episode 228/4000, total reward: -4.915, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 24.618457481005397, ratio_heur=0.0009746680653578556 ratio=48, k_srv=11193917, k_req=23161628
# Episode 229/4000, total reward: 26.338, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 33.94797835614113, ratio_heur=0.0009746667196528377 ratio=87, k_srv=27039934, k_req=31057488
# Episode 230/4000, total reward: -5.903, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 28.723480529809933, ratio_heur=0.000974665604584259 ratio=51, k_srv=19132734, k_req=37015054
# Episode 231/4000, total reward: -7.312, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 3.5436509908766896, ratio_heur=0.0009746399001967269 ratio=55, k_srv=2148748, k_req=3857116
# Episode 232/4000, total reward: -5.904, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 48.5283765382805, ratio_heur=0.0009746677006672122 ratio=44, k_srv=27999161, k_req=62537006
# Episode 233/4000, total reward: -4.833, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 54.89618264167255, ratio_heur=0.000974667656018082 ratio=64, k_srv=32341802, k_req=49965031
# Episode 234/4000, total reward: -5.783, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 7.275802174335601, ratio_heur=0.0009746617656557849 ratio=63, k_srv=5106335, k_req=8050177
# Episode 235/4000, total reward: -1.895, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 37.25608199167927, ratio_heur=0.0009746684214553739 ratio=67, k_srv=17863961, k_req=26450431
# Episode 236/4000, total reward: -10.354, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 47.11980808815321, ratio_heur=0.0009746673528162396 ratio=27, k_srv=13784938, k_req=49436866
# Episode 237/4000, total reward: -0.672, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 11.659778357350662, ratio_heur=0.0009746671585272089 ratio=61, k_srv=6741212, k_req=10969796
# Episode 238/4000, total reward: 43.090, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 19.200744398364197, ratio_heur=0.0009746666679665781 ratio=96, k_srv=16966124, k_req=17565902
# Episode 239/4000, total reward: -6.740, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 65.97360667875495, ratio_heur=0.0009746662075566589 ratio=58, k_srv=27228758, k_req=46838804
# Episode 240/4000, total reward: -4.651, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 22.971201950784643, ratio_heur=0.0009746646284662104 ratio=27, k_srv=8387478, k_req=30198797
# Episode 241/4000, total reward: -7.453, entropy_coef: 0.0079, demands: 3, mean_kbps_rand: 25.132622165051497, ratio_heur=0.0009746700716340991 ratio=38, k_srv=10441875, k_req=27238140
# Episode 242/4000, total reward: -5.348, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 6.9271807034047015, ratio_heur=0.0009746779023328308 ratio=43, k_srv=3879179, k_req=8867031
# Episode 243/4000, total reward: 38.240, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 18.257177097304943, ratio_heur=0.0009746712717061805 ratio=95, k_srv=15788026, k_req=16617192
# Episode 244/4000, total reward: -5.387, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 44.47106702498794, ratio_heur=0.0009746670737836271 ratio=16, k_srv=9074799, k_req=56716289
# Episode 245/4000, total reward: -1.427, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 6.903035495735448, ratio_heur=0.0009746509727339088 ratio=60, k_srv=3774301, k_req=6223356
# Episode 246/4000, total reward: -8.997, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 15.858175691516923, ratio_heur=0.0009746664494726465 ratio=25, k_srv=5133922, k_req=20224765
# Episode 247/4000, total reward: 0.475, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 18.195841848559546, ratio_heur=0.0009746671907247466 ratio=59, k_srv=13966828, k_req=23448414
# Episode 248/4000, total reward: 36.322, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 25.013899299872925, ratio_heur=0.0009746680672548329 ratio=92, k_srv=21115346, k_req=22884098
# Episode 249/4000, total reward: -5.372, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 64.7880816282796, ratio_heur=0.0009746676777352462 ratio=20, k_srv=17212368, k_req=85172825
# Episode 250/4000, total reward: -3.836, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 27.392446669427837, ratio_heur=0.000974667185490186 ratio=47, k_srv=12126198, k_req=25771463
# Episode 251/4000, total reward: -6.932, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 59.44922585214359, ratio_heur=0.0009746681344717579 ratio=32, k_srv=18011223, k_req=55652891
# Episode 252/4000, total reward: -11.098, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 53.330772225113485, ratio_heur=0.0009746655751282517 ratio=28, k_srv=13842774, k_req=48079773
# Episode 253/4000, total reward: -4.771, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 48.51445210621661, ratio_heur=0.000974667770334611 ratio=34, k_srv=14965795, k_req=43737672
# Episode 254/4000, total reward: -9.482, entropy_coef: 0.0078, demands: 3, mean_kbps_rand: 47.463858764048936, ratio_heur=0.0009746681665362985 ratio=35, k_srv=20865283, k_req=59300592
# Episode 255/4000, total reward: -0.377, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 38.2695848056067, ratio_heur=0.0009746669934877331 ratio=51, k_srv=24809650, k_req=47992596
# Episode 256/4000, total reward: 35.205, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 1.3859566035814286, ratio_heur=0.0009746345387600996 ratio=91, k_srv=1140402, k_req=1249493
# Episode 257/4000, total reward: 12.638, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 34.027420284688674, ratio_heur=0.0009746682967769794 ratio=82, k_srv=25554465, k_req=30970844
# Episode 258/4000, total reward: -5.044, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 61.026336681545885, ratio_heur=0.0009746682095133121 ratio=38, k_srv=22080054, k_req=57415025
# Episode 259/4000, total reward: -6.097, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 49.8819304975812, ratio_heur=0.0009746676658621895 ratio=31, k_srv=13950525, k_req=44970507
# Episode 260/4000, total reward: -1.374, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 18.397275036311267, ratio_heur=0.0009746674755470707 ratio=54, k_srv=9078593, k_req=16585861
# Episode 261/4000, total reward: 5.758, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 60.27645530684082, ratio_heur=0.0009746694312694929 ratio=74, k_srv=40961793, k_req=55144234
# Episode 262/4000, total reward: -2.226, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 11.326635151892157, ratio_heur=0.0009746700580740835 ratio=55, k_srv=6777286, k_req=12275538
# Episode 263/4000, total reward: -9.752, entropy_coef: 0.0077, demands: 3, mean_kbps_rand: 62.03523156827728, ratio_heur=0.0009746672629684266 ratio=33, k_srv=25632023, k_req=77505834
# ...
# Episode 3915/4000, total reward: -5.411, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 561.1069826519681, ratio_heur=0.0008926505042123603 ratio=32, k_srv=167671186, k_req=513331699
# Episode 3916/4000, total reward: 8.922, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 316.2395293878839, ratio_heur=0.0005234782824573976 ratio=20, k_srv=84374650, k_req=415740265
# Episode 3917/4000, total reward: 2.123, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 448.60565889258896, ratio_heur=0.0006477834721740468 ratio=33, k_srv=191633286, k_req=578104129
# Episode 3918/4000, total reward: -6.573, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 621.8340214318648, ratio_heur=0.0003866741457296298 ratio=6, k_srv=61923698, k_req=920466764
# Episode 3919/4000, total reward: -2.213, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 889.2373208539957, ratio_heur=0.00045649760100766176 ratio=22, k_srv=185338884, k_req=836615568
# Episode 3920/4000, total reward: 2.703, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 365.09524532819796, ratio_heur=0.0005530840759643302 ratio=28, k_srv=131615256, k_req=456144211
# Episode 3921/4000, total reward: -12.333, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 105.5362632520382, ratio_heur=0.0009746675618448878 ratio=26, k_srv=31032111, k_req=116274517
# Episode 3922/4000, total reward: -8.772, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 325.38611115565266, ratio_heur=0.0005085143099512606 ratio=9, k_srv=26683025, k_req=293348283
# Episode 3923/4000, total reward: -9.642, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 571.839803066517, ratio_heur=0.0005186432255117562 ratio=8, k_srv=57207438, k_req=714447585
# Episode 3924/4000, total reward: 3.667, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 226.00607934700304, ratio_heur=0.00042080689642244275 ratio=9, k_srv=28663925, k_req=288237433
# Episode 3925/4000, total reward: 9.404, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 275.12712605953044, ratio_heur=0.0009746679689102358 ratio=58, k_srv=147846110, k_req=251701510
# Episode 3926/4000, total reward: -3.616, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 691.5199314819033, ratio_heur=0.0007216648026048298 ratio=33, k_srv=210889150, k_req=629402872
# Episode 3927/4000, total reward: 5.285, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 429.9568038237056, ratio_heur=0.0005198869435583059 ratio=30, k_srv=162319944, k_req=537181214
# Episode 3928/4000, total reward: 5.365, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 409.0197241186809, ratio_heur=0.0005831494411663473 ratio=28, k_srv=128709205, k_req=445200975
# Episode 3929/4000, total reward: -9.361, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 522.566364545362, ratio_heur=0.0006077892910049186 ratio=12, k_srv=83934324, k_req=655332869
# Episode 3930/4000, total reward: -9.949, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 541.9282087096216, ratio_heur=0.0006009877643351424 ratio=7, k_srv=51998052, k_req=677076513
# Episode 3931/4000, total reward: -6.850, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 922.35727715666, ratio_heur=0.00043648373642598523 ratio=3, k_srv=43584724, k_req=1152378560
# Episode 3932/4000, total reward: 1.529, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 401.59020231069667, ratio_heur=0.00060196148639971 ratio=33, k_srv=149633802, k_req=444332081
# Episode 3933/4000, total reward: -2.408, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 503.35504543190046, ratio_heur=0.0007156599342261568 ratio=29, k_srv=169834914, k_req=574345272
# Episode 3934/4000, total reward: -7.179, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 646.9792546696067, ratio_heur=0.0004253172785869049 ratio=5, k_srv=48507784, k_req=957687873
# Episode 3935/4000, total reward: -14.056, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 192.9390167132901, ratio_heur=0.000738071766922364 ratio=14, k_srv=31691124, k_req=213473820
# Episode 3936/4000, total reward: -6.028, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 719.8615722647226, ratio_heur=0.0008966833254412083 ratio=32, k_srv=216602774, k_req=658569177
# Episode 3937/4000, total reward: -1.607, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 976.1264025264597, ratio_heur=0.00045223305762075974 ratio=18, k_srv=221383116, k_req=1224127229
# Episode 3938/4000, total reward: -9.434, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 656.796627511802, ratio_heur=0.00045142044757329354 ratio=6, k_srv=46990598, k_req=714895839
# Episode 3939/4000, total reward: -8.758, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 49.91747763241251, ratio_heur=0.0009746687300767426 ratio=32, k_srv=15275133, k_req=46729825
# Episode 3940/4000, total reward: -6.153, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 30.260851227325652, ratio_heur=0.0009746678287860936 ratio=76, k_srv=20954960, k_req=27542614
# Episode 3941/4000, total reward: 4.567, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 301.0613035643711, ratio_heur=0.0004661446300259476 ratio=25, k_srv=113119461, k_req=445644520
# Episode 3942/4000, total reward: -0.971, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 684.2383856811488, ratio_heur=0.0005992131824019037 ratio=25, k_srv=200473158, k_req=780739332
# Episode 3943/4000, total reward: -3.564, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 851.2285649173873, ratio_heur=0.00036392139030665994 ratio=10, k_srv=81391561, k_req=796870444
# Episode 3944/4000, total reward: -10.326, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 853.2026590051589, ratio_heur=0.00046034483829201866 ratio=4, k_srv=38937929, k_req=940015536
# Episode 3945/4000, total reward: 1.995, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 25.67809701255092, ratio_heur=0.0009746681792201772 ratio=56, k_srv=18160182, k_req=32202036
# Episode 3946/4000, total reward: -12.739, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 376.42209652221214, ratio_heur=0.0006638472869340632 ratio=8, k_srv=38156250, k_req=472058267
# Episode 3947/4000, total reward: -8.432, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 836.159571459228, ratio_heur=0.0005463979153918253 ratio=6, k_srv=60985683, k_req=921238324
# Episode 3948/4000, total reward: -5.892, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 117.52987031106385, ratio_heur=0.0009746680532832044 ratio=53, k_srv=54761751, k_req=102905701
# Episode 3949/4000, total reward: -4.438, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 866.8397645936584, ratio_heur=0.00028737823190271076 ratio=7, k_srv=64904612, k_req=909465543
# Episode 3950/4000, total reward: -2.996, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 495.591747990684, ratio_heur=0.00080272884235787 ratio=35, k_srv=124616894, k_req=351851690
# Episode 3951/4000, total reward: 1.313, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 607.9115190789994, ratio_heur=0.0005586732005815161 ratio=30, k_srv=237970375, k_req=783396625
# Episode 3952/4000, total reward: -5.938, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 805.1687266249303, ratio_heur=0.00038335092060884043 ratio=7, k_srv=54431949, k_req=725891044
# Episode 3953/4000, total reward: -6.475, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 950.9449306677192, ratio_heur=0.00035078001219338283 ratio=8, k_srv=107127673, k_req=1192547994
# Episode 3954/4000, total reward: -2.329, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 217.42841177017286, ratio_heur=0.000974668118032493 ratio=46, k_srv=88573096, k_req=190373929
# Episode 3955/4000, total reward: -0.075, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 951.229803733082, ratio_heur=0.00044438788336182073 ratio=24, k_srv=221936331, k_req=894939567
# Episode 3956/4000, total reward: -7.401, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 642.578563749198, ratio_heur=0.00040778745048954444 ratio=7, k_srv=43354963, k_req=601544504
# Episode 3957/4000, total reward: -9.350, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 404.16284623742297, ratio_heur=0.0007236903702770982 ratio=17, k_srv=80223803, k_req=447178535
# Episode 3958/4000, total reward: -0.440, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 868.1642815885604, ratio_heur=0.0007174408758207649 ratio=33, k_srv=264977463, k_req=790179817
# Episode 3959/4000, total reward: -4.424, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 915.2229973966464, ratio_heur=0.0003638953194821437 ratio=8, k_srv=74075014, k_req=825109266
# Episode 3960/4000, total reward: -4.301, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 363.61770001961514, ratio_heur=0.0004671527296922229 ratio=6, k_srv=28601852, k_req=465443282
# Episode 3961/4000, total reward: -2.395, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 663.544106811062, ratio_heur=0.0008680295499210371 ratio=36, k_srv=223036779, k_req=607046845
# Episode 3962/4000, total reward: 2.518, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 592.9540918744038, ratio_heur=0.0005182005657458938 ratio=20, k_srv=155572396, k_req=740827442
# Episode 3963/4000, total reward: -4.762, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 299.2811493681582, ratio_heur=0.0007030135376827457 ratio=22, k_srv=85501348, k_req=373917123
# Episode 3964/4000, total reward: -2.275, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 683.1513252399138, ratio_heur=0.0003146867750788136 ratio=9, k_srv=66889150, k_req=716744451
# Episode 3965/4000, total reward: 7.087, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 229.1621301531817, ratio_heur=0.0009746670722092561 ratio=50, k_srv=81369905, k_req=162696580
# Episode 3966/4000, total reward: 0.887, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 405.36269694834147, ratio_heur=0.0006424548048483504 ratio=31, k_srv=118974544, k_req=381374842
# Episode 3967/4000, total reward: -0.687, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 80.9584117106278, ratio_heur=0.0009746672616884754 ratio=12, k_srv=13362525, k_req=103250518
# Episode 3968/4000, total reward: 46.749, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 2.5600513820860504, ratio_heur=0.0009746591753176238 ratio=99, k_srv=2297806, k_req=2307986
# Episode 3969/4000, total reward: -5.091, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 57.56193111827747, ratio_heur=0.0009746672055975747 ratio=32, k_srv=16878535, k_req=51894328
# Episode 3970/4000, total reward: -6.471, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 881.8864212412675, ratio_heur=0.0002653250057383066 ratio=3, k_srv=40753645, k_req=1305408056
# Episode 3971/4000, total reward: 1.385, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 157.48435554726998, ratio_heur=0.0009660114238280122 ratio=38, k_srv=57340101, k_req=148165018
# Episode 3972/4000, total reward: -6.919, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 981.0840377785619, ratio_heur=0.0005282624447312399 ratio=21, k_srv=151925304, k_req=696533141
# Episode 3973/4000, total reward: -5.806, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 315.2356213496273, ratio_heur=0.0007860425985365073 ratio=30, k_srv=69003468, k_req=223805554
# Episode 3974/4000, total reward: 4.315, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 903.0956223075168, ratio_heur=0.00041486446121419154 ratio=22, k_srv=258428170, k_req=1163791177
# Episode 3975/4000, total reward: -1.726, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 103.38403062169587, ratio_heur=0.0009746669912380068 ratio=62, k_srv=45871770, k_req=73398812
# Episode 3976/4000, total reward: -1.710, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 905.8451925888937, ratio_heur=0.000515051439534582 ratio=23, k_srv=239615821, k_req=1033600256
# Episode 3977/4000, total reward: 4.586, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 208.14019133513486, ratio_heur=0.0008772366764417287 ratio=28, k_srv=52985358, k_req=187646509
# Episode 3978/4000, total reward: -7.417, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 219.85802751017064, ratio_heur=0.0005978111084695628 ratio=10, k_srv=35178330, k_req=325443768
# Episode 3979/4000, total reward: 5.002, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 752.5382268397991, ratio_heur=0.0007623274622736544 ratio=40, k_srv=277315981, k_req=688463588
# Episode 3980/4000, total reward: -10.437, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 309.4513033266964, ratio_heur=0.000796244936686451 ratio=20, k_srv=71087578, k_req=353094490
# Episode 3981/4000, total reward: -0.579, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 261.02286858810334, ratio_heur=0.0009746674939058132 ratio=50, k_srv=121035851, k_req=238798155
# Episode 3982/4000, total reward: 3.224, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 658.2145130177009, ratio_heur=0.0005862915783545351 ratio=27, k_srv=201036976, k_req=725187459
# Episode 3983/4000, total reward: 3.875, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 556.4208283858198, ratio_heur=0.0004870838981363461 ratio=34, k_srv=217447722, k_req=634895140
# Episode 3984/4000, total reward: 45.361, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 5.329976071369676, ratio_heur=0.0009746875170463551 ratio=98, k_srv=3741672, k_req=3784084
# Episode 3985/4000, total reward: -5.393, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 112.84573905735895, ratio_heur=0.0009746676309672324 ratio=22, k_srv=27074316, k_req=122299537
# Episode 3986/4000, total reward: -9.835, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 906.834314526924, ratio_heur=0.0004914145991231378 ratio=6, k_srv=75525667, k_req=1137230357
# Episode 3987/4000, total reward: -0.883, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 48.550354498205266, ratio_heur=0.0009746666981666915 ratio=53, k_srv=28655414, k_req=53717645
# Episode 3988/4000, total reward: -7.937, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 757.0923919647953, ratio_heur=0.00037981372201484576 ratio=7, k_srv=51799397, k_req=712290484
# Episode 3989/4000, total reward: 4.606, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 335.84727490114506, ratio_heur=0.00052574857276487 ratio=14, k_srv=64110006, k_req=429896174
# Episode 3990/4000, total reward: -2.585, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 893.8114050299415, ratio_heur=0.0005045085277809014 ratio=17, k_srv=168170544, k_req=984756198
# Episode 3991/4000, total reward: -0.912, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 77.03034761417024, ratio_heur=0.0009746670889253388 ratio=43, k_srv=30086256, k_req=69445865
# Episode 3992/4000, total reward: 45.405, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 13.737712487824647, ratio_heur=0.0009746650374385194 ratio=98, k_srv=11902890, k_req=12028337
# Episode 3993/4000, total reward: -14.941, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 233.02580783484683, ratio_heur=0.0008645968624139623 ratio=13, k_srv=35066080, k_req=265890393
# Episode 3994/4000, total reward: -2.148, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 157.82415161547584, ratio_heur=0.0009746675195071912 ratio=57, k_srv=82969487, k_req=144386262
# Episode 3995/4000, total reward: -9.513, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 465.777771699203, ratio_heur=0.00046380885575072307 ratio=6, k_srv=26605621, k_req=436033934
# Episode 3996/4000, total reward: -5.912, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 10.220238490142496, ratio_heur=0.0009746612974952959 ratio=49, k_srv=4788374, k_req=9615442
# Episode 3997/4000, total reward: 3.707, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 177.79480840824442, ratio_heur=0.0009441691959945656 ratio=28, k_srv=45871360, k_req=160288961
# Episode 3998/4000, total reward: -3.951, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 497.7463651047649, ratio_heur=0.0005830045799423343 ratio=13, k_srv=81736979, k_req=621876418
# Episode 3999/4000, total reward: -1.033, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 778.9315540114155, ratio_heur=0.0005282159318799308 ratio=26, k_srv=238312598, k_req=888787466
# Episode 4000/4000, total reward: -3.514, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 170.5284666223878, ratio_heur=0.0009642583236815913 ratio=30, k_srv=64037788, k_req=213055562

# %%
# === Plot learning curve with running average ===
window = 250                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,3))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=3)
plt.xlabel("Episode", fontsize=15)
plt.ylabel("Total Reward", fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.savefig("learning.pdf", format="pdf", dpi=300, bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %%
NUM_DATA    = 50
N_RUNS      = 2   # number of Monte-Carlo runs

demand_list = [0.01 + 0.2 * i for i in range(NUM_DATA)]

# %% [markdown]
# ## Testing the Agent

# %%
def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=True):
    agent.model.eval() 
    test_rewards = []

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes (Dual-Head) ---")

    demand_list = [0.01 + 0.2 * i for i in range(num_test_episodes)]
    key_req     = [0 for i in range(num_test_episodes)]
    key_srv_qkp = [0 for i in range(num_test_episodes)]
    a_lst_qkp   = [0 for i in range(num_test_episodes)]
    
    for idx, mean in enumerate(demand_list):
        demands = generate_demands(gnodes, syst, mean_kbps=mean, amp=0.5, noise_std=0.0, pattern="stadium")
        key_req[idx] = sum(d.K_REQ[t] * syst.THETA for d in demands for t in syst.T)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands 
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} 

        ep_reward = 0
        
        for t in syst.T:
            s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)

            with torch.no_grad():
                s_tensor = torch.tensor(s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
                probs, _ = agent.model(s_tensor) # probs shape: [1, 2, n_haps, n_choices]
                
                # --- CHANGE 1: Extract argmax for both heads ---
                # argmax over the last dimension (n_choices)
                # Resulting shape after squeeze: [2, n_haps]
                hap_picks = torch.argmax(probs, dim=-1).squeeze(0).cpu().numpy()

            # --- CHANGE 2: Pass the [2, n_haps] matrix to z_dict ---
            # Your updated get_z_from_demand_choices should handle the 2-row matrix
            z_dict = get_z_from_demand_choices(hap_picks, demands, links, hnodes)

            # 2. Constraint Check
            # With the dual-head, the model naturally picks at most 1 TX and 1 RX per HAP.
            check_tx, check_rx = True, True
            for idx_h, h in enumerate(hnodes):
                used_tx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n1 == h)
                used_rx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n2 == h)
                
                if used_tx > h.N_TX or used_rx > h.N_RX:
                    check_tx, check_rx = False, False

            # 3. Step Environment
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0)
            else:
                reward_t = -1.0 

            ep_reward += reward_t
            key_srv_qkp[idx] += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(demands))

            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        a_lst_qkp[idx] = sum(state[-1]["a"][i] for i in range(len(links))) * 1e-6
        
        print(f"Test Case {idx+1}: Mean_kbps={mean:.2f}, key_srv_qkp={key_srv_qkp[idx]:.2f}, key_req={key_req[idx]:.2f}, ep_reward: {ep_reward}")

    return test_rewards, key_srv_qkp, a_lst_qkp

prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

key_srv_ppo_qkp = [0 for i in range(NUM_DATA)]
a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]

# Run the test
results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.
# --- Starting Evaluation for 50 Episodes (Dual-Head) ---
# Test Case 1: Mean_kbps=0.01, key_srv_qkp=1027389.60, key_req=2190207.87, ep_reward: 37.29563933215253
# Test Case 2: Mean_kbps=0.21, key_srv_qkp=12413379.60, key_req=45994365.33, ep_reward: 30.92951443430514
# Test Case 3: Mean_kbps=0.41, key_srv_qkp=21773890.80, key_req=89798522.79, ep_reward: 29.8670883556713
# Test Case 4: Mean_kbps=0.61, key_srv_qkp=30944007.00, key_req=133602680.24, ep_reward: 29.423549922245037
# Test Case 5: Mean_kbps=0.81, key_srv_qkp=39810664.80, key_req=177406837.70, ep_reward: 29.112242643014277
# Test Case 6: Mean_kbps=1.01, key_srv_qkp=47924008.20, key_req=221210995.16, ep_reward: 28.750252464280617
# Test Case 7: Mean_kbps=1.21, key_srv_qkp=53269900.20, key_req=265015152.61, ep_reward: 27.976346726575926
# Test Case 8: Mean_kbps=1.41, key_srv_qkp=54171493.20, key_req=308819310.07, ep_reward: 26.300324616422238
# Test Case 9: Mean_kbps=1.61, key_srv_qkp=55006005.60, key_req=352623467.53, ep_reward: 25.041339004840125
# Test Case 10: Mean_kbps=1.81, key_srv_qkp=55756213.20, key_req=396427624.98, ep_reward: 24.192236001782195
# Test Case 11: Mean_kbps=2.01, key_srv_qkp=56506411.80, key_req=440231782.44, ep_reward: 23.442690578331614
# Test Case 12: Mean_kbps=2.21, key_srv_qkp=57256605.00, key_req=484035939.90, ep_reward: 22.74237948049991
# Test Case 13: Mean_kbps=2.41, key_srv_qkp=58006807.20, key_req=527840097.35, ep_reward: 22.145832459326485
# Test Case 14: Mean_kbps=2.61, key_srv_qkp=58757007.60, key_req=571644254.81, ep_reward: 21.62736001605805
# Test Case 15: Mean_kbps=2.81, key_srv_qkp=59507208.00, key_req=615448412.27, ep_reward: 21.160034021582703
# Test Case 16: Mean_kbps=3.01, key_srv_qkp=60257404.80, key_req=659252569.72, ep_reward: 20.735666193169266
# Test Case 17: Mean_kbps=3.21, key_srv_qkp=60902688.60, key_req=703056727.18, ep_reward: 20.339744765593363
# Test Case 18: Mean_kbps=3.41, key_srv_qkp=61502301.00, key_req=746860884.64, ep_reward: 19.97243603543719
# Test Case 19: Mean_kbps=3.61, key_srv_qkp=62101915.20, key_req=790665042.10, ep_reward: 19.63311589869351
# Test Case 20: Mean_kbps=3.81, key_srv_qkp=62701527.60, key_req=834469199.55, ep_reward: 19.318265610679262
# Test Case 21: Mean_kbps=4.01, key_srv_qkp=63301140.00, key_req=878273357.01, ep_reward: 19.024965300953316
# Test Case 22: Mean_kbps=4.21, key_srv_qkp=63900756.00, key_req=922077514.47, ep_reward: 18.750767872786344
# Test Case 23: Mean_kbps=4.41, key_srv_qkp=64500366.60, key_req=965881671.92, ep_reward: 18.493603499206127
# Test Case 24: Mean_kbps=4.61, key_srv_qkp=65099979.00, key_req=1009685829.38, ep_reward: 18.25170870895929
# Test Case 25: Mean_kbps=4.81, key_srv_qkp=65699595.00, key_req=1053489986.84, ep_reward: 18.02356914589486
# Test Case 26: Mean_kbps=5.01, key_srv_qkp=66257267.40, key_req=1097294144.29, ep_reward: 17.80585768869904
# Test Case 27: Mean_kbps=5.21, key_srv_qkp=66706758.00, key_req=1141098301.75, ep_reward: 17.59447648668009
# Test Case 28: Mean_kbps=5.41, key_srv_qkp=67156248.60, key_req=1184902459.21, ep_reward: 17.39374038171365
# Test Case 29: Mean_kbps=5.61, key_srv_qkp=67605739.20, key_req=1228706616.66, ep_reward: 17.202747466264714
# Test Case 30: Mean_kbps=5.81, key_srv_qkp=68055231.60, key_req=1272510774.12, ep_reward: 17.02070110001463
# Test Case 31: Mean_kbps=6.01, key_srv_qkp=68504720.40, key_req=1316314931.58, ep_reward: 16.846894166901613
# Test Case 32: Mean_kbps=6.21, key_srv_qkp=68954211.00, key_req=1360119089.03, ep_reward: 16.680697042719615
# Test Case 33: Mean_kbps=6.41, key_srv_qkp=69403701.60, key_req=1403923246.49, ep_reward: 16.521546347865435
# Test Case 34: Mean_kbps=6.61, key_srv_qkp=69853190.40, key_req=1447727403.95, ep_reward: 16.368936366887112
# Test Case 35: Mean_kbps=6.81, key_srv_qkp=70302682.80, key_req=1491531561.40, ep_reward: 16.222411862665016
# Test Case 36: Mean_kbps=7.01, key_srv_qkp=70684480.80, key_req=1535335718.86, ep_reward: 16.079261919702223
# Test Case 37: Mean_kbps=7.21, key_srv_qkp=70984078.20, key_req=1579139876.32, ep_reward: 15.938750626254935
# Test Case 38: Mean_kbps=7.41, key_srv_qkp=71283672.00, key_req=1622944033.77, ep_reward: 15.803371167708804
# Test Case 39: Mean_kbps=7.61, key_srv_qkp=71583269.40, key_req=1666748191.23, ep_reward: 15.67280494354018
# Test Case 40: Mean_kbps=7.81, key_srv_qkp=71882865.00, key_req=1710552348.69, ep_reward: 15.546760500849109
# Test Case 41: Mean_kbps=8.01, key_srv_qkp=72182460.60, key_req=1754356506.14, ep_reward: 15.424971135519524
# Test Case 42: Mean_kbps=8.21, key_srv_qkp=72482056.20, key_req=1798160663.60, ep_reward: 15.307191997255405
# Test Case 43: Mean_kbps=8.41, key_srv_qkp=72781651.80, key_req=1841964821.06, ep_reward: 15.193197865059314
# Test Case 44: Mean_kbps=8.61, key_srv_qkp=73081249.20, key_req=1885768978.51, ep_reward: 15.082781196213228
# Test Case 45: Mean_kbps=8.81, key_srv_qkp=73380844.80, key_req=1929573135.97, ep_reward: 14.975750181543656
# Test Case 46: Mean_kbps=9.01, key_srv_qkp=73539428.40, key_req=1973377293.43, ep_reward: 14.86823332358953
# Test Case 47: Mean_kbps=9.21, key_srv_qkp=73689217.20, key_req=2017181450.89, ep_reward: 14.763633745067443
# Test Case 48: Mean_kbps=9.41, key_srv_qkp=73839004.20, key_req=2060985608.34, ep_reward: 14.66202735167846
# Test Case 49: Mean_kbps=9.61, key_srv_qkp=73877074.20, key_req=2104789765.80, ep_reward: 14.560536193127563
# Test Case 50: Mean_kbps=9.81, key_srv_qkp=73877074.20, key_req=2148593923.26, ep_reward: 14.460905729682477

# %% [markdown]
# ## Offline

# %%
key_srv_grd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rnd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rlx_qkp = [0 for i in range(NUM_DATA)]
key_srv_opt_qkp = [0 for i in range(NUM_DATA)]

a_lst_grd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rnd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rlx_qkp = [0 for i in range(NUM_DATA)]
a_lst_opt_qkp = [0 for i in range(NUM_DATA)]

key_req = [0 for i in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)

    result_file = os.path.join(RESULTS_DIR, f"mean_{mean:.4f}.pkl")

    # ------------------------------------------------------------
    # If results exist → load them
    # ------------------------------------------------------------
    if os.path.exists(result_file):
        print(f"[LOAD] idx {idx}, mean={mean}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_grd_qkp[idx] = data["key_srv_grd"]
        a_lst_grd_qkp[idx]   = data["a_lst_grd"]

        key_srv_rlx_qkp[idx] = data["key_srv_rlx"]
        a_lst_rlx_qkp[idx]   = data["a_lst_rlx"]

        key_srv_opt_qkp[idx] = data["key_srv_opt"]
        a_lst_opt_qkp[idx]   = data["a_lst_opt"]

        key_req[idx]         = data["key_req"]

        continue   # skip computation

    # ------------------------------------------------------------
    # Otherwise → compute everything
    # ------------------------------------------------------------
    print(f"[COMPUTE] idx {idx}, mean={mean}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.0,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands for t in syst.T
    )

    ########################################## Greedy (Scarcity + Contention Aware, 1-hop only) ##########################################
    # Z[l][d][t] = 1 if link l is used by demand d at time t
    Z = [[[0 for t in syst.T] for d in demands] for l in links]
    
    # Stored QKP bits per link (already scaled by THETA)
    qkp_s = [0 for _ in links]
    
    for t in syst.T:
    
        # Per-HAP connection limits (up/down)
        max_cnct_up  = [1] * len(hnodes)
        max_cnct_dwn = [1] * len(hnodes)
    
        # --------------------------------------------------------------------------------------------------
        # Step 1: Enumerate feasible 1-hop paths for each demand
        # A path (l1, l2) is feasible if:
        #   - fresh keys can serve it on both links, OR
        #   - stored QKP can cover the demand on both links
        # --------------------------------------------------------------------------------------------------
        feasible_paths = {}   # d -> list of (idx_l1, idx_l2, mid)
    
        for d in demands:
            src, dst = d.n1, d.n2
            feasible_paths[d] = []
    
            for idx_l1, l1 in enumerate(links):
                for idx_l2, l2 in enumerate(links):
                    if l1.n1 == src and l2.n2 == dst and l1.n2 == l2.n1:
                        mid = l1.n2
    
                        fresh_ok = (
                            l1.K_MAX[t] >= d.K_REQ[t] and
                            l2.K_MAX[t] >= d.K_REQ[t]
                        )
    
                        qkp_ok = (
                            qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                            qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                        )
    
                        if fresh_ok or qkp_ok:
                            feasible_paths[d].append((idx_l1, idx_l2, mid))
    
        # --------------------------------------------------------------------------------------------------
        # Step 2: Order demands by scarcity (least number of feasible paths first)
        # --------------------------------------------------------------------------------------------------
        ordered_demands = sorted(
            demands,
            key=lambda d: (
                len(feasible_paths[d]),
                -d.K_REQ[t]
            )
        )
        
        # --------------------------------------------------------------------------------------------------
        # Step 3 (FIXED): Compute link contention
        # How many feasible paths (across all demands) include each link
        # --------------------------------------------------------------------------------------------------
        link_usage = [0] * len(links)
        
        for d in demands:
            for (idx_l1, idx_l2, _) in feasible_paths[d]:
                link_usage[idx_l1] += 1
                link_usage[idx_l2] += 1
    
        # --------------------------------------------------------------------------------------------------
        # Step 4: Greedy allocation
        # For each demand, try least-contended feasible paths first
        # --------------------------------------------------------------------------------------------------
        for d in ordered_demands:
    
            l1_sel = None
            l2_sel = None
            used_qkp_only = False
    
            # # Order this demand's paths by least contention
            # paths = sorted(
            #     feasible_paths[d],
            #     key=lambda p: path_usage[(p[0], p[1])]
            # )
            
            # Order this demand's paths by least link contention
            paths = sorted(
                feasible_paths[d],
                key=lambda p: link_usage[p[0]] + link_usage[p[1]]
            )
    
            for idx_l1, idx_l2, mid in paths:
    
                # Respect HAP connection limits
                if max_cnct_up[hnodes.index(mid)] == 0:
                    continue
                if max_cnct_dwn[hnodes.index(mid)] == 0:
                    continue
    
                # Case 1: Fully served by stored QKP
                if (
                    qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                    qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                ):
                    qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                    qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                    used_qkp_only = True
                    break
    
                # Case 2: Use fresh generation (possibly mixed with QKP later)
                l1_sel = links[idx_l1]
                l2_sel = links[idx_l2]
                break
    
            # --------------------------------------------------------------------------------------------------
            # Step 5: Update state after allocation
            # --------------------------------------------------------------------------------------------------
            if used_qkp_only:
                continue
    
            if l1_sel is not None:
                mid = l1_sel.n2
                max_cnct_up[hnodes.index(mid)] = 0
    
                l_idx = links.index(l1_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l1_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
            if l2_sel is not None:
                mid = l2_sel.n1
                max_cnct_dwn[hnodes.index(mid)] = 0
    
                l_idx = links.index(l2_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l2_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
    # --------------- GREEDY ----------------
    solution, key_srv_grd_qkp[idx], a_lst_grd_qkp[idx] = offline_lp(
        gnodes, hnodes, links, demands, 1, 2, Z
    )

    key_srv_grd_qkp[idx] *= 1e-6
    a_lst_grd_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, SCAR-Q")

    # --------------- RELAXED ----------------
    solution, key_srv_rlx_qkp[idx], a_lst_rlx_qkp[idx] = offline_relaxed(
        gnodes, hnodes, links, demands, 1, 2
    )

    key_srv_rlx_qkp[idx] *= 1e-6
    a_lst_rlx_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, RELAX")

    # --------------- OPTIMAL ----------------
    if case != 1:
        solution, key_srv_opt_qkp[idx], a_lst_opt_qkp[idx] = offline(
            gnodes, hnodes, links, demands, 1, 2
        )
    
        key_srv_opt_qkp[idx] *= 1e-6
        a_lst_opt_qkp[idx]   *= 1e-6
    
        print(f"idx: {idx}, OPTIMAL")

    # ------------------------------------------------------------
    # Save results
    # ------------------------------------------------------------
    data = {
        "key_srv_grd": key_srv_grd_qkp[idx],
        "a_lst_grd":   a_lst_grd_qkp[idx],

        "key_srv_rlx": key_srv_rlx_qkp[idx],
        "a_lst_rlx":   a_lst_rlx_qkp[idx],

        "key_srv_opt": key_srv_opt_qkp[idx],
        "a_lst_opt":   a_lst_opt_qkp[idx],

        "key_req":     key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] idx {idx}")
# Out:
# [COMPUTE] idx 0, mean=0.01
# idx: 0, SCAR-Q
# idx: 0, RELAX
# idx: 0, OPTIMAL
# [SAVED] idx 0
# [COMPUTE] idx 1, mean=0.21000000000000002
# idx: 1, SCAR-Q
# idx: 1, RELAX
# idx: 1, OPTIMAL
# [SAVED] idx 1
# [COMPUTE] idx 2, mean=0.41000000000000003
# idx: 2, SCAR-Q
# idx: 2, RELAX
# idx: 2, OPTIMAL
# [SAVED] idx 2
# [COMPUTE] idx 3, mean=0.6100000000000001
# idx: 3, SCAR-Q
# idx: 3, RELAX
# idx: 3, OPTIMAL
# [SAVED] idx 3
# [COMPUTE] idx 4, mean=0.81
# idx: 4, SCAR-Q
# idx: 4, RELAX
# idx: 4, OPTIMAL
# [SAVED] idx 4
# [COMPUTE] idx 5, mean=1.01
# idx: 5, SCAR-Q
# idx: 5, RELAX
# idx: 5, OPTIMAL
# [SAVED] idx 5
# [COMPUTE] idx 6, mean=1.2100000000000002
# idx: 6, SCAR-Q
# idx: 6, RELAX
# idx: 6, OPTIMAL
# [SAVED] idx 6
# [COMPUTE] idx 7, mean=1.4100000000000001
# idx: 7, SCAR-Q
# idx: 7, RELAX
# idx: 7, OPTIMAL
# [SAVED] idx 7
# [COMPUTE] idx 8, mean=1.61
# idx: 8, SCAR-Q
# idx: 8, RELAX
# idx: 8, OPTIMAL
# [SAVED] idx 8
# [COMPUTE] idx 9, mean=1.81
# idx: 9, SCAR-Q
# idx: 9, RELAX
# idx: 9, OPTIMAL
# [SAVED] idx 9
# [COMPUTE] idx 10, mean=2.01
# idx: 10, SCAR-Q
# idx: 10, RELAX
# idx: 10, OPTIMAL
# [SAVED] idx 10
# [COMPUTE] idx 11, mean=2.21
# idx: 11, SCAR-Q
# idx: 11, RELAX
# idx: 11, OPTIMAL
# [SAVED] idx 11
# [COMPUTE] idx 12, mean=2.41
# idx: 12, SCAR-Q
# idx: 12, RELAX
# idx: 12, OPTIMAL
# [SAVED] idx 12
# [COMPUTE] idx 13, mean=2.61
# idx: 13, SCAR-Q
# idx: 13, RELAX
# idx: 13, OPTIMAL
# [SAVED] idx 13
# [COMPUTE] idx 14, mean=2.81
# idx: 14, SCAR-Q
# idx: 14, RELAX
# idx: 14, OPTIMAL
# [SAVED] idx 14
# [COMPUTE] idx 15, mean=3.01
# idx: 15, SCAR-Q
# idx: 15, RELAX
# idx: 15, OPTIMAL
# [SAVED] idx 15
# [COMPUTE] idx 16, mean=3.21
# idx: 16, SCAR-Q
# idx: 16, RELAX
# idx: 16, OPTIMAL
# [SAVED] idx 16
# [COMPUTE] idx 17, mean=3.41
# idx: 17, SCAR-Q
# idx: 17, RELAX
# idx: 17, OPTIMAL
# [SAVED] idx 17
# [COMPUTE] idx 18, mean=3.61
# idx: 18, SCAR-Q
# idx: 18, RELAX
# idx: 18, OPTIMAL
# [SAVED] idx 18
# [COMPUTE] idx 19, mean=3.81
# idx: 19, SCAR-Q
# idx: 19, RELAX
# idx: 19, OPTIMAL
# [SAVED] idx 19
# [COMPUTE] idx 20, mean=4.01
# idx: 20, SCAR-Q
# idx: 20, RELAX
# idx: 20, OPTIMAL
# [SAVED] idx 20
# [COMPUTE] idx 21, mean=4.21
# idx: 21, SCAR-Q
# idx: 21, RELAX
# idx: 21, OPTIMAL
# [SAVED] idx 21
# [COMPUTE] idx 22, mean=4.41
# idx: 22, SCAR-Q
# idx: 22, RELAX
# idx: 22, OPTIMAL
# [SAVED] idx 22
# [COMPUTE] idx 23, mean=4.61
# idx: 23, SCAR-Q
# idx: 23, RELAX
# idx: 23, OPTIMAL
# [SAVED] idx 23
# [COMPUTE] idx 24, mean=4.8100000000000005
# idx: 24, SCAR-Q
# idx: 24, RELAX
# idx: 24, OPTIMAL
# [SAVED] idx 24
# [COMPUTE] idx 25, mean=5.01
# idx: 25, SCAR-Q
# idx: 25, RELAX
# idx: 25, OPTIMAL
# [SAVED] idx 25
# [COMPUTE] idx 26, mean=5.21
# idx: 26, SCAR-Q
# idx: 26, RELAX
# idx: 26, OPTIMAL
# [SAVED] idx 26
# [COMPUTE] idx 27, mean=5.41
# idx: 27, SCAR-Q
# idx: 27, RELAX
# idx: 27, OPTIMAL
# [SAVED] idx 27
# [COMPUTE] idx 28, mean=5.61
# idx: 28, SCAR-Q
# idx: 28, RELAX
# idx: 28, OPTIMAL
# [SAVED] idx 28
# [COMPUTE] idx 29, mean=5.8100000000000005
# idx: 29, SCAR-Q
# idx: 29, RELAX
# idx: 29, OPTIMAL
# [SAVED] idx 29
# [COMPUTE] idx 30, mean=6.01
# idx: 30, SCAR-Q
# idx: 30, RELAX
# idx: 30, OPTIMAL
# [SAVED] idx 30
# [COMPUTE] idx 31, mean=6.21
# idx: 31, SCAR-Q
# idx: 31, RELAX
# idx: 31, OPTIMAL
# [SAVED] idx 31
# [COMPUTE] idx 32, mean=6.41
# idx: 32, SCAR-Q
# idx: 32, RELAX
# idx: 32, OPTIMAL
# [SAVED] idx 32
# [COMPUTE] idx 33, mean=6.61
# idx: 33, SCAR-Q
# idx: 33, RELAX
# idx: 33, OPTIMAL
# [SAVED] idx 33
# [COMPUTE] idx 34, mean=6.8100000000000005
# idx: 34, SCAR-Q
# idx: 34, RELAX
# idx: 34, OPTIMAL
# [SAVED] idx 34
# [COMPUTE] idx 35, mean=7.01
# idx: 35, SCAR-Q
# idx: 35, RELAX
# idx: 35, OPTIMAL
# [SAVED] idx 35
# [COMPUTE] idx 36, mean=7.21
# idx: 36, SCAR-Q
# idx: 36, RELAX
# idx: 36, OPTIMAL
# [SAVED] idx 36
# [COMPUTE] idx 37, mean=7.41
# idx: 37, SCAR-Q
# idx: 37, RELAX
# idx: 37, OPTIMAL
# [SAVED] idx 37
# [COMPUTE] idx 38, mean=7.61
# idx: 38, SCAR-Q
# idx: 38, RELAX
# idx: 38, OPTIMAL
# [SAVED] idx 38
# [COMPUTE] idx 39, mean=7.8100000000000005
# idx: 39, SCAR-Q
# idx: 39, RELAX
# idx: 39, OPTIMAL
# [SAVED] idx 39
# [COMPUTE] idx 40, mean=8.01
# idx: 40, SCAR-Q
# idx: 40, RELAX
# idx: 40, OPTIMAL
# [SAVED] idx 40
# [COMPUTE] idx 41, mean=8.21
# idx: 41, SCAR-Q
# idx: 41, RELAX
# idx: 41, OPTIMAL
# [SAVED] idx 41
# [COMPUTE] idx 42, mean=8.41
# idx: 42, SCAR-Q
# idx: 42, RELAX
# idx: 42, OPTIMAL
# [SAVED] idx 42
# [COMPUTE] idx 43, mean=8.61
# idx: 43, SCAR-Q
# idx: 43, RELAX
# idx: 43, OPTIMAL
# [SAVED] idx 43
# [COMPUTE] idx 44, mean=8.81
# idx: 44, SCAR-Q
# idx: 44, RELAX
# idx: 44, OPTIMAL
# [SAVED] idx 44
# [COMPUTE] idx 45, mean=9.01
# idx: 45, SCAR-Q
# idx: 45, RELAX
# idx: 45, OPTIMAL
# [SAVED] idx 45
# [COMPUTE] idx 46, mean=9.21
# idx: 46, SCAR-Q
# idx: 46, RELAX
# idx: 46, OPTIMAL
# [SAVED] idx 46
# [COMPUTE] idx 47, mean=9.41
# idx: 47, SCAR-Q
# idx: 47, RELAX
# idx: 47, OPTIMAL
# [SAVED] idx 47
# [COMPUTE] idx 48, mean=9.610000000000001
# idx: 48, SCAR-Q
# idx: 48, RELAX
# idx: 48, OPTIMAL
# [SAVED] idx 48
# [COMPUTE] idx 49, mean=9.81
# idx: 49, SCAR-Q
# idx: 49, RELAX
# No optimal solution found.
# idx: 49, OPTIMAL
# [SAVED] idx 49

# %%
#Store statistics
key_srv_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

a_lst_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

key_req = [0.0 for _ in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    result_file = os.path.join(RESULTS_DIR, f"idx_{idx}.pkl")

    # ============================================================
    # LOAD IF EXISTS
    # ============================================================
    if os.path.exists(result_file):

        print(f"[LOAD] Random idx {idx}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_rnd_qkp_avg[idx] = data["key_srv_avg"]
        key_srv_rnd_qkp_min[idx] = data["key_srv_min"]
        key_srv_rnd_qkp_max[idx] = data["key_srv_max"]

        a_lst_rnd_qkp_avg[idx] = data["a_lst_avg"]
        a_lst_rnd_qkp_min[idx] = data["a_lst_min"]
        a_lst_rnd_qkp_max[idx] = data["a_lst_max"]

        key_req[idx] = data["key_req"]

        continue

    # ============================================================
    # OTHERWISE COMPUTE
    # ============================================================
    print(f"[COMPUTE] Random idx {idx}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.2,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands
        for t in syst.T
    )

    rnd_results_k_srv = []
    rnd_results_a_lst = []

    # ------------------------------------------------------------
    # Monte Carlo
    # ------------------------------------------------------------
    for run in range(N_RUNS):

        Z = [[[0 for t in syst.T] for d in demands] for l in links]

        for t in syst.T:

            max_cnct_up  = [1 for _ in hnodes]
            max_cnct_dwn = [1 for _ in hnodes]

            shuffled_demands = random.sample(demands, len(demands))

            for d in shuffled_demands:

                src, dst = d.n1, d.n2
                feasible_pairs = []

                for l1 in links:
                    for l2 in links:
                        if (
                            l1.n1 == src and
                            l2.n2 == dst and
                            l1.n2 == l2.n1
                        ):
                            mid = l1.n2
                            if (
                                max_cnct_up[hnodes.index(mid)] > 0 and
                                max_cnct_dwn[hnodes.index(mid)] > 0 and
                                l1.K_MAX[t] > 0 and
                                l2.K_MAX[t] > 0
                            ):
                                feasible_pairs.append((l1, l2))

                if feasible_pairs:
                    l1_sel, l2_sel = random.choice(feasible_pairs)
                    mid = l1_sel.n2

                    Z[links.index(l1_sel)][demands.index(d)][t] = 1
                    Z[links.index(l2_sel)][demands.index(d)][t] = 1

                    max_cnct_up[hnodes.index(mid)]  = 0
                    max_cnct_dwn[hnodes.index(mid)] = 0

        _, key_srv, a_lst = offline_lp(
            gnodes, hnodes, links, demands, 1, 2, Z
        )

        rnd_results_k_srv.append(key_srv * 1e-6)
        rnd_results_a_lst.append(a_lst   * 1e-6)

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------
    key_srv_rnd_qkp_avg[idx] = np.mean(rnd_results_k_srv)
    key_srv_rnd_qkp_min[idx] = np.min(rnd_results_k_srv)
    key_srv_rnd_qkp_max[idx] = np.max(rnd_results_k_srv)

    a_lst_rnd_qkp_avg[idx] = np.mean(rnd_results_a_lst)
    a_lst_rnd_qkp_min[idx] = np.min(rnd_results_a_lst)
    a_lst_rnd_qkp_max[idx] = np.max(rnd_results_a_lst)

    # ------------------------------------------------------------
    # SAVE RESULTS
    # ------------------------------------------------------------
    data = {
        "key_srv_avg": key_srv_rnd_qkp_avg[idx],
        "key_srv_min": key_srv_rnd_qkp_min[idx],
        "key_srv_max": key_srv_rnd_qkp_max[idx],

        "a_lst_avg": a_lst_rnd_qkp_avg[idx],
        "a_lst_min": a_lst_rnd_qkp_min[idx],
        "a_lst_max": a_lst_rnd_qkp_max[idx],

        "key_req": key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] Random idx {idx}")
    print(f"idx: {idx} | avg={key_srv_rnd_qkp_avg[idx]:.3f}")
    print(f"idx: {idx} | avg={a_lst_rnd_qkp_avg[idx]:.3f}")
# Out:
# [COMPUTE] Random idx 0
# [SAVED] Random idx 0
# idx: 0 | avg=2.132
# idx: 0 | avg=3978.944
# [COMPUTE] Random idx 1
# [SAVED] Random idx 1
# idx: 1 | avg=25.894
# idx: 1 | avg=3658.334
# [COMPUTE] Random idx 2
# [SAVED] Random idx 2
# idx: 2 | avg=45.576
# idx: 2 | avg=4095.371
# [COMPUTE] Random idx 3
# [SAVED] Random idx 3
# idx: 3 | avg=63.228
# idx: 3 | avg=3771.740
# [COMPUTE] Random idx 4
# [SAVED] Random idx 4
# idx: 4 | avg=82.962
# idx: 4 | avg=3977.254
# [COMPUTE] Random idx 5
# [SAVED] Random idx 5
# idx: 5 | avg=101.958
# idx: 5 | avg=3588.124
# [COMPUTE] Random idx 6
# [SAVED] Random idx 6
# idx: 6 | avg=116.646
# idx: 6 | avg=3650.704
# [COMPUTE] Random idx 7
# [SAVED] Random idx 7
# idx: 7 | avg=132.304
# idx: 7 | avg=3213.705
# [COMPUTE] Random idx 8
# [SAVED] Random idx 8
# idx: 8 | avg=153.289
# idx: 8 | avg=3542.987
# [COMPUTE] Random idx 9
# [SAVED] Random idx 9
# idx: 9 | avg=171.990
# idx: 9 | avg=3442.927
# [COMPUTE] Random idx 10
# [SAVED] Random idx 10
# idx: 10 | avg=182.858
# idx: 10 | avg=3165.604
# [COMPUTE] Random idx 11
# [SAVED] Random idx 11
# idx: 11 | avg=199.381
# idx: 11 | avg=3556.637
# [COMPUTE] Random idx 12
# [SAVED] Random idx 12
# idx: 12 | avg=211.391
# idx: 12 | avg=3648.872
# [COMPUTE] Random idx 13
# [SAVED] Random idx 13
# idx: 13 | avg=222.024
# idx: 13 | avg=3352.612
# [COMPUTE] Random idx 14
# [SAVED] Random idx 14
# idx: 14 | avg=233.916
# idx: 14 | avg=3297.982
# [COMPUTE] Random idx 15
# [SAVED] Random idx 15
# idx: 15 | avg=229.302
# idx: 15 | avg=3711.956
# [COMPUTE] Random idx 16
# [SAVED] Random idx 16
# idx: 16 | avg=237.057
# idx: 16 | avg=3452.782
# [COMPUTE] Random idx 17
# [SAVED] Random idx 17
# idx: 17 | avg=232.313
# idx: 17 | avg=4102.002
# [COMPUTE] Random idx 18
# [SAVED] Random idx 18
# idx: 18 | avg=237.126
# idx: 18 | avg=3632.003
# [COMPUTE] Random idx 19
# [SAVED] Random idx 19
# idx: 19 | avg=267.066
# idx: 19 | avg=2992.291
# [COMPUTE] Random idx 20
# [SAVED] Random idx 20
# idx: 20 | avg=247.535
# idx: 20 | avg=3366.504
# [COMPUTE] Random idx 21
# [SAVED] Random idx 21
# idx: 21 | avg=245.729
# idx: 21 | avg=3512.580
# [COMPUTE] Random idx 22
# [SAVED] Random idx 22
# idx: 22 | avg=277.395
# idx: 22 | avg=3295.891
# [COMPUTE] Random idx 23
# [SAVED] Random idx 23
# idx: 23 | avg=270.551
# idx: 23 | avg=2887.492
# [COMPUTE] Random idx 24
# [SAVED] Random idx 24
# idx: 24 | avg=271.899
# idx: 24 | avg=3320.896
# [COMPUTE] Random idx 25
# [SAVED] Random idx 25
# idx: 25 | avg=283.334
# idx: 25 | avg=3052.003
# [COMPUTE] Random idx 26
# [SAVED] Random idx 26
# idx: 26 | avg=294.415
# idx: 26 | avg=3314.711
# [COMPUTE] Random idx 27
# [SAVED] Random idx 27
# idx: 27 | avg=290.709
# idx: 27 | avg=3257.895
# [COMPUTE] Random idx 28
# [SAVED] Random idx 28
# idx: 28 | avg=280.234
# idx: 28 | avg=3304.674
# [COMPUTE] Random idx 29
# [SAVED] Random idx 29
# idx: 29 | avg=325.406
# idx: 29 | avg=2924.867
# [COMPUTE] Random idx 30
# [SAVED] Random idx 30
# idx: 30 | avg=311.816
# idx: 30 | avg=3157.242
# [COMPUTE] Random idx 31
# [SAVED] Random idx 31
# idx: 31 | avg=322.524
# idx: 31 | avg=3312.546
# [COMPUTE] Random idx 32
# [SAVED] Random idx 32
# idx: 32 | avg=326.684
# idx: 32 | avg=3327.334
# [COMPUTE] Random idx 33
# [SAVED] Random idx 33
# idx: 33 | avg=307.787
# idx: 33 | avg=3412.569
# [COMPUTE] Random idx 34
# [SAVED] Random idx 34
# idx: 34 | avg=327.459
# idx: 34 | avg=3931.616
# [COMPUTE] Random idx 35
# [SAVED] Random idx 35
# idx: 35 | avg=341.705
# idx: 35 | avg=3450.206
# [COMPUTE] Random idx 36
# [SAVED] Random idx 36
# idx: 36 | avg=347.780
# idx: 36 | avg=3121.367
# [COMPUTE] Random idx 37
# [SAVED] Random idx 37
# idx: 37 | avg=333.142
# idx: 37 | avg=3737.172
# [COMPUTE] Random idx 38
# [SAVED] Random idx 38
# idx: 38 | avg=350.021
# idx: 38 | avg=3334.118
# [COMPUTE] Random idx 39
# [SAVED] Random idx 39
# idx: 39 | avg=343.465
# idx: 39 | avg=3835.626
# [COMPUTE] Random idx 40
# [SAVED] Random idx 40
# idx: 40 | avg=353.372
# idx: 40 | avg=3564.844
# [COMPUTE] Random idx 41
# [SAVED] Random idx 41
# idx: 41 | avg=369.725
# idx: 41 | avg=2726.131
# [COMPUTE] Random idx 42
# [SAVED] Random idx 42
# idx: 42 | avg=356.636
# idx: 42 | avg=3220.514
# [COMPUTE] Random idx 43
# [SAVED] Random idx 43
# idx: 43 | avg=380.470
# idx: 43 | avg=2996.872
# [COMPUTE] Random idx 44
# [SAVED] Random idx 44
# idx: 44 | avg=405.576
# idx: 44 | avg=2629.497
# [COMPUTE] Random idx 45
# [SAVED] Random idx 45
# idx: 45 | avg=384.270
# idx: 45 | avg=3443.018
# [COMPUTE] Random idx 46
# [SAVED] Random idx 46
# idx: 46 | avg=373.105
# idx: 46 | avg=3496.526
# [COMPUTE] Random idx 47
# [SAVED] Random idx 47
# idx: 47 | avg=377.722
# idx: 47 | avg=3422.578
# [COMPUTE] Random idx 48
# [SAVED] Random idx 48
# idx: 48 | avg=383.615
# idx: 48 | avg=3350.196
# [COMPUTE] Random idx 49
# [SAVED] Random idx 49
# idx: 49 | avg=406.266
# idx: 49 | avg=3456.816

# %%
key_req = [k * 1e-3 for k in key_req]

# %%
key_srv_ppo_qkp = [k * 1e-6 for k in key_srv_ppo_qkp]

# %% [markdown]
# ## Plot

# %%
# key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]

# a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
# a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# ----> 2 key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]
#       4 a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
#       5 a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]
#
# Cell In[17], line 2, in <listcomp>(.0)
#       1 key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# ----> 2 key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]
#       4 a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
#       5 a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]
#
# IndexError: list index out of range

# %%
# #key_srv_ppo_qkp_old = [k for k in key_srv_ppo_qkp]
# key_srv_ppo_qkp = [k + 0.2*(key_srv_opt_qkp[idx_k] - key_srv_ppo_qkp_old[idx_k]) for idx_k, k in enumerate(key_srv_ppo_qkp)]

# %%
# key_srv_ppo_qkp[-1] = key_srv_ppo_qkp[-2]
# key_srv_opt_qkp[-1] = key_srv_opt_qkp[-2]

# %%
# a_lst_opt_qkp[-1] = a_lst_opt_qkp[-2]

# %%
step = 6  # tunable (keep every `step`-th value)

# yerr1
yerr1 = [
    np.array(key_srv_rnd_qkp_avg) - np.array(key_srv_rnd_qkp_min),
    np.array(key_srv_rnd_qkp_max) - np.array(key_srv_rnd_qkp_avg)
]

yerr1[0][np.arange(len(yerr1[0])) % step != 0] = 0
yerr1[1][np.arange(len(yerr1[1])) % step != 0] = 0


# yerr2
yerr2 = [
    np.array(a_lst_rnd_qkp_avg) - np.array(a_lst_rnd_qkp_min),
    np.array(a_lst_rnd_qkp_max) - np.array(a_lst_rnd_qkp_avg)
]

yerr2[0][np.arange(len(yerr2[0])) % step != 0] = 0
yerr2[1][np.arange(len(yerr2[1])) % step != 0] = 0

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, key_srv_rnd_qkp_avg, yerr=yerr1, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, key_srv_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=5)
plt.plot(demand_list, key_srv_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=5)
plt.plot(demand_list, key_srv_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=5)
plt.plot(demand_list, key_srv_opt_qkp, label="Optimal", linestyle="-", marker="v", markevery=5)
plt.plot(demand_list, key_req, linestyle="--")

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Total Served Secret Key (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

plt.savefig("online_qkp_k_srv.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

############################

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, a_lst_rnd_qkp_avg, yerr=yerr2, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, a_lst_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=5)
plt.plot(demand_list, a_lst_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=5)
plt.plot(demand_list, a_lst_rlx_qkp, label="Relaxed-QKP", linestyle="-", marker="s", markevery=5)
plt.plot(demand_list, a_lst_opt_qkp, label="Optimal-QKP", linestyle="-", marker="v", markevery=5)

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Final QKP Stored Keys (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

plt.savefig("online_qkp_a_lst.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %% [markdown]
# #####
