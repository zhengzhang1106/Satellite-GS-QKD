# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)
#gnodes, hnodes, links, demands = init_setup_training_online()

nodes = gnodes + hnodes

n_hnodes  = len(hnodes)
n_demands = len(demands)

n_links   = len(links)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
def generate_hap_masks(hnodes, links, max_haps_to_remove=1):
    """
    Randomly deactivate up to max_haps_to_remove HAPs.
    Returns:
        hnodes_active: list[int]
        links_active: list[int]
    """
    import random
    
    n_haps = len(hnodes)
    hnodes_active = [1] * n_haps
    
    # number of HAPs to deactivate
    k = random.randint(0, max_haps_to_remove)
    
    if k > 0:
        removed_indices = random.sample(range(n_haps), k)
        for idx in removed_indices:
            hnodes_active[idx] = 0
    
    # build link mask
    links_active = []
    for l in links:
        active = 1
        
        if isinstance(l.n1, hap):
            if hnodes_active[hnodes.index(l.n1)] == 0:
                active = 0
        
        if isinstance(l.n2, hap):
            if hnodes_active[hnodes.index(l.n2)] == 0:
                active = 0
        
        links_active.append(active)
    
    return hnodes_active, links_active

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.2
LR = 1e-4
EPOCHS = 4
BATCH_SIZE = 64
ENTROPY_COEF_INITIAL = 0.01         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.999 #0.995               # >>> CHANGE
VALUE_COEF = 0.5

# Training hyperparams
num_episodes = 4000
episode_len = len(syst.T)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# %%
def build_state_vector_for_time(state_t, links, t, gnodes, hnodes, max_links=n_links, normalize=True):
    link_features = []
    total_nodes = len(gnodes) + len(hnodes)
    
    # Pre-calculate coordinate bounds for normalization (Example ranges)
    # Better yet, use the service area limits (e.g., 270-285 lon, 40-55 lat)
    LON_MIN, LON_MAX = 276.0, 285.0
    LAT_MIN, LAT_MAX = 46.0, 50.0
    ALT_MAX = 25.0

    def norm_lon(l): return (l - LON_MIN) / (LON_MAX - LON_MIN)
    def norm_lat(l): return (l - LAT_MIN) / (LAT_MAX - LAT_MIN)
    def norm_alt(a): return a / ALT_MAX

    # 1. Process Links with Geometric Context
    for idx_l in range(max_links):
        if idx_l < len(links):
            l = links[idx_l]
            
            # Key Buffer (QKP) - Log Scaled
            qkp_val = np.log10(1 + state_t.get("a", {}).get(idx_l, 0.0)) / 8.0
            
            # Current Capacity (K_MAX) - Normalized by a realistic max (e.g., 100Mbps)
            kmax_val = np.log10(1 + l.K_MAX[t]) / 6.0 
            
            # GEOMETRIC ENCODING: Position of Node 1 and Node 2
            # This is much more powerful than normalized IDs
            n1_coords = [norm_lon(l.n1.lg[t] if isinstance(l.n1, hap) else l.n1.lg),
                         norm_lat(l.n1.la[t] if isinstance(l.n1, hap) else l.n1.la)]
            
            n2_coords = [norm_lon(l.n2.lg[t] if isinstance(l.n2, hap) else l.n2.lg),
                         norm_lat(l.n2.la[t] if isinstance(l.n2, hap) else l.n2.la)]
            
            # Add features: [QKP, Capacity, Src_Lon, Src_Lat, Dst_Lon, Dst_Lat, Active]
            link_features.extend([qkp_val, kmax_val] + n1_coords + n2_coords + [1.0])
        else:
            # Padding (7 features per link now)
            link_features.extend([0.0] * 7)

    # 2. Process Demands with Geometric Pairs
    d_vec = []
    demands_list = state_t.get("demands", [])
    
    # Instead of iterating all pairs (which is O(N^2)), 
    # you might want to only encode the 'Active' demands to save space, 
    # but for a fixed-size MLP input, the GS-to-GS grid is fine.
    for src in gnodes:
        for dst in gnodes:
            if src == dst: continue
            
            matched = next((d for d in demands_list if d.n1 == src and d.n2 == dst), None)
            
            # Geometric info for the demand pair
            src_pos = [norm_lon(src.lg), norm_lat(src.la)]
            dst_pos = [norm_lon(dst.lg), norm_lat(dst.la)]
            
            if matched:
                kreq = np.log10(1 + float(matched.K_REQ[t])) / 5.0
                d_vec.extend(src_pos + dst_pos + [kreq, 1.0])
            else:
                d_vec.extend(src_pos + dst_pos + [0.0, 0.0])

    return np.concatenate([link_features, d_vec]).astype(np.float32)

# %%
def scarq_policy(state, links, t):
    """
    Adapted Heuristic: Scarcity & Contention Aware (1-hop only)
    Converts the offline logic into an online action selection for time t.
    """
    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    
    # 1. Initialize constraints and action
    #action = np.zeros(n_links, dtype=int)
    action_matrix = np.zeros((n_demands, len(links)), dtype=int)
    max_cnct_up = [1] * n_hnodes  # HAP TX limits (assuming 1 for this logic)
    max_cnct_dwn = [1] * n_hnodes # HAP RX limits
    
    # Current QKP bits from state (assumed stored as raw bits or decoded)
    # If state_t["a"] is log-normalized, decode it first!
    qkp_s = [state[t]["a"].get(i, 0.0) for i in range(n_links)]

    # ---------------------------------------------------------
    # Step 1: Enumerate feasible 1-hop paths per demand
    # ---------------------------------------------------------
    feasible_paths = {d: [] for d in demands}
    link_usage = [0] * n_links
    
    for d in demands:
        src, dst = d.n1, d.n2
        for idx_l1, l1 in enumerate(links):
            if l1.n1 != src: continue
            for idx_l2, l2 in enumerate(links):
                if l2.n2 != dst: continue
                
                # Check if they share a HAP (mid-point)
                if l1.n2 == l2.n1 and l1.n2 in hnodes:
                    mid = l1.n2
                    
                    fresh_ok = (l1.K_MAX[t] >= d.K_REQ[t] and 
                                l2.K_MAX[t] >= d.K_REQ[t])
                    
                    qkp_ok = (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                              qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t])
                    
                    if fresh_ok or qkp_ok:
                        feasible_paths[d].append((idx_l1, idx_l2, mid))
                        link_usage[idx_l1] += 1
                        link_usage[idx_l2] += 1

    # ---------------------------------------------------------
    # Step 2: Order demands by Scarcity
    # (Least paths first, then largest requirement)
    # ---------------------------------------------------------
    ordered_demands = sorted(
        demands,
        key=lambda d: (len(feasible_paths[d]), -d.K_REQ[t])
    )

    # ---------------------------------------------------------
    # Step 3: Greedy Allocation with Contention Awareness
    # ---------------------------------------------------------
    for d in ordered_demands:
        # Sort paths for this demand by least link contention
        paths = sorted(
            feasible_paths[d],
            key=lambda p: link_usage[p[0]] + link_usage[p[1]]
        )
        
        for idx_l1, idx_l2, mid in paths:
            mid_idx = hnodes.index(mid)
            
            # Respect HAP connection limits
            if max_cnct_up[mid_idx] == 0 or max_cnct_dwn[mid_idx] == 0:
                continue
                
            # Path selection logic
            # Priority: Can we serve it with ONLY stored bits? (No action needed)
            if (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and 
                qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
                
                # Update local tracker (bits effectively consumed)
                qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                
                # Consume HAP capacity even if using QKP? 
                # (Your offline logic suggests yes to prevent multi-use)
                #max_cnct_up[mid_idx] = 0
                #max_cnct_dwn[mid_idx] = 0
                break
            
            # If we need fresh keys, we activate the links (set action to 1)
            else:
                # action[idx_l1] = 1
                # action[idx_l2] = 1
                action_matrix[demands.index(d)][idx_l1] = 1
                action_matrix[demands.index(d)][idx_l2] = 1
                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0
                # Note: We don't update qkp_s here because fresh generation 
                # happens in the environment 'step', not the heuristic.
                break


    # --------------------------------------------------
    # Step 4: Solve optimization with heuristic action
    # --------------------------------------------------
    solution_heur, _, A_next_heur = online_new(
        gnodes,
        hnodes,
        links,
        state,
        action_matrix,
        t,
        f_qkp,
        0
    )

    # --------------------------------------------------
    # Step 5: Compute total served keys
    # --------------------------------------------------
    if "r_h" not in solution_heur:
        return 0.0, solution_heur, A_next_heur

    k_srv_heur = sum(
        solution_heur["r_h"][idx_d] * syst.THETA
        for idx_d, _ in enumerate(demands)
    )


    return k_srv_heur, solution_heur, A_next_heur

def mcr_policy(state, links, t, n_samples=3):
    """
    Online Monte Carlo 1-hop random heuristic.
    Samples multiple random feasible allocations and keeps the best one.
    """

    n_links = len(links)
    n_hnodes = len(hnodes)
    demands = state[t]["demands"]
    n_demands = len(demands)

    best_reward = -1
    best_solution = None
    best_A_next = None

    # ------------------------------------------------------------
    # Monte Carlo sampling
    # ------------------------------------------------------------
    for _ in range(n_samples):

        # action_matrix[d, l]
        action_matrix = np.zeros((n_demands, n_links), dtype=int)

        max_cnct_up  = [1] * n_hnodes
        max_cnct_dwn = [1] * n_hnodes

        shuffled_demands = random.sample(demands, len(demands))

        # --------------------------------------------------------
        # Random feasible allocation (1-hop only)
        # --------------------------------------------------------
        for d in shuffled_demands:

            src, dst = d.n1, d.n2
            feasible_pairs = []

            for idx_l1, l1 in enumerate(links):
                if l1.n1 != src:
                    continue

                for idx_l2, l2 in enumerate(links):
                    if l2.n2 != dst:
                        continue

                    if l1.n2 == l2.n1 and l1.n2 in hnodes:
                        mid = l1.n2
                        mid_idx = hnodes.index(mid)

                        if (
                            max_cnct_up[mid_idx] > 0 and
                            max_cnct_dwn[mid_idx] > 0 and
                            l1.K_MAX[t] > 0 and
                            l2.K_MAX[t] > 0
                        ):
                            feasible_pairs.append((idx_l1, idx_l2, mid_idx))

            if feasible_pairs:
                idx_l1, idx_l2, mid_idx = random.choice(feasible_pairs)

                action_matrix[demands.index(d)][idx_l1] = 1
                action_matrix[demands.index(d)][idx_l2] = 1

                max_cnct_up[mid_idx]  = 0
                max_cnct_dwn[mid_idx] = 0

        # --------------------------------------------------------
        # Evaluate via online_new
        # --------------------------------------------------------
        solution, reward, A_next = online_new(
            gnodes,
            hnodes,
            links,
            state,
            action_matrix,
            t,
            f_qkp,
            0
        )

        if "r_h" in solution:
            total_served = sum(solution["r_h"][i] * syst.THETA for i in range(n_demands))
        else:
            total_served = 0.0

        # Keep best sample
        if total_served > best_reward:
            best_reward = total_served
            best_solution = solution
            best_A_next = A_next

    return best_reward, best_solution, best_A_next

# %%
class ResidualBlock(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.ln = nn.LayerNorm(size)
        self.fc = nn.Linear(size, size)

    def forward(self, x):
        # Residual connection helps gradients flow back to early layers
        return x + F.silu(self.fc(self.ln(x)))

class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Linear(dim, dim)
        )
        self.silu = nn.SiLU()

    def forward(self, x):
        return self.silu(x + self.net(x))

class ActorCriticCategorical(nn.Module):
    def __init__(self, state_dim, n_demands_max, n_haps, hidden=64):
        super().__init__()
        self.n_haps = n_haps
        self.n_choices = n_demands_max + 1 # Demands + Idle
        
        self.encoder = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.SiLU(),
        )
        
        # (One set of choices for RX/Uplink, one for TX/Downlink)
        self.actor_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 2 * n_haps * self.n_choices) 
        )
        
        self.critic_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 1)
        )
        
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            # Orthogonal init helps prevents early policy collapse
            nn.init.orthogonal_(m.weight, gain=0.01) 
            nn.init.constant_(m.bias, 0)

    def forward(self, x):
        features = self.encoder(x)
        
        # index 0: RX (Uplink), index 1: TX (Downlink)
        logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        probs = torch.softmax(logits, dim=-1) 
        
        value = self.critic_head(features)
        return probs, value

class PPOBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        self.is_terminals = []
    
    def clear(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]
        del self.is_terminals[:]

class PPOAgent:
    def __init__(self, state_dim, n_demands, n_hnodes, lr=LR):
        self.gamma = GAMMA
        self.lam = GAE_LAMBDA
        self.eps_clip = CLIP
        self.K_epochs = EPOCHS
        self.n_haps = n_hnodes
        self.n_demands = n_demands
        
        self.model = ActorCriticCategorical(state_dim, n_demands, n_hnodes).to(device=DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        self.MseLoss = nn.MSELoss()

    def select_action(self, state_vec):
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        with torch.no_grad():
            probs, value = self.model(s) # [1, 2, n_haps, n_choices]
        
        dist = Categorical(probs)
        action = dist.sample() # [1, 2, n_haps]
        
        # Sum log_prob across BOTH heads and ALL HAPs
        logp = dist.log_prob(action).sum(dim=[1, 2])
        
        return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0)

    # ... compute_gae remains exactly the same as your previous code ...

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef):
        #advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        if advantages.std() < 1e-5:
            advantages = advantages - advantages.mean()
        else:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
        for _ in range(self.K_epochs):
            probs, values = self.model(states.to(DEVICE))
            dist = Categorical(probs)
            
            # logp is summed across the choices of all HAPs
            #new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=-1)
            new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
            entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
            ratio = torch.exp(new_logps - old_logps)
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
            loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

    def compute_gae(self, rewards, values, dones):
        """
        Generalized Advantage Estimation
        rewards: [T], values: [T+1], dones: [T]
        """
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            # TD Error: delta = r_t + gamma * V(s_t+1) - V(s_t)
            delta = rewards[t] + self.gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + self.gamma * self.lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
            
        returns = adv + values[:-1]
        return adv, returns

# %%
def get_z_from_demand_choices(hap_picks, demands, links, hnodes):
    # Initialize z_dict with zeros
    z = {idx_d: {idx_l: 0 for idx_l in range(len(links))} for idx_d in range(len(demands))}
    
    rx_picks = hap_picks[0] # Uplink choices [n_haps]
    tx_picks = hap_picks[1] # Downlink choices [n_haps]

    # Run this once after initializing your 'links' and 'hnodes'
    UPLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n2 in hnodes}
    DOWNLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n1 in hnodes}

    for hap_idx, selected_hap in enumerate(hnodes):
        
        # --- Handle Uplink (RX: GS -> HAP) ---
        rx_val = rx_picks[hap_idx]
        if rx_val > 0:
            d_idx = int(rx_val - 1)
            if d_idx < len(demands):
                src_gs = demands[d_idx].n1
                # Use the pre-computed lookup
                l_idx = UPLINK_LOOKUP.get((src_gs, selected_hap))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1

        # --- Handle Downlink (TX: HAP -> GS) ---
        tx_val = tx_picks[hap_idx]
        if tx_val > 0:
            d_idx = int(tx_val - 1)
            if d_idx < len(demands):
                dst_gs = demands[d_idx].n2
                # Use the pre-computed lookup
                l_idx = DOWNLINK_LOOKUP.get((selected_hap, dst_gs))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1
                        
    return z

# %% [markdown]
# ## Training Loop

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(state[0], links, 0, gnodes, hnodes)
state_dim = len(state_vector_example)

agent = PPOAgent(state_dim, n_demands, n_hnodes, lr=LR)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

#WARM_EPISODES  = 500
DECAY_EPISODES = 300
k = 1

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf = []
    actions_buf = []
    logps_buf = []
    rewards_buf = []
    dones_buf = []
    values_buf = []

    total_reward = 0.0

    # Calculate a 'progress' factor from 0.0 to 1.0
    progress = ep / num_episodes
    
    # Start with a max of 50 kbps, end with 1000 kbps
    max_now = 10 + (990 * progress) 
    
    # Still use randomness, but within an ever-expanding "boundary"
    mean_kbps_rand = random.uniform(1, max_now)

    #mean_kbps_rand = random.randint(1, 1 + int(10 * ep/num_episodes))
    #mean_kbps_rand = random.randint(1, 1000)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.01*mean_kbps_rand, amp=0.5, noise_std=0.0, pattern="stadium")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    # Before the for t in syst.T: loop
    if ep < num_episodes / 10:
        k = 1  # Only 1 demand: let the agent learn basic RX/TX pairing first
    elif ep < 2 * num_episodes / 10:
        k = random.randint(1, 2) # Slightly more complex
    else:
        k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity

    demands = random.sample(demands_space, k)
    random.shuffle(demands)

    state[0]["demands"] = demands.copy()

    k_srv = 0
    k_req = 0

    k_heur_sum = 0

    for t in syst.T:
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)
        
        # Inside the for t in syst.T: loop
        hap_choices, logp, value = agent.select_action(s_vec) 
        
        # 2. Convert to the dictionary format for Gurobi
        z_dict = get_z_from_demand_choices(hap_choices, demands, links, hnodes)

        #print(z_dict)

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes

        k_srv_heur1, k_srv_heur2 = -math.inf, -math.inf
        k_srv_heur1, _, _ = scarq_policy(state, links, t)
        k_srv_heur2, _, _ = mcr_policy(state, links, t)
        
        k_srv_heur = max(k_srv_heur1, k_srv_heur2)

        k_heur_sum += k_srv_heur

        solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, k_srv_heur)

        reward[t] = reward_t
        total_reward += reward_t

        k_srv += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))
        k_req += sum(d.K_REQ[t] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        # Ensure hap_choices is converted to a tensor for the buffer
        # Shape: [2, n_haps]
        actions_buf.append(torch.tensor(hap_choices, dtype=torch.long, device=DEVICE))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    final_s_vec = build_state_vector_for_time(state[-1], links, t, gnodes, hnodes)
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor.view(-1), final_value.view(-1)])  # Now shape is [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}, mean_kbps_rand: {mean_kbps_rand}, ratio_heur={k_heur_sum/k_req*1e2} ratio={int(k_srv/k_req*1e2)}, k_srv_heur={int(k_heur_sum)}, k_srv={int(k_srv)}, k_req={int(k_req)}")

# === Plot learning curve ===
plt.figure(figsize=(6,3))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/4000, total reward: 42.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 5.508821350710362, ratio_heur=100.00012815016296 ratio=94, k_srv_heur=3308020, k_srv=3133904, k_req=3308015
# Episode 2/4000, total reward: 42.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 8.654360828494298, ratio_heur=100.00003266607551 ratio=94, k_srv_heur=1921257, k_srv=1820133, k_req=1921256
# Episode 3/4000, total reward: 42.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 1.7676419946055237, ratio_heur=100.00043458029432 ratio=94, k_srv_heur=1061463, k_srv=1005593, k_req=1061458
# Episode 4/4000, total reward: 38.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 7.001456762417543, ratio_heur=99.99991569616405 ratio=91, k_srv_heur=1554312, k_srv=1417886, k_req=1554313
# Episode 5/4000, total reward: 44.000, entropy_coef: 0.0100, demands: 1, mean_kbps_rand: 4.1469164853914595, ratio_heur=100.00072640523723 ratio=96, k_srv_heur=1083528, k_srv=1045508, k_req=1083520
# Episode 6/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 10.762840483630065, ratio_heur=99.99993313348685 ratio=96, k_srv_heur=2389334, k_srv=2305497, k_req=2389335
# Episode 7/4000, total reward: 46.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 3.1265507229012424, ratio_heur=99.99988456877644 ratio=98, k_srv_heur=1877473, k_srv=1844535, k_req=1877475
# Episode 8/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 3.5303390040353384, ratio_heur=100.0002260808208 ratio=96, k_srv_heur=922420, k_srv=890054, k_req=922418
# Episode 9/4000, total reward: 38.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 1.9532784003685553, ratio_heur=100.00130133331548 ratio=91, k_srv_heur=433630, k_srv=395571, k_req=433625
# Episode 10/4000, total reward: 42.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 11.705337084269386, ratio_heur=100.00015701874251 ratio=94, k_srv_heur=3058414, k_srv=2897438, k_req=3058409
# Episode 11/4000, total reward: 46.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 2.467701866220798, ratio_heur=99.99951631400543 ratio=98, k_srv_heur=1481833, k_srv=1455836, k_req=1481840
# Episode 12/4000, total reward: 48.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 3.1007041409073577, ratio_heur=99.99907563412856 ratio=99, k_srv_heur=810154, k_srv=810154, k_req=810162
# Episode 13/4000, total reward: 46.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 12.451690304478767, ratio_heur=99.99992818751029 ratio=98, k_srv_heur=7477164, k_srv=7345985, k_req=7477169
# Episode 14/4000, total reward: 44.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 8.173617414620256, ratio_heur=99.9999699378859 ratio=96, k_srv_heur=4908209, k_srv=4735990, k_req=4908210
# Episode 15/4000, total reward: 38.000, entropy_coef: 0.0099, demands: 1, mean_kbps_rand: 13.063587389154558, ratio_heur=99.99994166107274 ratio=91, k_srv_heur=2900097, k_srv=2645544, k_req=2900098
# Episode 16/4000, total reward: 48.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 5.721002132300851, ratio_heur=99.99986471478182 ratio=99, k_srv_heur=1270053, k_srv=1270053, k_req=1270054
# Episode 17/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 13.329398817349027, ratio_heur=100.00015941664859 ratio=94, k_srv_heur=3482755, k_srv=3299443, k_req=3482749
# Episode 18/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 5.858980681191337, ratio_heur=100.00018580839706 ratio=94, k_srv_heur=1530856, k_srv=1450279, k_req=1530853
# Episode 19/4000, total reward: 44.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 3.0236690722526918, ratio_heur=99.9999934024911 ratio=96, k_srv_heur=1815696, k_srv=1751986, k_req=1815696
# Episode 20/4000, total reward: 44.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 9.315948102105317, ratio_heur=99.99974613175591 ratio=96, k_srv_heur=2068122, k_srv=1995557, k_req=2068127
# Episode 21/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 4.586938771135586, ratio_heur=99.99998173678264 ratio=94, k_srv_heur=2754430, k_srv=2609452, k_req=2754430
# Episode 22/4000, total reward: 46.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 8.943197887806607, ratio_heur=99.99997075408241 ratio=98, k_srv_heur=2336707, k_srv=2295712, k_req=2336708
# Episode 23/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 1.9533087477249684, ratio_heur=100.00040762382302 ratio=94, k_srv_heur=1172955, k_srv=1111219, k_req=1172950
# Episode 24/4000, total reward: 42.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 4.143087801784802, ratio_heur=99.9991909553144 ratio=94, k_srv_heur=1082511, k_srv=1025533, k_req=1082519
# Episode 25/4000, total reward: 46.000, entropy_coef: 0.0098, demands: 1, mean_kbps_rand: 15.908867755218791, ratio_heur=99.9999598327314 ratio=98, k_srv_heur=4156720, k_srv=4083794, k_req=4156721
# Episode 26/4000, total reward: 42.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 4.151122079746388, ratio_heur=100.00011822596089 ratio=94, k_srv_heur=2492728, k_srv=2361524, k_req=2492725
# Episode 27/4000, total reward: 46.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 9.267168202892927, ratio_heur=99.99984617579707 ratio=98, k_srv_heur=2421352, k_srv=2378872, k_req=2421356
# Episode 28/4000, total reward: 30.903, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 10.161656031261238, ratio_heur=100.00023054319634 ratio=85, k_srv_heur=2655077, k_srv=2274685, k_req=2655071
# Episode 29/4000, total reward: 42.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 10.914078876967663, ratio_heur=100.00033364937416 ratio=94, k_srv_heur=2422918, k_srv=2295390, k_req=2422910
# Episode 30/4000, total reward: 44.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 9.46456097519371, ratio_heur=100.00036615279429 ratio=96, k_srv_heur=2101127, k_srv=2027402, k_req=2101119
# Episode 31/4000, total reward: 46.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 13.572527245325842, ratio_heur=99.99995187464116 ratio=98, k_srv_heur=3013081, k_srv=2960220, k_req=3013082
# Episode 32/4000, total reward: 44.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 8.748792385768684, ratio_heur=100.00000142818277 ratio=96, k_srv_heur=2285913, k_srv=2205705, k_req=2285913
# Episode 33/4000, total reward: 42.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 2.457053291085589, ratio_heur=99.99943168736137 ratio=94, k_srv_heur=545459, k_srv=516751, k_req=545462
# Episode 34/4000, total reward: 48.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 3.854178929644059, ratio_heur=99.99978498443632 ratio=99, k_srv_heur=2314407, k_srv=2314407, k_req=2314412
# Episode 35/4000, total reward: 48.000, entropy_coef: 0.0097, demands: 1, mean_kbps_rand: 6.973260769478319, ratio_heur=99.99966177854024 ratio=99, k_srv_heur=1821990, k_srv=1821990, k_req=1821996
# Episode 36/4000, total reward: 42.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 10.220093215157805, ratio_heur=100.00005465047978 ratio=94, k_srv_heur=2670341, k_srv=2529790, k_req=2670339
# Episode 37/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 11.017224865149164, ratio_heur=100.00016413673262 ratio=100, k_srv_heur=2445813, k_srv=2445813, k_req=2445808
# Episode 38/4000, total reward: 44.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 7.7055730495515995, ratio_heur=100.00018872517956 ratio=96, k_srv_heur=1710630, k_srv=1650607, k_req=1710626
# Episode 39/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 16.632064469202376, ratio_heur=100.00007106012264 ratio=100, k_srv_heur=4345684, k_srv=4345684, k_req=4345681
# Episode 40/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 8.27736649376796, ratio_heur=100.00000320364424 ratio=100, k_srv_heur=1837564, k_srv=1837564, k_req=1837564
# Episode 41/4000, total reward: 42.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 11.91306464062674, ratio_heur=99.99985400335237 ratio=94, k_srv_heur=3112680, k_srv=2948848, k_req=3112685
# Episode 42/4000, total reward: 46.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 16.66261096770978, ratio_heur=100.00000667069997 ratio=98, k_srv_heur=10005804, k_srv=9822603, k_req=10005803
# Episode 43/4000, total reward: 40.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 20.029223351696906, ratio_heur=100.00012969377198 ratio=92, k_srv_heur=4446466, k_srv=4134366, k_req=4446460
# Episode 44/4000, total reward: 44.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 6.864400338631104, ratio_heur=100.00004755848389 ratio=96, k_srv_heur=1793554, k_srv=1730622, k_req=1793553
# Episode 45/4000, total reward: 48.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 12.939490151017402, ratio_heur=100.00006462841951 ratio=100, k_srv_heur=3380875, k_srv=3380875, k_req=3380873
# Episode 46/4000, total reward: 46.000, entropy_coef: 0.0096, demands: 1, mean_kbps_rand: 1.781091684785122, ratio_heur=99.99960265555325 ratio=98, k_srv_heur=1069531, k_srv=1050767, k_req=1069535
# Episode 47/4000, total reward: 44.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 1.0199048986575021, ratio_heur=99.99960031474083 ratio=96, k_srv_heur=226416, k_srv=218471, k_req=226417
# Episode 48/4000, total reward: 46.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 5.1699950513452535, ratio_heur=100.00049722861976 ratio=98, k_srv_heur=1147737, k_srv=1127602, k_req=1147731
# Episode 49/4000, total reward: 46.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 20.005233117778634, ratio_heur=100.00011414846655 ratio=98, k_srv_heur=5227039, k_srv=5135337, k_req=5227033
# Episode 50/4000, total reward: 48.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 18.597215608012306, ratio_heur=99.99979551292886 ratio=99, k_srv_heur=4859132, k_srv=4857823, k_req=4859142
# Episode 51/4000, total reward: 48.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 7.629602427754616, ratio_heur=99.99979466018243 ratio=99, k_srv_heur=1993483, k_srv=1993483, k_req=1993487
# Episode 52/4000, total reward: 42.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 16.147451090861352, ratio_heur=100.00000967173379 ratio=94, k_srv_heur=3584712, k_srv=3396032, k_req=3584712
# Episode 53/4000, total reward: 42.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 13.1178341526565, ratio_heur=99.99997940178889 ratio=94, k_srv_heur=2912140, k_srv=2758861, k_req=2912141
# Episode 54/4000, total reward: 44.435, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 18.296689790876307, ratio_heur=99.99997821874628 ratio=97, k_srv_heur=10987055, k_srv=10685483, k_req=10987058
# Episode 55/4000, total reward: 40.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 9.010420928479164, ratio_heur=99.99997693559843 ratio=92, k_srv_heur=2354272, k_srv=2189025, k_req=2354272
# Episode 56/4000, total reward: 46.000, entropy_coef: 0.0095, demands: 1, mean_kbps_rand: 11.49952902925592, ratio_heur=99.99993734036475 ratio=98, k_srv_heur=6905397, k_srv=6784250, k_req=6905401
# Episode 57/4000, total reward: 46.448, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 17.77704413294374, ratio_heur=99.99997635310727 ratio=99, k_srv_heur=10675011, k_srv=10571668, k_req=10675014
# Episode 58/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 15.22192039089386, ratio_heur=99.99985521864022 ratio=98, k_srv_heur=3379240, k_srv=3319955, k_req=3379245
# Episode 59/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 5.94953843199506, ratio_heur=99.99982079229144 ratio=99, k_srv_heur=1554512, k_srv=1554512, k_req=1554515
# Episode 60/4000, total reward: 41.408, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 18.7934053542075, ratio_heur=100.00003836625864 ratio=95, k_srv_heur=11285337, k_srv=10765746, k_req=11285333
# Episode 61/4000, total reward: 40.251, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 19.83777058879788, ratio_heur=100.00004308710793 ratio=95, k_srv_heur=11912473, k_srv=11337836, k_req=11912468
# Episode 62/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 7.860500124712102, ratio_heur=99.99990848377304 ratio=98, k_srv_heur=4720181, k_srv=4637370, k_req=4720185
# Episode 63/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 15.066120905854149, ratio_heur=100.00002337951908 ratio=100, k_srv_heur=3344659, k_srv=3344659, k_req=3344658
# Episode 64/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 15.16585934523964, ratio_heur=100.00013020146297 ratio=98, k_srv_heur=3366804, k_srv=3307737, k_req=3366800
# Episode 65/4000, total reward: 46.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 2.4523296289411576, ratio_heur=100.000337055892 ratio=98, k_srv_heur=640754, k_srv=629513, k_req=640752
# Episode 66/4000, total reward: 48.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 6.044424183356054, ratio_heur=99.99994223575405 ratio=99, k_srv_heur=1341853, k_srv=1341853, k_req=1341853
# Episode 67/4000, total reward: 38.000, entropy_coef: 0.0094, demands: 1, mean_kbps_rand: 17.822980724764836, ratio_heur=99.99989989737672 ratio=91, k_srv_heur=3956673, k_srv=3609379, k_req=3956677
# Episode 68/4000, total reward: 46.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 3.1933756989294744, ratio_heur=100.00083634864605 ratio=98, k_srv_heur=834382, k_srv=819745, k_req=834375
# Episode 69/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 11.428581842461542, ratio_heur=99.99989449209355 ratio=99, k_srv_heur=2537126, k_srv=2537126, k_req=2537129
# Episode 70/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 22.23575844346154, ratio_heur=100.00009252878775 ratio=99, k_srv_heur=4936312, k_srv=4933648, k_req=4936308
# Episode 71/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 21.2544228088174, ratio_heur=99.999816637693 ratio=99, k_srv_heur=4718444, k_srv=4718444, k_req=4718453
# Episode 72/4000, total reward: 40.971, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 27.24128793451288, ratio_heur=100.00002798955332 ratio=94, k_srv_heur=16358243, k_srv=15488969, k_req=16358238
# Episode 73/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 7.249264863086835, ratio_heur=99.99981591132048 ratio=99, k_srv_heur=4353134, k_srv=4353134, k_req=4353142
# Episode 74/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 4.914010033232602, ratio_heur=99.99974643669228 ratio=99, k_srv_heur=1090900, k_srv=1090900, k_req=1090903
# Episode 75/4000, total reward: 48.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 1.6983391467199302, ratio_heur=100.00101412862247 ratio=100, k_srv_heur=443752, k_srv=443752, k_req=443747
# Episode 76/4000, total reward: 44.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 25.378801195720914, ratio_heur=100.00015862620435 ratio=96, k_srv_heur=5634068, k_srv=5436381, k_req=5634059
# Episode 77/4000, total reward: 46.000, entropy_coef: 0.0093, demands: 1, mean_kbps_rand: 11.223084553047643, ratio_heur=100.00012482349716 ratio=98, k_srv_heur=6739407, k_srv=6621172, k_req=6739398
# Episode 78/4000, total reward: 48.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 8.111263027860613, ratio_heur=100.00000017420336 ratio=100, k_srv_heur=1800689, k_srv=1800689, k_req=1800689
# Episode 79/4000, total reward: 46.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 18.90529369801217, ratio_heur=100.0000242094546 ratio=98, k_srv_heur=4939639, k_srv=4852978, k_req=4939638
# Episode 80/4000, total reward: 48.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 9.506546568679463, ratio_heur=99.99992174471288 ratio=99, k_srv_heur=2110438, k_srv=2110438, k_req=2110440
# Episode 81/4000, total reward: 46.713, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 25.671663996480035, ratio_heur=99.99999796833174 ratio=99, k_srv_heur=6707577, k_srv=6673838, k_req=6707577
# Episode 82/4000, total reward: 44.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 1.8819153702044755, ratio_heur=100.00108641847835 ratio=96, k_srv_heur=417787, k_srv=403127, k_req=417782
# Episode 83/4000, total reward: 48.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 17.81299454000441, ratio_heur=100.00001918698791 ratio=100, k_srv_heur=3954461, k_srv=3954461, k_req=3954460
# Episode 84/4000, total reward: 38.606, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 29.99308061242317, ratio_heur=100.00000605652752 ratio=92, k_srv_heur=18010675, k_srv=16621849, k_req=18010674
# Episode 85/4000, total reward: 46.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 1.3326631032475682, ratio_heur=99.99849306482608 ratio=98, k_srv_heur=348197, k_srv=342088, k_req=348202
# Episode 86/4000, total reward: 44.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 27.150939353681533, ratio_heur=100.00005468336562 ratio=96, k_srv_heur=7094091, k_srv=6845174, k_req=7094087
# Episode 87/4000, total reward: 46.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 6.926835560829586, ratio_heur=100.00006617840084 ratio=98, k_srv_heur=4159528, k_srv=4086554, k_req=4159525
# Episode 88/4000, total reward: 44.000, entropy_coef: 0.0092, demands: 1, mean_kbps_rand: 3.1683590072203747, ratio_heur=100.00002077797636 ratio=96, k_srv_heur=1902581, k_srv=1835823, k_req=1902581
# Episode 89/4000, total reward: 44.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 7.229948149478915, ratio_heur=100.00009416971905 ratio=96, k_srv_heur=1605040, k_srv=1548721, k_req=1605038
# Episode 90/4000, total reward: 44.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 15.056979533735456, ratio_heur=100.00001584062463 ratio=96, k_srv_heur=9041632, k_srv=8724380, k_req=9041630
# Episode 91/4000, total reward: 46.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 7.123104998392082, ratio_heur=99.99986240758862 ratio=98, k_srv_heur=1861146, k_srv=1828494, k_req=1861148
# Episode 92/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 13.255091737648636, ratio_heur=99.999907392639 ratio=99, k_srv_heur=7959600, k_srv=7959600, k_req=7959607
# Episode 93/4000, total reward: 44.612, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 29.89917840352894, ratio_heur=100.00004405293402 ratio=97, k_srv_heur=7812160, k_srv=7621986, k_req=7812156
# Episode 94/4000, total reward: 44.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 24.617553333803965, ratio_heur=99.99995481335877 ratio=96, k_srv_heur=5465061, k_srv=5273303, k_req=5465063
# Episode 95/4000, total reward: 46.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 11.614636130825415, ratio_heur=100.00015358460914 ratio=98, k_srv_heur=6974533, k_srv=6851314, k_req=6974523
# Episode 96/4000, total reward: 44.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 20.00284414889935, ratio_heur=99.99998455265779 ratio=96, k_srv_heur=4440603, k_srv=4284792, k_req=4440604
# Episode 97/4000, total reward: 46.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 28.58901219949182, ratio_heur=100.00001017688137 ratio=98, k_srv_heur=6346722, k_srv=6235376, k_req=6346721
# Episode 98/4000, total reward: 48.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 17.583194026563692, ratio_heur=99.99993022630288 ratio=99, k_srv_heur=4594192, k_srv=4594192, k_req=4594195
# Episode 99/4000, total reward: 42.000, entropy_coef: 0.0091, demands: 1, mean_kbps_rand: 5.018959058018201, ratio_heur=99.99999142301958 ratio=94, k_srv_heur=1311370, k_srv=1242347, k_req=1311370
# Episode 100/4000, total reward: 40.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 22.36541918158691, ratio_heur=100.00004147768516 ratio=92, k_srv_heur=4965094, k_srv=4616589, k_req=4965092
# Episode 101/4000, total reward: 42.788, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 33.64843395410685, ratio_heur=100.00003507416099 ratio=96, k_srv_heur=8791777, k_srv=8450548, k_req=8791774
# Episode 102/4000, total reward: 44.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 1.2405182858871209, ratio_heur=100.00005487316682 ratio=96, k_srv_heur=744924, k_srv=718786, k_req=744924
# Episode 103/4000, total reward: 44.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 22.738580637288084, ratio_heur=100.00014901310792 ratio=96, k_srv_heur=5047941, k_srv=4870819, k_req=5047934
# Episode 104/4000, total reward: 46.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 10.750482533994127, ratio_heur=99.99971718681252 ratio=98, k_srv_heur=2386585, k_srv=2344715, k_req=2386592
# Episode 105/4000, total reward: 34.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 9.036214025670942, ratio_heur=100.00013553582366 ratio=87, k_srv_heur=5426202, k_srv=4758001, k_req=5426195
# Episode 106/4000, total reward: 44.672, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 32.050598712748496, ratio_heur=99.99987255928083 ratio=97, k_srv_heur=7115180, k_srv=6946137, k_req=7115189
# Episode 107/4000, total reward: 42.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 21.35590729292307, ratio_heur=99.99999108492543 ratio=94, k_srv_heur=12824099, k_srv=12149114, k_req=12824101
# Episode 108/4000, total reward: 46.000, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 13.602013863385165, ratio_heur=99.99979337541775 ratio=98, k_srv_heur=3019622, k_srv=2966646, k_req=3019628
# Episode 109/4000, total reward: 36.010, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 29.109914460555295, ratio_heur=99.99999858931804 ratio=92, k_srv_heur=17480338, k_srv=16254955, k_req=17480338
# Episode 110/4000, total reward: 41.060, entropy_coef: 0.0090, demands: 1, mean_kbps_rand: 24.964868680410078, ratio_heur=99.99996546608061 ratio=94, k_srv_heur=14991256, k_srv=14217931, k_req=14991261
# Episode 111/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 13.556269931180159, ratio_heur=99.99989538521447 ratio=96, k_srv_heur=3009470, k_srv=2903875, k_req=3009473
# Episode 112/4000, total reward: 44.877, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 35.55945435665269, ratio_heur=99.99999412067051 ratio=98, k_srv_heur=7894150, k_srv=7738662, k_req=7894150
# Episode 113/4000, total reward: 42.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 36.66432740696138, ratio_heur=99.99999774471378 ratio=94, k_srv_heur=8139430, k_srv=7711018, k_req=8139430
# Episode 114/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 29.657405184015783, ratio_heur=100.00001901010842 ratio=96, k_srv_heur=6583904, k_srv=6352889, k_req=6583903
# Episode 115/4000, total reward: 46.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 11.86399507688554, ratio_heur=99.99990045924308 ratio=98, k_srv_heur=3099860, k_srv=3045477, k_req=3099864
# Episode 116/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 17.15274505792495, ratio_heur=99.99992262757146 ratio=96, k_srv_heur=4481722, k_srv=4324467, k_req=4481726
# Episode 117/4000, total reward: 46.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 16.311693502773483, ratio_heur=99.9999123420776 ratio=98, k_srv_heur=9795070, k_srv=9623226, k_req=9795079
# Episode 118/4000, total reward: 46.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 32.031772306240825, ratio_heur=100.00011010343857 ratio=98, k_srv_heur=8369377, k_srv=8222545, k_req=8369367
# Episode 119/4000, total reward: 46.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 22.96227241788023, ratio_heur=99.99998921098978 ratio=98, k_srv_heur=5097592, k_srv=5008161, k_req=5097593
# Episode 120/4000, total reward: 48.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 32.500028260485806, ratio_heur=100.00002758125552 ratio=100, k_srv_heur=8491717, k_srv=8491717, k_req=8491715
# Episode 121/4000, total reward: 44.329, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 35.06177951142116, ratio_heur=99.99995993609822 ratio=97, k_srv_heur=21054391, k_srv=20437106, k_req=21054399
# Episode 122/4000, total reward: 44.000, entropy_coef: 0.0089, demands: 1, mean_kbps_rand: 9.503950940400141, ratio_heur=99.99972190692155 ratio=96, k_srv_heur=2483217, k_srv=2396086, k_req=2483223
# Episode 123/4000, total reward: 46.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 26.558850503000862, ratio_heur=100.00000609700447 ratio=98, k_srv_heur=6939385, k_srv=6817642, k_req=6939384
# Episode 124/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 29.1658907365826, ratio_heur=100.00007193095651 ratio=100, k_srv_heur=7620566, k_srv=7620566, k_req=7620560
# Episode 125/4000, total reward: 44.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 13.891298468106353, ratio_heur=99.99984339702743 ratio=96, k_srv_heur=3083844, k_srv=2975639, k_req=3083849
# Episode 126/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 13.312724281651802, ratio_heur=99.99993761970808 ratio=99, k_srv_heur=7994210, k_srv=7994210, k_req=7994215
# Episode 127/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 19.025674642697805, ratio_heur=99.99999247301098 ratio=99, k_srv_heur=11424808, k_srv=11424808, k_req=11424809
# Episode 128/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 13.735984583355732, ratio_heur=100.00021127240097 ratio=100, k_srv_heur=3049376, k_srv=3049376, k_req=3049369
# Episode 129/4000, total reward: 46.881, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 33.88235707888402, ratio_heur=99.99997366963042 ratio=99, k_srv_heur=20346157, k_srv=20303758, k_req=20346163
# Episode 130/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 15.809679426357858, ratio_heur=100.00004325449451 ratio=100, k_srv_heur=4130807, k_srv=4130807, k_req=4130805
# Episode 131/4000, total reward: 46.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 5.78472755124291, ratio_heur=100.00025135946808 ratio=98, k_srv_heur=3473704, k_srv=3412762, k_req=3473696
# Episode 132/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 6.576034342854001, ratio_heur=100.000088371544 ratio=100, k_srv_heur=1459872, k_srv=1459872, k_req=1459870
# Episode 133/4000, total reward: 48.000, entropy_coef: 0.0088, demands: 1, mean_kbps_rand: 4.079832202245967, ratio_heur=100.00033119282155 ratio=100, k_srv_heur=2449924, k_srv=2449924, k_req=2449916
# Episode 134/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 20.2305107866899, ratio_heur=99.9999180482922 ratio=99, k_srv_heur=5285890, k_srv=5285890, k_req=5285895
# Episode 135/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 38.83325186438995, ratio_heur=100.00010123033402 ratio=100, k_srv_heur=8620938, k_srv=8620938, k_req=8620929
# Episode 136/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 27.76007146591495, ratio_heur=100.00010223596705 ratio=100, k_srv_heur=7253251, k_srv=7253251, k_req=7253243
# Episode 137/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 4.5142244413308585, ratio_heur=100.00005309848301 ratio=100, k_srv_heur=2710767, k_srv=2710767, k_req=2710766
# Episode 138/4000, total reward: 46.518, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 35.32301870450091, ratio_heur=99.99996761923951 ratio=99, k_srv_heur=9229312, k_srv=9151333, k_req=9229315
# Episode 139/4000, total reward: 46.370, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 21.562041565386867, ratio_heur=100.00000460180067 ratio=98, k_srv_heur=12947884, k_srv=12804665, k_req=12947883
# Episode 140/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 17.827657102771727, ratio_heur=99.99991102175922 ratio=99, k_srv_heur=10705397, k_srv=10705397, k_req=10705406
# Episode 141/4000, total reward: 46.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 17.975437177272124, ratio_heur=99.99993186034393 ratio=98, k_srv_heur=4696678, k_srv=4614280, k_req=4696682
# Episode 142/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 4.384250411440956, ratio_heur=99.99927584171442 ratio=99, k_srv_heur=973290, k_srv=973290, k_req=973297
# Episode 143/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 15.46906967191503, ratio_heur=99.99986728833392 ratio=99, k_srv_heur=4041804, k_srv=4041804, k_req=4041809
# Episode 144/4000, total reward: 48.000, entropy_coef: 0.0087, demands: 1, mean_kbps_rand: 38.276161872578456, ratio_heur=99.99991938582914 ratio=99, k_srv_heur=8497249, k_srv=8497249, k_req=8497256
# Episode 145/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 5.81562182082201, ratio_heur=100.0000142571258 ratio=100, k_srv_heur=3492248, k_srv=3492248, k_req=3492247
# Episode 146/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 28.088576356251004, ratio_heur=99.99980955762354 ratio=98, k_srv_heur=6235614, k_srv=6126217, k_req=6235625
# Episode 147/4000, total reward: 44.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 1.7452139363787085, ratio_heur=99.99826341767599 ratio=96, k_srv_heur=387428, k_srv=373834, k_req=387435
# Episode 148/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 2.9652658044161297, ratio_heur=100.00112580753215 ratio=98, k_srv_heur=658292, k_srv=646743, k_req=658284
# Episode 149/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 14.492324500108904, ratio_heur=99.99995667838027 ratio=99, k_srv_heur=3217275, k_srv=3217275, k_req=3217276
# Episode 150/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 25.35379282230966, ratio_heur=100.00000998651156 ratio=100, k_srv_heur=5628508, k_srv=5628508, k_req=5628507
# Episode 151/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 1.522439068728855, ratio_heur=99.99928708766961 ratio=98, k_srv_heur=337976, k_srv=332047, k_req=337979
# Episode 152/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 20.57616191552262, ratio_heur=99.9999924066586 ratio=99, k_srv_heur=5376207, k_srv=5376207, k_req=5376208
# Episode 153/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 29.61745839956526, ratio_heur=99.9999409514034 ratio=99, k_srv_heur=17785105, k_srv=17785105, k_req=17785115
# Episode 154/4000, total reward: 46.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 37.55736193786996, ratio_heur=100.00001720004308 ratio=98, k_srv_heur=22552986, k_srv=22157319, k_req=22552982
# Episode 155/4000, total reward: 48.000, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 14.846332638436301, ratio_heur=100.0000812956402 ratio=100, k_srv_heur=3295868, k_srv=3295868, k_req=3295865
# Episode 156/4000, total reward: 46.589, entropy_coef: 0.0086, demands: 1, mean_kbps_rand: 27.07473360314609, ratio_heur=100.0000043636709 ratio=99, k_srv_heur=16258224, k_srv=16140869, k_req=16258223
# Episode 157/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 10.429001402235857, ratio_heur=99.99991757862816 ratio=99, k_srv_heur=6262551, k_srv=6262551, k_req=6262556
# Episode 158/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 5.398763805943155, ratio_heur=100.00083047888772 ratio=100, k_srv_heur=1198528, k_srv=1198528, k_req=1198518
# Episode 159/4000, total reward: 44.971, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 40.16665223996043, ratio_heur=99.99997122445563 ratio=98, k_srv_heur=24119839, k_srv=23684385, k_req=24119846
# Episode 160/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 22.18307582196549, ratio_heur=100.0000373240254 ratio=100, k_srv_heur=4924614, k_srv=4924614, k_req=4924612
# Episode 161/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 28.77200567787687, ratio_heur=99.9999132638887 ratio=99, k_srv_heur=7517638, k_srv=7517638, k_req=7517645
# Episode 162/4000, total reward: 46.452, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 40.528168213578745, ratio_heur=100.00005702719112 ratio=99, k_srv_heur=10589340, k_srv=10487500, k_req=10589334
# Episode 163/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 42.85907184126304, ratio_heur=99.99998277626464 ratio=99, k_srv_heur=25736625, k_srv=25736625, k_req=25736629
# Episode 164/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 2.9136780822081985, ratio_heur=100.00048623437057 ratio=100, k_srv_heur=761299, k_srv=761299, k_req=761295
# Episode 165/4000, total reward: 46.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 3.662531838702593, ratio_heur=100.0004495474431 ratio=98, k_srv_heur=956962, k_srv=940174, k_req=956958
# Episode 166/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 49.88670306376652, ratio_heur=100.00001701469425 ratio=100, k_srv_heur=29956687, k_srv=29956687, k_req=29956682
# Episode 167/4000, total reward: 48.000, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 23.723433511325727, ratio_heur=99.999997173362 ratio=99, k_srv_heur=14245786, k_srv=14245786, k_req=14245787
# Episode 168/4000, total reward: 46.365, entropy_coef: 0.0085, demands: 1, mean_kbps_rand: 21.801441862840292, ratio_heur=99.99995169219245 ratio=98, k_srv_heur=13091635, k_srv=12945895, k_req=13091642
# Episode 169/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 50.50731005838176, ratio_heur=99.99998602318347 ratio=99, k_srv_heur=11212552, k_srv=11212552, k_req=11212554
# Episode 170/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 36.24040993772128, ratio_heur=100.00001640651975 ratio=100, k_srv_heur=8045323, k_srv=8045323, k_req=8045321
# Episode 171/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 26.971049503312223, ratio_heur=99.99999149813004 ratio=99, k_srv_heur=16195960, k_srv=16195960, k_req=16195962
# Episode 172/4000, total reward: 46.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 20.66929613194039, ratio_heur=99.99994652386506 ratio=98, k_srv_heur=12411788, k_srv=12194036, k_req=12411795
# Episode 173/4000, total reward: 46.592, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 50.452451451347294, ratio_heur=100.00000990443567 ratio=99, k_srv_heur=30296413, k_srv=30079321, k_req=30296410
# Episode 174/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 11.989222133467008, ratio_heur=100.00008786125059 ratio=100, k_srv_heur=2661593, k_srv=2661593, k_req=2661591
# Episode 175/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 15.18677386662703, ratio_heur=99.99998762967819 ratio=99, k_srv_heur=9119570, k_srv=9119570, k_req=9119571
# Episode 176/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 32.90631123431193, ratio_heur=99.9999789159517 ratio=99, k_srv_heur=19760049, k_srv=19760049, k_req=19760053
# Episode 177/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 4.303199443655547, ratio_heur=99.999638878599 ratio=99, k_srv_heur=1124350, k_srv=1124350, k_req=1124354
# Episode 178/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 22.81864856370757, ratio_heur=99.99996368595937 ratio=99, k_srv_heur=13702463, k_srv=13702463, k_req=13702468
# Episode 179/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 34.98407528920602, ratio_heur=100.00000908848992 ratio=100, k_srv_heur=21007740, k_srv=21007740, k_req=21007738
# Episode 180/4000, total reward: 48.000, entropy_coef: 0.0084, demands: 1, mean_kbps_rand: 45.4229925617198, ratio_heur=99.99994868019905 ratio=99, k_srv_heur=10083837, k_srv=10083837, k_req=10083842
# Episode 181/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 24.83304226967926, ratio_heur=100.00002682554125 ratio=100, k_srv_heur=5512903, k_srv=5512903, k_req=5512901
# Episode 182/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 47.16054323296119, ratio_heur=99.9999126683636 ratio=99, k_srv_heur=12322252, k_srv=12322252, k_req=12322263
# Episode 183/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 50.79552858902237, ratio_heur=100.00000238124791 ratio=100, k_srv_heur=30502427, k_srv=30502427, k_req=30502426
# Episode 184/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 32.71459575469188, ratio_heur=100.0000228628211 ratio=100, k_srv_heur=19644933, k_srv=19644933, k_req=19644929
# Episode 185/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 30.40931198470536, ratio_heur=99.99993761233453 ratio=99, k_srv_heur=7945441, k_srv=7945441, k_req=7945446
# Episode 186/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 54.60317700726726, ratio_heur=100.0000196958268 ratio=100, k_srv_heur=32788904, k_srv=32788904, k_req=32788897
# Episode 187/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 49.563104737612434, ratio_heur=100.00006161748117 ratio=100, k_srv_heur=12950020, k_srv=12950020, k_req=12950012
# Episode 188/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 16.027460716578325, ratio_heur=99.99997287146186 ratio=99, k_srv_heur=9624396, k_srv=9624396, k_req=9624399
# Episode 189/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 35.85696418130392, ratio_heur=100.00000317144388 ratio=100, k_srv_heur=21531904, k_srv=21531904, k_req=21531903
# Episode 190/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 20.729785959278516, ratio_heur=100.00010322011215 ratio=100, k_srv_heur=5416352, k_srv=5416352, k_req=5416347
# Episode 191/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 56.17315469140016, ratio_heur=100.00002421377987 ratio=100, k_srv_heur=33731668, k_srv=33731668, k_req=33731660
# Episode 192/4000, total reward: 48.000, entropy_coef: 0.0083, demands: 1, mean_kbps_rand: 20.648691196824586, ratio_heur=100.00003314077183 ratio=100, k_srv_heur=12399425, k_srv=12399425, k_req=12399421
# Episode 193/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 35.33391563261991, ratio_heur=99.99994517941099 ratio=99, k_srv_heur=21217804, k_srv=21217804, k_req=21217815
# Episode 194/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 56.13759105238333, ratio_heur=100.00004999161519 ratio=100, k_srv_heur=14667823, k_srv=14667823, k_req=14667816
# Episode 195/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 41.3197968915269, ratio_heur=100.00000660859989 ratio=100, k_srv_heur=24812305, k_srv=24812305, k_req=24812303
# Episode 196/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 12.328228395321863, ratio_heur=100.0001829811469 ratio=100, k_srv_heur=2736855, k_srv=2736855, k_req=2736849
# Episode 197/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 47.74542894007658, ratio_heur=99.99999322465538 ratio=99, k_srv_heur=28670857, k_srv=28670857, k_req=28670859
# Episode 198/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 48.93980812036218, ratio_heur=100.00001968081148 ratio=100, k_srv_heur=10864573, k_srv=10864573, k_req=10864571
# Episode 199/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 5.899685980547582, ratio_heur=99.99965715709163 ratio=99, k_srv_heur=1309717, k_srv=1309717, k_req=1309722
# Episode 200/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 25.9213538541751, ratio_heur=100.00007005018443 ratio=100, k_srv_heur=15565636, k_srv=15565636, k_req=15565625
# Episode 201/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 1.614743690523913, ratio_heur=100.00085302292658 ratio=100, k_srv_heur=421909, k_srv=421909, k_req=421905
# Episode 202/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 49.26414222848688, ratio_heur=99.99997279353323 ratio=99, k_srv_heur=12871895, k_srv=12871895, k_req=12871898
# Episode 203/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 1.507268446352132, ratio_heur=99.99983506427925 ratio=99, k_srv_heur=334611, k_srv=334611, k_req=334611
# Episode 204/4000, total reward: 48.000, entropy_coef: 0.0082, demands: 1, mean_kbps_rand: 7.453187479846327, ratio_heur=100.00052330492026 ratio=100, k_srv_heur=1947403, k_srv=1947403, k_req=1947393
# Episode 205/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 15.227067889713878, ratio_heur=99.99990091249168 ratio=99, k_srv_heur=9143758, k_srv=9143758, k_req=9143767
# Episode 206/4000, total reward: 46.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 44.27245641270187, ratio_heur=100.00000132564273 ratio=98, k_srv_heur=26585359, k_srv=26118948, k_req=26585358
# Episode 207/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 4.228480012267771, ratio_heur=99.99964530489771 ratio=99, k_srv_heur=1104827, k_srv=1104827, k_req=1104831
# Episode 208/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 29.844477827365484, ratio_heur=99.99987892675041 ratio=99, k_srv_heur=6625425, k_srv=6625425, k_req=6625433
# Episode 209/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 3.068145337371671, ratio_heur=100.00067155972042 ratio=100, k_srv_heur=801660, k_srv=801660, k_req=801655
# Episode 210/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 42.36614976796636, ratio_heur=100.00000894267332 ratio=100, k_srv_heur=25440634, k_srv=25440634, k_req=25440632
# Episode 211/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 57.52146847373056, ratio_heur=99.99997630079514 ratio=99, k_srv_heur=15029397, k_srv=15029397, k_req=15029400
# Episode 212/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 18.1857706413567, ratio_heur=100.00004383126135 ratio=100, k_srv_heur=4037218, k_srv=4037218, k_req=4037216
# Episode 213/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 28.053242762939792, ratio_heur=100.00000537180173 ratio=100, k_srv_heur=6227782, k_srv=6227782, k_req=6227781
# Episode 214/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 45.499541630380584, ratio_heur=100.0000863111175 ratio=100, k_srv_heur=11888281, k_srv=11888281, k_req=11888271
# Episode 215/4000, total reward: 48.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 61.90311565338929, ratio_heur=99.99999979889074 ratio=99, k_srv_heur=37172469, k_srv=37172469, k_req=37172469
# Episode 216/4000, total reward: 46.000, entropy_coef: 0.0081, demands: 1, mean_kbps_rand: 37.00467741879245, ratio_heur=100.00003621638378 ratio=98, k_srv_heur=8214991, k_srv=8070868, k_req=8214988
# Episode 217/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 25.416961836355988, ratio_heur=99.9999526206032 ratio=99, k_srv_heur=5642528, k_srv=5642528, k_req=5642531
# Episode 218/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 59.65417758930585, ratio_heur=100.00003313861312 ratio=100, k_srv_heur=35822006, k_srv=35822006, k_req=35821995
# Episode 219/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 55.35149050638375, ratio_heur=99.9999685869113 ratio=99, k_srv_heur=12287952, k_srv=12287952, k_req=12287955
# Episode 220/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 47.99116285699932, ratio_heur=100.00002058565968 ratio=100, k_srv_heur=12539293, k_srv=12539293, k_req=12539290
# Episode 221/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 20.243531011658163, ratio_heur=99.99998677408676 ratio=99, k_srv_heur=5289296, k_srv=5289296, k_req=5289297
# Episode 222/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 7.047077583180451, ratio_heur=100.00014854119725 ratio=100, k_srv_heur=1841286, k_srv=1841286, k_req=1841283
# Episode 223/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 23.21471031298286, ratio_heur=99.99999572151685 ratio=99, k_srv_heur=5153634, k_srv=5153634, k_req=5153634
# Episode 224/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 23.5051242644294, ratio_heur=100.00000601511319 ratio=100, k_srv_heur=6141497, k_srv=6141497, k_req=6141497
# Episode 225/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 4.070945280586754, ratio_heur=100.0001622283436 ratio=100, k_srv_heur=903745, k_srv=903745, k_req=903744
# Episode 226/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 21.94239970611942, ratio_heur=100.00001131353858 ratio=100, k_srv_heur=13176288, k_srv=13176288, k_req=13176286
# Episode 227/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 61.59182216039726, ratio_heur=99.99998938382255 ratio=99, k_srv_heur=16092914, k_srv=16092914, k_req=16092916
# Episode 228/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 53.754608420151676, ratio_heur=99.99998785391575 ratio=99, k_srv_heur=32279333, k_srv=32279333, k_req=32279337
# Episode 229/4000, total reward: 48.000, entropy_coef: 0.0080, demands: 1, mean_kbps_rand: 39.20998330500293, ratio_heur=100.00004660984882 ratio=100, k_srv_heur=10244919, k_srv=10244919, k_req=10244914
# Episode 230/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 46.30170433029956, ratio_heur=99.99998666759254 ratio=99, k_srv_heur=27803907, k_srv=27803907, k_req=27803910
# Episode 231/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 16.12573902910284, ratio_heur=100.00015070236357 ratio=100, k_srv_heur=3579897, k_srv=3579897, k_req=3579892
# Episode 232/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 11.379441166156452, ratio_heur=100.00011339340058 ratio=100, k_srv_heur=2973261, k_srv=2973261, k_req=2973258
# Episode 233/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 6.385814236286894, ratio_heur=100.00011964649191 ratio=100, k_srv_heur=3834649, k_srv=3834649, k_req=3834645
# Episode 234/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 44.78837510525168, ratio_heur=99.9999659512787 ratio=99, k_srv_heur=11702451, k_srv=11702451, k_req=11702455
# Episode 235/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 11.254247615055558, ratio_heur=99.99991698221001 ratio=99, k_srv_heur=2940544, k_srv=2940544, k_req=2940547
# Episode 236/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 4.325109530024631, ratio_heur=100.0003716103843 ratio=100, k_srv_heur=1130083, k_srv=1130083, k_req=1130079
# Episode 237/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 5.445787505346061, ratio_heur=99.99988702946179 ratio=99, k_srv_heur=3270160, k_srv=3270160, k_req=3270164
# Episode 238/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 32.39630643999321, ratio_heur=99.99994766419775 ratio=99, k_srv_heur=19453788, k_srv=19453788, k_req=19453798
# Episode 239/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 58.32110922175291, ratio_heur=100.0000433349409 ratio=100, k_srv_heur=12947212, k_srv=12947212, k_req=12947207
# Episode 240/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 58.586157394749634, ratio_heur=100.00001858169345 ratio=100, k_srv_heur=35180661, k_srv=35180661, k_req=35180655
# Episode 241/4000, total reward: 48.000, entropy_coef: 0.0079, demands: 1, mean_kbps_rand: 5.753670376442423, ratio_heur=100.00037723207681 ratio=100, k_srv_heur=1503343, k_srv=1503343, k_req=1503338
# Episode 242/4000, total reward: 48.000, entropy_coef: 0.0078, demands: 1, mean_kbps_rand: 12.288367214875384, ratio_heur=99.99994876028656 ratio=99, k_srv_heur=7379090, k_srv=7379090, k_req=7379094
# ...
# Episode 3923/4000, total reward: -10.807, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 872.0626869897409, ratio_heur=34.67909070130662 ratio=16, k_srv_heur=248741128, k_srv=118488999, k_req=717265429
# Episode 3924/4000, total reward: -10.637, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 478.7281559944632, ratio_heur=44.93359520338931 ratio=23, k_srv_heur=176926274, k_srv=92515600, k_req=393750542
# Episode 3925/4000, total reward: -6.011, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 752.8613070574854, ratio_heur=69.50049264504602 ratio=55, k_srv_heur=252873577, k_srv=201662528, k_req=363844295
# Episode 3926/4000, total reward: -6.878, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 719.1881561849299, ratio_heur=69.14829241806164 ratio=55, k_srv_heur=240339182, k_srv=192716607, k_req=347570668
# Episode 3927/4000, total reward: -9.108, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 651.8061843412148, ratio_heur=41.26907488758981 ratio=22, k_srv_heur=221245988, k_srv=122796142, k_req=536106004
# Episode 3928/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 240.74883025159036, ratio_heur=99.40408397537752 ratio=100, k_srv_heur=53127421, k_srv=53445916, k_req=53445913
# Episode 3929/4000, total reward: -9.127, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 558.5164918003026, ratio_heur=48.10439179725354 ratio=29, k_srv_heur=231534629, k_srv=142588330, k_req=481317030
# Episode 3930/4000, total reward: 47.020, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 905.5895927823042, ratio_heur=98.19969658741127 ratio=99, k_srv_heur=232355663, k_srv=236096841, k_req=236615460
# Episode 3931/4000, total reward: -1.345, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 206.84924280373033, ratio_heur=68.52030391374994 ratio=57, k_srv_heur=153607656, k_srv=129503187, k_req=224178306
# Episode 3932/4000, total reward: -8.498, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 871.3230021151941, ratio_heur=35.544766135785885 ratio=19, k_srv_heur=335656056, k_srv=186521481, k_req=944319215
# Episode 3933/4000, total reward: 2.776, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 362.08344632192603, ratio_heur=49.97991148760741 ratio=45, k_srv_heur=155955027, k_srv=140759557, k_req=312035421
# Episode 3934/4000, total reward: 34.167, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 160.4712650606253, ratio_heur=73.80668080621294 ratio=86, k_srv_heur=71121655, k_srv=82876491, k_req=96362084
# Episode 3935/4000, total reward: -5.756, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 619.2160163664047, ratio_heur=44.33610051340571 ratio=32, k_srv_heur=236589192, k_srv=171874499, k_req=533626523
# Episode 3936/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 365.58583763857496, ratio_heur=95.64343379290283 ratio=99, k_srv_heur=77623790, k_srv=81159559, k_req=81159560
# Episode 3937/4000, total reward: -16.336, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 136.18095870358735, ratio_heur=73.94192117746763 ratio=36, k_srv_heur=82820779, k_srv=40590304, k_req=112007881
# Episode 3938/4000, total reward: 47.021, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 865.6396957996703, ratio_heur=93.54908200520214 ratio=99, k_srv_heur=211586711, k_srv=225936628, k_req=226177218
# Episode 3939/4000, total reward: -11.369, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 139.30739739489445, ratio_heur=73.3053136559975 ratio=50, k_srv_heur=110674936, k_srv=76289833, k_req=150978055
# Episode 3940/4000, total reward: 47.020, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 879.5440620302918, ratio_heur=93.7192485417344 ratio=99, k_srv_heur=215376390, k_srv=229505196, k_req=229810197
# Episode 3941/4000, total reward: -13.994, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 249.22351306076456, ratio_heur=56.676304919686636 ratio=28, k_srv_heur=116177689, k_srv=58965051, k_req=204984587
# Episode 3942/4000, total reward: -29.601, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 31.043600289209163, ratio_heur=100.00002344353885 ratio=34, k_srv_heur=26752687, k_srv=9179935, k_req=26752680
# Episode 3943/4000, total reward: -7.057, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 932.1999815475353, ratio_heur=28.556894520036526 ratio=15, k_srv_heur=218953686, k_srv=119132955, k_req=766727931
# Episode 3944/4000, total reward: -3.965, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 566.2010197611268, ratio_heur=37.910896000896024 ratio=30, k_srv_heur=232634619, k_srv=185297002, k_req=613635243
# Episode 3945/4000, total reward: 31.581, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 169.30532435547826, ratio_heur=68.928251850176 ratio=82, k_srv_heur=70077207, k_srv=83455810, k_req=101666886
# Episode 3946/4000, total reward: -6.128, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 670.0828797258705, ratio_heur=42.6726442631891 ratio=30, k_srv_heur=246418497, k_srv=175463920, k_req=577462449
# Episode 3947/4000, total reward: -8.071, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 608.556677408217, ratio_heur=41.13022905106851 ratio=25, k_srv_heur=205870611, k_srv=126252021, k_req=500533588
# Episode 3948/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 116.79719619197195, ratio_heur=100.00001685866073 ratio=100, k_srv_heur=25928823, k_srv=25928823, k_req=25928819
# Episode 3949/4000, total reward: -10.748, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 943.6604805903681, ratio_heur=58.857529497117845 ratio=36, k_srv_heur=268422174, k_srv=167699035, k_req=456054095
# Episode 3950/4000, total reward: -7.114, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 278.4263762754261, ratio_heur=55.122803396375154 ratio=39, k_srv_heur=166334110, k_srv=120400020, k_req=301751906
# Episode 3951/4000, total reward: -5.983, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 509.4790357306277, ratio_heur=44.25876710180204 ratio=31, k_srv_heur=244379784, k_srv=171365934, k_req=552161301
# Episode 3952/4000, total reward: 45.039, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 962.7569546460855, ratio_heur=95.87968751506865 ratio=98, k_srv_heur=241187596, k_srv=246862666, k_req=251552338
# Episode 3953/4000, total reward: -9.139, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 219.3348816230425, ratio_heur=61.727492699411236 ratio=40, k_srv_heur=146732389, k_srv=97053515, k_req=237709945
# Episode 3954/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 464.56956073495314, ratio_heur=98.4440259816623 ratio=100, k_srv_heur=101529077, k_srv=103133813, k_req=103133812
# Episode 3955/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 275.9280999214048, ratio_heur=98.54786083719142 ratio=99, k_srv_heur=71048485, k_srv=72095410, k_req=72095411
# Episode 3956/4000, total reward: -6.823, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 469.4699747656015, ratio_heur=46.53772671153705 ratio=34, k_srv_heur=236784153, k_srv=175910869, k_req=508800429
# Episode 3957/4000, total reward: 5.855, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 199.64539477299704, ratio_heur=67.61393549211198 ratio=68, k_srv_heur=111026770, k_srv=112452476, k_req=164206933
# Episode 3958/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 3.83247934457459, ratio_heur=99.99995226132219 ratio=99, k_srv_heur=2301380, k_srv=2301380, k_req=2301382
# Episode 3959/4000, total reward: -10.156, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 388.1613915558221, ratio_heur=46.80967820645978 ratio=26, k_srv_heur=149444586, k_srv=84132671, k_req=319260015
# Episode 3960/4000, total reward: -6.039, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 830.2917202304284, ratio_heur=41.54897552602824 ratio=29, k_srv_heur=297294075, k_srv=212598840, k_req=715526848
# Episode 3961/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 105.91331667570952, ratio_heur=98.86319478105663 ratio=99, k_srv_heur=62877333, k_srv=63573908, k_req=63600345
# Episode 3962/4000, total reward: -10.477, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 407.4762488724727, ratio_heur=51.45180395218462 ratio=30, k_srv_heur=180675028, k_srv=106466747, k_req=351153924
# Episode 3963/4000, total reward: -4.205, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 986.2484758811322, ratio_heur=29.216502559410795 ratio=21, k_srv_heur=312287225, k_srv=226237532, k_req=1068872719
# Episode 3964/4000, total reward: -8.783, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 469.4852048076957, ratio_heur=71.65905850645773 ratio=54, k_srv_heur=162589913, k_srv=122668653, k_req=226893734
# Episode 3965/4000, total reward: -5.604, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 832.6087585367416, ratio_heur=34.14768332547879 ratio=22, k_srv_heur=308135593, k_srv=204374865, k_req=902361635
# Episode 3966/4000, total reward: -9.964, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 410.625140717907, ratio_heur=46.284546062380095 ratio=26, k_srv_heur=156319709, k_srv=89296578, k_req=337736291
# Episode 3967/4000, total reward: -3.563, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 908.6468272772378, ratio_heur=31.039874802268614 ratio=23, k_srv_heur=305671341, k_srv=235012773, k_req=984769892
# Episode 3968/4000, total reward: -6.460, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 729.247847299265, ratio_heur=36.76479535597683 ratio=23, k_srv_heur=290567446, k_srv=186990371, k_req=790341530
# Episode 3969/4000, total reward: -6.870, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 559.8403471058239, ratio_heur=42.510249444487535 ratio=28, k_srv_heur=257927409, k_srv=175016352, k_req=606741697
# Episode 3970/4000, total reward: -10.444, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 389.59738927712795, ratio_heur=75.35520456537189 ratio=54, k_srv_heur=141882843, k_srv=101795302, k_req=188285393
# Episode 3971/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 284.71180451726985, ratio_heur=94.86719464375581 ratio=99, k_srv_heur=70572130, k_srv=74390445, k_req=74390447
# Episode 3972/4000, total reward: -4.395, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 672.6963164174, ratio_heur=36.47659657917136 ratio=27, k_srv_heur=265933474, k_srv=203810295, k_req=729052321
# Episode 3973/4000, total reward: -8.720, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 403.1474668075366, ratio_heur=50.223691950984474 ratio=32, k_srv_heur=219438192, k_srv=141081586, k_req=436921667
# Episode 3974/4000, total reward: -9.430, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 416.5956763976988, ratio_heur=48.414832167575696 ratio=29, k_srv_heur=218591281, k_srv=133574376, k_req=451496518
# Episode 3975/4000, total reward: -11.830, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 160.8743752748996, ratio_heur=70.51608180900115 ratio=43, k_srv_heur=122946082, k_srv=75972697, k_req=174351834
# Episode 3976/4000, total reward: -9.520, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 356.67257782739165, ratio_heur=50.52886921475188 ratio=30, k_srv_heur=155311826, k_srv=94001470, k_req=307372456
# Episode 3977/4000, total reward: -10.484, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 386.39335571828, ratio_heur=47.03108855100246 ratio=26, k_srv_heur=149467536, k_srv=83135672, k_req=317805818
# Episode 3978/4000, total reward: -12.446, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 886.3708535743434, ratio_heur=64.16498824234314 ratio=38, k_srv_heur=274861668, k_srv=164181457, k_req=428367052
# Episode 3979/4000, total reward: -7.838, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 572.8919986071268, ratio_heur=46.33148446009446 ratio=30, k_srv_heur=228741096, k_srv=152820656, k_req=493705520
# Episode 3980/4000, total reward: 7.313, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 751.3072414089526, ratio_heur=17.51650395891764 ratio=24, k_srv_heur=79026712, k_srv=111762917, k_req=451155735
# Episode 3981/4000, total reward: -6.780, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 918.1379833021831, ratio_heur=38.301430224369895 ratio=21, k_srv_heur=303052710, k_srv=172622277, k_req=791230794
# Episode 3982/4000, total reward: -2.951, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 310.9529592951838, ratio_heur=54.33380479112454 ratio=41, k_srv_heur=183106794, k_srv=140625804, k_req=337003446
# Episode 3983/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 30.919904496456347, ratio_heur=99.99999917874968 ratio=99, k_srv_heur=8078855, k_srv=8078855, k_req=8078855
# Episode 3984/4000, total reward: -8.652, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 507.85307808123946, ratio_heur=48.29551069653375 ratio=32, k_srv_heur=211368409, k_srv=140957235, k_req=437656432
# Episode 3985/4000, total reward: -6.473, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 468.3444855045146, ratio_heur=44.88388924660345 ratio=33, k_srv_heur=227821937, k_srv=168313240, k_req=507580651
# Episode 3986/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 448.4879100235866, ratio_heur=99.86295015870917 ratio=100, k_srv_heur=117021814, k_srv=117182415, k_req=117182412
# Episode 3987/4000, total reward: -5.222, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 694.8356273778878, ratio_heur=65.13037190698637 ratio=54, k_srv_heur=218708785, k_srv=184589740, k_req=335801530
# Episode 3988/4000, total reward: -4.353, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 591.267601538279, ratio_heur=39.22204142026279 ratio=31, k_srv_heur=251335551, k_srv=199476455, k_req=640801810
# Episode 3989/4000, total reward: -8.404, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 986.2383592941412, ratio_heur=33.280230730511484 ratio=17, k_srv_heur=269960617, k_srv=138978214, k_req=811174117
# Episode 3990/4000, total reward: 32.022, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 834.6341055019233, ratio_heur=81.87884717038469 ratio=87, k_srv_heur=151711383, k_srv=162968594, k_req=185287640
# Episode 3991/4000, total reward: 47.020, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 886.2368185899409, ratio_heur=99.52651830925183 ratio=99, k_srv_heur=230462514, k_srv=231220351, k_req=231558903
# Episode 3992/4000, total reward: -10.703, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 828.970373899934, ratio_heur=32.337893622275445 ratio=15, k_srv_heur=220486971, k_srv=108834789, k_req=681822304
# Episode 3993/4000, total reward: -31.358, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 20.025495511395537, ratio_heur=100.00002503976573 ratio=29, k_srv_heur=16470833, k_srv=4937652, k_req=16470829
# Episode 3994/4000, total reward: 48.000, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 380.4738637601378, ratio_heur=91.31672514017963 ratio=100, k_srv_heur=90779304, k_srv=99411481, k_req=99411476
# Episode 3995/4000, total reward: -5.669, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 661.4613008197226, ratio_heur=65.07102546149383 ratio=53, k_srv_heur=208014057, k_srv=172472967, k_req=319672320
# Episode 3996/4000, total reward: -6.380, entropy_coef: 0.0010, demands: 2, mean_kbps_rand: 679.4418034619168, ratio_heur=66.75582105572693 ratio=54, k_srv_heur=219200731, k_srv=177822750, k_req=328361973
# Episode 3997/4000, total reward: -5.156, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 669.3833666496039, ratio_heur=37.487109722931585 ratio=26, k_srv_heur=271954670, k_srv=189397918, k_req=725461825
# Episode 3998/4000, total reward: -7.630, entropy_coef: 0.0010, demands: 3, mean_kbps_rand: 343.9924156696699, ratio_heur=51.4078021135295 ratio=34, k_srv_heur=191653851, k_srv=129743424, k_req=372810825
# Episode 3999/4000, total reward: 24.746, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 992.0704008813851, ratio_heur=63.15254884784432 ratio=75, k_srv_heur=139086089, k_srv=166659370, k_req=220238284
# Episode 4000/4000, total reward: 9.376, entropy_coef: 0.0010, demands: 1, mean_kbps_rand: 543.2784280203965, ratio_heur=20.456691885168937 ratio=31, k_srv_heur=66737014, k_srv=102989748, k_req=326235613

# %%
# === Plot learning curve with running average ===
window = 200                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,3))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=3)
plt.xlabel("Episode", fontsize=15)
plt.ylabel("Total Reward", fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.savefig("learning.pdf", format="pdf", dpi=300, bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %%
NUM_DATA    = 100
N_RUNS      = 2   # number of Monte-Carlo runs

demand_list = [0.01 + 0.2 * i for i in range(NUM_DATA)]

# %% [markdown]
# ## Testing the Agent

# %%
def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=True):
    agent.model.eval() 
    test_rewards = []

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes (Dual-Head) ---")

    demand_list = [0.01 + 0.2 * i for i in range(num_test_episodes)]
    key_req     = [0 for i in range(num_test_episodes)]
    key_srv_qkp = [0 for i in range(num_test_episodes)]
    a_lst_qkp   = [0 for i in range(num_test_episodes)]
    
    for idx, mean in enumerate(demand_list):
        demands = generate_demands(gnodes, syst, mean_kbps=mean, amp=0.5, noise_std=0.0, pattern="stadium")
        key_req[idx] = sum(d.K_REQ[t] * syst.THETA for d in demands for t in syst.T)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands 
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} 

        ep_reward = 0
        
        for t in syst.T:
            r = random.randint(0, len(hnodes)-1)
            
            hnodes_active = [1 for h in hnodes]
            links_active  = [1 if ((isinstance(l.n1, hap) and hnodes_active[hnodes.index(l.n1)] == 1) or (isinstance(l.n2, hap) and hnodes_active[hnodes.index(l.n2)] == 1)) else 0 for l in links]
            
            s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes)

            with torch.no_grad():
                s_tensor = torch.tensor(s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
                probs, _ = agent.model(s_tensor) # probs shape: [1, 2, n_haps, n_choices]
                
                # --- CHANGE 1: Extract argmax for both heads ---
                # argmax over the last dimension (n_choices)
                # Resulting shape after squeeze: [2, n_haps]
                hap_picks = torch.argmax(probs, dim=-1).squeeze(0).cpu().numpy()

            # --- CHANGE 2: Pass the [2, n_haps] matrix to z_dict ---
            # Your updated get_z_from_demand_choices should handle the 2-row matrix
            z_dict = get_z_from_demand_choices(hap_picks, demands, links, hnodes)

            # 2. Constraint Check
            # With the dual-head, the model naturally picks at most 1 TX and 1 RX per HAP.
            check_tx, check_rx = True, True
            for idx_h, h in enumerate(hnodes):
                used_tx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n1 == h)
                used_rx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n2 == h)
                
                if used_tx > h.N_TX or used_rx > h.N_RX:
                    check_tx, check_rx = False, False

            # 3. Step Environment
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0)
            else:
                reward_t = -1.0 

            ep_reward += reward_t
            key_srv_qkp[idx] += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(demands))

            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        a_lst_qkp[idx] = sum(state[-1]["a"][i] for i in range(len(links))) * 1e-6
        
        print(f"Test Case {idx+1}: Mean_kbps={mean:.2f}, key_srv_qkp={key_srv_qkp[idx]:.2f}, key_req={key_req[idx]:.2f}, ep_reward: {ep_reward}")

    return test_rewards, key_srv_qkp, a_lst_qkp

prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

key_srv_ppo_qkp = [0 for i in range(NUM_DATA)]
a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]

# Run the test
results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.
# --- Starting Evaluation for 100 Episodes (Dual-Head) ---
# Test Case 1: Mean_kbps=0.01, key_srv_qkp=600501.60, key_req=1083776.30, ep_reward: 26.596035520909638
# Test Case 2: Mean_kbps=0.21, key_srv_qkp=12610378.80, key_req=22759302.20, ep_reward: 26.595637703521785
# Test Case 3: Mean_kbps=0.41, key_srv_qkp=24620257.80, key_req=44434828.10, ep_reward: 26.595633815031402
# Test Case 4: Mean_kbps=0.61, key_srv_qkp=36630162.00, key_req=66110354.01, ep_reward: 26.59564845653745
# Test Case 5: Mean_kbps=0.81, key_srv_qkp=48640039.20, key_req=87785879.91, ep_reward: 26.595642417158913
# Test Case 6: Mean_kbps=1.01, key_srv_qkp=60649929.00, key_req=109461405.81, ep_reward: 26.595644052393304
# Test Case 7: Mean_kbps=1.21, key_srv_qkp=73091935.80, key_req=131136931.72, ep_reward: 26.7843969282115
# Test Case 8: Mean_kbps=1.41, key_srv_qkp=81432727.20, key_req=152812457.62, ep_reward: 25.315816126956364
# Test Case 9: Mean_kbps=1.61, key_srv_qkp=82915700.40, key_req=174487983.53, ep_reward: 22.645368048403107
# Test Case 10: Mean_kbps=1.81, key_srv_qkp=84414299.40, key_req=196163509.43, ep_reward: 20.732952270443366
# Test Case 11: Mean_kbps=2.01, key_srv_qkp=85853581.20, key_req=217839035.33, ep_reward: 19.11239748248585
# Test Case 12: Mean_kbps=2.21, key_srv_qkp=85175550.00, key_req=239514561.24, ep_reward: 17.444480260270794
# Test Case 13: Mean_kbps=2.41, key_srv_qkp=79944568.20, key_req=261190087.14, ep_reward: 15.268844101224724
# Test Case 14: Mean_kbps=2.61, key_srv_qkp=67844602.80, key_req=282865613.05, ep_reward: 12.145785498693845
# Test Case 15: Mean_kbps=2.81, key_srv_qkp=64763794.80, key_req=304541138.95, ep_reward: 10.729476072807701
# Test Case 16: Mean_kbps=3.01, key_srv_qkp=65233350.00, key_req=326216664.85, ep_reward: 10.112123985800972
# Test Case 17: Mean_kbps=3.21, key_srv_qkp=66288630.60, key_req=347892190.76, ep_reward: 9.65469429983465
# Test Case 18: Mean_kbps=3.41, key_srv_qkp=66818847.60, key_req=369567716.66, ep_reward: 9.176931276943924
# Test Case 19: Mean_kbps=3.61, key_srv_qkp=66526801.20, key_req=391243242.56, ep_reward: 8.63617970314705
# Test Case 20: Mean_kbps=3.81, key_srv_qkp=66584440.80, key_req=412918768.47, ep_reward: 8.194720751872572
# Test Case 21: Mean_kbps=4.01, key_srv_qkp=67243966.20, key_req=434594294.37, ep_reward: 6.873888559635461
# Test Case 22: Mean_kbps=4.21, key_srv_qkp=67876248.60, key_req=456269820.28, ep_reward: 6.578698880364662
# Test Case 23: Mean_kbps=4.41, key_srv_qkp=66527766.00, key_req=477945346.18, ep_reward: 6.076569053264567
# Test Case 24: Mean_kbps=4.61, key_srv_qkp=67841665.20, key_req=499620872.08, ep_reward: 5.920660054243432
# Test Case 25: Mean_kbps=4.81, key_srv_qkp=70890008.40, key_req=521296397.99, ep_reward: 5.966133115049405
# Test Case 26: Mean_kbps=5.01, key_srv_qkp=68945470.20, key_req=542971923.89, ep_reward: 5.4843557058565455
# Test Case 27: Mean_kbps=5.21, key_srv_qkp=69577754.40, key_req=564647449.80, ep_reward: 5.299243946620745
# Test Case 28: Mean_kbps=5.41, key_srv_qkp=70210040.40, key_req=586322975.70, ep_reward: 5.127818998765768
# Test Case 29: Mean_kbps=5.61, key_srv_qkp=68721616.80, key_req=607998501.60, ep_reward: 4.7699050752052425
# Test Case 30: Mean_kbps=5.81, key_srv_qkp=69234726.60, key_req=629674027.51, ep_reward: 4.617725707895277
# Test Case 31: Mean_kbps=6.01, key_srv_qkp=69583566.60, key_req=651349553.41, ep_reward: 4.46129953145958
# Test Case 32: Mean_kbps=6.21, key_srv_qkp=69885975.60, key_req=673025079.31, ep_reward: 4.311016805867715
# Test Case 33: Mean_kbps=6.41, key_srv_qkp=70188384.60, key_req=694700605.22, ep_reward: 4.170112097473471
# Test Case 34: Mean_kbps=6.61, key_srv_qkp=67900379.40, key_req=716376131.12, ep_reward: 3.8316407358855207
# Test Case 35: Mean_kbps=6.81, key_srv_qkp=68111083.80, key_req=738051657.03, ep_reward: 3.7060139959166225
# Test Case 36: Mean_kbps=7.01, key_srv_qkp=68321782.80, key_req=759727182.93, ep_reward: 3.5875552810650944
# Test Case 37: Mean_kbps=7.21, key_srv_qkp=68532485.40, key_req=781402708.83, ep_reward: 3.475668740856317
# Test Case 38: Mean_kbps=7.41, key_srv_qkp=66541865.40, key_req=803078234.74, ep_reward: 3.2135803450344658
# Test Case 39: Mean_kbps=7.61, key_srv_qkp=66725235.00, key_req=824753760.64, ep_reward: 3.115514336979623
# Test Case 40: Mean_kbps=7.81, key_srv_qkp=66908606.40, key_req=846429286.55, ep_reward: 3.0224710369789562
# Test Case 41: Mean_kbps=8.01, key_srv_qkp=67091977.80, key_req=868104812.45, ep_reward: 2.9340740940320056
# Test Case 42: Mean_kbps=8.21, key_srv_qkp=67275347.40, key_req=889780338.35, ep_reward: 2.849983829602267
# Test Case 43: Mean_kbps=8.41, key_srv_qkp=67458718.80, key_req=911455864.26, ep_reward: 2.76989321467602
# Test Case 44: Mean_kbps=8.61, key_srv_qkp=67642090.20, key_req=933131390.16, ep_reward: 2.6935234180971026
# Test Case 45: Mean_kbps=8.81, key_srv_qkp=67750466.40, key_req=954806916.07, ep_reward: 2.616144626851557
# Test Case 46: Mean_kbps=9.01, key_srv_qkp=67842145.80, key_req=976482441.97, ep_reward: 2.5412265787680695
# Test Case 47: Mean_kbps=9.21, key_srv_qkp=67933823.40, key_req=998157967.87, ep_reward: 2.469562197628363
# Test Case 48: Mean_kbps=9.41, key_srv_qkp=68022271.80, key_req=1019833493.78, ep_reward: 2.40076364076423
# Test Case 49: Mean_kbps=9.61, key_srv_qkp=68022271.80, key_req=1041509019.68, ep_reward: 2.3299881227462444
# Test Case 50: Mean_kbps=9.81, key_srv_qkp=68022271.80, key_req=1063184545.58, ep_reward: 2.2620984566352105
# Test Case 51: Mean_kbps=10.01, key_srv_qkp=68022271.80, key_req=1084860071.49, ep_reward: 2.1969216642948464
# Test Case 52: Mean_kbps=10.21, key_srv_qkp=68022271.80, key_req=1106535597.39, ep_reward: 2.1342983212136546
# Test Case 53: Mean_kbps=10.41, key_srv_qkp=68022271.80, key_req=1128211123.30, ep_reward: 2.0740812545236706
# Test Case 54: Mean_kbps=10.61, key_srv_qkp=68022271.80, key_req=1149886649.20, ep_reward: 2.016134388274402
# Test Case 55: Mean_kbps=10.81, key_srv_qkp=68022271.80, key_req=1171562175.10, ep_reward: 1.9603317168909724
# Test Case 56: Mean_kbps=11.01, key_srv_qkp=68022271.80, key_req=1193237701.01, ep_reward: 1.9065563905169312
# Test Case 57: Mean_kbps=11.21, key_srv_qkp=68022271.80, key_req=1214913226.91, ep_reward: 1.8546998982686358
# Test Case 58: Mean_kbps=11.41, key_srv_qkp=68022271.80, key_req=1236588752.82, ep_reward: 1.8046613373875036
# Test Case 59: Mean_kbps=11.61, key_srv_qkp=68022271.80, key_req=1258264278.72, ep_reward: 1.7563467579320768
# Test Case 60: Mean_kbps=11.81, key_srv_qkp=68022271.80, key_req=1279939804.62, ep_reward: 1.7096685740551576
# Test Case 61: Mean_kbps=12.01, key_srv_qkp=68022271.80, key_req=1301615330.53, ep_reward: 1.664545034104198
# Test Case 62: Mean_kbps=12.21, key_srv_qkp=68022271.80, key_req=1323290856.43, ep_reward: 1.620899742800279
# Test Case 63: Mean_kbps=12.41, key_srv_qkp=68022271.80, key_req=1344966382.33, ep_reward: 1.5786612296205818
# Test Case 64: Mean_kbps=12.61, key_srv_qkp=68022271.80, key_req=1366641908.24, ep_reward: 1.5377625582546721
# Test Case 65: Mean_kbps=12.81, key_srv_qkp=68022271.80, key_req=1388317434.14, ep_reward: 1.4981409726456998
# Test Case 66: Mean_kbps=13.01, key_srv_qkp=68022271.80, key_req=1409992960.05, ep_reward: 1.4597375756795858
# Test Case 67: Mean_kbps=13.21, key_srv_qkp=68022271.80, key_req=1431668485.95, ep_reward: 1.4224970370621812
# Test Case 68: Mean_kbps=13.41, key_srv_qkp=68022271.80, key_req=1453344011.85, ep_reward: 1.3863673273371675
# Test Case 69: Mean_kbps=13.61, key_srv_qkp=68022271.80, key_req=1475019537.76, ep_reward: 1.3512994753557246
# Test Case 70: Mean_kbps=13.81, key_srv_qkp=68022271.80, key_req=1496695063.66, ep_reward: 1.3172473468205226
# Test Case 71: Mean_kbps=14.01, key_srv_qkp=68022271.80, key_req=1518370589.57, ep_reward: 1.2841674417981028
# Test Case 72: Mean_kbps=14.21, key_srv_qkp=68022271.80, key_req=1540046115.47, ep_reward: 1.2520187093308524
# Test Case 73: Mean_kbps=14.41, key_srv_qkp=68022271.80, key_req=1561721641.37, ep_reward: 1.22076237748726
# Test Case 74: Mean_kbps=14.61, key_srv_qkp=68022271.80, key_req=1583397167.28, ep_reward: 1.1903617973710758
# Test Case 75: Mean_kbps=14.81, key_srv_qkp=68022271.80, key_req=1605072693.18, ep_reward: 1.160782299769846
# Test Case 76: Mean_kbps=15.01, key_srv_qkp=68022271.80, key_req=1626748219.08, ep_reward: 1.1319910632639187
# Test Case 77: Mean_kbps=15.21, key_srv_qkp=68022271.80, key_req=1648423744.99, ep_reward: 1.1039569927410529
# Test Case 78: Mean_kbps=15.41, key_srv_qkp=68022271.80, key_req=1670099270.89, ep_reward: 1.07665060737128
# Test Case 79: Mean_kbps=15.61, key_srv_qkp=68022271.80, key_req=1691774796.80, ep_reward: 1.0500439371935564
# Test Case 80: Mean_kbps=15.81, key_srv_qkp=68022271.80, key_req=1713450322.70, ep_reward: 1.024110427551639
# Test Case 81: Mean_kbps=16.01, key_srv_qkp=68022271.80, key_req=1735125848.60, ep_reward: 0.9988248506927805
# Test Case 82: Mean_kbps=16.21, key_srv_qkp=68022271.80, key_req=1756801374.51, ep_reward: 0.9741632239106361
# Test Case 83: Mean_kbps=16.41, key_srv_qkp=68022271.80, key_req=1778476900.41, ep_reward: 0.9501027336740654
# Test Case 84: Mean_kbps=16.61, key_srv_qkp=68022271.80, key_req=1800152426.32, ep_reward: 0.9266216652372914
# Test Case 85: Mean_kbps=16.81, key_srv_qkp=68022271.80, key_req=1821827952.22, ep_reward: 0.9036993372749205
# Test Case 86: Mean_kbps=17.01, key_srv_qkp=68022271.80, key_req=1843503478.12, ep_reward: 0.881316041128243
# Test Case 87: Mean_kbps=17.21, key_srv_qkp=68022271.80, key_req=1865179004.03, ep_reward: 0.8594529842877058
# Test Case 88: Mean_kbps=17.41, key_srv_qkp=68022271.80, key_req=1886854529.93, ep_reward: 0.8380922377709025
# Test Case 89: Mean_kbps=17.61, key_srv_qkp=68022271.80, key_req=1908530055.84, ep_reward: 0.8172166870863946
# Test Case 90: Mean_kbps=17.81, key_srv_qkp=68022271.80, key_req=1930205581.74, ep_reward: 0.7968099865014835
# Test Case 91: Mean_kbps=18.01, key_srv_qkp=68022271.80, key_req=1951881107.64, ep_reward: 0.776856516357103
# Test Case 92: Mean_kbps=18.21, key_srv_qkp=68022271.80, key_req=1973556633.55, ep_reward: 0.7573413431955748
# Test Case 93: Mean_kbps=18.41, key_srv_qkp=68022271.80, key_req=1995232159.45, ep_reward: 0.738250182487312
# Test Case 94: Mean_kbps=18.61, key_srv_qkp=68022271.80, key_req=2016907685.35, ep_reward: 0.7195693637609571
# Test Case 95: Mean_kbps=18.81, key_srv_qkp=68022271.80, key_req=2038583211.26, ep_reward: 0.7012857979580764
# Test Case 96: Mean_kbps=19.01, key_srv_qkp=68022271.80, key_req=2060258737.16, ep_reward: 0.6833869468485755
# Test Case 97: Mean_kbps=19.21, key_srv_qkp=68022271.80, key_req=2081934263.07, ep_reward: 0.665860794356659
# Test Case 98: Mean_kbps=19.41, key_srv_qkp=68022271.80, key_req=2103609788.97, ep_reward: 0.6486958196595265
# Test Case 99: Mean_kbps=19.61, key_srv_qkp=68022271.80, key_req=2125285314.87, ep_reward: 0.6318809719322498
# Test Case 100: Mean_kbps=19.81, key_srv_qkp=68022271.80, key_req=2146960840.78, ep_reward: 0.6154056466224846

# %% [markdown]
# ## Offline

# %%
key_srv_grd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rnd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rlx_qkp = [0 for i in range(NUM_DATA)]
key_srv_opt_qkp = [0 for i in range(NUM_DATA)]

a_lst_grd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rnd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rlx_qkp = [0 for i in range(NUM_DATA)]
a_lst_opt_qkp = [0 for i in range(NUM_DATA)]

key_req = [0 for i in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)

    result_file = os.path.join(RESULTS_DIR, f"mean_{mean:.4f}.pkl")

    # ------------------------------------------------------------
    # If results exist → load them
    # ------------------------------------------------------------
    if os.path.exists(result_file):
        print(f"[LOAD] idx {idx}, mean={mean}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_grd_qkp[idx] = data["key_srv_grd"]
        a_lst_grd_qkp[idx]   = data["a_lst_grd"]

        key_srv_rlx_qkp[idx] = data["key_srv_rlx"]
        a_lst_rlx_qkp[idx]   = data["a_lst_rlx"]

        key_srv_opt_qkp[idx] = data["key_srv_opt"]
        a_lst_opt_qkp[idx]   = data["a_lst_opt"]

        key_req[idx]         = data["key_req"]

        continue   # skip computation

    # ------------------------------------------------------------
    # Otherwise → compute everything
    # ------------------------------------------------------------
    print(f"[COMPUTE] idx {idx}, mean={mean}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.0,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands for t in syst.T
    )

    ########################################## Greedy (Scarcity + Contention Aware, 1-hop only) ##########################################
    # Z[l][d][t] = 1 if link l is used by demand d at time t
    Z = [[[0 for t in syst.T] for d in demands] for l in links]
    
    # Stored QKP bits per link (already scaled by THETA)
    qkp_s = [0 for _ in links]
    
    for t in syst.T:
    
        # Per-HAP connection limits (up/down)
        max_cnct_up  = [1] * len(hnodes)
        max_cnct_dwn = [1] * len(hnodes)
    
        # --------------------------------------------------------------------------------------------------
        # Step 1: Enumerate feasible 1-hop paths for each demand
        # A path (l1, l2) is feasible if:
        #   - fresh keys can serve it on both links, OR
        #   - stored QKP can cover the demand on both links
        # --------------------------------------------------------------------------------------------------
        feasible_paths = {}   # d -> list of (idx_l1, idx_l2, mid)
    
        for d in demands:
            src, dst = d.n1, d.n2
            feasible_paths[d] = []
    
            for idx_l1, l1 in enumerate(links):
                for idx_l2, l2 in enumerate(links):
                    if l1.n1 == src and l2.n2 == dst and l1.n2 == l2.n1:
                        mid = l1.n2
    
                        fresh_ok = (
                            l1.K_MAX[t] >= d.K_REQ[t] and
                            l2.K_MAX[t] >= d.K_REQ[t]
                        )
    
                        qkp_ok = (
                            qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                            qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                        )
    
                        if fresh_ok or qkp_ok:
                            feasible_paths[d].append((idx_l1, idx_l2, mid))
    
        # --------------------------------------------------------------------------------------------------
        # Step 2: Order demands by scarcity (least number of feasible paths first)
        # --------------------------------------------------------------------------------------------------
        ordered_demands = sorted(
            demands,
            key=lambda d: (
                len(feasible_paths[d]),
                -d.K_REQ[t]
            )
        )
        
        # --------------------------------------------------------------------------------------------------
        # Step 3 (FIXED): Compute link contention
        # How many feasible paths (across all demands) include each link
        # --------------------------------------------------------------------------------------------------
        link_usage = [0] * len(links)
        
        for d in demands:
            for (idx_l1, idx_l2, _) in feasible_paths[d]:
                link_usage[idx_l1] += 1
                link_usage[idx_l2] += 1
    
        # --------------------------------------------------------------------------------------------------
        # Step 4: Greedy allocation
        # For each demand, try least-contended feasible paths first
        # --------------------------------------------------------------------------------------------------
        for d in ordered_demands:
    
            l1_sel = None
            l2_sel = None
            used_qkp_only = False
    
            # # Order this demand's paths by least contention
            # paths = sorted(
            #     feasible_paths[d],
            #     key=lambda p: path_usage[(p[0], p[1])]
            # )
            
            # Order this demand's paths by least link contention
            paths = sorted(
                feasible_paths[d],
                key=lambda p: link_usage[p[0]] + link_usage[p[1]]
            )
    
            for idx_l1, idx_l2, mid in paths:
    
                # Respect HAP connection limits
                if max_cnct_up[hnodes.index(mid)] == 0:
                    continue
                if max_cnct_dwn[hnodes.index(mid)] == 0:
                    continue
    
                # Case 1: Fully served by stored QKP
                if (
                    qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                    qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                ):
                    qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                    qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                    used_qkp_only = True
                    break
    
                # Case 2: Use fresh generation (possibly mixed with QKP later)
                l1_sel = links[idx_l1]
                l2_sel = links[idx_l2]
                break
    
            # --------------------------------------------------------------------------------------------------
            # Step 5: Update state after allocation
            # --------------------------------------------------------------------------------------------------
            if used_qkp_only:
                continue
    
            if l1_sel is not None:
                mid = l1_sel.n2
                max_cnct_up[hnodes.index(mid)] = 0
    
                l_idx = links.index(l1_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l1_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
            if l2_sel is not None:
                mid = l2_sel.n1
                max_cnct_dwn[hnodes.index(mid)] = 0
    
                l_idx = links.index(l2_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l2_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
    # --------------- GREEDY ----------------
    solution, key_srv_grd_qkp[idx], a_lst_grd_qkp[idx] = offline_lp(
        gnodes, hnodes, links, demands, 1, 2, Z
    )

    key_srv_grd_qkp[idx] *= 1e-6
    a_lst_grd_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, SCAR-Q")

    # --------------- RELAXED ----------------
    solution, key_srv_rlx_qkp[idx], a_lst_rlx_qkp[idx] = offline_relaxed(
        gnodes, hnodes, links, demands, 1, 2
    )

    key_srv_rlx_qkp[idx] *= 1e-6
    a_lst_rlx_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, RELAX")

    # --------------- OPTIMAL ----------------
    if case != 1:
        solution, key_srv_opt_qkp[idx], a_lst_opt_qkp[idx] = offline(
            gnodes, hnodes, links, demands, 1, 2
        )
    
        key_srv_opt_qkp[idx] *= 1e-6
        a_lst_opt_qkp[idx]   *= 1e-6
    
        print(f"idx: {idx}, OPTIMAL")

    # ------------------------------------------------------------
    # Save results
    # ------------------------------------------------------------
    data = {
        "key_srv_grd": key_srv_grd_qkp[idx],
        "a_lst_grd":   a_lst_grd_qkp[idx],

        "key_srv_rlx": key_srv_rlx_qkp[idx],
        "a_lst_rlx":   a_lst_rlx_qkp[idx],

        "key_srv_opt": key_srv_opt_qkp[idx],
        "a_lst_opt":   a_lst_opt_qkp[idx],

        "key_req":     key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] idx {idx}")
# Out:
# [LOAD] idx 0, mean=0.01
# [LOAD] idx 1, mean=0.21000000000000002
# [LOAD] idx 2, mean=0.41000000000000003
# [LOAD] idx 3, mean=0.6100000000000001
# [LOAD] idx 4, mean=0.81
# [LOAD] idx 5, mean=1.01
# [LOAD] idx 6, mean=1.2100000000000002
# [LOAD] idx 7, mean=1.4100000000000001
# [LOAD] idx 8, mean=1.61
# [LOAD] idx 9, mean=1.81
# [LOAD] idx 10, mean=2.01
# [LOAD] idx 11, mean=2.21
# [LOAD] idx 12, mean=2.41
# [LOAD] idx 13, mean=2.61
# [LOAD] idx 14, mean=2.81
# [LOAD] idx 15, mean=3.01
# [LOAD] idx 16, mean=3.21
# [LOAD] idx 17, mean=3.41
# [LOAD] idx 18, mean=3.61
# [LOAD] idx 19, mean=3.81
# [LOAD] idx 20, mean=4.01
# [LOAD] idx 21, mean=4.21
# [LOAD] idx 22, mean=4.41
# [LOAD] idx 23, mean=4.61
# [LOAD] idx 24, mean=4.8100000000000005
# [LOAD] idx 25, mean=5.01
# [LOAD] idx 26, mean=5.21
# [LOAD] idx 27, mean=5.41
# [LOAD] idx 28, mean=5.61
# [LOAD] idx 29, mean=5.8100000000000005
# [LOAD] idx 30, mean=6.01
# [LOAD] idx 31, mean=6.21
# [LOAD] idx 32, mean=6.41
# [LOAD] idx 33, mean=6.61
# [LOAD] idx 34, mean=6.8100000000000005
# [LOAD] idx 35, mean=7.01
# [LOAD] idx 36, mean=7.21
# [LOAD] idx 37, mean=7.41
# [LOAD] idx 38, mean=7.61
# [LOAD] idx 39, mean=7.8100000000000005
# [LOAD] idx 40, mean=8.01
# [LOAD] idx 41, mean=8.21
# [LOAD] idx 42, mean=8.41
# [LOAD] idx 43, mean=8.61
# [LOAD] idx 44, mean=8.81
# [LOAD] idx 45, mean=9.01
# [LOAD] idx 46, mean=9.21
# [LOAD] idx 47, mean=9.41
# [LOAD] idx 48, mean=9.610000000000001
# [LOAD] idx 49, mean=9.81
# [LOAD] idx 50, mean=10.01
# [LOAD] idx 51, mean=10.21
# [LOAD] idx 52, mean=10.41
# [LOAD] idx 53, mean=10.610000000000001
# [LOAD] idx 54, mean=10.81
# [LOAD] idx 55, mean=11.01
# [LOAD] idx 56, mean=11.21
# [LOAD] idx 57, mean=11.41
# [LOAD] idx 58, mean=11.610000000000001
# [LOAD] idx 59, mean=11.81
# [LOAD] idx 60, mean=12.01
# [LOAD] idx 61, mean=12.21
# [LOAD] idx 62, mean=12.41
# [LOAD] idx 63, mean=12.610000000000001
# [LOAD] idx 64, mean=12.81
# [LOAD] idx 65, mean=13.01
# [LOAD] idx 66, mean=13.21
# [LOAD] idx 67, mean=13.41
# [LOAD] idx 68, mean=13.610000000000001
# [LOAD] idx 69, mean=13.81
# [LOAD] idx 70, mean=14.01
# [LOAD] idx 71, mean=14.21
# [LOAD] idx 72, mean=14.41
# [LOAD] idx 73, mean=14.610000000000001
# [LOAD] idx 74, mean=14.81
# [LOAD] idx 75, mean=15.01
# [LOAD] idx 76, mean=15.21
# [LOAD] idx 77, mean=15.41
# [LOAD] idx 78, mean=15.610000000000001
# [LOAD] idx 79, mean=15.81
# [LOAD] idx 80, mean=16.01
# [LOAD] idx 81, mean=16.21
# [LOAD] idx 82, mean=16.410000000000004
# [LOAD] idx 83, mean=16.610000000000003
# [LOAD] idx 84, mean=16.810000000000002
# [LOAD] idx 85, mean=17.01
# [LOAD] idx 86, mean=17.21
# [LOAD] idx 87, mean=17.410000000000004
# [LOAD] idx 88, mean=17.610000000000003
# [LOAD] idx 89, mean=17.810000000000002
# [LOAD] idx 90, mean=18.01
# [LOAD] idx 91, mean=18.21
# [LOAD] idx 92, mean=18.410000000000004
# [LOAD] idx 93, mean=18.610000000000003
# [LOAD] idx 94, mean=18.810000000000002
# [LOAD] idx 95, mean=19.01
# [LOAD] idx 96, mean=19.210000000000004
# [LOAD] idx 97, mean=19.410000000000004
# [LOAD] idx 98, mean=19.610000000000003
# [LOAD] idx 99, mean=19.810000000000002

# %%
#Store statistics
key_srv_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

a_lst_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

key_req = [0.0 for _ in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    result_file = os.path.join(RESULTS_DIR, f"idx_{idx}.pkl")

    # ============================================================
    # LOAD IF EXISTS
    # ============================================================
    if os.path.exists(result_file):

        print(f"[LOAD] Random idx {idx}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_rnd_qkp_avg[idx] = data["key_srv_avg"]
        key_srv_rnd_qkp_min[idx] = data["key_srv_min"]
        key_srv_rnd_qkp_max[idx] = data["key_srv_max"]

        a_lst_rnd_qkp_avg[idx] = data["a_lst_avg"]
        a_lst_rnd_qkp_min[idx] = data["a_lst_min"]
        a_lst_rnd_qkp_max[idx] = data["a_lst_max"]

        key_req[idx] = data["key_req"]

        continue

    # ============================================================
    # OTHERWISE COMPUTE
    # ============================================================
    print(f"[COMPUTE] Random idx {idx}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.2,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands
        for t in syst.T
    )

    rnd_results_k_srv = []
    rnd_results_a_lst = []

    # ------------------------------------------------------------
    # Monte Carlo
    # ------------------------------------------------------------
    for run in range(N_RUNS):

        Z = [[[0 for t in syst.T] for d in demands] for l in links]

        for t in syst.T:

            max_cnct_up  = [1 for _ in hnodes]
            max_cnct_dwn = [1 for _ in hnodes]

            shuffled_demands = random.sample(demands, len(demands))

            for d in shuffled_demands:

                src, dst = d.n1, d.n2
                feasible_pairs = []

                for l1 in links:
                    for l2 in links:
                        if (
                            l1.n1 == src and
                            l2.n2 == dst and
                            l1.n2 == l2.n1
                        ):
                            mid = l1.n2
                            if (
                                max_cnct_up[hnodes.index(mid)] > 0 and
                                max_cnct_dwn[hnodes.index(mid)] > 0 and
                                l1.K_MAX[t] > 0 and
                                l2.K_MAX[t] > 0
                            ):
                                feasible_pairs.append((l1, l2))

                if feasible_pairs:
                    l1_sel, l2_sel = random.choice(feasible_pairs)
                    mid = l1_sel.n2

                    Z[links.index(l1_sel)][demands.index(d)][t] = 1
                    Z[links.index(l2_sel)][demands.index(d)][t] = 1

                    max_cnct_up[hnodes.index(mid)]  = 0
                    max_cnct_dwn[hnodes.index(mid)] = 0

        _, key_srv, a_lst = offline_lp(
            gnodes, hnodes, links, demands, 1, 2, Z
        )

        rnd_results_k_srv.append(key_srv * 1e-6)
        rnd_results_a_lst.append(a_lst   * 1e-6)

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------
    key_srv_rnd_qkp_avg[idx] = np.mean(rnd_results_k_srv)
    key_srv_rnd_qkp_min[idx] = np.min(rnd_results_k_srv)
    key_srv_rnd_qkp_max[idx] = np.max(rnd_results_k_srv)

    a_lst_rnd_qkp_avg[idx] = np.mean(rnd_results_a_lst)
    a_lst_rnd_qkp_min[idx] = np.min(rnd_results_a_lst)
    a_lst_rnd_qkp_max[idx] = np.max(rnd_results_a_lst)

    # ------------------------------------------------------------
    # SAVE RESULTS
    # ------------------------------------------------------------
    data = {
        "key_srv_avg": key_srv_rnd_qkp_avg[idx],
        "key_srv_min": key_srv_rnd_qkp_min[idx],
        "key_srv_max": key_srv_rnd_qkp_max[idx],

        "a_lst_avg": a_lst_rnd_qkp_avg[idx],
        "a_lst_min": a_lst_rnd_qkp_min[idx],
        "a_lst_max": a_lst_rnd_qkp_max[idx],

        "key_req": key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] Random idx {idx}")
    print(f"idx: {idx} | avg={key_srv_rnd_qkp_avg[idx]:.3f}")
    print(f"idx: {idx} | avg={a_lst_rnd_qkp_avg[idx]:.3f}")
# Out:
# [LOAD] Random idx 0
# [LOAD] Random idx 1
# [LOAD] Random idx 2
# [LOAD] Random idx 3
# [LOAD] Random idx 4
# [LOAD] Random idx 5
# [LOAD] Random idx 6
# [LOAD] Random idx 7
# [LOAD] Random idx 8
# [LOAD] Random idx 9
# [LOAD] Random idx 10
# [LOAD] Random idx 11
# [LOAD] Random idx 12
# [LOAD] Random idx 13
# [LOAD] Random idx 14
# [LOAD] Random idx 15
# [LOAD] Random idx 16
# [LOAD] Random idx 17
# [LOAD] Random idx 18
# [LOAD] Random idx 19
# [LOAD] Random idx 20
# [LOAD] Random idx 21
# [LOAD] Random idx 22
# [LOAD] Random idx 23
# [LOAD] Random idx 24
# [LOAD] Random idx 25
# [LOAD] Random idx 26
# [LOAD] Random idx 27
# [LOAD] Random idx 28
# [LOAD] Random idx 29
# [LOAD] Random idx 30
# [LOAD] Random idx 31
# [LOAD] Random idx 32
# [LOAD] Random idx 33
# [LOAD] Random idx 34
# [LOAD] Random idx 35
# [LOAD] Random idx 36
# [LOAD] Random idx 37
# [LOAD] Random idx 38
# [LOAD] Random idx 39
# [LOAD] Random idx 40
# [LOAD] Random idx 41
# [LOAD] Random idx 42
# [LOAD] Random idx 43
# [LOAD] Random idx 44
# [LOAD] Random idx 45
# [LOAD] Random idx 46
# [LOAD] Random idx 47
# [LOAD] Random idx 48
# [LOAD] Random idx 49
# [LOAD] Random idx 50
# [LOAD] Random idx 51
# [LOAD] Random idx 52
# [LOAD] Random idx 53
# [LOAD] Random idx 54
# [LOAD] Random idx 55
# [LOAD] Random idx 56
# [LOAD] Random idx 57
# [LOAD] Random idx 58
# [LOAD] Random idx 59
# [LOAD] Random idx 60
# [LOAD] Random idx 61
# [LOAD] Random idx 62
# [LOAD] Random idx 63
# [LOAD] Random idx 64
# [LOAD] Random idx 65
# [LOAD] Random idx 66
# [LOAD] Random idx 67
# [LOAD] Random idx 68
# [LOAD] Random idx 69
# [LOAD] Random idx 70
# [LOAD] Random idx 71
# [LOAD] Random idx 72
# [LOAD] Random idx 73
# [LOAD] Random idx 74
# [LOAD] Random idx 75
# [LOAD] Random idx 76
# [LOAD] Random idx 77
# [LOAD] Random idx 78
# [LOAD] Random idx 79
# [LOAD] Random idx 80
# [LOAD] Random idx 81
# [LOAD] Random idx 82
# [LOAD] Random idx 83
# [LOAD] Random idx 84
# [LOAD] Random idx 85
# [LOAD] Random idx 86
# [LOAD] Random idx 87
# [LOAD] Random idx 88
# [LOAD] Random idx 89
# [LOAD] Random idx 90
# [LOAD] Random idx 91
# [LOAD] Random idx 92
# [LOAD] Random idx 93
# [LOAD] Random idx 94
# [LOAD] Random idx 95
# [LOAD] Random idx 96
# [LOAD] Random idx 97
# [LOAD] Random idx 98
# [LOAD] Random idx 99

# %%
key_req = [k * 1e-3 for k in key_req]

# %%
key_srv_ppo_qkp = [k * 1e-6 for k in key_srv_ppo_qkp]

# %% [markdown]
# ## Plot

# %%
# key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]

# a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
# a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]

# %%
#key_srv_ppo_qkp_old = [k for k in key_srv_ppo_qkp]
# key_srv_ppo_qkp = [k + 0.1*(key_srv_rlx_qkp[idx_k] - key_srv_ppo_qkp_old[idx_k]) for idx_k, k in enumerate(key_srv_ppo_qkp)]

# %%
# key_srv_ppo_qkp[-1] = key_srv_ppo_qkp[-2]
# key_srv_opt_qkp[-1] = key_srv_opt_qkp[-2]

# %%
# a_lst_opt_qkp[-1] = a_lst_opt_qkp[-2]

# %%
step = 6  # tunable (keep every `step`-th value)

# yerr1
yerr1 = [
    np.array(key_srv_rnd_qkp_avg) - np.array(key_srv_rnd_qkp_min),
    np.array(key_srv_rnd_qkp_max) - np.array(key_srv_rnd_qkp_avg)
]

yerr1[0][np.arange(len(yerr1[0])) % step != 0] = 0
yerr1[1][np.arange(len(yerr1[1])) % step != 0] = 0


# yerr2
yerr2 = [
    np.array(a_lst_rnd_qkp_avg) - np.array(a_lst_rnd_qkp_min),
    np.array(a_lst_rnd_qkp_max) - np.array(a_lst_rnd_qkp_avg)
]

yerr2[0][np.arange(len(yerr2[0])) % step != 0] = 0
yerr2[1][np.arange(len(yerr2[1])) % step != 0] = 0

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, key_srv_rnd_qkp_avg, yerr=yerr1, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, key_srv_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, key_srv_opt_qkp, label="Optimal", linestyle="-", marker="v", markevery=5)
plt.plot(demand_list, key_req, linestyle="--")

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Total Served Secret Key (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_k_srv.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

############################

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, a_lst_rnd_qkp_avg, yerr=yerr2, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, a_lst_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, a_lst_opt_qkp, label="Optimal-QKP", linestyle="-", marker="v", markevery=5)

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Final QKP Stored Keys (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_a_lst.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %% [markdown]
# #####
