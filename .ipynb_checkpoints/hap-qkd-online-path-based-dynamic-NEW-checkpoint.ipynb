# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)
#gnodes, hnodes, links, demands = init_setup_training_online()

nodes = gnodes + hnodes

n_hnodes  = len(hnodes)
n_demands = len(demands)
n_links   = len(links)

MAX_LINKS   = len(links)
MAX_HAPS    = len(hnodes)
MAX_DEMANDS = len(demands)   # maximum possible demands

demands_all = demands.copy()
links_all   = links.copy()
hnodes_all  = hnodes.copy()
gnodes_all  = gnodes.copy()
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
def generate_hap_masks(hnodes, links, max_haps_to_remove=1):
    """
    Randomly deactivate up to max_haps_to_remove HAPs.
    Returns:
        hnodes_active: list[int]
        links_active: list[int]
    """
    import random
    
    n_haps = len(hnodes)
    hnodes_active = [1] * n_haps
    
    # number of HAPs to deactivate
    k = random.randint(0, max_haps_to_remove)
    
    if k > 0:
        removed_indices = random.sample(range(n_haps), k)
        for idx in removed_indices:
            hnodes_active[idx] = 0
    
    # build link mask
    links_active = []
    for l in links:
        active = 1
        
        if isinstance(l.n1, hap):
            if hnodes_active[hnodes.index(l.n1)] == 0:
                active = 0
        
        if isinstance(l.n2, hap):
            if hnodes_active[hnodes.index(l.n2)] == 0:
                active = 0
        
        links_active.append(active)
    
    return hnodes_active, links_active

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.1
LR = 3e-4
EPOCHS = 10
BATCH_SIZE = 128
ENTROPY_COEF_INITIAL = 0.01         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.999 #0.995               # >>> CHANGE
VALUE_COEF = 0.5

# Training hyperparams
num_episodes = 2000
episode_len = len(syst.T)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# %%
def build_state_vector_for_time(state_t, links, t, gnodes, hnodes, demand_active, link_active, max_links=MAX_LINKS, normalize=True):
    link_features = []
    total_nodes = len(gnodes) + len(hnodes)
    
    # Pre-calculate coordinate bounds for normalization (Example ranges)
    # Better yet, use the service area limits (e.g., 270-285 lon, 40-55 lat)
    LON_MIN, LON_MAX = 276.0, 285.0
    LAT_MIN, LAT_MAX = 46.0, 50.0
    ALT_MAX = 25.0

    def norm_lon(l): return (l - LON_MIN) / (LON_MAX - LON_MIN)
    def norm_lat(l): return (l - LAT_MIN) / (LAT_MAX - LAT_MIN)
    def norm_alt(a): return a / ALT_MAX

    # 1. Process Links with Geometric Context
    for idx_l in range(max_links):
        if idx_l < len(links):
            l = links[idx_l]
            is_link_on = float(link_active[idx_l]) # 1.0 if active, 0.0 if masked
            
            # Key Buffer (QKP) - Log Scaled
            qkp_val = is_link_on * np.log10(1 + state_t.get("a", {}).get(idx_l, 0.0)) / 8.0
            
            # Current Capacity (K_MAX) - Normalized by a realistic max (e.g., 100Mbps)
            kmax_val = is_link_on * np.log10(1 + l.K_MAX[t]) / 6.0
            
            # GEOMETRIC ENCODING: Position of Node 1 and Node 2
            # This is much more powerful than normalized IDs
            n1_coords = [norm_lon(l.n1.lg[t] if isinstance(l.n1, hap) else l.n1.lg) * is_link_on,
                         norm_lat(l.n1.la[t] if isinstance(l.n1, hap) else l.n1.la) * is_link_on]
            
            n2_coords = [norm_lon(l.n2.lg[t] if isinstance(l.n2, hap) else l.n2.lg) * is_link_on,
                         norm_lat(l.n2.la[t] if isinstance(l.n2, hap) else l.n2.la) * is_link_on]
            
            # Add features: [QKP, Capacity, Src_Lon, Src_Lat, Dst_Lon, Dst_Lat, Active]
            link_features.extend([qkp_val, kmax_val] + n1_coords + n2_coords + [is_link_on])
        else:
            # Padding (7 features per link now)
            link_features.extend([0.0] * 7)

    # 2. Process Demands with Geometric Pairs
    d_vec = []
    demands_list = state_t.get("demands", [])
    
    # Instead of iterating all pairs (which is O(N^2)), 
    # you might want to only encode the 'Active' demands to save space, 
    # but for a fixed-size MLP input, the GS-to-GS grid is fine.
    for idx_src, src in enumerate(gnodes):
        for idx_dst, dst in enumerate(gnodes):
            if idx_src >= idx_dst: continue
            
            matched = next((d for d in demands_list if d.n1 == src and d.n2 == dst and demand_active[demands_list.index(d)]), None)
            
            # Geometric info for the demand pair
            src_pos = [norm_lon(src.lg), norm_lat(src.la)]
            dst_pos = [norm_lon(dst.lg), norm_lat(dst.la)]
            
            if matched:
                kreq = np.log10(1 + float(matched.K_REQ[t])) / 5.0
                d_vec.extend(src_pos + dst_pos + [kreq, 1.0])
            else:
                d_vec.extend(src_pos + dst_pos + [0.0, 0.0])

    return np.concatenate([link_features, d_vec]).astype(np.float32)

# %%
def scarq_policy(state, links, t, demand_active, link_active):
    """
    Adapted Heuristic: Scarcity & Contention Aware (1-hop only)
    Converts the offline logic into an online action selection for time t.
    """
    n_links = len(links)
    n_hnodes = len(hnodes)
    all_demands = state[t]["demands"] # This is the k-sampled demands
    
    # 1. Filter demands based on the active mask
    # Assuming demand_active matches the indexing of state[t]["demands"]
    active_indices = [i for i, val in enumerate(demand_active[:len(all_demands)]) if val == 1]
    demands = [all_demands[i] for i in active_indices]

    action_matrix = np.zeros((len(all_demands), n_links), dtype=int)
    max_cnct_up = [1] * n_hnodes
    max_cnct_dwn = [1] * n_hnodes
    
    qkp_s = [state[t]["a"].get(i, 0.0) for i in range(n_links)]

    # # Step 1: Enumerate feasible paths ONLY for active demands
    # feasible_paths = {d: [] for d in demands}
    # link_usage = [0] * n_links
    
    # for d in demands:
    #     src, dst = d.n1, d.n2
    #     for idx_l1, l1 in enumerate(links):
    #         if l1.n1 != src: continue
    #         for idx_l2, l2 in enumerate(links):
    #             if l2.n2 != dst: continue
    #             if l1.n2 == l2.n1 and l1.n2 in hnodes:
    #                 mid = l1.n2
    #                 # Capacity checks...
    #                 if (l1.K_MAX[t] >= d.K_REQ[t] and l2.K_MAX[t] >= d.K_REQ[t]) or \
    #                    (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
    #                     feasible_paths[d].append((idx_l1, idx_l2, mid))
    #                     link_usage[idx_l1] += 1
    #                     link_usage[idx_l2] += 1

    # Step 1: Enumerate feasible paths ONLY for active demands AND active links
    feasible_paths = {d: [] for d in demands}
    link_usage = [0] * n_links
    
    for d in demands:
        src, dst = d.n1, d.n2
        for idx_l1, l1 in enumerate(links):
            # NEW: Check if the uplink is active
            if l1.n1 != src or not link_active[idx_l1]: continue
            
            for idx_l2, l2 in enumerate(links):
                # NEW: Check if the downlink is active
                if l2.n2 != dst or not link_active[idx_l2]: continue
                
                if l1.n2 == l2.n1 and l1.n2 in hnodes:
                    mid = l1.n2
                    # Capacity checks...
                    if (l1.K_MAX[t] >= d.K_REQ[t] and l2.K_MAX[t] >= d.K_REQ[t]) or \
                       (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
                        feasible_paths[d].append((idx_l1, idx_l2, mid))
                        link_usage[idx_l1] += 1
                        link_usage[idx_l2] += 1

    # Step 2: Order only active demands
    ordered_demands = sorted(demands, key=lambda d: (len(feasible_paths[d]), -d.K_REQ[t]))

    # Step 3: Greedy Allocation
    for d in ordered_demands:
        paths = sorted(feasible_paths[d], key=lambda p: link_usage[p[0]] + link_usage[p[1]])
        for idx_l1, idx_l2, mid in paths:
            mid_idx = hnodes.index(mid)
            if max_cnct_up[mid_idx] == 0 or max_cnct_dwn[mid_idx] == 0:
                continue
            
            # Use original list index for the action matrix row
            orig_idx = all_demands.index(d)
            action_matrix[orig_idx][idx_l1] = 1
            action_matrix[orig_idx][idx_l2] = 1
            max_cnct_up[mid_idx], max_cnct_dwn[mid_idx] = 0, 0
            break

    # --------------------------------------------------
    # Step 4: Solve optimization with heuristic action
    # --------------------------------------------------
    solution_heur, _, A_next_heur = online_new(
        gnodes,
        hnodes,
        links,
        state,
        action_matrix,
        t,
        f_qkp,
        0,
        demand_active,
        link_active
    )

    # --------------------------------------------------
    # Step 5: Compute total served keys
    # --------------------------------------------------
    if "r_h" not in solution_heur:
        return 0.0, solution_heur, A_next_heur

    k_srv_heur = sum(
        solution_heur["r_h"][idx_d] * syst.THETA
        for idx_d, _ in enumerate(demands)
    )


    return k_srv_heur, solution_heur, A_next_heur

def mcr_policy(state, links, t, demand_active, link_active, n_samples=3):
    """
    Online Monte Carlo 1-hop random heuristic.
    Samples multiple random feasible allocations and keeps the best one.
    """

    n_links = len(links)
    n_hnodes = len(hnodes)
    all_demands = state[t]["demands"]
    
    # Filter for active only
    active_indices = [i for i, val in enumerate(demand_active[:len(all_demands)]) if val == 1]
    active_demands = [all_demands[i] for i in active_indices]

    best_reward = -1
    best_solution, best_A_next = None, None

    for _ in range(n_samples):
        action_matrix = np.zeros((len(all_demands), n_links), dtype=int)
        max_cnct_up, max_cnct_dwn = [1] * n_hnodes, [1] * n_hnodes

        shuffled_active = random.sample(active_demands, len(active_demands))

        # for d in shuffled_active:
        #     src, dst = d.n1, d.n2
        #     feasible_pairs = []
        #     for idx_l1, l1 in enumerate(links):
        #         if l1.n1 != src: continue
        #         for idx_l2, l2 in enumerate(links):
        #             if l2.n2 != dst or l1.n2 != l2.n1 or l1.n2 not in hnodes: continue
                    
        #             mid_idx = hnodes.index(l1.n2)
        #             if max_cnct_up[mid_idx] > 0 and max_cnct_dwn[mid_idx] > 0:
        #                 feasible_pairs.append((idx_l1, idx_l2, mid_idx))

        for d in shuffled_active:
            src, dst = d.n1, d.n2
            feasible_pairs = []
            for idx_l1, l1 in enumerate(links):
                # NEW: Check if uplink is active
                if l1.n1 != src or not link_active[idx_l1]: continue
                
                for idx_l2, l2 in enumerate(links):
                    # NEW: Check if downlink is active
                    if l2.n2 != dst or l1.n2 != l2.n1 or l1.n2 not in hnodes or not link_active[idx_l2]: 
                        continue
                    
                    mid_idx = hnodes.index(l1.n2)
                    if max_cnct_up[mid_idx] > 0 and max_cnct_dwn[mid_idx] > 0:
                        feasible_pairs.append((idx_l1, idx_l2, mid_idx))

            if feasible_pairs:
                idx_l1, idx_l2, mid_idx = random.choice(feasible_pairs)
                orig_idx = all_demands.index(d)
                action_matrix[orig_idx][idx_l1] = 1
                action_matrix[orig_idx][idx_l2] = 1
                max_cnct_up[mid_idx], max_cnct_dwn[mid_idx] = 0, 0

        # --------------------------------------------------------
        # Evaluate via online_new
        # --------------------------------------------------------
        solution, reward, A_next = online_new(
            gnodes,
            hnodes,
            links,
            state,
            action_matrix,
            t,
            f_qkp,
            0,
            demand_active,
            link_active
        )

        if "r_h" in solution:
            total_served = sum(solution["r_h"][i] * syst.THETA for i in range(n_demands))
        else:
            total_served = 0.0

        # Keep best sample
        if total_served > best_reward:
            best_reward = total_served
            best_solution = solution
            best_A_next = A_next

    return best_reward, best_solution, best_A_next

# %%
class ResidualBlock(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.ln = nn.LayerNorm(size)
        self.fc = nn.Linear(size, size)

    def forward(self, x):
        # Residual connection helps gradients flow back to early layers
        return x + F.silu(self.fc(self.ln(x)))

class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Linear(dim, dim)
        )
        self.silu = nn.SiLU()

    def forward(self, x):
        return self.silu(x + self.net(x))

class ActorCriticCategorical(nn.Module):
    def __init__(self, state_dim, n_demands_max, n_haps, hidden=64):
        super().__init__()
        self.n_haps = n_haps
        self.n_choices = n_demands_max + 1 # Demands + Idle
        
        self.encoder = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.SiLU(),
        )
        
        # (One set of choices for RX/Uplink, one for TX/Downlink)
        self.actor_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 2 * n_haps * self.n_choices) 
        )
        
        self.critic_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 1)
        )
        
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            # Orthogonal init helps prevents early policy collapse
            nn.init.orthogonal_(m.weight, gain=0.01) 
            nn.init.constant_(m.bias, 0)

    # def forward(self, x):
    #     features = self.encoder(x)
        
    #     # index 0: RX (Uplink), index 1: TX (Downlink)
    #     logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
    #     probs = torch.softmax(logits, dim=-1) 
        
    #     value = self.critic_head(features)
    #     return probs, value
    # def forward(self, x, action_mask=None):
    #     features = self.encoder(x)
        
    #     # [Batch, 2 * n_haps * n_choices] -> [Batch, 2, n_haps, n_choices]
    #     logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        
    #     if action_mask is not None:
    #         # action_mask shape: [Batch, n_choices] 
    #         # We broadcast it to [Batch, 2, n_haps, n_choices]
    #         mask = action_mask.view(-1, 1, 1, self.n_choices)
    #         # Use a very large negative number to mask logits before softmax
    #         logits = logits.masked_fill(mask == 0, -1e9)

    #     probs = torch.softmax(logits, dim=-1) 
    #     value = self.critic_head(features)
    #     return probs, value
    def forward(self, x, action_mask=None):
        features = self.encoder(x)
        
        # [Batch, 2, n_haps, n_choices]
        logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        
        if action_mask is not None:
            # NEW: Ensure the mask has a batch dimension if it doesn't already
            # Expected action_mask shape from select_action: [Batch, 2, n_haps, n_choices]
            if action_mask.dim() == 3:
                mask = action_mask.unsqueeze(0) # Add batch dim if missing
            else:
                mask = action_mask
                
            # No more .view(-1, 1, 1, n_choices)! 
            # We want the specific mask for each HAP and each Head.
            logits = logits.masked_fill(mask == 0, -1e9)
    
        probs = torch.softmax(logits, dim=-1) 
        value = self.critic_head(features)
        return probs, value

class PPOBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        self.is_terminals = []
    
    def clear(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]
        del self.is_terminals[:]

class PPOAgent:
    def __init__(self, state_dim, n_demands, n_hnodes, lr=LR):
        self.gamma = GAMMA
        self.lam = GAE_LAMBDA
        self.eps_clip = CLIP
        self.K_epochs = EPOCHS
        self.n_haps = n_hnodes
        self.n_choices = n_demands + 1 # Demands + Idle
        
        self.model = ActorCriticCategorical(state_dim, n_demands, n_hnodes).to(device=DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        self.MseLoss = nn.MSELoss()

    # def select_action(self, state_vec):
    #     s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    #     with torch.no_grad():
    #         probs, value = self.model(s) # [1, 2, n_haps, n_choices]
        
    #     dist = Categorical(probs)
    #     action = dist.sample() # [1, 2, n_haps]
        
    #     # Sum log_prob across BOTH heads and ALL HAPs
    #     logp = dist.log_prob(action).sum(dim=[1, 2])
        
    #     return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0)
    # def select_action(self, state_vec, demand_active_vec):
    #     """
    #     demand_active_vec: np.array of size MAX_DEMANDS (1 for active, 0 for inactive)
    #     """
    #     s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        
    #     # Create mask: [Idle_slot (1)] + [Demands_active_mask]
    #     # Resulting size: n_choices (MAX_DEMANDS + 1)
    #     mask = np.concatenate([[1], demand_active_vec])
    #     mask_t = torch.tensor(mask, dtype=torch.bool, device=DEVICE).unsqueeze(0)

    #     with torch.no_grad():
    #         probs, value = self.model(s, action_mask=mask_t)
        
    #     dist = Categorical(probs)
    #     action = dist.sample() 
    #     logp = dist.log_prob(action).sum(dim=[1, 2])
        
    #     return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0), mask
    def select_action(self, state_vec, demand_active, link_active):
        # s: [Batch, state_dim]
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        
        # 1. Start with an "All Active" mask [2, n_haps, n_choices]
        # Head 0: RX (Uplink), Head 1: TX (Downlink)
        full_mask = np.ones((2, self.n_haps, self.n_choices), dtype=bool)
        
        # 2. Apply Demand Mask: If demand 'd' is inactive, no HAP can select it (all heads)
        # n_choices is [Idle, D1, D2, ... Dn] -> index 0 is Idle (always 1)
        full_mask[:, :, 1:] = demand_active[None, None, :]
    
        # 3. Apply Link Mask: HAP-specific restrictions
        for h_idx, h_node in enumerate(hnodes):
            for d_idx, d in enumerate(state[t]["demands"]):
                # Check Uplink (GS_src -> HAP) for RX Head
                up_link_idx = [idx_l for idx_l, l in enumerate(links) if l.n2 == h_node and l.n1 == d.n1][0] #find_link_idx(d.n1, h_node, links)
                if up_link_idx is not None and not link_active[up_link_idx]:
                    full_mask[0, h_idx, d_idx + 1] = 0 # Mask this demand for this HAP's RX
                
                # Check Downlink (HAP -> GS_dst) for TX Head
                dn_link_idx = [idx_l for idx_l, l in enumerate(links) if l.n1 == h_node and l.n2 == d.n2][0] #find_link_idx(h_node, d.n2, links)
                if dn_link_idx is not None and not link_active[dn_link_idx]:
                    full_mask[1, h_idx, d_idx + 1] = 0 # Mask this demand for this HAP's TX
    
        mask_t = torch.tensor(full_mask, dtype=torch.bool, device=DEVICE).unsqueeze(0)
    
        with torch.no_grad():
            # The model's forward() now expects [Batch, 2, n_haps, n_choices]
            probs, value = self.model(s, action_mask=mask_t)
        
        # ... sampling logic ...
        dist = Categorical(probs)
        action = dist.sample() 
        logp = dist.log_prob(action).sum(dim=[1, 2])
        
        return action.squeeze(0).cpu().numpy(), logp, value.squeeze(0), full_mask

    # ... compute_gae remains exactly the same as your previous code ...

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef, masks):
        #advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        if advantages.std() < 1e-5:
            advantages = advantages - advantages.mean()
        else:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
            
        # for _ in range(self.K_epochs):
        #     probs, values = self.model(states.to(DEVICE))
        #     dist = Categorical(probs)
            
        #     # logp is summed across the choices of all HAPs
        #     #new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=-1)
        #     new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
        #     entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
        #     ratio = torch.exp(new_logps - old_logps)
        #     surr1 = ratio * advantages
        #     surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
        #     loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
        #     self.optimizer.zero_grad()
        #     loss.backward()
        #     self.optimizer.step()
        for _ in range(self.K_epochs):
            # Pass the saved masks into the model
            probs, values = self.model(states.to(DEVICE), action_mask=masks.to(DEVICE))
            dist = Categorical(probs)
            
            new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
            entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
            ratio = torch.exp(new_logps - old_logps)
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
            loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

    def compute_gae(self, rewards, values, dones):
        """
        Generalized Advantage Estimation
        rewards: [T], values: [T+1], dones: [T]
        """
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            # TD Error: delta = r_t + gamma * V(s_t+1) - V(s_t)
            delta = rewards[t] + self.gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + self.gamma * self.lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
            
        returns = adv + values[:-1]
        return adv, returns

# %%
def get_z_from_demand_choices(hap_picks, demands, links, hnodes):
    # Initialize z_dict with zeros
    z = {idx_d: {idx_l: 0 for idx_l in range(len(links))} for idx_d in range(len(demands))}
    
    rx_picks = hap_picks[0] # Uplink choices [n_haps]
    tx_picks = hap_picks[1] # Downlink choices [n_haps]

    # Run this once after initializing your 'links' and 'hnodes'
    UPLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n2 in hnodes}
    DOWNLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n1 in hnodes}

    for hap_idx, selected_hap in enumerate(hnodes):
        
        # --- Handle Uplink (RX: GS -> HAP) ---
        rx_val = rx_picks[hap_idx]
        if rx_val > 0:
            d_idx = int(rx_val - 1)
            if d_idx < len(demands):
                src_gs = demands[d_idx].n1
                # Use the pre-computed lookup
                l_idx = UPLINK_LOOKUP.get((src_gs, selected_hap))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1

        # --- Handle Downlink (TX: HAP -> GS) ---
        tx_val = tx_picks[hap_idx]
        if tx_val > 0:
            d_idx = int(tx_val - 1)
            if d_idx < len(demands):
                dst_gs = demands[d_idx].n2
                # Use the pre-computed lookup
                l_idx = DOWNLINK_LOOKUP.get((selected_hap, dst_gs))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1
                        
    return z

# %% [markdown]
# ## Training Loop

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T

demand_active = np.ones(MAX_DEMANDS)
link_active   = np.ones(MAX_LINKS)

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(
    state[0], links, 0, gnodes, hnodes,
    demand_active, link_active
)#build_state_vector_for_time(state[0], links, 0, gnodes, hnodes, demand_active)
state_dim = len(state_vector_example)

agent = PPOAgent(state_dim, n_demands, n_hnodes, lr=LR)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

#WARM_EPISODES  = 500
DECAY_EPISODES = 300

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf  = []
    actions_buf = []
    logps_buf   = []
    rewards_buf = []
    dones_buf   = []
    values_buf  = []
    masks_buf   = [] # New buffer

    total_reward = 0.0

    # Calculate a 'progress' factor from 0.0 to 1.0
    progress = ep * 4 / num_episodes
    
    # Start with a max of 50 kbps, end with 1000 kbps
    max_now = min(1 + (9 * progress), 10) #in(10 + (990 * progress), 1000)
    
    # Still use randomness, but within an ever-expanding "boundary"
    mean_kbps_rand = random.uniform(1, max_now)

    #mean_kbps_rand = random.randint(1, 1 + int(10 * ep/num_episodes))
    #mean_kbps_rand = random.randint(1, 1000)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.01 + 0.2*mean_kbps_rand, amp=0.5, noise_std=0.0, pattern="stadium")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    # # Before the for t in syst.T: loop
    # if ep < num_episodes / 10:
    #     k = 1  # Only 1 demand: let the agent learn basic RX/TX pairing first
    # elif ep < 2 * num_episodes / 10:
    #     k = random.randint(1, 2) # Slightly more complex
    # else:
    #     k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity

    #k = MAX_DEMANDS

    demands = demands_space.copy() #random.sample(demands_space, k)
    random.shuffle(demands)

    state[0]["demands"] = demands.copy()

    k_srv = 0
    k_req = 0

    k_heur_sum = 0
    
    demand_active = np.ones(MAX_DEMANDS)
    link_active   = np.ones(MAX_LINKS)
    for t in syst.T:
        #if k == MAX_DEMANDS:
        # demand_active = np.ones(MAX_DEMANDS)
        # d_inactive = random.randint(0, MAX_DEMANDS-1)
        # demand_active[d_inactive] = 0

        # link_active = np.ones(MAX_LINKS)
        # l_inactive = random.randint(0, MAX_LINKS-1)
        # link_active[l_inactive] = 0
        
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes, demand_active, link_active)
        
        # # Inside the for t in syst.T: loop
        # hap_choices, logp, value = agent.select_action(s_vec) 
        # demand_active is your np.ones(MAX_DEMANDS) modified by your logic
        hap_choices, logp, value, current_mask = agent.select_action(s_vec, demand_active, link_active)
        
        # 2. Convert to the dictionary format for Gurobi
        z_dict = get_z_from_demand_choices(hap_choices, demands, links, hnodes)

        #print(z_dict)

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes

        k_srv_heur1, k_srv_heur2 = -math.inf, -math.inf
        k_srv_heur1, _, _ = scarq_policy(state, links, t, demand_active, link_active)
        k_srv_heur2, _, _ = mcr_policy(state, links, t, demand_active, link_active)
        
        k_srv_heur = max(k_srv_heur1, k_srv_heur2)

        k_heur_sum += k_srv_heur

        solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, k_srv_heur, demand_active, link_active)

        reward[t] = reward_t
        total_reward += reward_t

        k_srv += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))
        k_req += sum(d.K_REQ[t] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]) if demand_active[idx_d] == 1)

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        # Ensure hap_choices is converted to a tensor for the buffer
        # Shape: [2, n_haps]
        actions_buf.append(torch.tensor(hap_choices, dtype=torch.long, device=DEVICE))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))
        masks_buf.append(torch.tensor(current_mask, dtype=torch.bool))

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    #final_s_vec = build_state_vector_for_time(state[-1], links, t, gnodes, hnodes, demand_active)
    final_s_vec = build_state_vector_for_time(
        state[-1], links, t, gnodes, hnodes, 
        demand_active, link_active
    )
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor.view(-1), final_value.view(-1)])  # Now shape is [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()
    masks_b = torch.stack(masks_buf)

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    #agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE
    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef, masks_b)

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}, mean_kbps_rand: {mean_kbps_rand}, ratio_heur={k_heur_sum/k_req*1e2} ratio={k_srv/k_req*1e2}, k_srv_heur={int(k_heur_sum)}, k_srv={int(k_srv)}, k_req={int(k_req)}")

# === Plot learning curve ===
plt.figure(figsize=(6,3))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/2000, total reward: 248.002, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0, ratio_heur=98.92111543267438 ratio=93.69677951235218, k_srv_heur=22513755, k_srv=21324733, k_req=22759302
# Episode 2/2000, total reward: 258.343, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0086551709646825, ratio_heur=98.9944136015524 ratio=96.1182613459344, k_srv_heur=22716156, k_srv=22056168, k_req=22946907
# Episode 3/2000, total reward: 259.750, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.022653980681712, ratio_heur=99.64060075153905 ratio=96.30074753397675, k_srv_heur=23166777, k_srv=22390250, k_req=23250339
# Episode 4/2000, total reward: 258.010, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.031200658426079, ratio_heur=99.28122544260572 ratio=96.13175444858727, k_srv_heur=23267143, k_srv=22529046, k_req=23435592
# Episode 5/2000, total reward: 258.579, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0422160777458727, ratio_heur=99.28124983740796 ratio=96.1951184055674, k_srv_heur=23504198, k_srv=22773576, k_req=23674357
# Episode 6/2000, total reward: 258.161, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0257026394061748, ratio_heur=99.28123347303793 ratio=96.4618324328739, k_srv_heur=23148829, k_srv=22491446, k_req=23316420
# Episode 7/2000, total reward: 270.268, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.057787371280639, ratio_heur=99.36766591796274 ratio=97.69435128076952, k_srv_heur=23860038, k_srv=23458244, k_req=24011873
# Episode 8/2000, total reward: 254.952, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.1154453479574884, ratio_heur=99.61350321679473 ratio=94.59286972518682, k_srv_heur=25164005, k_srv=23895711, k_req=25261640
# Episode 9/2000, total reward: 247.203, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0651705048025162, ratio_heur=99.28127572685027 ratio=94.60693210832345, k_srv_heur=23998177, k_srv=22868299, k_req=24171907
# Episode 10/2000, total reward: 259.286, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.035486949925579, ratio_heur=99.63807850222979 ratio=96.41564365155021, k_srv_heur=23443345, k_srv=22685155, k_req=23528500
# Episode 11/2000, total reward: 258.250, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.075111807199954, ratio_heur=99.35691223651843 ratio=96.67575448762898, k_srv_heur=24230557, k_srv=23576693, k_req=24387390
# Episode 12/2000, total reward: 258.836, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.1329062166942712, ratio_heur=99.28123198149179 ratio=96.0751893365885, k_srv_heur=25455821, k_srv=24633788, k_req=25640114
# Episode 13/2000, total reward: 258.614, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.1702255625540239, ratio_heur=99.53496371691618 ratio=96.2774772447251, k_srv_heur=26326033, k_srv=25464459, k_req=26449030
# Episode 14/2000, total reward: 264.094, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0033728336009982, ratio_heur=99.2812561611761 ratio=96.92237772184107, k_srv_heur=22668303, k_srv=22129714, k_req=22832410
# Episode 15/2000, total reward: 242.154, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0640271598398567, ratio_heur=99.56532314871565 ratio=93.75877837161605, k_srv_heur=24042162, k_srv=22640049, k_req=24147124
# Episode 16/2000, total reward: 250.996, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.065121794504904, ratio_heur=99.28122621627966 ratio=91.4127553336015, k_srv_heur=23997117, k_srv=22095241, k_req=24170851
# Episode 17/2000, total reward: 259.159, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.0922633443491352, ratio_heur=99.2812683517987 ratio=96.24436306425233, k_srv_heur=24581206, k_srv=23829294, k_req=24759158
# Episode 18/2000, total reward: 258.646, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.2855372419622437, ratio_heur=99.64061839455275 ratio=97.16680285800645, k_srv_heur=28844436, k_srv=28128304, k_req=28948472
# Episode 19/2000, total reward: 264.917, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.2033604631843777, ratio_heur=99.28126473289738 ratio=96.27527816977641, k_srv_heur=26971986, k_srv=26155342, k_req=27167247
# Episode 20/2000, total reward: 258.792, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.102655052559102, ratio_heur=99.61724903166932 ratio=96.31539326139422, k_srv_heur=24888776, k_srv=24063827, k_req=24984404
# Episode 21/2000, total reward: 277.719, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.244144842411341, ratio_heur=99.58051362805527 ratio=97.14982154651246, k_srv_heur=27933598, k_srv=27251758, k_req=28051270
# Episode 22/2000, total reward: 259.307, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.153387846502418, ratio_heur=99.28129973879585 ratio=95.51439292759657, k_srv_heur=25896598, k_srv=24914035, k_req=26084064
# Episode 23/2000, total reward: 240.466, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.361344158429908, ratio_heur=99.46627596488187 ratio=95.70981278278491, k_srv_heur=30428352, k_srv=29279188, k_req=30591626
# Episode 24/2000, total reward: 264.144, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.231797282457996, ratio_heur=99.28128542603395 ratio=97.4533709441798, k_srv_heur=27583945, k_srv=27076084, k_req=27783630
# Episode 25/2000, total reward: 258.985, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.2785390095320905, ratio_heur=99.50920725516245 ratio=96.03134361783732, k_srv_heur=28655449, k_srv=27653936, k_req=28796781
# Episode 26/2000, total reward: 271.941, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.292101455891404, ratio_heur=99.28125318953978 ratio=96.28351111026574, k_srv_heur=28881666, k_srv=28009600, k_req=29090754
# Episode 27/2000, total reward: 264.063, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.319136046272595, ratio_heur=99.28126199401423 ratio=97.32351688830725, k_srv_heur=29463445, k_srv=28882450, k_req=29676743
# Episode 28/2000, total reward: 252.024, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.4383795793033198, ratio_heur=99.28127219155925 ratio=96.83043883705716, k_srv_heur=32029538, k_srv=31238865, k_req=32261410
# Episode 29/2000, total reward: 258.883, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.412093876829366, ratio_heur=99.08332993969006 ratio=96.35855385780903, k_srv_heur=31401145, k_srv=30537619, k_req=31691653
# Episode 30/2000, total reward: 235.034, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.3316997167884927, ratio_heur=99.26404386744001 ratio=93.9959981310501, k_srv_heur=29728655, k_srv=28150925, k_req=29949068
# Episode 31/2000, total reward: 277.420, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.5114797606790524, ratio_heur=99.46566222889906 ratio=97.35368971353262, k_srv_heur=33665043, k_srv=32950227, k_req=33845895
# Episode 32/2000, total reward: 264.042, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2059046978151848, ratio_heur=99.58965546177939 ratio=97.4526046840852, k_srv_heur=27110689, k_srv=26528932, k_req=27222394
# Episode 33/2000, total reward: 258.131, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.471406696647586, ratio_heur=99.47219961947954 ratio=96.61864314931177, k_srv_heur=32803235, k_srv=31862210, k_req=32977290
# Episode 34/2000, total reward: 254.813, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.0178598687000764, ratio_heur=99.28125293160306 ratio=93.7969760233218, k_srv_heur=22980059, k_srv=21710646, k_req=23146424
# Episode 35/2000, total reward: 265.046, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.3507781491736255, ratio_heur=99.5577050567029 ratio=96.47213166824532, k_srv_heur=30228310, k_srv=29291450, k_req=30362603
# Episode 36/2000, total reward: 265.102, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.0485343180319489, ratio_heur=99.63380565705181 ratio=96.31823826096402, k_srv_heur=23724113, k_srv=22934633, k_req=23811309
# Episode 37/2000, total reward: 258.173, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.2905899328918757, ratio_heur=99.20203082746445 ratio=97.20407858197166, k_srv_heur=28826117, k_srv=28245553, k_req=29057991
# Episode 38/2000, total reward: 235.137, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.4594237335399467, ratio_heur=99.47427231184027 ratio=94.83384767789245, k_srv_heur=32545548, k_srv=31027314, k_req=32717553
# Episode 39/2000, total reward: 258.007, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.409055408038813, ratio_heur=99.24253254328 ratio=97.34319742004148, k_srv_heur=31386238, k_srv=30785558, k_req=31625793
# Episode 40/2000, total reward: 253.814, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.57634975755001, ratio_heur=99.5193794270696 ratio=95.08207031559468, k_srv_heur=35082558, k_srv=33518318, k_req=35251986
# Episode 41/2000, total reward: 247.222, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.5384740859583195, ratio_heur=99.27477994656961 ratio=94.3976185110465, k_srv_heur=34181310, k_srv=32502054, k_req=34431011
# Episode 42/2000, total reward: 242.745, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.369330000637265, ratio_heur=99.49049894304166 ratio=93.41151124222756, k_srv_heur=30607977, k_srv=28737793, k_req=30764724
# Episode 43/2000, total reward: 246.743, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.6066508095082137, ratio_heur=99.26025625658909 ratio=94.92985319990527, k_srv_heur=35643144, k_srv=34088149, k_req=35908777
# Episode 44/2000, total reward: 264.254, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.559489824025695, ratio_heur=99.00571627666777 ratio=96.3349095888657, k_srv_heur=34539667, k_srv=33607915, k_req=34886538
# Episode 45/2000, total reward: 265.010, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.0318667776769026, ratio_heur=99.215974762632 ratio=96.50117157061764, k_srv_heur=23266177, k_srv=22629555, k_req=23450031
# Episode 46/2000, total reward: 276.829, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.0811588630369497, ratio_heur=99.64060538260554 ratio=97.95821201231011, k_srv_heur=24430345, k_srv=24017848, k_req=24518463
# Episode 47/2000, total reward: 265.077, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.6587629491583198, ratio_heur=99.18633771355734 ratio=96.9229789876774, k_srv_heur=36736968, k_srv=35898658, k_req=37038335
# Episode 48/2000, total reward: 264.766, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.2885887332896848, ratio_heur=99.14670601328925 ratio=96.26761074760228, k_srv_heur=28767034, k_srv=27931676, k_req=29014614
# Episode 49/2000, total reward: 264.840, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.8027650956567425, ratio_heur=98.89057016713942 ratio=96.35441310014859, k_srv_heur=39714114, k_srv=38695602, k_req=40159657
# Episode 50/2000, total reward: 235.576, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.4061686933933855, ratio_heur=99.12416662660901 ratio=92.71595397644926, k_srv_heur=31286781, k_srv=29264142, k_req=31563222
# Episode 51/2000, total reward: 253.045, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.1048650681276821, ratio_heur=99.55307157050456 ratio=95.70324593092616, k_srv_heur=24920431, k_srv=23956731, k_req=25032307
# Episode 52/2000, total reward: 258.354, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.1095213116141447, ratio_heur=98.93477845482606 ratio=95.90905485251268, k_srv_heur=24865509, k_srv=24105047, k_req=25133234
# Episode 53/2000, total reward: 214.207, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.9082255912374415, ratio_heur=98.16241332808077 ratio=87.74083093646652, k_srv_heur=41665595, k_srv=37242095, k_req=42445569
# Episode 54/2000, total reward: 264.152, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.0139602963939147, ratio_heur=99.28125274757787 ratio=96.73830257298147, k_srv_heur=22896142, k_srv=22309689, k_req=23061898
# Episode 55/2000, total reward: 258.125, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.626171284139998, ratio_heur=99.28123348578771 ratio=97.17448617960117, k_srv_heur=36070752, k_srv=35305331, k_req=36331894
# Episode 56/2000, total reward: 264.011, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.016186099755168, ratio_heur=99.28124194925942 ratio=97.26319830811236, k_srv_heur=22944038, k_srv=22477665, k_req=23110144
# Episode 57/2000, total reward: 254.396, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.1553633136396018, ratio_heur=99.64067077674498 ratio=95.31941144961593, k_srv_heur=26033002, k_srv=24903991, k_req=26126883
# Episode 58/2000, total reward: 253.271, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.6915745955634824, ratio_heur=99.18016956888327 ratio=94.96246843089905, k_srv_heur=37440062, k_srv=35847900, k_req=37749545
# Episode 59/2000, total reward: 259.690, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.5312514855781163, ratio_heur=99.2812947195122 ratio=95.92826834765155, k_srv_heur=34028125, k_srv=32878893, k_req=34274457
# Episode 60/2000, total reward: 248.354, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.207120022407526, ratio_heur=99.28123785856361 ratio=93.32572966868385, k_srv_heur=27052884, k_srv=25430083, k_req=27248737
# Episode 61/2000, total reward: 252.531, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.2085247404427006, ratio_heur=98.9216429834031 ratio=96.48274832774872, k_srv_heur=26985018, k_srv=26319707, k_req=27279185
# Episode 62/2000, total reward: 209.419, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.5954876446641348, ratio_heur=99.26254221805935 ratio=87.7161067719608, k_srv_heur=35403782, k_srv=31285537, k_req=35666810
# Episode 63/2000, total reward: 258.816, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.7255046148975826, ratio_heur=99.15974352615044 ratio=96.22117600755631, k_srv_heur=38161623, k_srv=37030716, k_req=38484996
# Episode 64/2000, total reward: 265.559, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.1619367013051896, ratio_heur=99.12874422422871 ratio=96.67664920366275, k_srv_heur=26040491, k_srv=25396342, k_req=26269365
# Episode 65/2000, total reward: 258.569, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.0693803929957137, ratio_heur=99.56368209949873 ratio=96.59096033322018, k_srv_heur=24157294, k_srv=23436017, k_req=24263158
# Episode 66/2000, total reward: 246.006, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.783042715459425, ratio_heur=98.92188944821258 ratio=96.6948494591329, k_srv_heur=39303808, k_srv=38418957, k_req=39732164
# Episode 67/2000, total reward: 208.522, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 2.175871324487331, ratio_heur=99.45526162154894 ratio=89.99274068376975, k_srv_heur=47984111, k_srv=43418735, k_req=48246931
# Episode 68/2000, total reward: 264.294, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.7495240655389397, ratio_heur=99.49648475178738 ratio=97.10787882971026, k_srv_heur=38809231, k_srv=37877540, k_req=39005630
# Episode 69/2000, total reward: 259.675, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.2309556915818625, ratio_heur=98.92178682457681 ratio=94.59490405917454, k_srv_heur=27466018, k_srv=26264642, k_req=27765388
# Episode 70/2000, total reward: 235.329, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 2.0874489538382806, ratio_heur=99.019528318773 ratio=93.97933501219077, k_srv_heur=45876074, k_srv=43540936, k_req=46330330
# Episode 71/2000, total reward: 179.797, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.7324143864024562, ratio_heur=99.28126915313018 ratio=83.3394775314512, k_srv_heur=38357089, k_srv=32198014, k_req=38634769
# Episode 72/2000, total reward: 258.142, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.2270452207268019, ratio_heur=99.28125196016161 ratio=96.58118304041167, k_srv_heur=27481672, k_srv=26734276, k_req=27680626
# Episode 73/2000, total reward: 241.944, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 2.213780580403303, ratio_heur=98.56223957160232 ratio=93.24828408728747, k_srv_heur=48363145, k_srv=45755659, k_req=49068634
# Episode 74/2000, total reward: 247.099, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.710430045331202, ratio_heur=99.46034248048994 ratio=95.5111374815168, k_srv_heur=37952323, k_srv=36445375, k_req=38158247
# Episode 75/2000, total reward: 241.234, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 2.0800418200203254, ratio_heur=99.46306986047854 ratio=94.54049244058346, k_srv_heur=45921877, k_srv=43649134, k_req=46169776
# Episode 76/2000, total reward: 242.885, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.9978742343536562, ratio_heur=99.38472561551136 ratio=92.98300911065593, k_srv_heur=44115638, k_srv=41273996, k_req=44388751
# Episode 77/2000, total reward: 258.114, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.3653720644839173, ratio_heur=99.55490615154562 ratio=96.76401125193478, k_srv_heur=30542383, k_srv=29686167, k_req=30678933
# Episode 78/2000, total reward: 230.851, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.645668750527678, ratio_heur=99.48085903897635 ratio=92.39335858402823, k_srv_heur=36563704, k_srv=33958728, k_req=36754511
# Episode 79/2000, total reward: 252.389, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.6754880974735755, ratio_heur=99.28127444247126 ratio=96.4130982990152, k_srv_heur=37132052, k_srv=36059329, k_req=37400861
# Episode 80/2000, total reward: 252.792, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.572509288845263, ratio_heur=99.28124321659065 ratio=95.82823146010145, k_srv_heur=34915964, k_srv=33701583, k_req=35168742
# Episode 81/2000, total reward: 258.526, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.7167837194936144, ratio_heur=99.28128806985285 ratio=97.77706750570225, k_srv_heur=38020728, k_srv=37444672, k_req=38295966
# Episode 82/2000, total reward: 258.193, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.1532791579922954, ratio_heur=99.64061649400674 ratio=96.68227425862288, k_srv_heur=25987975, k_srv=25216389, k_req=26081708
# Episode 83/2000, total reward: 241.508, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.8049919111654869, ratio_heur=99.2812869096586 ratio=94.51361936795041, k_srv_heur=39918945, k_srv=38001965, k_req=40207925
# Episode 84/2000, total reward: 230.249, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.951302695539313, ratio_heur=99.47476450873214 ratio=93.25282842266067, k_srv_heur=43151445, k_srv=40452413, k_req=43379288
# Episode 85/2000, total reward: 241.839, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.1406350844157174, ratio_heur=99.28128956115565 ratio=94.28785924598162, k_srv_heur=25622159, k_srv=24333472, k_req=25807641
# Episode 86/2000, total reward: 178.505, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 2.3895956769269695, ratio_heur=99.01924734349834 ratio=86.34406517472961, k_srv_heur=52360902, k_srv=45658326, k_req=52879519
# Episode 87/2000, total reward: 214.362, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.7389735916413323, ratio_heur=99.2352212404054 ratio=88.41212578960909, k_srv_heur=38480385, k_srv=34283519, k_req=38776943
# Episode 88/2000, total reward: 200.487, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 2.275691646382172, ratio_heur=98.41263684260245 ratio=90.22001890484488, k_srv_heur=49610390, k_srv=45480443, k_req=50410589
# Episode 89/2000, total reward: 259.161, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.9211197064380103, ratio_heur=99.28128437170633 ratio=95.32358144944924, k_srv_heur=42417984, k_srv=40727053, k_req=42725056
# Episode 90/2000, total reward: 110.151, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.5081139913181114, ratio_heur=94.4209091750652 ratio=70.5645814274298, k_srv_heur=52354945, k_srv=39126978, k_req=55448466
# Episode 91/2000, total reward: 241.211, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.0244958002787117, ratio_heur=99.30562395532405 ratio=94.31368068695221, k_srv_heur=44653555, k_srv=42408889, k_req=44965787
# Episode 92/2000, total reward: 252.835, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.8807053443470445, ratio_heur=99.28124705937536 ratio=95.68792709894845, k_srv_heur=41548262, k_srv=40044491, k_req=41849053
# Episode 93/2000, total reward: 120.586, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.537889922918618, ratio_heur=98.58062389216303 ratio=76.0965637583579, k_srv_heur=55297692, k_srv=42685511, k_req=56093875
# Episode 94/2000, total reward: 246.791, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.356724418695352, ratio_heur=99.37591909353588 ratio=95.82283741741283, k_srv_heur=30301200, k_srv=29217812, k_req=30491491
# Episode 95/2000, total reward: 241.530, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.2441319171113747, ratio_heur=98.9218713846262 ratio=94.04613947142441, k_srv_heur=49190399, k_srv=46765868, k_req=49726515
# Episode 96/2000, total reward: 197.255, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.4837529878729172, ratio_heur=99.5336968781498 ratio=86.31441917294428, k_srv_heur=33089880, k_srv=28695144, k_req=33244902
# Episode 97/2000, total reward: 259.675, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.4526296573279018, ratio_heur=99.28126376750606 ratio=94.9691993566674, k_srv_heur=32336193, k_srv=30931741, k_req=32570288
# Episode 98/2000, total reward: 264.272, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.1401301445429604, ratio_heur=99.2812530278104 ratio=97.07373085967174, k_srv_heur=25611283, k_srv=25041816, k_req=25796696
# Episode 99/2000, total reward: 156.348, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.367333660300057, ratio_heur=97.55202568551631 ratio=79.85043355527985, k_srv_heur=51114313, k_srv=41839214, k_req=52396978
# Episode 100/2000, total reward: 241.253, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.249052500111439, ratio_heur=98.87806937058423 ratio=93.55422645143751, k_srv_heur=49274078, k_srv=46621038, k_req=49833172
# Episode 101/2000, total reward: 206.449, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.471148037796302, ratio_heur=98.71414843344742 ratio=90.35710397798975, k_srv_heur=53944527, k_srv=49377636, k_req=54647209
# Episode 102/2000, total reward: 264.891, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.4645997902495547, ratio_heur=99.5369291527039 ratio=96.9300835978941, k_srv_heur=32677722, k_srv=31821901, k_req=32829746
# Episode 103/2000, total reward: 259.152, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.0967544955722568, ratio_heur=99.61892403060104 ratio=95.79047537268374, k_srv_heur=24761784, k_srv=23810165, k_req=24856506
# Episode 104/2000, total reward: 235.649, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.9307403853992318, ratio_heur=99.4132013295592 ratio=94.03515624844742, k_srv_heur=42681655, k_srv=40372668, k_req=42933589
# Episode 105/2000, total reward: 179.482, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.5244017091506903, ratio_heur=99.1078905833965 ratio=84.23655778047704, k_srv_heur=55303700, k_srv=47005272, k_req=55801510
# Episode 106/2000, total reward: 229.182, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.9215117434645475, ratio_heur=99.14262907692581 ratio=93.36682815060067, k_srv_heur=42367168, k_srv=39898963, k_req=42733553
# Episode 107/2000, total reward: 234.186, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.950944183160435, ratio_heur=99.4748289025995 ratio=95.45706401569322, k_srv_heur=43143742, k_srv=41401177, k_req=43371517
# Episode 108/2000, total reward: 240.572, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.704847208108651, ratio_heur=98.56222435561853 ratio=93.01373288918828, k_srv_heur=37490345, k_srv=35379853, k_req=38037236
# Episode 109/2000, total reward: 115.623, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.9006999603634482, ratio_heur=95.8393537461109 ratio=72.7043711825033, k_srv_heur=61296908, k_srv=46500242, k_req=63957973
# Episode 110/2000, total reward: 155.652, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.3009595463515393, ratio_heur=96.3278937614292 ratio=79.48778292081778, k_srv_heur=49087042, k_srv=40505610, k_req=50958284
# Episode 111/2000, total reward: 262.277, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.7923741813088765, ratio_heur=99.43630121786346 ratio=93.2672274544378, k_srv_heur=39709319, k_srv=37245735, k_req=39934429
# Episode 112/2000, total reward: 132.248, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.9766341819689126, ratio_heur=96.52596104328805 ratio=80.36328107745402, k_srv_heur=63324783, k_srv=52721436, k_req=65603887
# Episode 113/2000, total reward: 168.516, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.8101152495137347, ratio_heur=99.13881205573777 ratio=82.72995636293857, k_srv_heur=61460613, k_srv=51288024, k_req=61994502
# Episode 114/2000, total reward: 252.720, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.2634032335080074, ratio_heur=99.28119595078999 ratio=96.15003991600074, k_srv_heur=28264071, k_srv=27372671, k_req=28468705
# Episode 115/2000, total reward: 159.927, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.4415472596669296, ratio_heur=97.05163047698791 ratio=83.50125165738493, k_srv_heur=52413312, k_srv=45095349, k_req=54005597
# Episode 116/2000, total reward: 63.497, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.764571514537895, ratio_heur=95.16186667525596 ratio=70.56711485193534, k_srv_heur=58055702, k_srv=43051104, k_req=61007317
# Episode 117/2000, total reward: 148.263, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.9780210322702048, ratio_heur=94.5649039657153 ratio=79.39106260076024, k_srv_heur=62066680, k_srv=52107489, k_req=65633948
# Episode 118/2000, total reward: 160.395, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.8580428379195664, ratio_heur=96.37052706624448 ratio=83.06661135506876, k_srv_heur=60745579, k_srv=52359674, k_req=63033357
# Episode 119/2000, total reward: 258.427, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.633355787595741, ratio_heur=99.19128854268409 ratio=96.12101555906528, k_srv_heur=36192542, k_srv=35072272, k_req=36487621
# Episode 120/2000, total reward: 252.733, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.3209775896762004, ratio_heur=98.93920293902794 ratio=95.4847770679328, k_srv_heur=29401426, k_srv=28374886, k_req=29716660
# Episode 121/2000, total reward: 234.183, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.0600088765775766, ratio_heur=98.92184008415222 ratio=93.9459078380724, k_srv_heur=23800620, k_srv=22603409, k_req=24060026
# Episode 122/2000, total reward: 200.491, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.36636947313283, ratio_heur=97.33440621755693 ratio=90.1753376812234, k_srv_heur=50979945, k_srv=47230306, k_req=52376079
# Episode 123/2000, total reward: 211.721, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.2998984985803212, ratio_heur=99.19803536744148 ratio=92.9279568722398, k_srv_heur=50526802, k_srv=47333120, k_req=50935285
# Episode 124/2000, total reward: 258.866, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.856916458949717, ratio_heur=98.71075042949619 ratio=95.95578923870701, k_srv_heur=40800526, k_srv=39661806, k_req=41333417
# Episode 125/2000, total reward: 203.741, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.639290155488569, ratio_heur=98.10763874762499 ratio=87.07682861732613, k_srv_heur=57188687, k_srv=50758632, k_req=58291778
# Episode 126/2000, total reward: 201.991, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.284947335223994, ratio_heur=99.18088021025942 ratio=88.57228767453023, k_srv_heur=50196645, k_srv=44827507, k_req=50611211
# Episode 127/2000, total reward: 130.060, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.7692777796095713, ratio_heur=98.06317468977231 ratio=84.6315013334804, k_srv_heur=59925747, k_srv=51717742, k_req=61109328
# Episode 128/2000, total reward: 240.730, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.3118907188688695, ratio_heur=99.28129766682883 ratio=95.11702329475372, k_srv_heur=29307538, k_srv=28078257, k_req=29519697
# Episode 129/2000, total reward: 265.063, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.3192362326814324, ratio_heur=99.48693667612638 ratio=96.33784653432342, k_srv_heur=29526643, k_srv=28592028, k_req=29678915
# Episode 130/2000, total reward: 153.397, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.6752232362397437, ratio_heur=95.69825423219429 ratio=83.49674335626064, k_srv_heur=56529577, k_srv=49322066, k_req=59070646
# Episode 131/2000, total reward: 121.200, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.6963673259471044, ratio_heur=97.52655075583058 ratio=76.99087266269325, k_srv_heur=58056537, k_srv=45831862, k_req=59528956
# Episode 132/2000, total reward: 156.288, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.684790515904357, ratio_heur=98.22580575098577 ratio=80.63774641541298, k_srv_heur=58226315, k_srv=47800461, k_req=59278022
# Episode 133/2000, total reward: 147.457, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.5346127611844533, ratio_heur=96.44596913318028 ratio=81.59933430917435, k_srv_heur=54031771, k_srv=45714265, k_req=56022840
# Episode 134/2000, total reward: 159.265, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.791714993156025, ratio_heur=98.49017310524029 ratio=87.0077147591814, k_srv_heur=60665679, k_srv=53592982, k_req=61595666
# Episode 135/2000, total reward: 236.052, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.728457366284899, ratio_heur=99.45486181522895 ratio=94.28229322296522, k_srv_heur=38338853, k_srv=36344880, k_req=38548998
# Episode 136/2000, total reward: 90.761, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.2178434695952776, ratio_heur=92.79477904422158 ratio=81.17049883854716, k_srv_heur=65728607, k_srv=57494871, k_req=70832225
# Episode 137/2000, total reward: 143.695, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.201722841525324, ratio_heur=93.81916223845602 ratio=80.60674779773737, k_srv_heur=66126375, k_srv=56813895, k_req=70482802
# Episode 138/2000, total reward: 64.868, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.397326494364102, ratio_heur=91.04702672404328 ratio=69.00099252136008, k_srv_heur=68032718, k_srv=51559345, k_req=74722614
# Episode 139/2000, total reward: 153.532, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.6716856842211394, ratio_heur=98.8529899460311 ratio=86.86117997999537, k_srv_heur=58317301, k_srv=51242857, k_req=58993968
# Episode 140/2000, total reward: 78.333, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.454088923261809, ratio_heur=93.01893789031183 ratio=70.1183232753261, k_srv_heur=70650646, k_srv=53256949, k_req=75952970
# Episode 141/2000, total reward: 246.527, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.005046023572821, ratio_heur=99.13106422664099 ratio=95.24267949641896, k_srv_heur=44157142, k_srv=42425092, k_req=44544203
# Episode 142/2000, total reward: 260.836, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.0012995833721408, ratio_heur=99.64059745445991 ratio=95.13347077888348, k_srv_heur=22705572, k_srv=21678512, k_req=22787471
# Episode 143/2000, total reward: 72.731, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.166951450154432, ratio_heur=93.91944653198708 ratio=73.7704480786118, k_srv_heur=65489198, k_srv=51439480, k_req=69729114
# Episode 144/2000, total reward: 254.287, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.4013164615936335, ratio_heur=99.28128229331605 ratio=94.0657761593888, k_srv_heur=31231953, k_srv=29591256, k_req=31458047
# Episode 145/2000, total reward: 112.743, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.42258998034988, ratio_heur=95.32366113748951 ratio=76.57636889995848, k_srv_heur=71750323, k_srv=57639196, k_req=75270214
# Episode 146/2000, total reward: 154.739, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.326841792852613, ratio_heur=95.88497316322085 ratio=81.56158485171673, k_srv_heur=49399262, k_srv=42019954, k_req=51519295
# Episode 147/2000, total reward: 105.691, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.561927824922395, ratio_heur=92.650407521315 ratio=80.29920678562158, k_srv_heur=72536407, k_srv=62866598, k_req=78290435
# Episode 148/2000, total reward: 241.243, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.2779220310668467, ratio_heur=99.64062774871871 ratio=95.03406766948598, k_srv_heur=28679968, k_srv=27354043, k_req=28783408
# Episode 149/2000, total reward: 231.145, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.0984126556983123, ratio_heur=99.36306232757934 ratio=91.75148706986856, k_srv_heur=46271365, k_srv=42726808, k_req=46567974
# Episode 150/2000, total reward: 246.498, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.2282474729918886, ratio_heur=99.16117210624856 ratio=95.40456912593692, k_srv_heur=27474274, k_srv=26433444, k_req=27706686
# Episode 151/2000, total reward: 252.696, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.4274283886377759, ratio_heur=99.54340263967858 ratio=96.63640377811483, k_srv_heur=31877816, k_srv=30946878, k_req=32024037
# Episode 152/2000, total reward: 88.765, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.500543945657858, ratio_heur=96.74664974319283 ratio=69.96575569144935, k_srv_heur=53485786, k_srv=38680135, k_req=55284381
# Episode 153/2000, total reward: 108.410, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.594928405306524, ratio_heur=96.51633646892645 ratio=76.96314106639136, k_srv_heur=55333022, k_srv=44123133, k_req=57330214
# Episode 154/2000, total reward: 127.412, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.344150508949971, ratio_heur=94.8425173049821 ratio=75.1155466146221, k_srv_heur=69775637, k_srv=55262505, k_req=73569997
# Episode 155/2000, total reward: 117.150, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.3060108150913496, ratio_heur=99.11651305089723 ratio=75.8621740949781, k_srv_heur=72100621, k_srv=55184648, k_req=72743299
# Episode 156/2000, total reward: 151.323, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.167912401672903, ratio_heur=95.22758923359753 ratio=77.73621509475544, k_srv_heur=66421189, k_srv=54220966, k_req=69749943
# Episode 157/2000, total reward: 69.821, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.2596473396252184, ratio_heur=94.74178870961887 ratio=66.84750380273843, k_srv_heur=67966192, k_srv=47955293, k_req=71738346
# Episode 158/2000, total reward: 118.723, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.59105072244072, ratio_heur=93.36315086357325 ratio=79.6120290833364, k_srv_heur=73683775, k_srv=62831158, k_req=78921689
# Episode 159/2000, total reward: 217.071, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.5393885684993727, ratio_heur=98.92163685311864 ratio=93.05796384744427, k_srv_heur=34079328, k_srv=32059243, k_req=34450833
# Episode 160/2000, total reward: 129.940, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.4122841578788012, ratio_heur=95.78991523996929 ratio=81.22411011910012, k_srv_heur=71887294, k_srv=60956119, k_req=75046829
# Episode 161/2000, total reward: 114.920, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.0923600090972783, ratio_heur=96.38240821777548 ratio=75.21857616764464, k_srv_heur=65648280, k_srv=51233106, k_req=68112305
# Episode 162/2000, total reward: 160.933, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.2508676670148535, ratio_heur=98.09063913270786 ratio=84.69932215185845, k_srv_heur=48920270, k_srv=42241683, k_req=49872516
# Episode 163/2000, total reward: 265.664, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.4024940647354194, ratio_heur=99.64065410756483 ratio=97.04327671608227, k_srv_heur=31370437, k_srv=30552690, k_req=31483572
# Episode 164/2000, total reward: 212.841, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.8219273167921113, ratio_heur=98.92171842823551 ratio=90.74276424415432, k_srv_heur=40137496, k_srv=36818884, k_req=40575009
# Episode 165/2000, total reward: 116.731, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.3310041272323336, ratio_heur=91.75476068322963 ratio=77.75978784238433, k_srv_heur=67242515, k_srv=56986293, k_req=73285042
# Episode 166/2000, total reward: 72.345, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.6739728523137614, ratio_heur=94.26199283001947 ratio=71.43659036421536, k_srv_heur=76087404, k_srv=57662951, k_req=80719070
# Episode 167/2000, total reward: 252.695, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.0881927666823437, ratio_heur=99.18401802159302 ratio=95.55208569047178, k_srv_heur=45968273, k_srv=44285002, k_req=46346452
# Episode 168/2000, total reward: 205.215, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.6674997888353364, ratio_heur=96.91878756240459 ratio=90.12623591456696, k_srv_heur=57088303, k_srv=53087270, k_req=58903237
# Episode 169/2000, total reward: 259.042, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.461211253999409, ratio_heur=98.86959913918929 ratio=95.53618405895963, k_srv_heur=32386021, k_srv=31294117, k_req=32756298
# Episode 170/2000, total reward: 79.389, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 3.488690088621922, ratio_heur=90.56364726675955 ratio=68.52413863944874, k_srv_heur=69465006, k_srv=52560048, k_req=76702968
# Episode 171/2000, total reward: 63.364, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 4.014330862887597, ratio_heur=88.80301702812667 ratio=71.7320374992964, k_srv_heur=78232357, k_srv=63193420, k_req=88096508
# Episode 172/2000, total reward: 264.198, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.2320350287933803, ratio_heur=99.28127664731427 ratio=97.41457744314455, k_srv_heur=27589058, k_srv=27070325, k_req=27788783
# Episode 173/2000, total reward: 177.699, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.0608824320181287, ratio_heur=98.20235064993432 ratio=83.55631161963363, k_srv_heur=44931981, k_srv=38230761, k_req=45754486
# Episode 174/2000, total reward: 223.975, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.7173113269665357, ratio_heur=99.23910777231328 ratio=91.74300671479864, k_srv_heur=38015924, k_srv=35144362, k_req=38307402
# Episode 175/2000, total reward: 114.747, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.9905240473865433, ratio_heur=97.94113948819346 ratio=77.22958687376592, k_srv_heur=64548066, k_srv=50898126, k_req=65904957
# Episode 176/2000, total reward: 236.835, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.4650884642651132, ratio_heur=99.53683409709157 ratio=92.95598916946676, k_srv_heur=32688233, k_srv=30527062, k_req=32840339
# Episode 177/2000, total reward: 240.713, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.8003297516824848, ratio_heur=99.22483240479329 ratio=94.61468212719257, k_srv_heur=39795975, k_srv=37946988, k_req=40106870
# Episode 178/2000, total reward: 205.143, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.6143838156816277, ratio_heur=98.00167612374489 ratio=92.2906047406298, k_srv_heur=56597850, k_srv=53299596, k_req=57751920
# Episode 179/2000, total reward: 113.676, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 3.265797647029135, ratio_heur=94.46586330071463 ratio=74.24381938677558, k_srv_heur=67894182, k_srv=53360263, k_req=71871657
# Episode 180/2000, total reward: 116.169, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 3.3042208817832637, ratio_heur=96.51899627352407 ratio=82.68546633077143, k_srv_heur=70173655, k_srv=60116056, k_req=72704501
# Episode 181/2000, total reward: 166.733, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.7222490742389054, ratio_heur=98.00591298776952 ratio=83.14588528567785, k_srv_heur=58891710, k_srv=49962326, k_req=60089956
# Episode 182/2000, total reward: 89.019, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.2239961706381908, ratio_heur=92.20622797768657 ratio=75.53293321735337, k_srv_heur=65434692, k_srv=53602390, k_req=70965588
# Episode 183/2000, total reward: 212.524, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.73830626192198, ratio_heur=97.95036481395256 ratio=91.36043480911586, k_srv_heur=59199246, k_srv=55216423, k_req=60438004
# Episode 184/2000, total reward: 132.150, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.331725810092564, ratio_heur=96.27096533650634 ratio=79.49467895767606, k_srv_heur=49700039, k_srv=41039254, k_req=51625159
# Episode 185/2000, total reward: 101.658, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.966023675984192, ratio_heur=94.1734142290026 ratio=74.43187955669679, k_srv_heur=61564833, k_srv=48659022, k_req=65373899
# Episode 186/2000, total reward: 91.092, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.9185059089984033, ratio_heur=95.18558769432079 ratio=72.68810496905422, k_srv_heur=61246144, k_srv=46770381, k_req=64343926
# Episode 187/2000, total reward: 42.345, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 4.106335751593123, ratio_heur=93.03728370966678 ratio=71.42625601060121, k_srv_heur=83817999, k_srv=64348459, k_req=90090763
# Episode 188/2000, total reward: 224.525, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.800357912195368, ratio_heur=99.31227892045466 ratio=92.45004151527988, k_srv_heur=61358111, k_srv=57118415, k_req=61783006
# Episode 189/2000, total reward: 57.538, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 4.105019817318988, ratio_heur=88.97637221049693 ratio=72.96141738477921, k_srv_heur=80134113, k_srv=65710686, k_req=90062239
# Episode 190/2000, total reward: 152.879, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.1022898739183544, ratio_heur=96.70642965977927 ratio=83.44090057530195, k_srv_heur=66077125, k_srv=57013115, k_req=68327540
# Episode 191/2000, total reward: 67.243, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 4.399187625216909, ratio_heur=89.15711897811293 ratio=67.69889415743265, k_srv_heur=85981771, k_srv=65287785, k_req=96438481
# Episode 192/2000, total reward: 81.915, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.8944934345087154, ratio_heur=92.70954674048988 ratio=73.64379065832638, k_srv_heur=79265707, k_srv=62964682, k_req=85498969
# Episode 193/2000, total reward: 28.173, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.4502082069487825, ratio_heur=87.86487625879758 ratio=67.27293350403272, k_srv_heur=85707248, k_srv=65620965, k_req=97544379
# Episode 194/2000, total reward: 97.872, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.11312622845138, ratio_heur=93.65833335075376 ratio=69.26695555348854, k_srv_heur=84515360, k_srv=62505080, k_req=90237950
# Episode 195/2000, total reward: 44.249, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.1281944729199616, ratio_heur=89.28828201866199 ratio=64.10598249321801, k_srv_heur=80863541, k_srv=58057302, k_req=90564562
# Episode 196/2000, total reward: 53.441, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.481457206344372, ratio_heur=90.58663537846905 ratio=67.89894304268842, k_srv_heur=88975749, k_srv=66691508, k_req=98221718
# Episode 197/2000, total reward: 153.579, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.749055842429249, ratio_heur=95.3740790892825 ratio=83.09893562813131, k_srv_heur=57864414, k_srv=50416961, k_req=60671007
# Episode 198/2000, total reward: 86.909, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.7924508019167966, ratio_heur=95.16294591588999 ratio=71.71458902982273, k_srv_heur=58631428, k_srv=44184517, k_req=61611615
# Episode 199/2000, total reward: 100.200, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.0502772316175526, ratio_heur=93.91997475459884 ratio=78.55680574102252, k_srv_heur=63114353, k_srv=52790282, k_req=67200139
# Episode 200/2000, total reward: 158.990, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.935896828895452, ratio_heur=95.91055514863946 ratio=83.9025164564043, k_srv_heur=62074159, k_srv=54302450, k_req=64720884
# Episode 201/2000, total reward: 102.149, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.1534521413729526, ratio_heur=96.08436818451312 ratio=75.73980474660797, k_srv_heur=66717631, k_srv=52591077, k_req=69436509
# Episode 202/2000, total reward: 43.745, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.318737025736173, ratio_heur=88.74853940616015 ratio=61.75053697735067, k_srv_heur=84040138, k_srv=58474468, k_req=94694672
# Episode 203/2000, total reward: 253.083, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 1.5394656282265382, ratio_heur=98.85132992121335 ratio=94.7215052069788, k_srv_heur=34056757, k_srv=32633929, k_req=34452503
# Episode 204/2000, total reward: 40.089, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 4.54127340065613, ratio_heur=87.99483023111695 ratio=58.70776815716561, k_srv_heur=87570928, k_srv=58424952, k_req=99518265
# Episode 205/2000, total reward: 58.799, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.270651990492535, ratio_heur=91.4771709123022 ratio=70.41193208491163, k_srv_heur=85670569, k_srv=65942467, k_req=93652404
# Episode 206/2000, total reward: 71.400, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.358169804209716, ratio_heur=91.94892455837766 ratio=63.79620864019703, k_srv_heur=87856644, k_srv=60956893, k_req=95549398
# Episode 207/2000, total reward: 235.970, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.7679693914737555, ratio_heur=99.44322554795401 ratio=94.33882000044463, k_srv_heur=39186043, k_srv=37174629, k_req=39405442
# Episode 208/2000, total reward: 138.407, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 2.5690002718803884, ratio_heur=96.14626618776079 ratio=74.62663613470447, k_srv_heur=54580512, k_srv=42364204, k_req=56768208
# Episode 209/2000, total reward: 71.829, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.26812393921317, ratio_heur=90.4340136903699 ratio=69.54946827967336, k_srv_heur=84644073, k_srv=65096638, k_req=93597607
# Episode 210/2000, total reward: 265.348, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.4311158801765902, ratio_heur=99.54271933537729 ratio=96.45877509156938, k_srv_heur=31957160, k_srv=30967092, k_req=32103965
# Episode 211/2000, total reward: 250.398, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.1641122582386954, ratio_heur=99.6406170058642 ratio=92.49690773770817, k_srv_heur=26221944, k_srv=24341968, k_req=26316521
# Episode 212/2000, total reward: 30.358, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.574869972878975, ratio_heur=90.1963218791367 ratio=65.36176510473585, k_srv_heur=90418645, k_srv=65522874, k_req=100246488
# Episode 213/2000, total reward: 70.008, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 2.726465264095916, ratio_heur=95.61536192998965 ratio=66.83059836069253, k_srv_heur=57542610, k_srv=40219552, k_req=60181344
# Episode 214/2000, total reward: 252.477, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.0367568915338115, ratio_heur=99.21455450685102 ratio=96.80204837288646, k_srv_heur=23371007, k_srv=22802716, k_req=23556027
# Episode 215/2000, total reward: 36.039, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.76396692735849, ratio_heur=86.81248329174072 ratio=61.7775561759941, k_srv_heur=90584715, k_srv=64461954, k_req=104345264
# Episode 216/2000, total reward: 242.593, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.7925264288629723, ratio_heur=99.37271161498424 ratio=92.91205688370611, k_srv_heur=39687204, k_srv=37106965, k_req=39937729
# Episode 217/2000, total reward: 55.432, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 4.303631867314358, ratio_heur=90.28992313098026 ratio=65.17461436746275, k_srv_heur=85204126, k_srv=61503498, k_req=94367260
# Episode 218/2000, total reward: 253.656, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 1.3943600365179123, ratio_heur=99.28124734738259 ratio=95.12709824797733, k_srv_heur=31082241, k_srv=29781691, k_req=31307263
# Episode 219/2000, total reward: 201.769, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 1.4909378147563603, ratio_heur=98.24603192186517 ratio=85.61734901880685, k_srv_heur=32814800, k_srv=28596740, k_req=33400637
# Episode 220/2000, total reward: 27.045, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 3.919195725148183, ratio_heur=93.79643019212021 ratio=62.150602367080175, k_srv_heur=80697200, k_srv=53470900, k_req=86034404
# Episode 221/2000, total reward: 230.077, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 2.0362008084064898, ratio_heur=98.56225197510598 ratio=93.22803904050566, k_srv_heur=44569357, k_srv=42157252, k_req=45219499
# Episode 222/2000, total reward: 71.689, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 3.687605457318515, ratio_heur=89.84557231238419 ratio=71.4356913225418, k_srv_heur=72787998, k_srv=57873313, k_req=81014563
# ...
# Episode 1928/2000, total reward: 15.873, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 6.542081555549823, ratio_heur=81.12214732116615 ratio=56.37959457350876, k_srv_heur=115912868, k_srv=80559017, k_req=142886834
# Episode 1929/2000, total reward: 13.829, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 9.770180314442133, ratio_heur=70.66226652457654 ratio=41.60077616261306, k_srv_heur=150409985, k_srv=88550402, k_req=212857572
# Episode 1930/2000, total reward: 51.303, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 5.555405718058587, ratio_heur=86.04410540173222 ratio=68.24100992992129, k_srv_heur=104543688, k_srv=82912906, k_req=121500116
# Episode 1931/2000, total reward: 246.775, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.5617166379284417, ratio_heur=99.44639756530458 ratio=95.26571652452714, k_srv_heur=34741405, k_srv=33280892, k_req=34934805
# Episode 1932/2000, total reward: 22.991, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.690459230411773, ratio_heur=77.28697017944008 ratio=54.20598477122526, k_srv_heur=112918580, k_srv=79196569, k_req=146102998
# Episode 1933/2000, total reward: 29.850, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.309595071596096, ratio_heur=80.94043468749841 ratio=54.0370914617076, k_srv_heur=129118685, k_srv=86201639, k_req=159523093
# Episode 1934/2000, total reward: -0.560, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.387782143648817, ratio_heur=70.79130578393533 ratio=44.58017033148416, k_srv_heur=144816989, k_srv=91197160, k_req=204568891
# Episode 1935/2000, total reward: 70.226, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.8202602346909886, ratio_heur=92.26000083260934 ratio=65.7955123462568, k_srv_heur=77396846, k_srv=55195806, k_req=83889925
# Episode 1936/2000, total reward: 14.071, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.036522483183895, ratio_heur=81.98056864707341 ratio=52.26611017301591, k_srv_heur=125925516, k_srv=80282889, k_req=153604101
# Episode 1937/2000, total reward: 217.470, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.424099423428733, ratio_heur=99.28123905168232 ratio=93.25724426421111, k_srv_heur=31722222, k_srv=29797443, k_req=31951880
# Episode 1938/2000, total reward: 65.572, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.644521431614949, ratio_heur=91.65006579224807 ratio=68.84606501922427, k_srv_heur=93259643, k_srv=70055154, k_req=101756220
# Episode 1939/2000, total reward: 205.960, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.4482200071543723, ratio_heur=98.38790335947478 ratio=90.26887450445466, k_srv_heur=53277278, k_srv=48880805, k_req=54150232
# Episode 1940/2000, total reward: 9.352, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.12353525691022, ratio_heur=78.51922502013228 ratio=48.791825816378136, k_srv_heur=122089660, k_srv=75866482, k_req=155490149
# Episode 1941/2000, total reward: 30.033, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.4371099074599964, ratio_heur=80.62171235307956 ratio=55.18826517616336, k_srv_heur=130838594, k_srv=89563404, k_req=162287044
# Episode 1942/2000, total reward: 18.277, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.281866996377547, ratio_heur=73.62885343214606 ratio=46.637615890871956, k_srv_heur=148931382, k_srv=94335363, k_req=202273124
# Episode 1943/2000, total reward: 30.156, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.309983552285832, ratio_heur=82.22525423138029 ratio=55.86913821132453, k_srv_heur=113352436, k_srv=77018952, k_req=137855988
# Episode 1944/2000, total reward: 30.971, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.357322322637218, ratio_heur=86.17821241779967 ratio=56.906653861977695, k_srv_heur=101006513, k_srv=66698328, k_req=117206555
# Episode 1945/2000, total reward: 80.509, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.2064547380332242, ratio_heur=96.29257300061307 ratio=69.39838535075995, k_srv_heur=67968468, k_srv=48985106, k_req=70585369
# Episode 1946/2000, total reward: 12.159, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.814944398995149, ratio_heur=74.36560896496388 ratio=46.122021990322615, k_srv_heur=142895251, k_srv=88624540, k_req=192152331
# Episode 1947/2000, total reward: 36.856, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.290042384720344, ratio_heur=78.0131059679789 ratio=52.396456731254425, k_srv_heur=124118289, k_srv=83362384, k_req=159099278
# Episode 1948/2000, total reward: 28.172, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.780378530087449, ratio_heur=87.84748611040347 ratio=67.35612152561713, k_srv_heur=91977191, k_srv=70522529, k_req=104700994
# Episode 1949/2000, total reward: 12.040, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.608318709282841, ratio_heur=71.60393416506182 ratio=46.15171708103774, k_srv_heur=134381689, k_srv=86614594, k_req=187673611
# Episode 1950/2000, total reward: 247.570, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.1794390104035832, ratio_heur=99.24737140651713 ratio=94.18177568510522, k_srv_heur=47960560, k_srv=45512649, k_req=48324263
# Episode 1951/2000, total reward: 201.412, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.7152325432808557, ratio_heur=97.85114747952991 ratio=88.08556916167333, k_srv_heur=58649893, k_srv=52796613, k_req=59937869
# Episode 1952/2000, total reward: 247.862, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.2738702414174756, ratio_heur=99.57376747436332 ratio=95.57139410723158, k_srv_heur=28573273, k_srv=27424769, k_req=28695583
# Episode 1953/2000, total reward: 30.183, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.330070169114354, ratio_heur=76.85333108373726 ratio=51.33121518625982, k_srv_heur=139598256, k_srv=93239265, k_req=181642428
# Episode 1954/2000, total reward: 105.510, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.5137992578161814, ratio_heur=94.00925192969324 ratio=77.88256893009546, k_srv_heur=72619536, k_srv=60162121, k_req=77247223
# Episode 1955/2000, total reward: 17.895, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.447663367353327, ratio_heur=72.91433259082982 ratio=50.500906464839915, k_srv_heur=118497308, k_srv=82071950, k_req=162515796
# Episode 1956/2000, total reward: 24.344, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.33852858119873, ratio_heur=87.79965824905983 ratio=62.94155693018136, k_srv_heur=102549290, k_srv=73515229, k_req=116799190
# Episode 1957/2000, total reward: -0.913, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.49790144363193, ratio_heur=68.24383853436426 ratio=45.27816700981205, k_srv_heur=141234571, k_srv=93705786, k_req=206955785
# Episode 1958/2000, total reward: 22.314, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.138350101172605, ratio_heur=72.68425687544578 ratio=50.743205396259285, k_srv_heur=129004957, k_srv=90062488, k_req=177486794
# Episode 1959/2000, total reward: 31.702, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.70573745203339, ratio_heur=75.65460722636608 ratio=50.96649229222717, k_srv_heur=127182724, k_srv=85679611, k_req=168109688
# Episode 1960/2000, total reward: 29.261, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.411216312434434, ratio_heur=79.43409328070159 ratio=48.796345999889986, k_srv_heur=111247655, k_srv=68339410, k_req=140050261
# Episode 1961/2000, total reward: 41.097, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.173638431283264, ratio_heur=89.53103620635667 ratio=65.19835071316137, k_srv_heur=81965291, k_srv=59688819, k_req=91549584
# Episode 1962/2000, total reward: 20.708, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.8071760882819525, ratio_heur=85.11014545786612 ratio=55.939454217743254, k_srv_heur=108053604, k_srv=71019261, k_req=126957372
# Episode 1963/2000, total reward: 4.076, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.39413918804723, ratio_heur=65.59828483944167 ratio=41.98675689732746, k_srv_heur=134284073, k_srv=85949697, k_req=204706683
# Episode 1964/2000, total reward: 24.535, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.956987312610546, ratio_heur=84.85947798996119 ratio=59.61584442926875, k_srv_heur=110490951, k_srv=77622577, k_req=130204609
# Episode 1965/2000, total reward: 136.949, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.7473780353534716, ratio_heur=93.69187328108617 ratio=78.88262456187358, k_srv_heur=77117936, k_srv=64928419, k_req=82310165
# Episode 1966/2000, total reward: 30.808, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.188571553762408, ratio_heur=78.32645776498636 ratio=52.532435761260174, k_srv_heur=122894090, k_srv=82423310, k_req=156899845
# Episode 1967/2000, total reward: 22.318, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.297461925540422, ratio_heur=77.68240569624442 ratio=55.384075033822945, k_srv_heur=123717077, k_srv=88204734, k_req=159260101
# Episode 1968/2000, total reward: 58.556, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.864103796315929, ratio_heur=89.50297101738937 ratio=68.8202572020927, k_srv_heur=95334791, k_srv=73304436, k_req=106515784
# Episode 1969/2000, total reward: 49.930, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.286136487661805, ratio_heur=88.81309675187768 ratio=65.44447060589452, k_srv_heur=83473687, k_srv=61509974, k_req=93988038
# Episode 1970/2000, total reward: 31.804, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.5132823021907855, ratio_heur=80.73986514268641 ratio=52.948888431190476, k_srv_heur=114862627, k_srv=75326463, k_req=142262595
# Episode 1971/2000, total reward: 46.654, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.677023546297752, ratio_heur=90.43593974438713 ratio=66.3877647158168, k_srv_heur=92661316, k_srv=68021382, k_req=102460721
# Episode 1972/2000, total reward: 98.696, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.409952824647277, ratio_heur=93.7316813495815 ratio=78.0134253029792, k_srv_heur=70295290, k_srv=58507180, k_req=74996297
# Episode 1973/2000, total reward: 1.735, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.915907943027841, ratio_heur=68.63707079513476 ratio=46.180338824265135, k_srv_heur=133389811, k_srv=89747226, k_req=194340769
# Episode 1974/2000, total reward: 46.896, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.764940170219955, ratio_heur=88.48759165231536 ratio=63.38889404196366, k_srv_heur=92351278, k_srv=66156681, k_req=104366360
# Episode 1975/2000, total reward: 247.854, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.5592349679800748, ratio_heur=99.27025105362931 ratio=94.02421380330199, k_srv_heur=34626470, k_srv=32796599, k_req=34881014
# Episode 1976/2000, total reward: 259.117, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.8477139779036384, ratio_heur=99.21725412214616 ratio=95.28362737453679, k_srv_heur=40811974, k_srv=39193918, k_req=41133948
# Episode 1977/2000, total reward: 35.541, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.931166388454637, ratio_heur=80.9358501506112 ratio=58.60692768559166, k_srv_heur=122472494, k_srv=88684268, k_req=151320452
# Episode 1978/2000, total reward: 63.374, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.703624593914732, ratio_heur=91.58116844454686 ratio=69.18738960548708, k_srv_heur=94362775, k_srv=71288827, k_req=103037313
# Episode 1979/2000, total reward: 35.721, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.601426872998134, ratio_heur=75.02258712504691 ratio=49.95822702663156, k_srv_heur=140685526, k_srv=93683779, k_req=187524227
# Episode 1980/2000, total reward: 19.295, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.477595215424912, ratio_heur=75.24541378601471 ratio=50.11384839242646, k_srv_heur=122773867, k_srv=81768052, k_req=163164585
# Episode 1981/2000, total reward: 191.666, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.001526021178934, ratio_heur=98.76908568233294 ratio=84.59446436557828, k_srv_heur=43920543, k_srv=37617386, k_req=44467905
# Episode 1982/2000, total reward: 29.248, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.892797736153282, ratio_heur=76.10459047781292 ratio=56.97105409693501, k_srv_heur=114528878, k_srv=85735051, k_req=150488792
# Episode 1983/2000, total reward: 29.582, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.569785391403312, ratio_heur=84.86444905460475 ratio=61.55903224896887, k_srv_heur=103374916, k_srv=74986167, k_req=121811803
# Episode 1984/2000, total reward: 38.045, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.534913594299674, ratio_heur=87.92380797626508 ratio=59.59364259749817, k_srv_heur=106436991, k_srv=72141643, k_req=121055939
# Episode 1985/2000, total reward: 27.461, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.5352968888988086, ratio_heur=78.21858478058921 ratio=48.143132897793336, k_srv_heur=128603320, k_srv=79154676, k_req=164415299
# Episode 1986/2000, total reward: 58.901, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.4472758528043106, ratio_heur=91.38039990021089 ratio=66.56588897215808, k_srv_heur=69271180, k_srv=50460467, k_req=75805293
# Episode 1987/2000, total reward: 218.724, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.4802982128856246, ratio_heur=99.4707824665449 ratio=91.06438017449516, k_srv_heur=32994477, k_srv=30206071, k_req=33170018
# Episode 1988/2000, total reward: 259.352, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.1805533346717634, ratio_heur=98.56221702274831 ratio=94.70051184692257, k_srv_heur=26289392, k_srv=25259364, k_req=26672890
# Episode 1989/2000, total reward: 49.301, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.4914682347217365, ratio_heur=92.94358779350048 ratio=68.05184751888208, k_srv_heur=71346459, k_srv=52238766, k_req=76763186
# Episode 1990/2000, total reward: 27.861, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.99093331366009, ratio_heur=63.77403031752554 ratio=42.64262636037393, k_srv_heur=138799400, k_srv=92808482, k_req=217642510
# Episode 1991/2000, total reward: 25.343, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.786581647339222, ratio_heur=80.97422295697453 ratio=54.04674136967167, k_srv_heur=119992869, k_srv=80089975, k_req=148186502
# Episode 1992/2000, total reward: 49.917, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.060930968258722, ratio_heur=91.01634028485931 ratio=63.06218380024824, k_srv_heur=81101557, k_srv=56192562, k_req=89106590
# Episode 1993/2000, total reward: 174.387, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.4612235617910536, ratio_heur=97.14012795579646 ratio=80.37921362863743, k_srv_heur=52875403, k_srv=43752087, k_req=54432091
# Episode 1994/2000, total reward: 37.854, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.557454720265249, ratio_heur=81.3363163623727 ratio=56.00073178946421, k_srv_heur=116489917, k_srv=80204279, k_req=143220055
# Episode 1995/2000, total reward: -0.266, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.068136378034822, ratio_heur=69.58255180889647 ratio=44.22278362323493, k_srv_heur=137523234, k_srv=87402087, k_req=197640401
# Episode 1996/2000, total reward: 28.287, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.879085012016043, ratio_heur=72.11483452185531 ratio=49.99527170323338, k_srv_heur=123941665, k_srv=85925417, k_req=171867087
# Episode 1997/2000, total reward: 37.477, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.67419564039103, ratio_heur=79.27774256542203 ratio=52.11876231774456, k_srv_heur=132731555, k_srv=87260360, k_req=167426002
# Episode 1998/2000, total reward: 27.237, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.635536614373717, ratio_heur=78.10602704431243 ratio=49.46418089661797, k_srv_heur=130115305, k_srv=82401413, k_req=166588047
# Episode 1999/2000, total reward: 51.318, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.585096319391418, ratio_heur=89.8195574383782 ratio=61.301331608953404, k_srv_heur=90240048, k_srv=61588314, k_req=100468150
# Episode 2000/2000, total reward: 0.656, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.274015593700335, ratio_heur=71.21638562551503 ratio=43.07688306821988, k_srv_heur=143930410, k_srv=87059647, k_req=202102941

# %%
# === Plot learning curve with running average ===
window = 100                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,3))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=3)
plt.xlabel("Episode", fontsize=15)
plt.ylabel("Total Reward", fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.savefig("learning.pdf", format="pdf", dpi=300, bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %%
NUM_DATA    = 10
N_RUNS      = 2   # number of Monte-Carlo runs

demand_list = [0.01 + 0.2 * i for i in range(NUM_DATA)]

# %% [markdown]
# ## Testing the Agent

# %%
demand_active = np.ones(MAX_DEMANDS)
link_active   = np.ones(MAX_LINKS)

def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=True):
    agent.model.eval() 
    test_rewards = []

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes (Dual-Head) ---")

    demand_list = [0.01 + 0.2 * i for i in range(num_test_episodes)]
    key_req     = [0 for i in range(num_test_episodes)]
    key_srv_qkp = [0 for i in range(num_test_episodes)]
    a_lst_qkp   = [0 for i in range(num_test_episodes)]
    
    for idx, mean in enumerate(demand_list):
        demands = generate_demands(gnodes, syst, mean_kbps=mean, amp=0.5, noise_std=0.0, pattern="stadium")
        key_req[idx] = sum(d.K_REQ[t] * syst.THETA for d in demands for t in syst.T)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands 
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} 

        ep_reward = 0
        
        for t in syst.T:
            r = random.randint(0, len(hnodes)-1)
            
            hnodes_active = [1 for h in hnodes]
            links_active  = [1 if ((isinstance(l.n1, hap) and hnodes_active[hnodes.index(l.n1)] == 1) or (isinstance(l.n2, hap) and hnodes_active[hnodes.index(l.n2)] == 1)) else 0 for l in links]
            
            s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes, demand_active, link_active) #build_state_vector_for_time(state[t], links, t, gnodes, hnodes)

            with torch.no_grad():
                s_tensor = torch.tensor(s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
                probs, _ = agent.model(s_tensor) # probs shape: [1, 2, n_haps, n_choices]
                
                # --- CHANGE 1: Extract argmax for both heads ---
                # argmax over the last dimension (n_choices)
                # Resulting shape after squeeze: [2, n_haps]
                hap_picks = torch.argmax(probs, dim=-1).squeeze(0).cpu().numpy()

            # --- CHANGE 2: Pass the [2, n_haps] matrix to z_dict ---
            # Your updated get_z_from_demand_choices should handle the 2-row matrix
            z_dict = get_z_from_demand_choices(hap_picks, demands, links, hnodes)

            # 2. Constraint Check
            # With the dual-head, the model naturally picks at most 1 TX and 1 RX per HAP.
            check_tx, check_rx = True, True
            for idx_h, h in enumerate(hnodes):
                used_tx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n1 == h)
                used_rx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n2 == h)
                
                if used_tx > h.N_TX or used_rx > h.N_RX:
                    check_tx, check_rx = False, False

            # 3. Step Environment
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0, demand_active, link_active) #online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0)
            else:
                reward_t = -1.0 

            ep_reward += reward_t
            key_srv_qkp[idx] += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(demands))

            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        a_lst_qkp[idx] = sum(state[-1]["a"][i] for i in range(len(links))) * 1e-6
        
        print(f"Test Case {idx+1}: Mean_kbps={mean:.2f}, key_srv_qkp={key_srv_qkp[idx]:.2f}, key_req={key_req[idx]:.2f}, ep_reward: {ep_reward}")

    return test_rewards, key_srv_qkp, a_lst_qkp

prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

key_srv_ppo_qkp = [0 for i in range(NUM_DATA)]
a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]

# Run the test
results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.
# --- Starting Evaluation for 10 Episodes (Dual-Head) ---
# Test Case 1: Mean_kbps=0.01, key_srv_qkp=0.00, key_req=1083776.30, ep_reward: -288.0
# Test Case 2: Mean_kbps=0.21, key_srv_qkp=12610378.80, key_req=22759302.20, ep_reward: 26.792689682299674
# Test Case 3: Mean_kbps=0.41, key_srv_qkp=24620257.80, key_req=44434828.10, ep_reward: 26.792674012916383
# Test Case 4: Mean_kbps=0.61, key_srv_qkp=32007600.00, key_req=66110354.01, ep_reward: 20.854140626579536
# Test Case 5: Mean_kbps=0.81, key_srv_qkp=33076056.60, key_req=87785879.91, ep_reward: 6.996220625119204
# Test Case 6: Mean_kbps=1.01, key_srv_qkp=34131337.20, key_req=109461405.81, ep_reward: 1.8396492262680317
# Test Case 7: Mean_kbps=1.21, key_srv_qkp=35101652.40, key_req=131136931.72, ep_reward: -0.042803363781351966
# Test Case 8: Mean_kbps=1.41, key_srv_qkp=35945112.60, key_req=152812457.62, ep_reward: -42.35956937278739
# Test Case 9: Mean_kbps=1.61, key_srv_qkp=18894963.60, key_req=174487983.53, ep_reward: -216.1181522393023
# Test Case 10: Mean_kbps=1.81, key_srv_qkp=17231751.00, key_req=196163509.43, ep_reward: -229.1314648736277

# %% [markdown]
# ## Offline

# %%
key_srv_grd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rnd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rlx_qkp = [0 for i in range(NUM_DATA)]
key_srv_opt_qkp = [0 for i in range(NUM_DATA)]

a_lst_grd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rnd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rlx_qkp = [0 for i in range(NUM_DATA)]
a_lst_opt_qkp = [0 for i in range(NUM_DATA)]

key_req = [0 for i in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)

    result_file = os.path.join(RESULTS_DIR, f"mean_{mean:.4f}.pkl")

    # ------------------------------------------------------------
    # If results exist → load them
    # ------------------------------------------------------------
    if os.path.exists(result_file):
        print(f"[LOAD] idx {idx}, mean={mean}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_grd_qkp[idx] = data["key_srv_grd"]
        a_lst_grd_qkp[idx]   = data["a_lst_grd"]

        key_srv_rlx_qkp[idx] = data["key_srv_rlx"]
        a_lst_rlx_qkp[idx]   = data["a_lst_rlx"]

        key_srv_opt_qkp[idx] = data["key_srv_opt"]
        a_lst_opt_qkp[idx]   = data["a_lst_opt"]

        key_req[idx]         = data["key_req"]

        continue   # skip computation

    # ------------------------------------------------------------
    # Otherwise → compute everything
    # ------------------------------------------------------------
    print(f"[COMPUTE] idx {idx}, mean={mean}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.0,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands for t in syst.T
    )

    ########################################## Greedy (Scarcity + Contention Aware, 1-hop only) ##########################################
    # Z[l][d][t] = 1 if link l is used by demand d at time t
    Z = [[[0 for t in syst.T] for d in demands] for l in links]
    
    # Stored QKP bits per link (already scaled by THETA)
    qkp_s = [0 for _ in links]
    
    for t in syst.T:
    
        # Per-HAP connection limits (up/down)
        max_cnct_up  = [1] * len(hnodes)
        max_cnct_dwn = [1] * len(hnodes)
    
        # --------------------------------------------------------------------------------------------------
        # Step 1: Enumerate feasible 1-hop paths for each demand
        # A path (l1, l2) is feasible if:
        #   - fresh keys can serve it on both links, OR
        #   - stored QKP can cover the demand on both links
        # --------------------------------------------------------------------------------------------------
        feasible_paths = {}   # d -> list of (idx_l1, idx_l2, mid)
    
        for d in demands:
            src, dst = d.n1, d.n2
            feasible_paths[d] = []
    
            for idx_l1, l1 in enumerate(links):
                for idx_l2, l2 in enumerate(links):
                    if l1.n1 == src and l2.n2 == dst and l1.n2 == l2.n1:
                        mid = l1.n2
    
                        fresh_ok = (
                            l1.K_MAX[t] >= d.K_REQ[t] and
                            l2.K_MAX[t] >= d.K_REQ[t]
                        )
    
                        qkp_ok = (
                            qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                            qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                        )
    
                        if fresh_ok or qkp_ok:
                            feasible_paths[d].append((idx_l1, idx_l2, mid))
    
        # --------------------------------------------------------------------------------------------------
        # Step 2: Order demands by scarcity (least number of feasible paths first)
        # --------------------------------------------------------------------------------------------------
        ordered_demands = sorted(
            demands,
            key=lambda d: (
                len(feasible_paths[d]),
                -d.K_REQ[t]
            )
        )
        
        # --------------------------------------------------------------------------------------------------
        # Step 3 (FIXED): Compute link contention
        # How many feasible paths (across all demands) include each link
        # --------------------------------------------------------------------------------------------------
        link_usage = [0] * len(links)
        
        for d in demands:
            for (idx_l1, idx_l2, _) in feasible_paths[d]:
                link_usage[idx_l1] += 1
                link_usage[idx_l2] += 1
    
        # --------------------------------------------------------------------------------------------------
        # Step 4: Greedy allocation
        # For each demand, try least-contended feasible paths first
        # --------------------------------------------------------------------------------------------------
        for d in ordered_demands:
    
            l1_sel = None
            l2_sel = None
            used_qkp_only = False
    
            # # Order this demand's paths by least contention
            # paths = sorted(
            #     feasible_paths[d],
            #     key=lambda p: path_usage[(p[0], p[1])]
            # )
            
            # Order this demand's paths by least link contention
            paths = sorted(
                feasible_paths[d],
                key=lambda p: link_usage[p[0]] + link_usage[p[1]]
            )
    
            for idx_l1, idx_l2, mid in paths:
    
                # Respect HAP connection limits
                if max_cnct_up[hnodes.index(mid)] == 0:
                    continue
                if max_cnct_dwn[hnodes.index(mid)] == 0:
                    continue
    
                # Case 1: Fully served by stored QKP
                if (
                    qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                    qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                ):
                    qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                    qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                    used_qkp_only = True
                    break
    
                # Case 2: Use fresh generation (possibly mixed with QKP later)
                l1_sel = links[idx_l1]
                l2_sel = links[idx_l2]
                break
    
            # --------------------------------------------------------------------------------------------------
            # Step 5: Update state after allocation
            # --------------------------------------------------------------------------------------------------
            if used_qkp_only:
                continue
    
            if l1_sel is not None:
                mid = l1_sel.n2
                max_cnct_up[hnodes.index(mid)] = 0
    
                l_idx = links.index(l1_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l1_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
            if l2_sel is not None:
                mid = l2_sel.n1
                max_cnct_dwn[hnodes.index(mid)] = 0
    
                l_idx = links.index(l2_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l2_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
    # --------------- GREEDY ----------------
    solution, key_srv_grd_qkp[idx], a_lst_grd_qkp[idx] = offline_lp(
        gnodes, hnodes, links, demands, 1, 2, Z
    )

    key_srv_grd_qkp[idx] *= 1e-6
    a_lst_grd_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, SCAR-Q")

    # --------------- RELAXED ----------------
    solution, key_srv_rlx_qkp[idx], a_lst_rlx_qkp[idx] = offline_relaxed(
        gnodes, hnodes, links, demands, 1, 2
    )

    key_srv_rlx_qkp[idx] *= 1e-6
    a_lst_rlx_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, RELAX")

    # --------------- OPTIMAL ----------------
    if case != 1:
        solution, key_srv_opt_qkp[idx], a_lst_opt_qkp[idx] = offline(
            gnodes, hnodes, links, demands, 1, 2
        )
    
        key_srv_opt_qkp[idx] *= 1e-6
        a_lst_opt_qkp[idx]   *= 1e-6
    
        print(f"idx: {idx}, OPTIMAL")

    # ------------------------------------------------------------
    # Save results
    # ------------------------------------------------------------
    data = {
        "key_srv_grd": key_srv_grd_qkp[idx],
        "a_lst_grd":   a_lst_grd_qkp[idx],

        "key_srv_rlx": key_srv_rlx_qkp[idx],
        "a_lst_rlx":   a_lst_rlx_qkp[idx],

        "key_srv_opt": key_srv_opt_qkp[idx],
        "a_lst_opt":   a_lst_opt_qkp[idx],

        "key_req":     key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] idx {idx}")
# Out:
# [LOAD] idx 0, mean=0.01
# [LOAD] idx 1, mean=0.21000000000000002
# [LOAD] idx 2, mean=0.41000000000000003
# [LOAD] idx 3, mean=0.6100000000000001
# [LOAD] idx 4, mean=0.81
# [LOAD] idx 5, mean=1.01
# [LOAD] idx 6, mean=1.2100000000000002
# [LOAD] idx 7, mean=1.4100000000000001
# [LOAD] idx 8, mean=1.61
# [LOAD] idx 9, mean=1.81

# %%
#Store statistics
key_srv_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

a_lst_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

key_req = [0.0 for _ in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    result_file = os.path.join(RESULTS_DIR, f"idx_{idx}.pkl")

    # ============================================================
    # LOAD IF EXISTS
    # ============================================================
    if os.path.exists(result_file):

        print(f"[LOAD] Random idx {idx}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_rnd_qkp_avg[idx] = data["key_srv_avg"]
        key_srv_rnd_qkp_min[idx] = data["key_srv_min"]
        key_srv_rnd_qkp_max[idx] = data["key_srv_max"]

        a_lst_rnd_qkp_avg[idx] = data["a_lst_avg"]
        a_lst_rnd_qkp_min[idx] = data["a_lst_min"]
        a_lst_rnd_qkp_max[idx] = data["a_lst_max"]

        key_req[idx] = data["key_req"]

        continue

    # ============================================================
    # OTHERWISE COMPUTE
    # ============================================================
    print(f"[COMPUTE] Random idx {idx}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.2,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands
        for t in syst.T
    )

    rnd_results_k_srv = []
    rnd_results_a_lst = []

    # ------------------------------------------------------------
    # Monte Carlo
    # ------------------------------------------------------------
    for run in range(N_RUNS):

        Z = [[[0 for t in syst.T] for d in demands] for l in links]

        for t in syst.T:

            max_cnct_up  = [1 for _ in hnodes]
            max_cnct_dwn = [1 for _ in hnodes]

            shuffled_demands = random.sample(demands, len(demands))

            for d in shuffled_demands:

                src, dst = d.n1, d.n2
                feasible_pairs = []

                for l1 in links:
                    for l2 in links:
                        if (
                            l1.n1 == src and
                            l2.n2 == dst and
                            l1.n2 == l2.n1
                        ):
                            mid = l1.n2
                            if (
                                max_cnct_up[hnodes.index(mid)] > 0 and
                                max_cnct_dwn[hnodes.index(mid)] > 0 and
                                l1.K_MAX[t] > 0 and
                                l2.K_MAX[t] > 0
                            ):
                                feasible_pairs.append((l1, l2))

                if feasible_pairs:
                    l1_sel, l2_sel = random.choice(feasible_pairs)
                    mid = l1_sel.n2

                    Z[links.index(l1_sel)][demands.index(d)][t] = 1
                    Z[links.index(l2_sel)][demands.index(d)][t] = 1

                    max_cnct_up[hnodes.index(mid)]  = 0
                    max_cnct_dwn[hnodes.index(mid)] = 0

        _, key_srv, a_lst = offline_lp(
            gnodes, hnodes, links, demands, 1, 2, Z
        )

        rnd_results_k_srv.append(key_srv * 1e-6)
        rnd_results_a_lst.append(a_lst   * 1e-6)

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------
    key_srv_rnd_qkp_avg[idx] = np.mean(rnd_results_k_srv)
    key_srv_rnd_qkp_min[idx] = np.min(rnd_results_k_srv)
    key_srv_rnd_qkp_max[idx] = np.max(rnd_results_k_srv)

    a_lst_rnd_qkp_avg[idx] = np.mean(rnd_results_a_lst)
    a_lst_rnd_qkp_min[idx] = np.min(rnd_results_a_lst)
    a_lst_rnd_qkp_max[idx] = np.max(rnd_results_a_lst)

    # ------------------------------------------------------------
    # SAVE RESULTS
    # ------------------------------------------------------------
    data = {
        "key_srv_avg": key_srv_rnd_qkp_avg[idx],
        "key_srv_min": key_srv_rnd_qkp_min[idx],
        "key_srv_max": key_srv_rnd_qkp_max[idx],

        "a_lst_avg": a_lst_rnd_qkp_avg[idx],
        "a_lst_min": a_lst_rnd_qkp_min[idx],
        "a_lst_max": a_lst_rnd_qkp_max[idx],

        "key_req": key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] Random idx {idx}")
    print(f"idx: {idx} | avg={key_srv_rnd_qkp_avg[idx]:.3f}")
    print(f"idx: {idx} | avg={a_lst_rnd_qkp_avg[idx]:.3f}")
# Out:
# [LOAD] Random idx 0
# [LOAD] Random idx 1
# [LOAD] Random idx 2
# [LOAD] Random idx 3
# [LOAD] Random idx 4
# [LOAD] Random idx 5
# [LOAD] Random idx 6
# [LOAD] Random idx 7
# [LOAD] Random idx 8
# [LOAD] Random idx 9

# %%
key_req = [k * 1e-3 for k in key_req]

# %%
key_srv_ppo_qkp = [k * 1e-6 for k in key_srv_ppo_qkp]

# %% [markdown]
# ## Plot

# %%
# key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]

# a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
# a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]

# %%
#key_srv_ppo_qkp_old = [k for k in key_srv_ppo_qkp]
# key_srv_ppo_qkp = [k + 0.1*(key_srv_rlx_qkp[idx_k] - key_srv_ppo_qkp_old[idx_k]) for idx_k, k in enumerate(key_srv_ppo_qkp)]

# %%
# key_srv_ppo_qkp[-1] = key_srv_ppo_qkp[-2]
# key_srv_opt_qkp[-1] = key_srv_opt_qkp[-2]

# %%
# a_lst_opt_qkp[-1] = a_lst_opt_qkp[-2]

# %%
step = 6  # tunable (keep every `step`-th value)

# yerr1
yerr1 = [
    np.array(key_srv_rnd_qkp_avg) - np.array(key_srv_rnd_qkp_min),
    np.array(key_srv_rnd_qkp_max) - np.array(key_srv_rnd_qkp_avg)
]

yerr1[0][np.arange(len(yerr1[0])) % step != 0] = 0
yerr1[1][np.arange(len(yerr1[1])) % step != 0] = 0


# yerr2
yerr2 = [
    np.array(a_lst_rnd_qkp_avg) - np.array(a_lst_rnd_qkp_min),
    np.array(a_lst_rnd_qkp_max) - np.array(a_lst_rnd_qkp_avg)
]

yerr2[0][np.arange(len(yerr2[0])) % step != 0] = 0
yerr2[1][np.arange(len(yerr2[1])) % step != 0] = 0

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, key_srv_rnd_qkp_avg, yerr=yerr1, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, key_srv_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, key_srv_opt_qkp, label="Optimal", linestyle="-", marker="v", markevery=5)
plt.plot(demand_list, key_req, linestyle="--")

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Total Served Secret Key (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_k_srv.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

############################

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, a_lst_rnd_qkp_avg, yerr=yerr2, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, a_lst_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, a_lst_opt_qkp, label="Optimal-QKP", linestyle="-", marker="v", markevery=5)

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Final QKP Stored Keys (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_a_lst.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %% [markdown]
# #####
