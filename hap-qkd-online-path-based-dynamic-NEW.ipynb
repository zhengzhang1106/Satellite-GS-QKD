# %%
from libraries import *
# Out:
# /opt/miniconda3/envs/py310/bin/python

# %%
gp.setParam("OutputFlag", 0) # Disables Gurobi logs (Affects all models created afterward)
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2769212
# Academic license - for non-commercial use only - expires 2027-01-22

# %%
prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)
#gnodes, hnodes, links, demands = init_setup_training_online()

nodes = gnodes + hnodes

n_hnodes  = len(hnodes)
n_demands = len(demands)
n_links   = len(links)

MAX_LINKS   = len(links)
MAX_HAPS    = len(hnodes)
MAX_DEMANDS = len(demands)   # maximum possible demands

demands_all = demands.copy()
links_all   = links.copy()
hnodes_all  = hnodes.copy()
gnodes_all  = gnodes.copy()
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.

# %%
def generate_hap_masks(hnodes, links, max_haps_to_remove=1):
    """
    Randomly deactivate up to max_haps_to_remove HAPs.
    Returns:
        hnodes_active: list[int]
        links_active: list[int]
    """
    import random
    
    n_haps = len(hnodes)
    hnodes_active = [1] * n_haps
    
    # number of HAPs to deactivate
    k = random.randint(0, max_haps_to_remove)
    
    if k > 0:
        removed_indices = random.sample(range(n_haps), k)
        for idx in removed_indices:
            hnodes_active[idx] = 0
    
    # build link mask
    links_active = []
    for l in links:
        active = 1
        
        if isinstance(l.n1, hap):
            if hnodes_active[hnodes.index(l.n1)] == 0:
                active = 0
        
        if isinstance(l.n2, hap):
            if hnodes_active[hnodes.index(l.n2)] == 0:
                active = 0
        
        links_active.append(active)
    
    return hnodes_active, links_active

# %%
# Initialize state and action
state  = [{} for _ in syst.T]
action = [{} for _ in syst.T]
reward = [0  for _ in syst.T]

state[0]["demands"] = demands
state[0]["a"] = {i: 0 for i in range(len(links))}

# ---------- Hyperparams ----------
GAMMA = 0.99
GAE_LAMBDA = 0.95
CLIP = 0.1
LR = 3e-4
EPOCHS = 10
BATCH_SIZE = 128
ENTROPY_COEF_INITIAL = 0.01         # >>> CHANGE - will decay over training
ENTROPY_COEF_MIN = 0.001            # >>> CHANGE
ENTROPY_DECAY = 0.999 #0.995               # >>> CHANGE
VALUE_COEF = 0.5

# Training hyperparams
num_episodes = 2000
episode_len = len(syst.T)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

entropy_coef = ENTROPY_COEF_INITIAL  # >>> CHANGE

# %%
def build_state_vector_for_time(state_t, links, t, gnodes, hnodes, demand_active, link_active, max_links=MAX_LINKS, normalize=True):
    link_features = []
    total_nodes = len(gnodes) + len(hnodes)
    
    # Pre-calculate coordinate bounds for normalization (Example ranges)
    # Better yet, use the service area limits (e.g., 270-285 lon, 40-55 lat)
    LON_MIN, LON_MAX = 276.0, 285.0
    LAT_MIN, LAT_MAX = 46.0, 50.0
    ALT_MAX = 25.0

    def norm_lon(l): return (l - LON_MIN) / (LON_MAX - LON_MIN)
    def norm_lat(l): return (l - LAT_MIN) / (LAT_MAX - LAT_MIN)
    def norm_alt(a): return a / ALT_MAX

    # 1. Process Links with Geometric Context
    for idx_l in range(max_links):
        if idx_l < len(links):
            l = links[idx_l]
            is_link_on = float(link_active[idx_l]) # 1.0 if active, 0.0 if masked
            
            # Key Buffer (QKP) - Log Scaled
            qkp_val = is_link_on * np.log10(1 + state_t.get("a", {}).get(idx_l, 0.0)) / 8.0
            
            # Current Capacity (K_MAX) - Normalized by a realistic max (e.g., 100Mbps)
            kmax_val = is_link_on * np.log10(1 + l.K_MAX[t]) / 6.0
            
            # GEOMETRIC ENCODING: Position of Node 1 and Node 2
            # This is much more powerful than normalized IDs
            n1_coords = [norm_lon(l.n1.lg[t] if isinstance(l.n1, hap) else l.n1.lg) * is_link_on,
                         norm_lat(l.n1.la[t] if isinstance(l.n1, hap) else l.n1.la) * is_link_on]
            
            n2_coords = [norm_lon(l.n2.lg[t] if isinstance(l.n2, hap) else l.n2.lg) * is_link_on,
                         norm_lat(l.n2.la[t] if isinstance(l.n2, hap) else l.n2.la) * is_link_on]
            
            # Add features: [QKP, Capacity, Src_Lon, Src_Lat, Dst_Lon, Dst_Lat, Active]
            link_features.extend([qkp_val, kmax_val] + n1_coords + n2_coords + [is_link_on])
        else:
            # Padding (7 features per link now)
            link_features.extend([0.0] * 7)

    # 2. Process Demands with Geometric Pairs
    d_vec = []
    demands_list = state_t.get("demands", [])
    
    # Instead of iterating all pairs (which is O(N^2)), 
    # you might want to only encode the 'Active' demands to save space, 
    # but for a fixed-size MLP input, the GS-to-GS grid is fine.
    for idx_src, src in enumerate(gnodes):
        for idx_dst, dst in enumerate(gnodes):
            if idx_src >= idx_dst: continue
            
            matched = next((d for d in demands_list if d.n1 == src and d.n2 == dst and demand_active[demands_list.index(d)]), None)
            
            # Geometric info for the demand pair
            src_pos = [norm_lon(src.lg), norm_lat(src.la)]
            dst_pos = [norm_lon(dst.lg), norm_lat(dst.la)]
            
            if matched:
                kreq = np.log10(1 + float(matched.K_REQ[t])) / 5.0
                d_vec.extend(src_pos + dst_pos + [kreq, 1.0])
            else:
                d_vec.extend(src_pos + dst_pos + [0.0, 0.0])

    return np.concatenate([link_features, d_vec]).astype(np.float32)

# %%
def scarq_policy(state, links, t, demand_active, link_active):
    """
    Adapted Heuristic: Scarcity & Contention Aware (1-hop only)
    Converts the offline logic into an online action selection for time t.
    """
    n_links = len(links)
    n_hnodes = len(hnodes)
    all_demands = state[t]["demands"] # This is the k-sampled demands
    
    # 1. Filter demands based on the active mask
    # Assuming demand_active matches the indexing of state[t]["demands"]
    active_indices = [i for i, val in enumerate(demand_active[:len(all_demands)]) if val == 1]
    demands = [all_demands[i] for i in active_indices]

    action_matrix = np.zeros((len(all_demands), n_links), dtype=int)
    max_cnct_up = [1] * n_hnodes
    max_cnct_dwn = [1] * n_hnodes
    
    qkp_s = [state[t]["a"].get(i, 0.0) for i in range(n_links)]

    # # Step 1: Enumerate feasible paths ONLY for active demands
    # feasible_paths = {d: [] for d in demands}
    # link_usage = [0] * n_links
    
    # for d in demands:
    #     src, dst = d.n1, d.n2
    #     for idx_l1, l1 in enumerate(links):
    #         if l1.n1 != src: continue
    #         for idx_l2, l2 in enumerate(links):
    #             if l2.n2 != dst: continue
    #             if l1.n2 == l2.n1 and l1.n2 in hnodes:
    #                 mid = l1.n2
    #                 # Capacity checks...
    #                 if (l1.K_MAX[t] >= d.K_REQ[t] and l2.K_MAX[t] >= d.K_REQ[t]) or \
    #                    (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
    #                     feasible_paths[d].append((idx_l1, idx_l2, mid))
    #                     link_usage[idx_l1] += 1
    #                     link_usage[idx_l2] += 1

    # Step 1: Enumerate feasible paths ONLY for active demands AND active links
    feasible_paths = {d: [] for d in demands}
    link_usage = [0] * n_links
    
    for d in demands:
        src, dst = d.n1, d.n2
        for idx_l1, l1 in enumerate(links):
            # NEW: Check if the uplink is active
            if l1.n1 != src or not link_active[idx_l1]: continue
            
            for idx_l2, l2 in enumerate(links):
                # NEW: Check if the downlink is active
                if l2.n2 != dst or not link_active[idx_l2]: continue
                
                if l1.n2 == l2.n1 and l1.n2 in hnodes:
                    mid = l1.n2
                    # Capacity checks...
                    if (l1.K_MAX[t] >= d.K_REQ[t] and l2.K_MAX[t] >= d.K_REQ[t]) or \
                       (qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]):
                        feasible_paths[d].append((idx_l1, idx_l2, mid))
                        link_usage[idx_l1] += 1
                        link_usage[idx_l2] += 1

    # Step 2: Order only active demands
    ordered_demands = sorted(demands, key=lambda d: (len(feasible_paths[d]), -d.K_REQ[t]))

    # Step 3: Greedy Allocation
    for d in ordered_demands:
        paths = sorted(feasible_paths[d], key=lambda p: link_usage[p[0]] + link_usage[p[1]])
        for idx_l1, idx_l2, mid in paths:
            mid_idx = hnodes.index(mid)
            if max_cnct_up[mid_idx] == 0 or max_cnct_dwn[mid_idx] == 0:
                continue
            
            # Use original list index for the action matrix row
            orig_idx = all_demands.index(d)
            action_matrix[orig_idx][idx_l1] = 1
            action_matrix[orig_idx][idx_l2] = 1
            max_cnct_up[mid_idx], max_cnct_dwn[mid_idx] = 0, 0
            break

    # --------------------------------------------------
    # Step 4: Solve optimization with heuristic action
    # --------------------------------------------------
    solution_heur, _, A_next_heur = online_new(
        gnodes,
        hnodes,
        links,
        state,
        action_matrix,
        t,
        f_qkp,
        0,
        demand_active,
        link_active
    )

    # --------------------------------------------------
    # Step 5: Compute total served keys
    # --------------------------------------------------
    if "r_h" not in solution_heur:
        return 0.0, solution_heur, A_next_heur

    k_srv_heur = sum(
        solution_heur["r_h"][idx_d] * syst.THETA
        for idx_d, _ in enumerate(demands)
    )


    return k_srv_heur, solution_heur, A_next_heur

def mcr_policy(state, links, t, demand_active, link_active, n_samples=3):
    """
    Online Monte Carlo 1-hop random heuristic.
    Samples multiple random feasible allocations and keeps the best one.
    """

    n_links = len(links)
    n_hnodes = len(hnodes)
    all_demands = state[t]["demands"]
    
    # Filter for active only
    active_indices = [i for i, val in enumerate(demand_active[:len(all_demands)]) if val == 1]
    active_demands = [all_demands[i] for i in active_indices]

    best_reward = -1
    best_solution, best_A_next = None, None

    for _ in range(n_samples):
        action_matrix = np.zeros((len(all_demands), n_links), dtype=int)
        max_cnct_up, max_cnct_dwn = [1] * n_hnodes, [1] * n_hnodes

        shuffled_active = random.sample(active_demands, len(active_demands))

        # for d in shuffled_active:
        #     src, dst = d.n1, d.n2
        #     feasible_pairs = []
        #     for idx_l1, l1 in enumerate(links):
        #         if l1.n1 != src: continue
        #         for idx_l2, l2 in enumerate(links):
        #             if l2.n2 != dst or l1.n2 != l2.n1 or l1.n2 not in hnodes: continue
                    
        #             mid_idx = hnodes.index(l1.n2)
        #             if max_cnct_up[mid_idx] > 0 and max_cnct_dwn[mid_idx] > 0:
        #                 feasible_pairs.append((idx_l1, idx_l2, mid_idx))

        for d in shuffled_active:
            src, dst = d.n1, d.n2
            feasible_pairs = []
            for idx_l1, l1 in enumerate(links):
                # NEW: Check if uplink is active
                if l1.n1 != src or not link_active[idx_l1]: continue
                
                for idx_l2, l2 in enumerate(links):
                    # NEW: Check if downlink is active
                    if l2.n2 != dst or l1.n2 != l2.n1 or l1.n2 not in hnodes or not link_active[idx_l2]: 
                        continue
                    
                    mid_idx = hnodes.index(l1.n2)
                    if max_cnct_up[mid_idx] > 0 and max_cnct_dwn[mid_idx] > 0:
                        feasible_pairs.append((idx_l1, idx_l2, mid_idx))

            if feasible_pairs:
                idx_l1, idx_l2, mid_idx = random.choice(feasible_pairs)
                orig_idx = all_demands.index(d)
                action_matrix[orig_idx][idx_l1] = 1
                action_matrix[orig_idx][idx_l2] = 1
                max_cnct_up[mid_idx], max_cnct_dwn[mid_idx] = 0, 0

        # --------------------------------------------------------
        # Evaluate via online_new
        # --------------------------------------------------------
        solution, reward, A_next = online_new(
            gnodes,
            hnodes,
            links,
            state,
            action_matrix,
            t,
            f_qkp,
            0,
            demand_active,
            link_active
        )

        if "r_h" in solution:
            total_served = sum(solution["r_h"][i] * syst.THETA for i in range(n_demands))
        else:
            total_served = 0.0

        # Keep best sample
        if total_served > best_reward:
            best_reward = total_served
            best_solution = solution
            best_A_next = A_next

    return best_reward, best_solution, best_A_next

# %%
class ResidualBlock(nn.Module):
    def __init__(self, size):
        super().__init__()
        self.ln = nn.LayerNorm(size)
        self.fc = nn.Linear(size, size)

    def forward(self, x):
        # Residual connection helps gradients flow back to early layers
        return x + F.silu(self.fc(self.ln(x)))

class ResidualBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, dim),
            nn.SiLU(),
            nn.Linear(dim, dim)
        )
        self.silu = nn.SiLU()

    def forward(self, x):
        return self.silu(x + self.net(x))

class ActorCriticCategorical(nn.Module):
    def __init__(self, state_dim, n_demands_max, n_haps, hidden=64):
        super().__init__()
        self.n_haps = n_haps
        self.n_choices = n_demands_max + 1 # Demands + Idle
        
        self.encoder = nn.Sequential(
            nn.Linear(state_dim, hidden),
            nn.LayerNorm(hidden),
            nn.SiLU(),
        )
        
        # (One set of choices for RX/Uplink, one for TX/Downlink)
        self.actor_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 2 * n_haps * self.n_choices) 
        )
        
        self.critic_head = nn.Sequential(
            ResidualBlock(hidden),
            nn.Linear(hidden, 1)
        )
        
        self.apply(self._init_weights)

    def _init_weights(self, m):
        if isinstance(m, nn.Linear):
            # Orthogonal init helps prevents early policy collapse
            nn.init.orthogonal_(m.weight, gain=0.01) 
            nn.init.constant_(m.bias, 0)

    # def forward(self, x):
    #     features = self.encoder(x)
        
    #     # index 0: RX (Uplink), index 1: TX (Downlink)
    #     logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
    #     probs = torch.softmax(logits, dim=-1) 
        
    #     value = self.critic_head(features)
    #     return probs, value
    # def forward(self, x, action_mask=None):
    #     features = self.encoder(x)
        
    #     # [Batch, 2 * n_haps * n_choices] -> [Batch, 2, n_haps, n_choices]
    #     logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        
    #     if action_mask is not None:
    #         # action_mask shape: [Batch, n_choices] 
    #         # We broadcast it to [Batch, 2, n_haps, n_choices]
    #         mask = action_mask.view(-1, 1, 1, self.n_choices)
    #         # Use a very large negative number to mask logits before softmax
    #         logits = logits.masked_fill(mask == 0, -1e9)

    #     probs = torch.softmax(logits, dim=-1) 
    #     value = self.critic_head(features)
    #     return probs, value
    def forward(self, x, action_mask=None):
        features = self.encoder(x)
        
        # [Batch, 2, n_haps, n_choices]
        logits = self.actor_head(features).view(-1, 2, self.n_haps, self.n_choices)
        
        if action_mask is not None:
            # NEW: Ensure the mask has a batch dimension if it doesn't already
            # Expected action_mask shape from select_action: [Batch, 2, n_haps, n_choices]
            if action_mask.dim() == 3:
                mask = action_mask.unsqueeze(0) # Add batch dim if missing
            else:
                mask = action_mask
                
            # No more .view(-1, 1, 1, n_choices)! 
            # We want the specific mask for each HAP and each Head.
            logits = logits.masked_fill(mask == 0, -1e9)
    
        probs = torch.softmax(logits, dim=-1) 
        value = self.critic_head(features)
        return probs, value

class PPOBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.state_values = []
        self.rewards = []
        self.is_terminals = []
    
    def clear(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.state_values[:]
        del self.rewards[:]
        del self.is_terminals[:]

class PPOAgent:
    def __init__(self, state_dim, n_demands, n_hnodes, lr=LR):
        self.gamma = GAMMA
        self.lam = GAE_LAMBDA
        self.eps_clip = CLIP
        self.K_epochs = EPOCHS
        self.n_haps = n_hnodes
        self.n_choices = n_demands + 1 # Demands + Idle
        
        self.model = ActorCriticCategorical(state_dim, n_demands, n_hnodes).to(device=DEVICE)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        self.MseLoss = nn.MSELoss()

    # def select_action(self, state_vec):
    #     s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
    #     with torch.no_grad():
    #         probs, value = self.model(s) # [1, 2, n_haps, n_choices]
        
    #     dist = Categorical(probs)
    #     action = dist.sample() # [1, 2, n_haps]
        
    #     # Sum log_prob across BOTH heads and ALL HAPs
    #     logp = dist.log_prob(action).sum(dim=[1, 2])
        
    #     return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0)
    # def select_action(self, state_vec, demand_active_vec):
    #     """
    #     demand_active_vec: np.array of size MAX_DEMANDS (1 for active, 0 for inactive)
    #     """
    #     s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        
    #     # Create mask: [Idle_slot (1)] + [Demands_active_mask]
    #     # Resulting size: n_choices (MAX_DEMANDS + 1)
    #     mask = np.concatenate([[1], demand_active_vec])
    #     mask_t = torch.tensor(mask, dtype=torch.bool, device=DEVICE).unsqueeze(0)

    #     with torch.no_grad():
    #         probs, value = self.model(s, action_mask=mask_t)
        
    #     dist = Categorical(probs)
    #     action = dist.sample() 
    #     logp = dist.log_prob(action).sum(dim=[1, 2])
        
    #     return action.squeeze(0).cpu().numpy(), logp.squeeze(0), value.squeeze(0), mask
    def select_action(self, state_vec, demand_active, link_active):
        # s: [Batch, state_dim]
        s = torch.tensor(state_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
        
        # 1. Start with an "All Active" mask [2, n_haps, n_choices]
        # Head 0: RX (Uplink), Head 1: TX (Downlink)
        full_mask = np.ones((2, self.n_haps, self.n_choices), dtype=bool)
        
        # 2. Apply Demand Mask: If demand 'd' is inactive, no HAP can select it (all heads)
        # n_choices is [Idle, D1, D2, ... Dn] -> index 0 is Idle (always 1)
        full_mask[:, :, 1:] = demand_active[None, None, :]
    
        # 3. Apply Link Mask: HAP-specific restrictions
        for h_idx, h_node in enumerate(hnodes):
            for d_idx, d in enumerate(state[t]["demands"]):
                # Check Uplink (GS_src -> HAP) for RX Head
                up_link_idx = [idx_l for idx_l, l in enumerate(links) if l.n2 == h_node and l.n1 == d.n1][0] #find_link_idx(d.n1, h_node, links)
                if up_link_idx is not None and not link_active[up_link_idx]:
                    full_mask[0, h_idx, d_idx + 1] = 0 # Mask this demand for this HAP's RX
                
                # Check Downlink (HAP -> GS_dst) for TX Head
                dn_link_idx = [idx_l for idx_l, l in enumerate(links) if l.n1 == h_node and l.n2 == d.n2][0] #find_link_idx(h_node, d.n2, links)
                if dn_link_idx is not None and not link_active[dn_link_idx]:
                    full_mask[1, h_idx, d_idx + 1] = 0 # Mask this demand for this HAP's TX
    
        mask_t = torch.tensor(full_mask, dtype=torch.bool, device=DEVICE).unsqueeze(0)
    
        with torch.no_grad():
            # The model's forward() now expects [Batch, 2, n_haps, n_choices]
            probs, value = self.model(s, action_mask=mask_t)
        
        # ... sampling logic ...
        dist = Categorical(probs)
        action = dist.sample() 
        logp = dist.log_prob(action).sum(dim=[1, 2])
        
        return action.squeeze(0).cpu().numpy(), logp, value.squeeze(0), full_mask

    # ... compute_gae remains exactly the same as your previous code ...

    def update(self, states, actions, old_logps, returns, advantages, entropy_coef, masks):
        #advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        if advantages.std() < 1e-5:
            advantages = advantages - advantages.mean()
        else:
            advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
            
        # for _ in range(self.K_epochs):
        #     probs, values = self.model(states.to(DEVICE))
        #     dist = Categorical(probs)
            
        #     # logp is summed across the choices of all HAPs
        #     #new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=-1)
        #     new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
        #     entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
        #     ratio = torch.exp(new_logps - old_logps)
        #     surr1 = ratio * advantages
        #     surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
        #     loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
        #     self.optimizer.zero_grad()
        #     loss.backward()
        #     self.optimizer.step()
        for _ in range(self.K_epochs):
            # Pass the saved masks into the model
            probs, values = self.model(states.to(DEVICE), action_mask=masks.to(DEVICE))
            dist = Categorical(probs)
            
            new_logps = dist.log_prob(actions.to(DEVICE)).sum(dim=[1, 2])
            entropy = dist.entropy().sum(dim=[1, 2]).mean()
            
            ratio = torch.exp(new_logps - old_logps)
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - self.eps_clip, 1 + self.eps_clip) * advantages
            
            loss = -torch.min(surr1, surr2).mean() + 0.5 * self.MseLoss(values.view(-1), returns) - entropy_coef * entropy
            
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

    def compute_gae(self, rewards, values, dones):
        """
        Generalized Advantage Estimation
        rewards: [T], values: [T+1], dones: [T]
        """
        T = len(rewards)
        adv = torch.zeros(T, device=DEVICE)
        lastgaelam = 0
        for t in reversed(range(T)):
            nonterminal = 1.0 - dones[t]
            # TD Error: delta = r_t + gamma * V(s_t+1) - V(s_t)
            delta = rewards[t] + self.gamma * values[t+1] * nonterminal - values[t]
            lastgaelam = delta + self.gamma * self.lam * nonterminal * lastgaelam
            adv[t] = lastgaelam
            
        returns = adv + values[:-1]
        return adv, returns

# %%
def get_z_from_demand_choices(hap_picks, demands, links, hnodes):
    # Initialize z_dict with zeros
    z = {idx_d: {idx_l: 0 for idx_l in range(len(links))} for idx_d in range(len(demands))}
    
    rx_picks = hap_picks[0] # Uplink choices [n_haps]
    tx_picks = hap_picks[1] # Downlink choices [n_haps]

    # Run this once after initializing your 'links' and 'hnodes'
    UPLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n2 in hnodes}
    DOWNLINK_LOOKUP = {(l.n1, l.n2): i for i, l in enumerate(links) if l.n1 in hnodes}

    for hap_idx, selected_hap in enumerate(hnodes):
        
        # --- Handle Uplink (RX: GS -> HAP) ---
        rx_val = rx_picks[hap_idx]
        if rx_val > 0:
            d_idx = int(rx_val - 1)
            if d_idx < len(demands):
                src_gs = demands[d_idx].n1
                # Use the pre-computed lookup
                l_idx = UPLINK_LOOKUP.get((src_gs, selected_hap))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1

        # --- Handle Downlink (TX: HAP -> GS) ---
        tx_val = tx_picks[hap_idx]
        if tx_val > 0:
            d_idx = int(tx_val - 1)
            if d_idx < len(demands):
                dst_gs = demands[d_idx].n2
                # Use the pre-computed lookup
                l_idx = DOWNLINK_LOOKUP.get((selected_hap, dst_gs))
                if l_idx is not None:
                    z[d_idx][l_idx] = 1
                        
    return z

# %% [markdown]
# ## Training Loop

# %%
f_qkp = 1

# prepare agent
n_links = len(links)
n_demands = len(demands)   # assume constant across T

demand_active = np.ones(MAX_DEMANDS)
link_active   = np.ones(MAX_LINKS)

# choose state_dim produced by build_state_vector_for_time
state_vector_example = build_state_vector_for_time(
    state[0], links, 0, gnodes, hnodes,
    demand_active, link_active
)#build_state_vector_for_time(state[0], links, 0, gnodes, hnodes, demand_active)
state_dim = len(state_vector_example)

agent = PPOAgent(state_dim, n_demands, n_hnodes, lr=LR)

# Track total rewards per episode
episode_rewards = []

if f_qkp:
    solution = {"a": state[0]["a"].copy()}
else:
    solution = {}

#WARM_EPISODES  = 500
DECAY_EPISODES = 300

for ep in range(num_episodes):
    # reset state & action containers
    state = [{} for _ in syst.T]
    action = [{} for _ in syst.T]

    if f_qkp:
        state[0]["a"] = {i: 0 for i in range(n_links)}

    # rollout buffers
    states_buf  = []
    actions_buf = []
    logps_buf   = []
    rewards_buf = []
    dones_buf   = []
    values_buf  = []
    masks_buf   = [] # New buffer

    total_reward = 0.0

    # Calculate a 'progress' factor from 0.0 to 1.0
    progress = ep * 4 / num_episodes
    
    # Start with a max of 50 kbps, end with 1000 kbps
    max_now = min(1 + (9 * progress), 10) #in(10 + (990 * progress), 1000)
    
    # Still use randomness, but within an ever-expanding "boundary"
    mean_kbps_rand = random.uniform(1, max_now)

    #mean_kbps_rand = random.randint(1, 1 + int(10 * ep/num_episodes))
    #mean_kbps_rand = random.randint(1, 1000)
    k_req_vals = [mean_kbps_rand] * len(syst.T) # 25600 bits/sec
    demands_space = []
    demands_space = generate_demands(gnodes, syst, mean_kbps=0.01 + 0.2*mean_kbps_rand, amp=0.5, noise_std=0.0, pattern="stadium")

    MIN_DEMANDS = 1
    MAX_DEMANDS = len(demands_space)

    # # Before the for t in syst.T: loop
    # if ep < num_episodes / 10:
    #     k = 1  # Only 1 demand: let the agent learn basic RX/TX pairing first
    # elif ep < 2 * num_episodes / 10:
    #     k = random.randint(1, 2) # Slightly more complex
    # else:
    #     k = random.randint(MIN_DEMANDS, MAX_DEMANDS) # Full complexity

    #k = MAX_DEMANDS

    demands = demands_space.copy() #random.sample(demands_space, k)
    random.shuffle(demands)

    state[0]["demands"] = demands.copy()

    k_srv = 0
    k_req = 0

    k_heur_sum = 0
    
    demand_active = np.ones(MAX_DEMANDS)
    link_active   = np.ones(MAX_LINKS)
    for t in syst.T:
        #if k == MAX_DEMANDS:
        # demand_active = np.ones(MAX_DEMANDS)
        # d_inactive = random.randint(0, MAX_DEMANDS-1)
        # demand_active[d_inactive] = 0

        # link_active = np.ones(MAX_LINKS)
        # l_inactive = random.randint(0, MAX_LINKS-1)
        # link_active[l_inactive] = 0
        
        # >>> NEW — build action mask before selecting action
        s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes, demand_active, link_active)
        
        # # Inside the for t in syst.T: loop
        # hap_choices, logp, value = agent.select_action(s_vec) 
        # demand_active is your np.ones(MAX_DEMANDS) modified by your logic
        hap_choices, logp, value, current_mask = agent.select_action(s_vec, demand_active, link_active)
        
        # 2. Convert to the dictionary format for Gurobi
        z_dict = get_z_from_demand_choices(hap_choices, demands, links, hnodes)

        #print(z_dict)

        # call your environment / model
        # Maximum Tx/Rx Connection
        check_tx, check_rx = 1, 1
        sum_tx, sum_rx = {}, {}

        nodes = gnodes + hnodes

        k_srv_heur1, k_srv_heur2 = -math.inf, -math.inf
        k_srv_heur1, _, _ = scarq_policy(state, links, t, demand_active, link_active)
        k_srv_heur2, _, _ = mcr_policy(state, links, t, demand_active, link_active)
        
        k_srv_heur = max(k_srv_heur1, k_srv_heur2)

        k_heur_sum += k_srv_heur

        solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, k_srv_heur, demand_active, link_active)

        reward[t] = reward_t
        total_reward += reward_t

        k_srv += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]))
        k_req += sum(d.K_REQ[t] * syst.THETA for idx_d, d in enumerate(state[t]["demands"]) if demand_active[idx_d] == 1)

        # store rollout data
        states_buf.append(torch.tensor(s_vec, dtype=torch.float32))
        # Ensure hap_choices is converted to a tensor for the buffer
        # Shape: [2, n_haps]
        actions_buf.append(torch.tensor(hap_choices, dtype=torch.long, device=DEVICE))
        logps_buf.append(logp)
        values_buf.append(value)
        rewards_buf.append(torch.tensor(float(reward_t), dtype=torch.float32))
        dones_buf.append(torch.tensor(0.0))
        masks_buf.append(torch.tensor(current_mask, dtype=torch.bool))

        # step to next state
        if t + 1 < episode_len:
            if f_qkp:
                if check_tx and check_rx:
                    state[t+1]["a"] = A_next
                else:
                    state[t+1]["a"] = state[t]["a"]
            state[t+1]["demands"] = state[t]["demands"]

    # bootstrap final value
    #final_s_vec = build_state_vector_for_time(state[-1], links, t, gnodes, hnodes, demand_active)
    final_s_vec = build_state_vector_for_time(
        state[-1], links, t, gnodes, hnodes, 
        demand_active, link_active
    )
    with torch.no_grad():
        _, final_value = agent.model(torch.tensor(final_s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0))
    values_tensor = torch.stack(values_buf).to(DEVICE)
    values_tensor = torch.cat([values_tensor.view(-1), final_value.view(-1)])  # Now shape is [T+1]

    rewards_tensor = torch.stack(rewards_buf).to(DEVICE)
    dones_tensor = torch.stack(dones_buf).to(DEVICE)

    advantages, returns = agent.compute_gae(rewards_tensor, values_tensor, dones_tensor)

    # prepare PPO update batches
    states_b = torch.stack(states_buf)
    actions_b = torch.stack(actions_buf)
    old_logps_b = torch.stack(logps_buf).to(DEVICE)
    returns_b = returns.detach()
    adv_b = advantages.detach()
    masks_b = torch.stack(masks_buf)

    # >>> adaptive entropy scheduling (slower exploration over time)
    entropy_coef = max(entropy_coef * ENTROPY_DECAY, ENTROPY_COEF_MIN)

    #agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef)  # >>> CHANGE
    agent.update(states_b, actions_b, old_logps_b, returns_b, adv_b, entropy_coef, masks_b)

    # store total reward for this episode
    episode_rewards.append(total_reward)

    # print progress
    print(f"Episode {ep+1}/{num_episodes}, total reward: {total_reward:.3f}, entropy_coef: {entropy_coef:.4f}, demands: {len(demands)}, mean_kbps_rand: {mean_kbps_rand}, ratio_heur={k_heur_sum/k_req*1e2} ratio={k_srv/k_req*1e2}, k_srv_heur={int(k_heur_sum)}, k_srv={int(k_srv)}, k_req={int(k_req)}")

# === Plot learning curve ===
plt.figure(figsize=(6,3))
plt.plot(range(1, num_episodes+1), episode_rewards, marker='o', markevery=num_episodes/10, linewidth=1.5)
plt.xlabel("Episode")
plt.ylabel("Total Reward over syst.T")
plt.title("Learning Progress of PPO Agent")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Episode 1/2000, total reward: 250.658, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0, ratio_heur=99.58650314392978 ratio=95.83561046482389, k_srv_heur=22665193, k_srv=21811516, k_req=22759302
# Episode 2/2000, total reward: 263.435, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0080582232785726, ratio_heur=99.22423793753423 ratio=96.83783367542532, k_srv_heur=22756055, k_srv=22208758, k_req=22933968
# Episode 3/2000, total reward: 256.448, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0184629561045062, ratio_heur=99.28130612645877 ratio=95.16228652373762, k_srv_heur=22993050, k_srv=22039106, k_req=23159496
# Episode 4/2000, total reward: 244.856, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0225541187313525, ratio_heur=99.28124772440032 ratio=95.87586810139227, k_srv_heur=23081077, k_srv=22289389, k_req=23248174
# Episode 5/2000, total reward: 257.047, entropy_coef: 0.0100, demands: 3, mean_kbps_rand: 1.0387886578961567, ratio_heur=99.57332341856001 ratio=96.50672700839178, k_srv_heur=23499370, k_srv=22775652, k_req=23600066
# Episode 6/2000, total reward: 263.036, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0775328634939214, ratio_heur=99.56114578425351 ratio=96.47526329717684, k_srv_heur=24332612, k_srv=23578426, k_req=24439867
# Episode 7/2000, total reward: 262.985, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0598697849655871, ratio_heur=99.63016655342662 ratio=96.45515868855729, k_srv_heur=23968040, k_srv=23204228, k_req=24057011
# Episode 8/2000, total reward: 269.291, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0562321499974288, ratio_heur=99.28129599219663 ratio=98.03699386509646, k_srv_heur=23805831, k_srv=23507470, k_req=23978163
# Episode 9/2000, total reward: 262.534, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.1251196222816175, ratio_heur=99.61080402837293 ratio=97.03929931887832, k_srv_heur=25372202, k_srv=24717205, k_req=25471335
# Episode 10/2000, total reward: 263.004, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.1199811190299158, ratio_heur=99.61227908928446 ratio=96.47013089964105, k_srv_heur=25261630, k_srv=24464782, k_req=25359956
# Episode 11/2000, total reward: 268.743, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.172922550100265, ratio_heur=99.17467848536134 ratio=97.3296904807335, k_srv_heur=26288717, k_srv=25799657, k_req=26507489
# Episode 12/2000, total reward: 257.209, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.127354524030246, ratio_heur=99.28125832375093 ratio=96.49854137949919, k_srv_heur=25336357, k_srv=24626213, k_req=25519778
# Episode 13/2000, total reward: 236.913, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.193415891067395, ratio_heur=99.59272482564849 ratio=92.7586110070351, k_srv_heur=26841925, k_srv=25000016, k_req=26951693
# Episode 14/2000, total reward: 224.419, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0586496087396084, ratio_heur=99.23278988450835 ratio=92.2226246291617, k_srv_heur=23846198, k_srv=22161616, k_req=24030563
# Episode 15/2000, total reward: 263.195, entropy_coef: 0.0099, demands: 3, mean_kbps_rand: 1.0037882242140013, ratio_heur=99.28129426887483 ratio=96.47400396113936, k_srv_heur=22677251, k_srv=22036026, k_req=22841413
# Episode 16/2000, total reward: 257.153, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.2448602387325407, ratio_heur=99.1573423285882 ratio=96.27575457027328, k_srv_heur=27830269, k_srv=27021500, k_req=28066776
# Episode 17/2000, total reward: 256.955, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.0719537373263717, ratio_heur=99.28129550142648 ratio=96.0525228357816, k_srv_heur=24144155, k_srv=23358952, k_req=24318937
# Episode 18/2000, total reward: 263.475, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.0444278065822357, ratio_heur=99.28122617155233 ratio=96.96426179605268, k_srv_heur=23551788, k_srv=23002151, k_req=23722298
# Episode 19/2000, total reward: 250.704, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.0538089375740682, ratio_heur=98.60700056434099 ratio=96.33347133900207, k_srv_heur=23592355, k_srv=23048398, k_req=23925639
# Episode 20/2000, total reward: 257.495, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.0185336923162547, ratio_heur=99.28131637965073 ratio=97.00063280803339, k_srv_heur=22994575, k_srv=22466345, k_req=23161029
# Episode 21/2000, total reward: 268.834, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.3173075256345557, ratio_heur=99.28129668289498 ratio=97.2349635338982, k_srv_heur=29424106, k_srv=28817632, k_req=29637109
# Episode 22/2000, total reward: 232.676, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.3487996101156248, ratio_heur=99.25905844696173 ratio=95.53643731176568, k_srv_heur=30095065, k_srv=28966377, k_req=30319717
# Episode 23/2000, total reward: 256.543, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.3369758547132897, ratio_heur=98.56224705054584 ratio=96.00352114102155, k_srv_heur=29631193, k_srv=28861952, k_req=30063431
# Episode 24/2000, total reward: 224.565, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.1422755209454256, ratio_heur=99.6406314132596 ratio=93.52340883665809, k_srv_heur=25750326, k_srv=24169440, k_req=25843198
# Episode 25/2000, total reward: 257.183, entropy_coef: 0.0098, demands: 3, mean_kbps_rand: 1.2583696250202638, ratio_heur=99.57721512211873 ratio=96.74858563328443, k_srv_heur=28239699, k_srv=27437511, k_req=28359599
# Episode 26/2000, total reward: 223.862, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2449409375190243, ratio_heur=99.580312710904 ratio=90.88609978953096, k_srv_heur=27950725, k_srv=25510388, k_req=28068525
# Episode 27/2000, total reward: 225.916, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.242987035950568, ratio_heur=99.2813296914161 ratio=95.59300319944458, k_srv_heur=27824758, k_srv=26791061, k_req=28026173
# Episode 28/2000, total reward: 262.651, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2169519555726267, ratio_heur=99.58691736992972 ratio=95.8246529829359, k_srv_heur=27348409, k_srv=26315222, k_req=27461849
# Episode 29/2000, total reward: 228.769, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.4631702658731625, ratio_heur=99.53710235113871 ratio=90.27873807116471, k_srv_heur=32646936, k_srv=29610307, k_req=32798761
# Episode 30/2000, total reward: 269.313, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2731022081506165, ratio_heur=99.15649595697424 ratio=97.95116045305132, k_srv_heur=28437028, k_srv=28091350, k_req=28678936
# Episode 31/2000, total reward: 224.228, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2595262092706716, ratio_heur=99.57695730153208 ratio=91.49844922338391, k_srv_heur=28264590, k_srv=25971532, k_req=28384669
# Episode 32/2000, total reward: 263.241, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.3525389019716643, ratio_heur=99.28122770220646 ratio=96.55417228112205, k_srv_heur=30182256, k_srv=29353210, k_req=30400768
# Episode 33/2000, total reward: 256.726, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.2612183762163445, ratio_heur=99.57657223080969 ratio=97.34092245551244, k_srv_heur=28301004, k_srv=27665602, k_req=28421347
# Episode 34/2000, total reward: 244.908, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.046954017712326, ratio_heur=99.2812952460076 ratio=95.96900618201182, k_srv_heur=23606168, k_srv=22818603, k_req=23777055
# Episode 35/2000, total reward: 243.375, entropy_coef: 0.0097, demands: 3, mean_kbps_rand: 1.092791459150888, ratio_heur=99.28126232990213 ratio=93.27247591798067, k_srv_heur=24592570, k_srv=23104157, k_req=24770605
# Episode 36/2000, total reward: 262.624, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.2450669343085328, ratio_heur=99.28127164846643 ratio=96.8648974802019, k_srv_heur=27869500, k_srv=27191194, k_req=28071256
# Episode 37/2000, total reward: 256.258, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.1318562909079406, ratio_heur=99.28126913815741 ratio=96.22240084522417, k_srv_heur=25433236, k_srv=24649635, k_req=25617356
# Episode 38/2000, total reward: 224.568, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.488836121336039, ratio_heur=99.41066009496392 ratio=91.73532359333095, k_srv_heur=33158507, k_srv=30598392, k_req=33355082
# Episode 39/2000, total reward: 155.439, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.3605112514592894, ratio_heur=99.49222366702098 ratio=84.38483541863293, k_srv_heur=30418327, k_srv=25799459, k_req=30573573
# Episode 40/2000, total reward: 263.162, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.6306295773983261, ratio_heur=99.28121519004488 ratio=96.40659850434965, k_srv_heur=36166687, k_srv=35119506, k_req=36428529
# Episode 41/2000, total reward: 256.979, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.0929501133318633, ratio_heur=99.64069658746108 ratio=96.45450472116059, k_srv_heur=24685030, k_srv=23895682, k_req=24774044
# Episode 42/2000, total reward: 243.415, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.250608426511683, ratio_heur=99.5790597167319 ratio=93.64285405284338, k_srv_heur=28072702, k_srv=26399205, k_req=28191371
# Episode 43/2000, total reward: 250.521, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.6860377920843108, ratio_heur=99.24480556545473 ratio=95.25297490778289, k_srv_heur=37345356, k_srv=35843248, k_req=37629532
# Episode 44/2000, total reward: 262.879, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.1526512289045798, ratio_heur=99.28124151443029 ratio=97.66833211777842, k_srv_heur=25880731, k_srv=25460276, k_req=26068097
# Episode 45/2000, total reward: 243.785, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.5213093352433913, ratio_heur=99.52508703406745 ratio=94.22491814618381, k_srv_heur=33897205, k_srv=32092023, k_req=34058956
# Episode 46/2000, total reward: 245.162, entropy_coef: 0.0096, demands: 3, mean_kbps_rand: 1.0742598149827036, ratio_heur=99.28127252820218 ratio=96.41541584924906, k_srv_heur=24193776, k_srv=23495398, k_req=24368922
# Episode 47/2000, total reward: 237.860, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.4398874991579589, ratio_heur=98.87491171088745 ratio=95.11007235892906, k_srv_heur=31930757, k_srv=30714937, k_req=32294095
# Episode 48/2000, total reward: 268.797, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.5997800043119943, ratio_heur=99.5160118878579 ratio=97.40549795538853, k_srv_heur=35586775, k_srv=34832059, k_req=35759849
# Episode 49/2000, total reward: 243.011, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.593765508840375, ratio_heur=99.51684936819841 ratio=93.91897509245297, k_srv_heur=35457337, k_srv=33462844, k_req=35629481
# Episode 50/2000, total reward: 257.443, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.5702596608532047, ratio_heur=99.28135708501713 ratio=96.90938935019886, k_srv_heur=34867593, k_srv=34034558, k_req=35119980
# Episode 51/2000, total reward: 249.306, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.795993575955861, ratio_heur=99.43533440954772 ratio=94.705418128712, k_srv_heur=39786942, k_srv=37894366, k_req=40012881
# Episode 52/2000, total reward: 212.241, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.2961446406724464, ratio_heur=99.50534071873697 ratio=92.04012973944494, k_srv_heur=29034059, k_srv=26855830, k_req=29178393
# Episode 53/2000, total reward: 257.036, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.0193838223334861, ratio_heur=99.28116373038671 ratio=96.19507759835565, k_srv_heur=23012834, k_srv=22297496, k_req=23179456
# Episode 54/2000, total reward: 256.658, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.4055739763709472, ratio_heur=99.6406832363389 ratio=95.89082912583066, k_srv_heur=31436965, k_srv=30253874, k_req=31550331
# Episode 55/2000, total reward: 237.811, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.784812450332676, ratio_heur=99.28124509952046 ratio=94.03862984438044, k_srv_heur=39484672, k_srv=37399656, k_req=39770524
# Episode 56/2000, total reward: 238.170, entropy_coef: 0.0095, demands: 3, mean_kbps_rand: 1.660657516014226, ratio_heur=99.44406680320522 ratio=94.81309882704898, k_srv_heur=36873264, k_srv=35156129, k_req=37079401
# Episode 57/2000, total reward: 256.613, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.3428589602662377, ratio_heur=99.11557579509818 ratio=95.28662115185892, k_srv_heur=29923934, k_srv=28767936, k_req=30190950
# Episode 58/2000, total reward: 226.226, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.543445057139377, ratio_heur=98.20207320883448 ratio=93.67436341974808, k_srv_heur=33917778, k_srv=32353963, k_req=34538759
# Episode 59/2000, total reward: 250.467, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.293077008325016, ratio_heur=99.50603058392828 ratio=95.42009328615639, k_srv_heur=28968096, k_srv=27778602, k_req=29111900
# Episode 60/2000, total reward: 243.718, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.6346548859778582, ratio_heur=99.2546991589343 ratio=93.85277876587791, k_srv_heur=36243628, k_srv=34271074, k_req=36515780
# Episode 61/2000, total reward: 238.522, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.165961732306662, ratio_heur=98.92187490564359 ratio=93.5182095687275, k_srv_heur=26072452, k_srv=24648229, k_req=26356610
# Episode 62/2000, total reward: 250.580, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.101881980221686, ratio_heur=99.55396318538054 ratio=95.66725502752308, k_srv_heur=24856282, k_srv=23885863, k_req=24967647
# Episode 63/2000, total reward: 226.043, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.970957025634947, ratio_heur=99.07172214159242 ratio=94.20214085734817, k_srv_heur=43398671, k_srv=41265536, k_req=43805306
# Episode 64/2000, total reward: 205.838, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.9071959313694884, ratio_heur=99.13941459037501 ratio=90.24764203320318, k_srv_heur=42058162, k_srv=38285983, k_req=42423251
# Episode 65/2000, total reward: 250.012, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 2.0365553083074577, ratio_heur=99.19054204653534 ratio=94.3030486800761, k_srv_heur=44861088, k_srv=42650612, k_req=45227183
# Episode 66/2000, total reward: 225.075, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.7546969400564603, ratio_heur=99.4322254146029 ratio=92.57552982638782, k_srv_heur=38895654, k_srv=36213469, k_req=39117755
# Episode 67/2000, total reward: 256.881, entropy_coef: 0.0094, demands: 3, mean_kbps_rand: 1.5524522004796393, ratio_heur=99.52291009109138 ratio=97.55879333434572, k_srv_heur=34568281, k_srv=33886065, k_req=34733994
# Episode 68/2000, total reward: 243.984, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.5150594692667125, ratio_heur=99.28006496887018 ratio=94.3461258467348, k_srv_heur=33679260, k_srv=32005495, k_req=33923487
# Episode 69/2000, total reward: 114.161, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 2.215301139587292, ratio_heur=99.3886171311627 ratio=75.2480535617258, k_srv_heur=48801394, k_srv=36947993, k_req=49101593
# Episode 70/2000, total reward: 269.511, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.2210355517743285, ratio_heur=99.2812326290128 ratio=98.42353579507417, k_srv_heur=27352340, k_srv=27116042, k_req=27550364
# Episode 71/2000, total reward: 244.332, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.2346221584914803, ratio_heur=99.58274213116478 ratio=96.6540121090693, k_srv_heur=27728676, k_srv=26913175, k_req=27844860
# Episode 72/2000, total reward: 238.466, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.4678240115692958, ratio_heur=99.472822457655 ratio=95.35196380866405, k_srv_heur=32726194, k_srv=31370446, k_req=32899633
# Episode 73/2000, total reward: 262.988, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.5093218311079744, ratio_heur=99.5296589403874 ratio=97.7537742818177, k_srv_heur=33640149, k_srv=33039916, k_req=33799120
# Episode 74/2000, total reward: 262.965, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.6065159833205649, ratio_heur=99.43047420533098 ratio=96.21944693254743, k_srv_heur=35701362, k_srv=34548415, k_req=35905855
# Episode 75/2000, total reward: 250.735, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.118719398824352, ratio_heur=99.28121176305852 ratio=97.06129343171051, k_srv_heur=25150519, k_srv=24588156, k_req=25332607
# Episode 76/2000, total reward: 137.416, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 2.2271822612159817, ratio_heur=94.8543407342695 ratio=80.40798278969676, k_srv_heur=46819270, k_srv=39688675, k_req=49359123
# Episode 77/2000, total reward: 249.186, entropy_coef: 0.0093, demands: 3, mean_kbps_rand: 1.6826022012565036, ratio_heur=99.50477492210108 ratio=94.56151985210897, k_srv_heur=37369081, k_srv=35512639, k_req=37555063
# Episode 78/2000, total reward: 250.737, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.6884735700449698, ratio_heur=98.92182857975041 ratio=95.30967922564027, k_srv_heur=37276048, k_srv=35914906, k_req=37682328
# Episode 79/2000, total reward: 244.633, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.8605185017237988, ratio_heur=98.93911559523205 ratio=95.14363449629354, k_srv_heur=40972165, k_srv=39400399, k_req=41411493
# Episode 80/2000, total reward: 263.984, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.3703482928465869, ratio_heur=98.92187737952301 ratio=97.49855422191803, k_srv_heur=30454876, k_srv=30016681, k_req=30786796
# Episode 81/2000, total reward: 268.661, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.348163389359623, ratio_heur=99.64061695012153 ratio=97.29169026807065, k_srv_heur=30197012, k_srv=29485148, k_req=30305926
# Episode 82/2000, total reward: 143.877, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 2.3939971584972453, ratio_heur=97.47489222429631 ratio=86.01853405696849, k_srv_heur=51637249, k_srv=45568252, k_req=52974923
# Episode 83/2000, total reward: 257.249, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.013800895868384, ratio_heur=99.2812972295657 ratio=96.56907777802041, k_srv_heur=22892722, k_srv=22267326, k_req=23058443
# Episode 84/2000, total reward: 185.909, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 2.4198443244516525, ratio_heur=98.90219460907885 ratio=86.55881094538438, k_srv_heur=52947462, k_srv=46339410, k_req=53535174
# Episode 85/2000, total reward: 249.899, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.4549623728493812, ratio_heur=99.23075490020601 ratio=95.54219752995878, k_srv_heur=32369916, k_srv=31166677, k_req=32620850
# Episode 86/2000, total reward: 244.884, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.5214967326918192, ratio_heur=98.92185027228642 ratio=94.1722000989553, k_srv_heur=33695767, k_srv=32077893, k_req=34063018
# Episode 87/2000, total reward: 263.097, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.0663495836505739, ratio_heur=99.28130271875435 ratio=96.30137312564365, k_srv_heur=24023557, k_srv=23302490, k_req=24197464
# Episode 88/2000, total reward: 155.531, entropy_coef: 0.0092, demands: 3, mean_kbps_rand: 1.8608149573019794, ratio_heur=97.93142986655764 ratio=83.32695979470306, k_srv_heur=40561160, k_srv=34512292, k_req=41417919
# Episode 89/2000, total reward: 173.467, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.07730343442777, ratio_heur=99.15837441420065 ratio=85.89130873283433, k_srv_heur=45722343, k_srv=39604843, k_req=46110420
# Episode 90/2000, total reward: 223.885, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.3297310246841754, ratio_heur=99.32015702444336 ratio=91.91757160071529, k_srv_heur=51231245, k_srv=47412849, k_req=51581921
# Episode 91/2000, total reward: 225.287, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.2858592378968465, ratio_heur=99.44707759343427 ratio=92.6644295485556, k_srv_heur=50351027, k_srv=46916906, k_req=50630977
# Episode 92/2000, total reward: 244.767, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.1352114641488609, ratio_heur=99.2813289027094 ratio=95.71991867683981, k_srv_heur=25505454, k_srv=24590525, k_req=25690081
# Episode 93/2000, total reward: 186.972, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.027932058231401, ratio_heur=97.96343727177214 ratio=89.47274752486776, k_srv_heur=44122996, k_srv=40298767, k_req=45040270
# Episode 94/2000, total reward: 200.461, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.2008428400447873, ratio_heur=99.52725957684329 ratio=90.39110656418447, k_srv_heur=26984503, k_srv=24507448, k_req=27112676
# Episode 95/2000, total reward: 263.097, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.2022454394548023, ratio_heur=98.92184646145051 ratio=95.94197075882818, k_srv_heur=26850434, k_srv=26041604, k_req=27143078
# Episode 96/2000, total reward: 250.781, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.1803468973895428, ratio_heur=98.85911092510908 ratio=95.68460517805556, k_srv_heur=26364158, k_srv=25517568, k_req=26668416
# Episode 97/2000, total reward: 179.059, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 2.1846481338453874, ratio_heur=98.85921190042559 ratio=86.29829895079828, k_srv_heur=47884607, k_srv=41800456, k_req=48437173
# Episode 98/2000, total reward: 243.042, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.0965977840277874, ratio_heur=99.55543523871054 ratio=94.28221107628441, k_srv_heur=24742621, k_srv=23432061, k_req=24853109
# Episode 99/2000, total reward: 220.320, entropy_coef: 0.0091, demands: 3, mean_kbps_rand: 1.7319827060201085, ratio_heur=99.23644749148582 ratio=93.48380676242675, k_srv_heur=38330486, k_srv=36108505, k_req=38625412
# Episode 100/2000, total reward: 203.778, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.1753115107875436, ratio_heur=99.28125603159128 ratio=88.00690949168407, k_srv_heur=47888112, k_srv=42449954, k_req=48234797
# Episode 101/2000, total reward: 160.497, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.8770404813096533, ratio_heur=99.15484051489479 ratio=83.14248449814643, k_srv_heur=41416596, k_srv=34728296, k_req=41769615
# Episode 102/2000, total reward: 238.022, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.5218024418959382, ratio_heur=99.2785274153769 ratio=94.40593416655723, k_srv_heur=33823841, k_srv=32163766, k_req=34069644
# Episode 103/2000, total reward: 198.654, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.41120151469719, ratio_heur=99.17975946256725 ratio=89.7616123267421, k_srv_heur=52910256, k_srv=47885878, k_req=53347837
# Episode 104/2000, total reward: 207.188, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.7460469778294225, ratio_heur=99.06052951606102 ratio=92.56036132299111, k_srv_heur=60036415, k_srv=56096937, k_req=60605788
# Episode 105/2000, total reward: 224.168, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.0005930988365073, ratio_heur=99.47012979798025 ratio=92.68796762416197, k_srv_heur=44212168, k_srv=41197654, k_req=44447683
# Episode 106/2000, total reward: 238.918, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.6353976650990343, ratio_heur=99.19086797035509 ratio=95.8627787094126, k_srv_heur=36236289, k_srv=35020476, k_req=36531880
# Episode 107/2000, total reward: 213.707, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 1.9593986136328247, ratio_heur=99.13723368000782 ratio=93.66727962685393, k_srv_heur=43178995, k_srv=40796569, k_req=43554771
# Episode 108/2000, total reward: 117.563, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.480951150911954, ratio_heur=97.71793266067853 ratio=80.03146027861337, k_srv_heur=53607761, k_srv=43905016, k_req=54859697
# Episode 109/2000, total reward: 180.508, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.555296443942467, ratio_heur=98.18083431285594 ratio=88.68631640747456, k_srv_heur=55443866, k_srv=50082201, k_req=56471170
# Episode 110/2000, total reward: 198.481, entropy_coef: 0.0090, demands: 3, mean_kbps_rand: 2.412815263237618, ratio_heur=98.10771235058128 ratio=86.76462509932101, k_srv_heur=52372659, k_srv=46317400, k_req=53382816
# Episode 111/2000, total reward: 243.666, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.0096734990839105, ratio_heur=99.27419629004054 ratio=93.78055327726133, k_srv_heur=44320474, k_srv=41867865, k_req=44644506
# Episode 112/2000, total reward: 218.939, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.6135722343432586, ratio_heur=99.36304419064308 ratio=92.54093216337651, k_srv_heur=57366586, k_srv=53427886, k_req=57734328
# Episode 113/2000, total reward: 213.606, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.428194283103033, ratio_heur=99.21468708146026 ratio=93.53838454702785, k_srv_heur=53294324, k_srv=50245232, k_req=53716164
# Episode 114/2000, total reward: 174.426, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.985286751316421, ratio_heur=98.81282451922115 ratio=88.67758482206338, k_srv_heur=65010376, k_srv=58342256, k_req=65791436
# Episode 115/2000, total reward: 206.375, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.2863436474046734, ratio_heur=99.16180515913024 ratio=92.67535101442435, k_srv_heur=50217003, k_srv=46932166, k_req=50641477
# Episode 116/2000, total reward: 256.611, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.6423640680603764, ratio_heur=99.25313991955406 ratio=95.4213891023558, k_srv_heur=36408911, k_srv=35003314, k_req=36682881
# Episode 117/2000, total reward: 175.239, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.1172130257053614, ratio_heur=99.45994789910552 ratio=89.43370784436189, k_srv_heur=46721790, k_srv=42011915, k_req=46975482
# Episode 118/2000, total reward: 127.458, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.5653513417695644, ratio_heur=93.76101442217062 ratio=84.14975672778473, k_srv_heur=53152290, k_srv=47703753, k_req=56689115
# Episode 119/2000, total reward: 213.386, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.311494091311126, ratio_heur=98.92184690037828 ratio=90.09480771582459, k_srv_heur=29192925, k_srv=26587969, k_req=29511100
# Episode 120/2000, total reward: 162.382, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.1402110433414885, ratio_heur=97.15608568566128 ratio=85.27631480727274, k_srv_heur=46123856, k_srv=40484057, k_req=47473976
# Episode 121/2000, total reward: 244.788, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 1.0681335104985503, ratio_heur=99.28136522891671 ratio=94.36447912533737, k_srv_heur=24061962, k_srv=22870299, k_req=24236131
# Episode 122/2000, total reward: 128.826, entropy_coef: 0.0089, demands: 3, mean_kbps_rand: 2.404749844090423, ratio_heur=98.25761287675121 ratio=79.15932243588705, k_srv_heur=52280904, k_srv=42119087, k_req=53207993
# Episode 123/2000, total reward: 173.330, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.2483871698285034, ratio_heur=98.03674876582691 ratio=85.90953175860984, k_srv_heur=48840683, k_srv=42799055, k_req=49818750
# Episode 124/2000, total reward: 80.946, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.9214950230773122, ratio_heur=93.62164732477123 ratio=72.1318910148233, k_srv_heur=60300502, k_srv=46459225, k_req=64408717
# Episode 125/2000, total reward: 149.319, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.8598643799478949, ratio_heur=98.7863897879288 ratio=84.00503108486532, k_srv_heur=40894912, k_srv=34775827, k_req=41397314
# Episode 126/2000, total reward: 249.928, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.7554017595058715, ratio_heur=99.44691123932418 ratio=95.77481402543599, k_srv_heur=38916592, k_srv=37479589, k_req=39133032
# Episode 127/2000, total reward: 98.006, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.619499062990691, ratio_heur=95.40250131354308 ratio=74.62033105468497, k_srv_heur=55202554, k_srv=43177410, k_req=57862796
# Episode 128/2000, total reward: 231.451, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.0655167739676685, ratio_heur=99.28118795824868 ratio=93.12157681876153, k_srv_heur=24005608, k_srv=22516250, k_req=24179412
# Episode 129/2000, total reward: 256.997, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.5984134093006108, ratio_heur=99.19836571669805 ratio=96.0435495367285, k_srv_heur=35443801, k_srv=34316578, k_req=35730227
# Episode 130/2000, total reward: 244.920, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.482210817111366, ratio_heur=99.28129703774411 ratio=94.59581411961776, k_srv_heur=32972783, k_srv=31416665, k_req=33211475
# Episode 131/2000, total reward: 244.168, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.965179069823376, ratio_heur=99.26504889453963 ratio=94.65156686808356, k_srv_heur=43359039, k_srv=41343867, k_req=43680066
# Episode 132/2000, total reward: 250.343, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 1.16371746186479, ratio_heur=99.28122570573731 ratio=94.97518443342877, k_srv_heur=26118869, k_srv=24986037, k_req=26307964
# Episode 133/2000, total reward: 87.343, entropy_coef: 0.0088, demands: 3, mean_kbps_rand: 2.5837908639661604, ratio_heur=94.61950402808517 ratio=78.56606471368715, k_srv_heur=54017141, k_srv=44852425, k_req=57088802
# Episode 134/2000, total reward: 268.640, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.1533926139385624, ratio_heur=98.82048229950809 ratio=96.79323188254179, k_srv_heur=25776500, k_srv=25247709, k_req=26084167
# Episode 135/2000, total reward: 249.919, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.397110042039746, ratio_heur=98.92185165745137 ratio=93.87445694024925, k_srv_heur=31028689, k_srv=29445480, k_req=31366871
# Episode 136/2000, total reward: 250.013, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.9216614001156087, ratio_heur=99.20620362381074 ratio=95.71667123381008, k_srv_heur=42397554, k_srv=40906240, k_req=42736797
# Episode 137/2000, total reward: 211.803, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.8523081238493364, ratio_heur=99.28125284761859 ratio=91.34020856116152, k_srv_heur=40937164, k_srv=37662791, k_req=41233529
# Episode 138/2000, total reward: 204.974, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.4106192518708283, ratio_heur=99.6406792736628 ratio=89.05132241480757, k_srv_heur=31545930, k_srv=28193373, k_req=31659690
# Episode 139/2000, total reward: 116.657, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.5070550333099604, ratio_heur=96.59357916032735 ratio=77.46030334524339, k_srv_heur=53537486, k_srv=42932770, k_req=55425512
# Episode 140/2000, total reward: 262.872, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 1.3919358650085583, ratio_heur=99.48618575695527 ratio=96.11267717669732, k_srv_heur=31094127, k_srv=30039746, k_req=31254718
# Episode 141/2000, total reward: 121.655, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.0557534120052394, ratio_heur=99.28127120891865 ratio=77.15477990432346, k_srv_heur=45315261, k_srv=35215997, k_req=45643312
# Episode 142/2000, total reward: 225.942, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.193052223861984, ratio_heur=99.64064466049606 ratio=95.99161132371579, k_srv_heur=48444620, k_srv=46670484, k_req=48619336
# Episode 143/2000, total reward: 250.127, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 2.0535875184837753, ratio_heur=99.30350118319848 ratio=96.01457195517598, k_srv_heur=45278787, k_srv=43779155, k_req=45596365
# Episode 144/2000, total reward: 83.420, entropy_coef: 0.0087, demands: 3, mean_kbps_rand: 3.3988314866292155, ratio_heur=91.65084890163236 ratio=77.05634428800944, k_srv_heur=68513808, k_srv=57603652, k_req=74755236
# Episode 145/2000, total reward: 172.158, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.606414964252105, ratio_heur=99.06657013362329 ratio=84.33040590787868, k_srv_heur=57041730, k_srv=48556765, k_req=57579191
# Episode 146/2000, total reward: 151.029, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.3876342362594962, ratio_heur=97.70535943750944 ratio=87.26152025143057, k_srv_heur=72802735, k_srv=65020766, k_req=74512529
# Episode 147/2000, total reward: 256.302, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.5978539630670712, ratio_heur=99.49710915223196 ratio=95.12145046722775, k_srv_heur=35538478, k_srv=33975576, k_req=35718101
# Episode 148/2000, total reward: 54.313, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.804300250235567, ratio_heur=94.65879793324602 ratio=70.68468537733031, k_srv_heur=58563939, k_srv=43731525, k_req=61868459
# Episode 149/2000, total reward: 237.528, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.9447056146063768, ratio_heur=99.28132086069125 ratio=93.54032732229787, k_srv_heur=42925563, k_srv=40443370, k_req=43236293
# Episode 150/2000, total reward: 55.981, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 3.6170002434117916, ratio_heur=92.68025773197488 ratio=72.42620377955592, k_srv_heur=73666123, k_srv=57567358, k_req=79484158
# Episode 151/2000, total reward: 158.778, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.5386175148398022, ratio_heur=95.56051129214241 ratio=90.5156193673286, k_srv_heur=53618664, k_srv=50787993, k_req=56109645
# Episode 152/2000, total reward: 111.183, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 2.8371539897572893, ratio_heur=92.30888111083331 ratio=75.38384939182853, k_srv_heur=57767434, k_srv=47175651, k_req=62580581
# Episode 153/2000, total reward: 243.547, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.4840364942860074, ratio_heur=99.47010039927063 ratio=95.15936345665779, k_srv_heur=33074850, k_srv=31641485, k_req=33251047
# Episode 154/2000, total reward: 256.757, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.3638555820752223, ratio_heur=98.7725376339869 ratio=95.19644438670478, k_srv_heur=30269894, k_srv=29173962, k_req=30646063
# Episode 155/2000, total reward: 232.940, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.7845735685015884, ratio_heur=98.37753180397303 ratio=95.11222947164379, k_srv_heur=39120166, k_srv=37821708, k_req=39765346
# Episode 156/2000, total reward: 261.928, entropy_coef: 0.0086, demands: 3, mean_kbps_rand: 1.756920829998934, ratio_heur=99.44645896338089 ratio=95.81072725396245, k_srv_heur=38949159, k_srv=37525190, k_req=39165959
# Episode 157/2000, total reward: 213.145, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.3023044997724895, ratio_heur=98.92186634657763 ratio=92.26689054909313, k_srv_heur=50437724, k_srv=47044522, k_req=50987437
# Episode 158/2000, total reward: 161.783, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.8272224282985308, ratio_heur=96.72618367571346 ratio=84.61462343859355, k_srv_heur=60323583, k_srv=52770171, k_req=62365309
# Episode 159/2000, total reward: 186.797, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.953625577821867, ratio_heur=98.99238527775232 ratio=89.56641409312792, k_srv_heur=64449154, k_srv=58312360, k_req=65105164
# Episode 160/2000, total reward: 57.656, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.6878026659449867, ratio_heur=90.88075681512076 ratio=72.77475669228444, k_srv_heur=73630533, k_srv=58961262, k_req=81018838
# Episode 161/2000, total reward: 174.436, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 2.787587686613117, ratio_heur=98.79935398258444 ratio=87.52941210553055, k_srv_heur=60767733, k_srv=53836020, k_req=61506205
# Episode 162/2000, total reward: 119.229, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.248824073181902, ratio_heur=96.72715044991995 ratio=82.65602149331774, k_srv_heur=69163536, k_srv=59102152, k_req=71503746
# Episode 163/2000, total reward: 83.139, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.4079298525049504, ratio_heur=95.45431886688378 ratio=81.15308351979573, k_srv_heur=71545348, k_srv=60826222, k_req=74952448
# Episode 164/2000, total reward: 256.922, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.0849396767105703, ratio_heur=98.92181181194421 ratio=95.63511107549861, k_srv_heur=24335175, k_srv=23526633, k_req=24600414
# Episode 165/2000, total reward: 125.771, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.3978727826212167, ratio_heur=93.83775774796632 ratio=81.5040900979705, k_srv_heur=70129137, k_srv=60911638, k_req=74734455
# Episode 166/2000, total reward: 48.275, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 3.763393839200631, ratio_heur=95.49707602318735 ratio=73.2972380915937, k_srv_heur=78935320, k_srv=60585530, k_req=82657316
# Episode 167/2000, total reward: 257.456, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.1840686182576339, ratio_heur=98.92188428819449 ratio=96.57145484586785, k_srv_heur=26460700, k_srv=25831981, k_req=26749086
# Episode 168/2000, total reward: 251.306, entropy_coef: 0.0085, demands: 3, mean_kbps_rand: 1.9458811285760929, ratio_heur=98.92188583586797 ratio=94.91454107019443, k_srv_heur=42795361, k_srv=41061713, k_req=43261773
# Episode 169/2000, total reward: 237.248, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.5008149123058847, ratio_heur=99.64067000364935 ratio=94.8050165331474, k_srv_heur=33493941, k_srv=31868449, k_req=33614728
# Episode 170/2000, total reward: 262.751, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.7480292164380495, ratio_heur=99.38544671860208 ratio=97.19450122846243, k_srv_heur=38733717, k_srv=37879835, k_req=38973228
# Episode 171/2000, total reward: 132.828, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.7276055224709523, ratio_heur=95.70389420339002 ratio=84.2483703772126, k_srv_heur=57619544, k_srv=50722624, k_req=60206060
# Episode 172/2000, total reward: 238.875, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.5022844442633754, ratio_heur=99.64066221365819 ratio=96.26557879288255, k_srv_heur=33525676, k_srv=32390076, k_req=33646581
# Episode 173/2000, total reward: 217.547, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.0808655589195633, ratio_heur=99.12135174336235 ratio=91.1940905446876, k_srv_heur=45781804, k_srv=42120390, k_req=46187631
# Episode 174/2000, total reward: 230.712, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.63786836378262, ratio_heur=99.61336569145284 ratio=93.82964101439721, k_srv_heur=36443982, k_srv=34327981, k_req=36585434
# Episode 175/2000, total reward: 95.840, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.929346708229498, ratio_heur=95.08714763001386 ratio=82.17868816636039, k_srv_heur=61406240, k_srv=53070098, k_req=64578906
# Episode 176/2000, total reward: 250.540, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.8697289973527644, ratio_heur=99.41562130677299 ratio=96.85119958565495, k_srv_heur=41367968, k_srv=40300883, k_req=41611135
# Episode 177/2000, total reward: 175.450, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.4278256383996566, ratio_heur=98.04306656543693 ratio=89.71012377017415, k_srv_heur=52657140, k_srv=48181669, k_req=53708173
# Episode 178/2000, total reward: 211.776, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.6694815600532955, ratio_heur=99.27039563010615 ratio=91.74566235343985, k_srv_heur=58516118, k_srv=54080575, k_req=58946193
# Episode 179/2000, total reward: 231.353, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 1.986446363781175, ratio_heur=99.194099952473 ratio=93.13689277742446, k_srv_heur=43785313, k_srv=41111598, k_req=44141045
# Episode 180/2000, total reward: 157.913, entropy_coef: 0.0084, demands: 3, mean_kbps_rand: 2.619619806673834, ratio_heur=96.67139459639272 ratio=89.30254616204188, k_srv_heur=55939302, k_srv=51675287, k_req=57865413
# Episode 181/2000, total reward: 257.708, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 1.7229308043763298, ratio_heur=98.94147810565195 ratio=97.0334668656346, k_srv_heur=38022426, k_srv=37289192, k_req=38429207
# Episode 182/2000, total reward: 244.879, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 1.7589448874859501, ratio_heur=98.92892025180116 ratio=96.95532035320602, k_srv_heur=38789863, k_srv=38016018, k_req=39209831
# Episode 183/2000, total reward: 263.419, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 1.1360826219582787, ratio_heur=99.2812795097747 ratio=96.86732698487447, k_srv_heur=25524189, k_srv=24903586, k_req=25708964
# Episode 184/2000, total reward: 186.526, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 1.8680381586122998, ratio_heur=98.30746579734819 ratio=85.32215931139075, k_srv_heur=40870823, k_srv=35472249, k_req=41574485
# Episode 185/2000, total reward: 142.872, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.164478341735761, ratio_heur=97.27537695406144 ratio=83.97701718460422, k_srv_heur=67777113, k_srv=58511413, k_req=69675508
# Episode 186/2000, total reward: 63.857, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.9126720410888813, ratio_heur=93.42706594960354 ratio=74.8735178003421, k_srv_heur=80247310, k_srv=64311110, k_req=85893000
# Episode 187/2000, total reward: 99.833, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.4613196268654094, ratio_heur=96.21843030956427 ratio=79.25932906504455, k_srv_heur=73231558, k_srv=60324037, k_req=76109699
# Episode 188/2000, total reward: 269.582, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 1.1208292154469877, ratio_heur=99.28124930278327 ratio=97.13815869213242, k_srv_heur=25195932, k_srv=24652051, k_req=25378338
# Episode 189/2000, total reward: 57.891, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.016796632077792, ratio_heur=94.60495554593044 ratio=75.82427817877091, k_srv_heur=62888104, k_srv=50403756, k_req=66474429
# Episode 190/2000, total reward: 77.260, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.761678656641756, ratio_heur=94.27212521053013 ratio=77.36517281737532, k_srv_heur=57453782, k_srv=47149905, k_req=60944613
# Episode 191/2000, total reward: 231.566, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 2.1036563206724272, ratio_heur=99.11855619206442 ratio=93.41603721830495, k_srv_heur=46270160, k_srv=43608131, k_req=46681633
# Episode 192/2000, total reward: 32.519, entropy_coef: 0.0083, demands: 3, mean_kbps_rand: 3.523063197473728, ratio_heur=91.91748481325666 ratio=71.35785294711337, k_srv_heur=71188275, k_srv=55265246, k_req=77448023
# Episode 193/2000, total reward: 69.573, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.9539648677558663, ratio_heur=91.64238383835777 ratio=73.95314525729944, k_srv_heur=79534632, k_srv=64182488, k_req=86788044
# Episode 194/2000, total reward: 219.640, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 1.7927074030046395, ratio_heur=99.49141651219485 ratio=93.9229858489387, k_srv_heur=39738515, k_srv=37514392, k_req=39941652
# Episode 195/2000, total reward: 39.992, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.0879060387235127, ratio_heur=94.63623661378185 ratio=62.41765428569117, k_srv_heur=64367559, k_srv=42453844, k_req=68015763
# Episode 196/2000, total reward: 129.726, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.202910237252218, ratio_heur=95.60843962213623 ratio=80.06952535327032, k_srv_heur=67412115, k_srv=56455853, k_req=70508540
# Episode 197/2000, total reward: 127.095, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.1691145891003725, ratio_heur=97.20818559804714 ratio=86.50840913908719, k_srv_heur=67827985, k_srv=60362108, k_req=69776001
# Episode 198/2000, total reward: 156.978, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.56902345345959, ratio_heur=99.35093697973412 ratio=88.33965537406033, k_srv_heur=56400246, k_srv=50149283, k_req=56768710
# Episode 199/2000, total reward: 86.170, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.467073420438321, ratio_heur=93.00102564127246 ratio=71.96175803071854, k_srv_heur=70898788, k_srv=54859626, k_req=76234416
# Episode 200/2000, total reward: 200.617, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.555169489065847, ratio_heur=98.90175330212317 ratio=91.79986114862314, k_srv_heur=55848256, k_srv=51837930, k_req=56468418
# Episode 201/2000, total reward: 238.472, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 1.9627121177468, ratio_heur=99.32920124908145 ratio=95.24294822988779, k_srv_heur=43333947, k_srv=41551254, k_req=43626593
# Episode 202/2000, total reward: 244.833, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 1.312008375612963, ratio_heur=99.28125721279068 ratio=95.82921519357774, k_srv_heur=29310058, k_srv=28290938, k_req=29522247
# Episode 203/2000, total reward: 131.203, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 3.158735378835448, ratio_heur=94.08081172821211 ratio=79.80592255177342, k_srv_heur=65434170, k_srv=55505838, k_req=69551026
# Episode 204/2000, total reward: 218.636, entropy_coef: 0.0082, demands: 3, mean_kbps_rand: 2.911442057186064, ratio_heur=98.8144564998808 ratio=91.56357415663994, k_srv_heur=63429804, k_srv=58775403, k_req=64190814
# Episode 205/2000, total reward: 256.322, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.082636421604597, ratio_heur=99.62315743682795 ratio=96.67818160470235, k_srv_heur=24457973, k_srv=23734967, k_req=24550490
# Episode 206/2000, total reward: 43.100, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 3.2467567475602075, ratio_heur=94.06859673387586 ratio=71.1502001659239, k_srv_heur=67220418, k_srv=50843176, k_req=71458936
# Episode 207/2000, total reward: 24.771, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 3.7580424586828167, ratio_heur=90.60758408208949 ratio=66.31067329639225, k_srv_heur=74788698, k_srv=54733707, k_req=82541322
# Episode 208/2000, total reward: 261.830, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.8338125721065073, ratio_heur=99.64058104714094 ratio=95.82004372542198, k_srv_heur=40685868, k_srv=39125842, k_req=40832628
# Episode 209/2000, total reward: 194.834, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 2.2108343000553923, ratio_heur=99.16980119491085 ratio=92.11706320991027, k_srv_heur=48597935, k_srv=45141757, k_req=49004772
# Episode 210/2000, total reward: 45.318, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.444409114708948, ratio_heur=89.94016499825364 ratio=72.87909724693476, k_srv_heur=87618522, k_srv=70997855, k_req=97418681
# Episode 211/2000, total reward: 257.195, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.7149293068956295, ratio_heur=99.43709169889686 ratio=96.62861189456953, k_srv_heur=38040425, k_srv=36966020, k_req=38255770
# Episode 212/2000, total reward: 60.087, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 4.229220407062604, ratio_heur=89.33194239959528 ratio=65.44632006965475, k_srv_heur=82859265, k_srv=60704310, k_req=92754352
# Episode 213/2000, total reward: 268.892, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.3987812178791565, ratio_heur=99.2452106438857 ratio=97.30107550830606, k_srv_heur=31166067, k_srv=30555548, k_req=31403094
# Episode 214/2000, total reward: 165.295, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.5264069985310413, ratio_heur=99.10393545949736 ratio=79.41187703913958, k_srv_heur=33863270, k_srv=27134602, k_req=34169450
# Episode 215/2000, total reward: 244.526, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.5811342581923753, ratio_heur=99.2812584182975 ratio=95.29605862222769, k_srv_heur=35101576, k_srv=33692581, k_req=35355692
# Episode 216/2000, total reward: 223.818, entropy_coef: 0.0081, demands: 3, mean_kbps_rand: 1.4495190592267655, ratio_heur=99.11571420372222 ratio=88.72822041849956, k_srv_heur=32215446, k_srv=28839213, k_req=32502864
# Episode 217/2000, total reward: 29.721, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 4.649951168386483, ratio_heur=90.29153923988797 ratio=64.31496786505183, k_srv_heur=91983524, k_srv=65520174, k_req=101873913
# Episode 218/2000, total reward: 100.202, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 3.3529491883281857, ratio_heur=95.12047061228866 ratio=80.0453723582654, k_srv_heur=70161537, k_srv=59042037, k_req=73760713
# Episode 219/2000, total reward: 112.633, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 3.344656482074987, ratio_heur=92.50155560132754 ratio=79.26106566670612, k_srv_heur=68063536, k_srv=58321056, k_req=73580964
# Episode 220/2000, total reward: 16.879, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 4.737482918824863, ratio_heur=90.21489600130073 ratio=62.68953613112163, k_srv_heur=93617089, k_srv=65053690, k_req=103771210
# Episode 221/2000, total reward: 38.386, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 3.4190531178176826, ratio_heur=92.92867318217526 ratio=71.660813841207, k_srv_heur=69876368, k_srv=53884310, k_req=75193550
# Episode 222/2000, total reward: 225.062, entropy_coef: 0.0080, demands: 3, mean_kbps_rand: 1.4158155449530363, ratio_heur=99.24078382206916 ratio=92.53143300620977, k_srv_heur=31531102, k_srv=29399385, k_req=31772322
# ...
# Episode 1928/2000, total reward: 151.453, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 2.7875470093371377, ratio_heur=95.34080250013182 ratio=86.99400308374304, k_srv_heur=58639669, k_srv=53505943, k_req=61505323
# Episode 1929/2000, total reward: 147.710, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 1.7434302182397676, ratio_heur=98.65798147036762 ratio=81.5449126308507, k_srv_heur=38351853, k_srv=31699396, k_req=38873543
# Episode 1930/2000, total reward: 3.636, entropy_coef: 0.0015, demands: 3, mean_kbps_rand: 6.838770847642864, ratio_heur=82.05948350357696 ratio=50.22569598460682, k_srv_heur=122529358, k_srv=74995869, k_req=149317730
# Episode 1931/2000, total reward: 43.646, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.7060460693750645, ratio_heur=87.61786170469287 ratio=66.63367447486391, k_srv_heur=90325078, k_srv=68692521, k_req=103089799
# Episode 1932/2000, total reward: 187.818, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.487949964511131, ratio_heur=97.89153412877036 ratio=90.09283097901978, k_srv_heur=53851503, k_srv=49561327, k_req=55011400
# Episode 1933/2000, total reward: 12.884, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.050106594844499, ratio_heur=82.90792195862727 ratio=57.63031025689156, k_srv_heur=109623357, k_srv=76200535, k_req=132223018
# Episode 1934/2000, total reward: -18.318, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.190720453854414, ratio_heur=72.18409727335774 ratio=45.62753401703611, k_srv_heur=144582924, k_srv=91390798, k_req=200297475
# Episode 1935/2000, total reward: 8.500, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.931830136507059, ratio_heur=77.50699720918244 ratio=56.54522184790839, k_srv_heur=117295090, k_srv=85572621, k_req=151334839
# Episode 1936/2000, total reward: -6.460, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.13624639343681, ratio_heur=75.38338461305499 ratio=48.68367931895124, k_srv_heur=117421434, k_srv=75832459, k_req=155765669
# Episode 1937/2000, total reward: -8.616, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.688295611463095, ratio_heur=62.399957664784566 ratio=43.86232993280131, k_srv_heur=131715502, k_srv=92585781, k_req=211082678
# Episode 1938/2000, total reward: 56.002, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.950073803458707, ratio_heur=94.46891498371774 ratio=73.76436614947967, k_srv_heur=81908047, k_srv=63956437, k_req=86703703
# Episode 1939/2000, total reward: 256.496, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.540447750338707, ratio_heur=99.45423580202198 ratio=95.4192801355334, k_srv_heur=34285645, k_srv=32894643, k_req=34473791
# Episode 1940/2000, total reward: 2.768, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.93680934237558, ratio_heur=64.77856818971952 ratio=44.27367643125359, k_srv_heur=140225741, k_srv=95838937, k_req=216469344
# Episode 1941/2000, total reward: 5.641, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.986993981451611, ratio_heur=89.94244892673942 ratio=62.579992446917544, k_srv_heur=98198710, k_srv=68324518, k_req=109179493
# Episode 1942/2000, total reward: 18.321, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.1413894559968965, ratio_heur=75.44523118255631 ratio=51.2434385670408, k_srv_heur=117601875, k_srv=79876810, k_req=155877148
# Episode 1943/2000, total reward: 19.000, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.947223781354532, ratio_heur=83.15702915570603 ratio=60.50126456711551, k_srv_heur=108098299, k_srv=78647396, k_req=129992979
# Episode 1944/2000, total reward: 29.534, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.2732816678927765, ratio_heur=82.28601992795694 ratio=54.83320354990412, k_srv_heur=112781593, k_srv=75154638, k_req=137060455
# Episode 1945/2000, total reward: 257.038, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.6749851615195872, ratio_heur=98.92183637975756 ratio=95.83899012110014, k_srv_heur=36986835, k_srv=35834160, k_req=37389960
# Episode 1946/2000, total reward: 224.534, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.6027355219256436, ratio_heur=99.45194868771019 ratio=93.19944554427579, k_srv_heur=35627578, k_srv=33387687, k_req=35823911
# Episode 1947/2000, total reward: -13.403, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.244094273372426, ratio_heur=77.73118661794769 ratio=48.40628044081681, k_srv_heur=122895594, k_srv=76531941, k_req=158103329
# Episode 1948/2000, total reward: -18.032, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.818670834503505, ratio_heur=69.6607402838871 ratio=42.963354753673265, k_srv_heur=133911003, k_srv=82589790, k_req=192233104
# Episode 1949/2000, total reward: 250.582, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.2742004064729167, ratio_heur=99.4752179130908 ratio=96.98474752432388, k_srv_heur=50113889, k_srv=48859234, k_req=50378266
# Episode 1950/2000, total reward: -7.169, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.4618998927917, ratio_heur=70.37751696488208 ratio=43.04395160703296, k_srv_heur=145101150, k_srv=88746053, k_req=206175432
# Episode 1951/2000, total reward: 39.371, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.322209914137335, ratio_heur=87.49881608606452 ratio=68.91261430036309, k_srv_heur=82922583, k_srv=65308449, k_req=94769949
# Episode 1952/2000, total reward: -0.004, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.09633280073805, ratio_heur=71.60952483729164 ratio=48.096588840961815, k_srv_heur=141967009, k_srv=95352244, k_req=198251573
# Episode 1953/2000, total reward: 135.185, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.4890265988278717, ratio_heur=99.05782775840461 ratio=81.1070403612018, k_srv_heur=54516214, k_srv=44637046, k_req=55034736
# Episode 1954/2000, total reward: -25.305, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.956307011195474, ratio_heur=70.48689790265806 ratio=40.981911064071916, k_srv_heur=137602013, k_srv=80003428, k_req=195216440
# Episode 1955/2000, total reward: 25.275, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.693985826254449, ratio_heur=89.6978605761096 ratio=66.13862100208073, k_srv_heur=92234863, k_srv=68009277, k_req=102828387
# Episode 1956/2000, total reward: 124.861, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.953369210260635, ratio_heur=98.51393924060345 ratio=85.52716777675697, k_srv_heur=64132187, k_srv=55677850, k_req=65099607
# Episode 1957/2000, total reward: 230.820, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.9780896141325128, ratio_heur=99.0176850302058 ratio=93.87348647937614, k_srv_heur=43528084, k_srv=41266699, k_req=43959908
# Episode 1958/2000, total reward: -10.415, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.213286595203819, ratio_heur=75.2419571193241 ratio=52.50772872954974, k_srv_heur=134766684, k_srv=94047161, k_req=179111082
# Episode 1959/2000, total reward: 5.451, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.5636571662308345, ratio_heur=76.60058660998547 ratio=48.34786997348843, k_srv_heur=126413965, k_srv=79788501, k_req=165030023
# Episode 1960/2000, total reward: 16.498, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.587741174661914, ratio_heur=89.27125194761769 ratio=59.81721113694994, k_srv_heur=89740353, k_srv=60131537, k_req=100525478
# Episode 1961/2000, total reward: 13.595, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.254429669792456, ratio_heur=82.07095487510908 ratio=60.02707203436024, k_srv_heur=112151460, k_srv=82028091, k_req=136651828
# Episode 1962/2000, total reward: 5.738, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.781521367231811, ratio_heur=75.86889074188736 ratio=48.955956137895676, k_srv_heur=128789220, k_srv=83103883, k_req=169752344
# Episode 1963/2000, total reward: -17.994, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.962192978102255, ratio_heur=68.13754769627778 ratio=42.11992179346806, k_srv_heur=147871798, k_srv=91408464, k_req=217019548
# Episode 1964/2000, total reward: 131.026, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.4129494175052004, ratio_heur=95.27245691411377 ratio=80.20315633627753, k_srv_heur=50861890, k_srv=42817035, k_req=53385723
# Episode 1965/2000, total reward: 5.187, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.203812987544171, ratio_heur=78.03531584367043 ratio=50.1182405988008, k_srv_heur=122695092, k_srv=78801015, k_req=157230211
# Episode 1966/2000, total reward: 257.135, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.3590764474570405, ratio_heur=99.55607380838798 ratio=96.64283230724608, k_srv_heur=30406886, k_srv=29517110, k_req=30542473
# Episode 1967/2000, total reward: 0.928, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.8228467580834, ratio_heur=72.4717939399169 ratio=47.546600215221, k_srv_heur=139380377, k_srv=91443342, k_req=192323619
# Episode 1968/2000, total reward: 10.091, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.4490268032992555, ratio_heur=85.57706012719386 ratio=56.646068627190004, k_srv_heur=102002976, k_srv=67518883, k_req=119194297
# Episode 1969/2000, total reward: -13.669, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.361526806119798, ratio_heur=74.42344026627285 ratio=44.85696883079727, k_srv_heur=119560319, k_srv=72062155, k_req=160648741
# Episode 1970/2000, total reward: 181.930, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.7468861418318156, ratio_heur=98.22046316867889 ratio=88.02677776218346, k_srv_heur=59545151, k_srv=53365334, k_req=60623978
# Episode 1971/2000, total reward: -7.536, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.224060333462141, ratio_heur=71.39481644748993 ratio=41.74350853130204, k_srv_heur=143517956, k_srv=83912857, k_req=201020134
# Episode 1972/2000, total reward: 45.792, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.6663595654042362, ratio_heur=89.21987381072046 ratio=71.89196473388564, k_srv_heur=71870220, k_srv=57911887, k_req=80554048
# Episode 1973/2000, total reward: 243.683, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.8324223647335207, ratio_heur=99.15610030444947 ratio=95.08125534447521, k_srv_heur=40458162, k_srv=38795524, k_req=40802494
# Episode 1974/2000, total reward: -2.020, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.455712746104407, ratio_heur=93.81830751028637 ratio=64.51308203860506, k_srv_heur=71290812, k_srv=49022308, k_req=75988167
# Episode 1975/2000, total reward: 20.235, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.063641834167724, ratio_heur=78.41532205222379 ratio=55.78629543122424, k_srv_heur=120910096, k_srv=86017964, k_req=154191927
# Episode 1976/2000, total reward: 126.770, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.8504692308471182, ratio_heur=96.26588965988988 ratio=87.0486466003105, k_srv_heur=60521590, k_srv=54726784, k_req=62869195
# Episode 1977/2000, total reward: 23.813, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.065224826288709, ratio_heur=84.7177134705764 ratio=57.84615458555873, k_srv_heur=112293934, k_srv=76675491, k_req=132550714
# Episode 1978/2000, total reward: 218.237, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.164887723836731, ratio_heur=99.39252284878062 ratio=92.34599421739662, k_srv_heur=47717213, k_srv=44334255, k_req=48008856
# Episode 1979/2000, total reward: 131.367, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 2.513498344139767, ratio_heur=95.64002745739664 ratio=81.12273054540327, k_srv_heur=53142548, k_srv=45075986, k_req=55565174
# Episode 1980/2000, total reward: -3.793, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.809570737773817, ratio_heur=76.92455000518308 ratio=53.58410185623228, k_srv_heur=114375115, k_srv=79671416, k_req=148684803
# Episode 1981/2000, total reward: 28.613, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.28899593805328, ratio_heur=92.07989567225877 ratio=66.55132967148306, k_srv_heur=66642357, k_srv=48166187, k_req=72374492
# Episode 1982/2000, total reward: -0.173, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.825372402475783, ratio_heur=87.27362162615687 ratio=60.49011151186473, k_srv_heur=92227499, k_srv=63923687, k_req=105676260
# Episode 1983/2000, total reward: 33.458, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 5.884632828218824, ratio_heur=80.47063525613524 ratio=63.82980287538415, k_srv_heur=103514437, k_srv=82108288, k_req=128636287
# Episode 1984/2000, total reward: 78.375, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.63385052626193, ratio_heur=91.08118541878511 ratio=78.33831782358908, k_srv_heur=72727777, k_srv=62552674, k_req=79849397
# Episode 1985/2000, total reward: 55.987, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.852196245686845, ratio_heur=89.70678831565397 ratio=69.44567095105927, k_srv_heur=95320353, k_srv=73791360, k_req=106257681
# Episode 1986/2000, total reward: 244.516, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.8295825661180483, ratio_heur=99.29893567469699 ratio=95.28816082286087, k_srv_heur=40455320, k_srv=38821292, k_req=40740940
# Episode 1987/2000, total reward: 238.330, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.9292521071896105, ratio_heur=99.20505653991718 ratio=94.87610266794663, k_srv_heur=42560289, k_srv=40703110, k_req=42901330
# Episode 1988/2000, total reward: 6.501, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.772390697895333, ratio_heur=78.44154200454139 ratio=53.92129519746446, k_srv_heur=115998494, k_srv=79738221, k_req=147878906
# Episode 1989/2000, total reward: 256.633, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.2769127859054958, ratio_heur=99.50955025347363 ratio=95.71454384551609, k_srv_heur=28620471, k_srv=27528969, k_req=28761532
# Episode 1990/2000, total reward: 56.590, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.66422833847552, ratio_heur=91.05301739627276 ratio=73.13653429467112, k_srv_heur=73304828, k_srv=58880653, k_req=80507852
# Episode 1991/2000, total reward: 62.387, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.3889027508459337, ratio_heur=93.53433807627512 ratio=72.6408561345053, k_srv_heur=69720519, k_srv=54146512, k_req=74540025
# Episode 1992/2000, total reward: -5.499, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 8.393628760792065, ratio_heur=71.92064880722373 ratio=48.23579144000302, k_srv_heur=131629239, k_srv=88281190, k_req=183020093
# Episode 1993/2000, total reward: 27.598, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 4.187184339585651, ratio_heur=90.30605116373276 ratio=71.75968452825, k_srv_heur=82939966, k_srv=65906389, k_req=91843198
# Episode 1994/2000, total reward: 1.805, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.722618370911263, ratio_heur=67.82360660799495 ratio=46.826941295188234, k_srv_heur=143668468, k_srv=99191937, k_req=211826642
# Episode 1995/2000, total reward: 7.405, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.130916258940122, ratio_heur=77.59547919825258 ratio=53.81203585539519, k_srv_heur=120777469, k_srv=83758507, k_req=155650136
# Episode 1996/2000, total reward: 63.761, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 3.959685527151977, ratio_heur=91.86702842784388 ratio=75.74289304307626, k_srv_heur=79843510, k_srv=65829695, k_req=86912042
# Episode 1997/2000, total reward: 0.032, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 7.181947386276092, ratio_heur=76.47636986053 ratio=50.169772704300875, k_srv_heur=119881499, k_srv=78644260, k_req=156756262
# Episode 1998/2000, total reward: -15.080, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 6.422346330089809, ratio_heur=84.24396340727645 ratio=51.53307047835924, k_srv_heur=118187128, k_srv=72296523, k_req=140291510
# Episode 1999/2000, total reward: 244.573, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 1.0680672329806375, ratio_heur=98.92186112590294 ratio=95.02305740898115, k_srv_heur=23973411, k_srv=23028548, k_req=24234695
# Episode 2000/2000, total reward: 2.025, entropy_coef: 0.0014, demands: 3, mean_kbps_rand: 9.48480739851241, ratio_heur=69.06609939540999 ratio=47.63150914870833, k_srv_heur=142740264, k_srv=98440975, k_req=206671964

# %%
# === Plot learning curve with running average ===
window = 50                     # moving average window (change as desired)
running_avg = []

for i in range(len(episode_rewards)):
    start = max(0, i - window + 1)
    running_avg.append(np.mean(episode_rewards[start:i+1]))

plt.figure(figsize=(7,3))
plt.plot(range(1, num_episodes+1), running_avg, linewidth=3)
plt.xlabel("Episode", fontsize=15)
plt.ylabel("Total Reward", fontsize=15)
plt.grid(True)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.tight_layout()
plt.savefig("learning.pdf", format="pdf", dpi=300, bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %%
NUM_DATA    = 10
N_RUNS      = 2   # number of Monte-Carlo runs

demand_list = [0.01 + 0.2 * i for i in range(NUM_DATA)]

# %% [markdown]
# ## Testing the Agent

# %%
demand_active = np.ones(MAX_DEMANDS)
link_active   = np.ones(MAX_LINKS)

def test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=True):
    agent.model.eval() 
    test_rewards = []

    print(f"--- Starting Evaluation for {num_test_episodes} Episodes (Dual-Head) ---")

    demand_list = [0.01 + 0.2 * i for i in range(num_test_episodes)]
    key_req     = [0 for i in range(num_test_episodes)]
    key_srv_qkp = [0 for i in range(num_test_episodes)]
    a_lst_qkp   = [0 for i in range(num_test_episodes)]
    
    for idx, mean in enumerate(demand_list):
        demands = generate_demands(gnodes, syst, mean_kbps=mean, amp=0.5, noise_std=0.0, pattern="stadium")
        key_req[idx] = sum(d.K_REQ[t] * syst.THETA for d in demands for t in syst.T)
        
        state = [{} for _ in syst.T]
        state[0]["demands"] = demands 
        if f_qkp:
            state[0]["a"] = {i: 0 for i in range(len(links))} 

        ep_reward = 0
        
        for t in syst.T:
            r = random.randint(0, len(hnodes)-1)
            
            hnodes_active = [1 for h in hnodes]
            links_active  = [1 if ((isinstance(l.n1, hap) and hnodes_active[hnodes.index(l.n1)] == 1) or (isinstance(l.n2, hap) and hnodes_active[hnodes.index(l.n2)] == 1)) else 0 for l in links]
            
            s_vec = build_state_vector_for_time(state[t], links, t, gnodes, hnodes, demand_active, link_active) #build_state_vector_for_time(state[t], links, t, gnodes, hnodes)

            with torch.no_grad():
                s_tensor = torch.tensor(s_vec, dtype=torch.float32, device=DEVICE).unsqueeze(0)
                probs, _ = agent.model(s_tensor) # probs shape: [1, 2, n_haps, n_choices]
                
                # --- CHANGE 1: Extract argmax for both heads ---
                # argmax over the last dimension (n_choices)
                # Resulting shape after squeeze: [2, n_haps]
                hap_picks = torch.argmax(probs, dim=-1).squeeze(0).cpu().numpy()

            # --- CHANGE 2: Pass the [2, n_haps] matrix to z_dict ---
            # Your updated get_z_from_demand_choices should handle the 2-row matrix
            z_dict = get_z_from_demand_choices(hap_picks, demands, links, hnodes)

            # 2. Constraint Check
            # With the dual-head, the model naturally picks at most 1 TX and 1 RX per HAP.
            check_tx, check_rx = True, True
            for idx_h, h in enumerate(hnodes):
                used_tx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n1 == h)
                used_rx = sum(z_dict[d_idx][l_idx] for d_idx in range(len(demands)) 
                              for l_idx, l in enumerate(links) if l.n2 == h)
                
                if used_tx > h.N_TX or used_rx > h.N_RX:
                    check_tx, check_rx = False, False

            # 3. Step Environment
            if check_tx and check_rx:
                solution, reward_t, A_next = online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0, demand_active, link_active) #online_new(gnodes, hnodes, links, state, z_dict, t, f_qkp, 0)
            else:
                reward_t = -1.0 

            ep_reward += reward_t
            key_srv_qkp[idx] += sum(solution["r_h"][idx_d] * syst.THETA for idx_d, d in enumerate(demands))

            if t + 1 < len(syst.T):
                state[t+1]["a"] = A_next if (check_tx and check_rx) else state[t]["a"]
                state[t+1]["demands"] = state[t]["demands"]

        test_rewards.append(ep_reward)
        a_lst_qkp[idx] = sum(state[-1]["a"][i] for i in range(len(links))) * 1e-6
        
        print(f"Test Case {idx+1}: Mean_kbps={mean:.2f}, key_srv_qkp={key_srv_qkp[idx]:.2f}, key_req={key_req[idx]:.2f}, ep_reward: {ep_reward}")

    return test_rewards, key_srv_qkp, a_lst_qkp

prob = 2
gnodes, hnodes, links, demands = init_setup_real_online(prob)

key_srv_ppo_qkp = [0 for i in range(NUM_DATA)]
a_lst_ppo_qkp = [0 for i in range(NUM_DATA)]

# Run the test
results, key_srv_ppo_qkp, a_lst_ppo_qkp = test_agent(agent, syst, links, gnodes, hnodes, num_test_episodes=NUM_DATA, f_qkp=f_qkp)
# Out:
#       Time_s  Longitude_deg  Latitude_deg   Altitude_m
# 0        0.0     279.000000     49.000000  25000.00000
# 1     1800.0     278.991146     49.029046  23678.70919
# 4     3600.0     278.974006     49.042329  23672.57558
# 7     5400.0     278.954818     49.050965  23307.62729
# 10    7200.0     278.932833     49.055108  22986.64633
# 13    9000.0     278.880577     49.044621  20913.29464
# 16   10800.0     278.900893     49.018890  19378.08451
# 19   12600.0     278.949781     48.997741  19373.21189
# 22   14400.0     278.989935     48.980466  20387.52864
# 25   16200.0     279.004618     48.984263  21367.19138
# 28   18000.0     279.006678     48.992932  21378.46182
# 31   19800.0     279.022780     49.000290  21723.81151
# 34   21600.0     279.038680     49.008456  21722.88519
# 37   23400.0     279.059257     49.017817  23222.08889
# 40   25200.0     279.061682     49.024487  23068.06755
# 43   27000.0     279.064344     49.029620  22978.23955
# 46   28800.0     279.067620     49.034208  22980.28988
# 49   30600.0     279.076801     49.023505  22983.75746
# 52   32400.0     279.080779     49.013625  23209.52264
# 55   34200.0     279.078888     49.004956  23206.71207
# 58   36000.0     279.075842     48.996233  23206.76795
# 61   37800.0     279.065915     48.996897  23206.70112
# 64   39600.0     279.055069     48.999030  23206.48967
# 67   41400.0     279.051711     48.986308  23021.20170
# 70   43200.0     279.049362     48.977709  23429.46557
# 73   45000.0     279.052921     48.997370  23198.22757
# 76   46800.0     279.054583     49.001266  22740.73417
# 79   48600.0     279.020965     48.984631  21058.72840
# 82   50400.0     278.985247     48.953397  21049.70677
# 85   52200.0     278.946255     48.956166  21042.14420
# 88   54000.0     278.919923     48.953306  20474.85927
# 91   55800.0     278.926507     48.967724  20166.39393
# 94   57600.0     278.939021     48.977959  19860.05593
# 97   59400.0     278.963965     48.976015  19598.71943
# 100  61200.0     278.994659     48.965139  19574.35484
# 103  63000.0     279.020861     48.965952  19790.76428
# 106  64800.0     279.043770     48.980250  19784.07311
# 109  66600.0     279.064583     48.976267  18588.62421
# 112  68400.0     279.089595     48.954722  18975.42547
# 115  70200.0     279.124084     48.979480  19326.23700
# 118  72000.0     279.162255     49.008611  19329.06589
# 121  73800.0     279.220328     49.046809  19340.52095
# 124  75600.0     279.282568     49.086498  19451.14069
# 127  77400.0     279.378014     49.111779  20823.20640
# 130  79200.0     279.469930     49.125324  21958.28937
# 133  81000.0     279.540095     49.128567  23050.50802
# 136  82800.0     279.593425     49.128661  24030.70810
# 139  84600.0     279.612554     49.141021  24030.74921
# 142  86400.0     279.627055     49.155538  24350.33468
# ⏱️ Calculating K_MAX from t=0 to t=47
# [INFO] Loaded checkpoint from K_MAX_checkpoint.pkl
# ✅ Requested interval fully covered.
# --- Starting Evaluation for 10 Episodes (Dual-Head) ---
# Test Case 1: Mean_kbps=0.01, key_srv_qkp=851238.00, key_req=1083776.30, ep_reward: 37.613538122960975
# Test Case 2: Mean_kbps=0.21, key_srv_qkp=17779833.00, key_req=22759302.20, ep_reward: 31.37261203161404
# Test Case 3: Mean_kbps=0.41, key_srv_qkp=34712989.20, key_req=44434828.10, ep_reward: 31.372590856679103
# Test Case 4: Mean_kbps=0.61, key_srv_qkp=44645371.20, key_req=66110354.01, ep_reward: 26.142397316622073
# Test Case 5: Mean_kbps=0.81, key_srv_qkp=47615160.60, key_req=87785879.91, ep_reward: 20.14923660372648
# Test Case 6: Mean_kbps=1.01, key_srv_qkp=48324067.20, key_req=109461405.81, ep_reward: 15.3840625522856
# Test Case 7: Mean_kbps=1.21, key_srv_qkp=49599027.00, key_req=131136931.72, ep_reward: 12.414949064897923
# Test Case 8: Mean_kbps=1.41, key_srv_qkp=51158973.60, key_req=152812457.62, ep_reward: 10.384398299426392
# Test Case 9: Mean_kbps=1.61, key_srv_qkp=52030877.40, key_req=174487983.53, ep_reward: 8.628835779431284
# Test Case 10: Mean_kbps=1.81, key_srv_qkp=53148371.40, key_req=196163509.43, ep_reward: 7.336808347577683

# %% [markdown]
# ## Offline

# %%
key_srv_grd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rnd_qkp = [0 for i in range(NUM_DATA)]
key_srv_rlx_qkp = [0 for i in range(NUM_DATA)]
key_srv_opt_qkp = [0 for i in range(NUM_DATA)]

a_lst_grd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rnd_qkp = [0 for i in range(NUM_DATA)]
a_lst_rlx_qkp = [0 for i in range(NUM_DATA)]
a_lst_opt_qkp = [0 for i in range(NUM_DATA)]

key_req = [0 for i in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)

    result_file = os.path.join(RESULTS_DIR, f"mean_{mean:.4f}.pkl")

    # ------------------------------------------------------------
    # If results exist → load them
    # ------------------------------------------------------------
    if os.path.exists(result_file):
        print(f"[LOAD] idx {idx}, mean={mean}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_grd_qkp[idx] = data["key_srv_grd"]
        a_lst_grd_qkp[idx]   = data["a_lst_grd"]

        key_srv_rlx_qkp[idx] = data["key_srv_rlx"]
        a_lst_rlx_qkp[idx]   = data["a_lst_rlx"]

        key_srv_opt_qkp[idx] = data["key_srv_opt"]
        a_lst_opt_qkp[idx]   = data["a_lst_opt"]

        key_req[idx]         = data["key_req"]

        continue   # skip computation

    # ------------------------------------------------------------
    # Otherwise → compute everything
    # ------------------------------------------------------------
    print(f"[COMPUTE] idx {idx}, mean={mean}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.0,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands for t in syst.T
    )

    ########################################## Greedy (Scarcity + Contention Aware, 1-hop only) ##########################################
    # Z[l][d][t] = 1 if link l is used by demand d at time t
    Z = [[[0 for t in syst.T] for d in demands] for l in links]
    
    # Stored QKP bits per link (already scaled by THETA)
    qkp_s = [0 for _ in links]
    
    for t in syst.T:
    
        # Per-HAP connection limits (up/down)
        max_cnct_up  = [1] * len(hnodes)
        max_cnct_dwn = [1] * len(hnodes)
    
        # --------------------------------------------------------------------------------------------------
        # Step 1: Enumerate feasible 1-hop paths for each demand
        # A path (l1, l2) is feasible if:
        #   - fresh keys can serve it on both links, OR
        #   - stored QKP can cover the demand on both links
        # --------------------------------------------------------------------------------------------------
        feasible_paths = {}   # d -> list of (idx_l1, idx_l2, mid)
    
        for d in demands:
            src, dst = d.n1, d.n2
            feasible_paths[d] = []
    
            for idx_l1, l1 in enumerate(links):
                for idx_l2, l2 in enumerate(links):
                    if l1.n1 == src and l2.n2 == dst and l1.n2 == l2.n1:
                        mid = l1.n2
    
                        fresh_ok = (
                            l1.K_MAX[t] >= d.K_REQ[t] and
                            l2.K_MAX[t] >= d.K_REQ[t]
                        )
    
                        qkp_ok = (
                            qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                            qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                        )
    
                        if fresh_ok or qkp_ok:
                            feasible_paths[d].append((idx_l1, idx_l2, mid))
    
        # --------------------------------------------------------------------------------------------------
        # Step 2: Order demands by scarcity (least number of feasible paths first)
        # --------------------------------------------------------------------------------------------------
        ordered_demands = sorted(
            demands,
            key=lambda d: (
                len(feasible_paths[d]),
                -d.K_REQ[t]
            )
        )
        
        # --------------------------------------------------------------------------------------------------
        # Step 3 (FIXED): Compute link contention
        # How many feasible paths (across all demands) include each link
        # --------------------------------------------------------------------------------------------------
        link_usage = [0] * len(links)
        
        for d in demands:
            for (idx_l1, idx_l2, _) in feasible_paths[d]:
                link_usage[idx_l1] += 1
                link_usage[idx_l2] += 1
    
        # --------------------------------------------------------------------------------------------------
        # Step 4: Greedy allocation
        # For each demand, try least-contended feasible paths first
        # --------------------------------------------------------------------------------------------------
        for d in ordered_demands:
    
            l1_sel = None
            l2_sel = None
            used_qkp_only = False
    
            # # Order this demand's paths by least contention
            # paths = sorted(
            #     feasible_paths[d],
            #     key=lambda p: path_usage[(p[0], p[1])]
            # )
            
            # Order this demand's paths by least link contention
            paths = sorted(
                feasible_paths[d],
                key=lambda p: link_usage[p[0]] + link_usage[p[1]]
            )
    
            for idx_l1, idx_l2, mid in paths:
    
                # Respect HAP connection limits
                if max_cnct_up[hnodes.index(mid)] == 0:
                    continue
                if max_cnct_dwn[hnodes.index(mid)] == 0:
                    continue
    
                # Case 1: Fully served by stored QKP
                if (
                    qkp_s[idx_l1] / syst.THETA >= d.K_REQ[t] and
                    qkp_s[idx_l2] / syst.THETA >= d.K_REQ[t]
                ):
                    qkp_s[idx_l1] -= d.K_REQ[t] * syst.THETA
                    qkp_s[idx_l2] -= d.K_REQ[t] * syst.THETA
                    used_qkp_only = True
                    break
    
                # Case 2: Use fresh generation (possibly mixed with QKP later)
                l1_sel = links[idx_l1]
                l2_sel = links[idx_l2]
                break
    
            # --------------------------------------------------------------------------------------------------
            # Step 5: Update state after allocation
            # --------------------------------------------------------------------------------------------------
            if used_qkp_only:
                continue
    
            if l1_sel is not None:
                mid = l1_sel.n2
                max_cnct_up[hnodes.index(mid)] = 0
    
                l_idx = links.index(l1_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l1_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
            if l2_sel is not None:
                mid = l2_sel.n1
                max_cnct_dwn[hnodes.index(mid)] = 0
    
                l_idx = links.index(l2_sel)
                Z[l_idx][demands.index(d)][t] = 1
                qkp_s[l_idx] += (l2_sel.K_MAX[t] - d.K_REQ[t]) * syst.THETA
    
    # --------------- GREEDY ----------------
    solution, key_srv_grd_qkp[idx], a_lst_grd_qkp[idx] = offline_lp(
        gnodes, hnodes, links, demands, 1, 2, Z
    )

    key_srv_grd_qkp[idx] *= 1e-6
    a_lst_grd_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, SCAR-Q")

    # --------------- RELAXED ----------------
    solution, key_srv_rlx_qkp[idx], a_lst_rlx_qkp[idx] = offline_relaxed(
        gnodes, hnodes, links, demands, 1, 2
    )

    key_srv_rlx_qkp[idx] *= 1e-6
    a_lst_rlx_qkp[idx]   *= 1e-6

    print(f"idx: {idx}, RELAX")

    # --------------- OPTIMAL ----------------
    if case != 1:
        solution, key_srv_opt_qkp[idx], a_lst_opt_qkp[idx] = offline(
            gnodes, hnodes, links, demands, 1, 2
        )
    
        key_srv_opt_qkp[idx] *= 1e-6
        a_lst_opt_qkp[idx]   *= 1e-6
    
        print(f"idx: {idx}, OPTIMAL")

    # ------------------------------------------------------------
    # Save results
    # ------------------------------------------------------------
    data = {
        "key_srv_grd": key_srv_grd_qkp[idx],
        "a_lst_grd":   a_lst_grd_qkp[idx],

        "key_srv_rlx": key_srv_rlx_qkp[idx],
        "a_lst_rlx":   a_lst_rlx_qkp[idx],

        "key_srv_opt": key_srv_opt_qkp[idx],
        "a_lst_opt":   a_lst_opt_qkp[idx],

        "key_req":     key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] idx {idx}")
# Out:
# [LOAD] idx 0, mean=0.01
# [LOAD] idx 1, mean=0.21000000000000002
# [LOAD] idx 2, mean=0.41000000000000003
# [LOAD] idx 3, mean=0.6100000000000001
# [LOAD] idx 4, mean=0.81
# [LOAD] idx 5, mean=1.01
# [LOAD] idx 6, mean=1.2100000000000002
# [LOAD] idx 7, mean=1.4100000000000001
# [LOAD] idx 8, mean=1.61
# [LOAD] idx 9, mean=1.81

# %%
#Store statistics
key_srv_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
key_srv_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

a_lst_rnd_qkp_avg = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_min = [0.0 for _ in range(NUM_DATA)]
a_lst_rnd_qkp_max = [0.0 for _ in range(NUM_DATA)]

key_req = [0.0 for _ in range(NUM_DATA)]

# %%
for idx, mean in enumerate(demand_list):
    RESULTS_DIR = f"results_{case}"
    os.makedirs(RESULTS_DIR, exist_ok=True)
    
    result_file = os.path.join(RESULTS_DIR, f"idx_{idx}.pkl")

    # ============================================================
    # LOAD IF EXISTS
    # ============================================================
    if os.path.exists(result_file):

        print(f"[LOAD] Random idx {idx}")

        with open(result_file, "rb") as f:
            data = pickle.load(f)

        key_srv_rnd_qkp_avg[idx] = data["key_srv_avg"]
        key_srv_rnd_qkp_min[idx] = data["key_srv_min"]
        key_srv_rnd_qkp_max[idx] = data["key_srv_max"]

        a_lst_rnd_qkp_avg[idx] = data["a_lst_avg"]
        a_lst_rnd_qkp_min[idx] = data["a_lst_min"]
        a_lst_rnd_qkp_max[idx] = data["a_lst_max"]

        key_req[idx] = data["key_req"]

        continue

    # ============================================================
    # OTHERWISE COMPUTE
    # ============================================================
    print(f"[COMPUTE] Random idx {idx}")

    demands = generate_demands(
        gnodes,
        syst,
        mean_kbps=mean,
        amp=0.5,
        noise_std=0.2,
        pattern="stadium"
    )

    key_req[idx] = sum(
        d.K_REQ[t] * syst.THETA * 1e-3
        for d in demands
        for t in syst.T
    )

    rnd_results_k_srv = []
    rnd_results_a_lst = []

    # ------------------------------------------------------------
    # Monte Carlo
    # ------------------------------------------------------------
    for run in range(N_RUNS):

        Z = [[[0 for t in syst.T] for d in demands] for l in links]

        for t in syst.T:

            max_cnct_up  = [1 for _ in hnodes]
            max_cnct_dwn = [1 for _ in hnodes]

            shuffled_demands = random.sample(demands, len(demands))

            for d in shuffled_demands:

                src, dst = d.n1, d.n2
                feasible_pairs = []

                for l1 in links:
                    for l2 in links:
                        if (
                            l1.n1 == src and
                            l2.n2 == dst and
                            l1.n2 == l2.n1
                        ):
                            mid = l1.n2
                            if (
                                max_cnct_up[hnodes.index(mid)] > 0 and
                                max_cnct_dwn[hnodes.index(mid)] > 0 and
                                l1.K_MAX[t] > 0 and
                                l2.K_MAX[t] > 0
                            ):
                                feasible_pairs.append((l1, l2))

                if feasible_pairs:
                    l1_sel, l2_sel = random.choice(feasible_pairs)
                    mid = l1_sel.n2

                    Z[links.index(l1_sel)][demands.index(d)][t] = 1
                    Z[links.index(l2_sel)][demands.index(d)][t] = 1

                    max_cnct_up[hnodes.index(mid)]  = 0
                    max_cnct_dwn[hnodes.index(mid)] = 0

        _, key_srv, a_lst = offline_lp(
            gnodes, hnodes, links, demands, 1, 2, Z
        )

        rnd_results_k_srv.append(key_srv * 1e-6)
        rnd_results_a_lst.append(a_lst   * 1e-6)

    # ------------------------------------------------------------
    # Statistics
    # ------------------------------------------------------------
    key_srv_rnd_qkp_avg[idx] = np.mean(rnd_results_k_srv)
    key_srv_rnd_qkp_min[idx] = np.min(rnd_results_k_srv)
    key_srv_rnd_qkp_max[idx] = np.max(rnd_results_k_srv)

    a_lst_rnd_qkp_avg[idx] = np.mean(rnd_results_a_lst)
    a_lst_rnd_qkp_min[idx] = np.min(rnd_results_a_lst)
    a_lst_rnd_qkp_max[idx] = np.max(rnd_results_a_lst)

    # ------------------------------------------------------------
    # SAVE RESULTS
    # ------------------------------------------------------------
    data = {
        "key_srv_avg": key_srv_rnd_qkp_avg[idx],
        "key_srv_min": key_srv_rnd_qkp_min[idx],
        "key_srv_max": key_srv_rnd_qkp_max[idx],

        "a_lst_avg": a_lst_rnd_qkp_avg[idx],
        "a_lst_min": a_lst_rnd_qkp_min[idx],
        "a_lst_max": a_lst_rnd_qkp_max[idx],

        "key_req": key_req[idx]
    }

    with open(result_file, "wb") as f:
        pickle.dump(data, f)

    print(f"[SAVED] Random idx {idx}")
    print(f"idx: {idx} | avg={key_srv_rnd_qkp_avg[idx]:.3f}")
    print(f"idx: {idx} | avg={a_lst_rnd_qkp_avg[idx]:.3f}")
# Out:
# [LOAD] Random idx 0
# [LOAD] Random idx 1
# [LOAD] Random idx 2
# [LOAD] Random idx 3
# [LOAD] Random idx 4
# [LOAD] Random idx 5
# [LOAD] Random idx 6
# [LOAD] Random idx 7
# [LOAD] Random idx 8
# [LOAD] Random idx 9

# %%
key_req = [k * 1e-3 for k in key_req]

# %%
key_srv_ppo_qkp = [k * 1e-6 for k in key_srv_ppo_qkp]

# %% [markdown]
# ## Plot

# %%
# key_srv_rlx_qkp = [k if k != 0 else (key_srv_rlx_qkp[idx_k-1]+key_srv_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_rlx_qkp)]
# key_srv_opt_qkp = [k if k != 0 else (key_srv_opt_qkp[idx_k-1]+key_srv_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(key_srv_opt_qkp)]

# a_lst_rlx_qkp = [k if k != 0 else (a_lst_rlx_qkp[idx_k-1]+a_lst_rlx_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_rlx_qkp)]
# a_lst_opt_qkp = [k if k != 0 else (a_lst_opt_qkp[idx_k-1]+a_lst_opt_qkp[idx_k+1])/2 for idx_k, k in enumerate(a_lst_opt_qkp)]

# %%
#key_srv_ppo_qkp_old = [k for k in key_srv_ppo_qkp]
# key_srv_ppo_qkp = [k + 0.1*(key_srv_rlx_qkp[idx_k] - key_srv_ppo_qkp_old[idx_k]) for idx_k, k in enumerate(key_srv_ppo_qkp)]

# %%
# key_srv_ppo_qkp[-1] = key_srv_ppo_qkp[-2]
# key_srv_opt_qkp[-1] = key_srv_opt_qkp[-2]

# %%
# a_lst_opt_qkp[-1] = a_lst_opt_qkp[-2]

# %%
step = 6  # tunable (keep every `step`-th value)

# yerr1
yerr1 = [
    np.array(key_srv_rnd_qkp_avg) - np.array(key_srv_rnd_qkp_min),
    np.array(key_srv_rnd_qkp_max) - np.array(key_srv_rnd_qkp_avg)
]

yerr1[0][np.arange(len(yerr1[0])) % step != 0] = 0
yerr1[1][np.arange(len(yerr1[1])) % step != 0] = 0


# yerr2
yerr2 = [
    np.array(a_lst_rnd_qkp_avg) - np.array(a_lst_rnd_qkp_min),
    np.array(a_lst_rnd_qkp_max) - np.array(a_lst_rnd_qkp_avg)
]

yerr2[0][np.arange(len(yerr2[0])) % step != 0] = 0
yerr2[1][np.arange(len(yerr2[1])) % step != 0] = 0

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, key_srv_rnd_qkp_avg, yerr=yerr1, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, key_srv_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, key_srv_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, key_srv_opt_qkp, label="Optimal", linestyle="-", marker="v", markevery=5)
plt.plot(demand_list, key_req, linestyle="--")

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Total Served Secret Key (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_k_srv.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

############################

plt.figure(figsize=(4,3))
plt.errorbar(demand_list, a_lst_rnd_qkp_avg, yerr=yerr2, capsize=0, label="MCR-Q", linestyle="-")
plt.plot(demand_list, a_lst_grd_qkp, label="SCAR-Q", linestyle="-", marker="o", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_ppo_qkp, label="StratoQ", linestyle="-", marker="^", markevery=int(NUM_DATA / 10))
plt.plot(demand_list, a_lst_rlx_qkp, label="Relaxed", linestyle="-", marker="s", markevery=int(NUM_DATA / 10))
#plt.plot(demand_list, a_lst_opt_qkp, label="Optimal-QKP", linestyle="-", marker="v", markevery=5)

plt.xlabel(r"Mean SKR demand $\bar{K}$ (kbps)")
plt.ylabel("Final QKP Stored Keys (Mb)")
plt.yscale("log")
plt.grid(True, which="both", linestyle="--", alpha=0.5)
plt.legend()

#plt.savefig("online_qkp_a_lst.pdf", format="pdf", bbox_inches="tight", pad_inches=0.01, transparent="True")
plt.show()

# %% [markdown]
# #####
